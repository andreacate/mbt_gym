# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 10

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16dfb76a0>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x178cb86a0>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL  Std PnL Mean terminal inventory  \
# Inventory    2.326632  21.129975  4.80754                   -0.07
#
#           Std terminal inventory
# Inventory               3.089515

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_100_000_000steps_RandomStart"
# Paths with timestamp
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x178d51690>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env_eval = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env_eval = StableBaselinesTradingEnvironment(trading_env=rl_env_eval)

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env_eval, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-10.          0.         -5.5999999], [ 10.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/PPO_1
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x178d51690> != <mbt_gym.gym.StableBaselinesTradingEnvironment.StableBaselinesTradingEnvironment object at 0x178d50880>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 875      |
# |    ep_rew_mean     | 5.2      |
# | time/              |          |
# |    fps             | 423927   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 124290       |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0020765378 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0344       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0951       |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000364    |
# |    std                  | 0.997        |
# |    value_loss           | 0.218        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 546          |
# |    ep_rew_mean          | 4.4          |
# | time/                   |              |
# |    fps                  | 101895       |
# |    iterations           | 3            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032408466 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0449       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0975       |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000524    |
# |    std                  | 0.993        |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 92952        |
# |    iterations           | 4            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029955134 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0566       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0893       |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000761    |
# |    std                  | 0.988        |
# |    value_loss           | 0.181        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | 0.495       |
# | time/                   |             |
# |    fps                  | 88511       |
# |    iterations           | 5           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.003296408 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0717      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0789      |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.000711   |
# |    std                  | 0.983       |
# |    value_loss           | 0.159       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 2.14         |
# | time/                   |              |
# |    fps                  | 84826        |
# |    iterations           | 6            |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0027900902 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000543    |
# |    std                  | 0.979        |
# |    value_loss           | 0.209        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 7.88         |
# | time/                   |              |
# |    fps                  | 83305        |
# |    iterations           | 7            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0030998806 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0963       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0935       |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000646    |
# |    std                  | 0.974        |
# |    value_loss           | 0.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | 4.28         |
# | time/                   |              |
# |    fps                  | 82067        |
# |    iterations           | 8            |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032908574 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.109        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.000393    |
# |    std                  | 0.969        |
# |    value_loss           | 0.216        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 738         |
# |    ep_rew_mean          | 7.36        |
# | time/                   |             |
# |    fps                  | 81041       |
# |    iterations           | 9           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.003267771 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0919      |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00067    |
# |    std                  | 0.962       |
# |    value_loss           | 0.185       |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=1.48 +/- 0.97
# Episode length: 84.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 84           |
# |    mean_reward          | 1.48         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033117023 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.105        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.00049     |
# |    std                  | 0.957        |
# |    value_loss           | 0.212        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 3.03     |
# | time/              |          |
# |    fps             | 80141    |
# |    iterations      | 10       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 747        |
# |    ep_rew_mean          | 8.06       |
# | time/                   |            |
# |    fps                  | 79510      |
# |    iterations           | 11         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 11000000   |
# | train/                  |            |
# |    approx_kl            | 0.00359223 |
# |    clip_fraction        | 0.0184     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.0798     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0782     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.000718  |
# |    std                  | 0.949      |
# |    value_loss           | 0.162      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 137        |
# |    ep_rew_mean          | 1.67       |
# | time/                   |            |
# |    fps                  | 78813      |
# |    iterations           | 12         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 12000000   |
# | train/                  |            |
# |    approx_kl            | 0.00348469 |
# |    clip_fraction        | 0.016      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | 0.131      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0995     |
# |    n_updates            | 33         |
# |    policy_gradient_loss | -0.000578  |
# |    std                  | 0.942      |
# |    value_loss           | 0.201      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81           |
# |    ep_rew_mean          | 1.01         |
# | time/                   |              |
# |    fps                  | 78232        |
# |    iterations           | 13           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029307988 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.0519       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0811       |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000585    |
# |    std                  | 0.934        |
# |    value_loss           | 0.163        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | 5.42        |
# | time/                   |             |
# |    fps                  | 77495       |
# |    iterations           | 14          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 14000000    |
# | train/                  |             |
# |    approx_kl            | 0.003185736 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.094       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0935      |
# |    n_updates            | 39          |
# |    policy_gradient_loss | -0.000585   |
# |    std                  | 0.928       |
# |    value_loss           | 0.185       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 77089        |
# |    iterations           | 15           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026497114 |
# |    clip_fraction        | 0.00914      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.000348    |
# |    std                  | 0.924        |
# |    value_loss           | 0.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 834          |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 76800        |
# |    iterations           | 16           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026306484 |
# |    clip_fraction        | 0.00569      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000335    |
# |    std                  | 0.919        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94           |
# |    ep_rew_mean          | 1.36         |
# | time/                   |              |
# |    fps                  | 76475        |
# |    iterations           | 17           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022433333 |
# |    clip_fraction        | 0.00792      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000338    |
# |    std                  | 0.913        |
# |    value_loss           | 0.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22           |
# |    ep_rew_mean          | 0.441        |
# | time/                   |              |
# |    fps                  | 76210        |
# |    iterations           | 18           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027090628 |
# |    clip_fraction        | 0.00689      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.115        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000366    |
# |    std                  | 0.908        |
# |    value_loss           | 0.232        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 2.8          |
# | time/                   |              |
# |    fps                  | 75755        |
# |    iterations           | 19           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022834376 |
# |    clip_fraction        | 0.00761      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.0571       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0997       |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.000211    |
# |    std                  | 0.902        |
# |    value_loss           | 0.199        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=2.29 +/- 1.49
# Episode length: 101.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 101          |
# |    mean_reward          | 2.29         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025541345 |
# |    clip_fraction        | 0.00985      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.0919       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000368    |
# |    std                  | 0.897        |
# |    value_loss           | 0.209        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 2.35     |
# | time/              |          |
# |    fps             | 75459    |
# |    iterations      | 20       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 473          |
# |    ep_rew_mean          | 7.23         |
# | time/                   |              |
# |    fps                  | 75364        |
# |    iterations           | 21           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022023786 |
# |    clip_fraction        | 0.00349      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.112        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000252    |
# |    std                  | 0.892        |
# |    value_loss           | 0.224        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 2.37         |
# | time/                   |              |
# |    fps                  | 75307        |
# |    iterations           | 22           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029741265 |
# |    clip_fraction        | 0.00802      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.0906       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.105        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.000379    |
# |    std                  | 0.884        |
# |    value_loss           | 0.212        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 871          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 75191        |
# |    iterations           | 23           |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016688941 |
# |    clip_fraction        | 0.0033       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.000161    |
# |    std                  | 0.881        |
# |    value_loss           | 0.233        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | 1.52        |
# | time/                   |             |
# |    fps                  | 75102       |
# |    iterations           | 24          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 24000000    |
# | train/                  |             |
# |    approx_kl            | 0.002691685 |
# |    clip_fraction        | 0.00524     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 69          |
# |    policy_gradient_loss | -0.000263   |
# |    std                  | 0.877       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70          |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 75040       |
# |    iterations           | 25          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 25000000    |
# | train/                  |             |
# |    approx_kl            | 0.001607598 |
# |    clip_fraction        | 0.005       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.000216   |
# |    std                  | 0.872       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63           |
# |    ep_rew_mean          | 0.994        |
# | time/                   |              |
# |    fps                  | 74973        |
# |    iterations           | 26           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013723201 |
# |    clip_fraction        | 0.00207      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000107    |
# |    std                  | 0.868        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 830           |
# |    ep_rew_mean          | 13.3          |
# | time/                   |               |
# |    fps                  | 74864         |
# |    iterations           | 27            |
# |    time_elapsed         | 360           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00092436466 |
# |    clip_fraction        | 0.00214       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.55         |
# |    explained_variance   | 0.163         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.116         |
# |    n_updates            | 78            |
# |    policy_gradient_loss | -5.1e-05      |
# |    std                  | 0.864         |
# |    value_loss           | 0.237         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 1.48         |
# | time/                   |              |
# |    fps                  | 74752        |
# |    iterations           | 28           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025057457 |
# |    clip_fraction        | 0.00373      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -9.44e-05    |
# |    std                  | 0.86         |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 822          |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 74637        |
# |    iterations           | 29           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028941813 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | 2.26e-05     |
# |    std                  | 0.857        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=3.20 +/- 2.06
# Episode length: 150.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 150          |
# |    mean_reward          | 3.2          |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024875766 |
# |    clip_fraction        | 0.00569      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.000105    |
# |    std                  | 0.856        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 791      |
# |    ep_rew_mean     | 12.4     |
# | time/              |          |
# |    fps             | 74348    |
# |    iterations      | 30       |
# |    time_elapsed    | 403      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82           |
# |    ep_rew_mean          | 1.18         |
# | time/                   |              |
# |    fps                  | 74080        |
# |    iterations           | 31           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018562665 |
# |    clip_fraction        | 0.0039       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000146    |
# |    std                  | 0.852        |
# |    value_loss           | 0.247        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 194          |
# |    ep_rew_mean          | 3.13         |
# | time/                   |              |
# |    fps                  | 73737        |
# |    iterations           | 32           |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017742416 |
# |    clip_fraction        | 0.00119      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -5.84e-05    |
# |    std                  | 0.849        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 296          |
# |    ep_rew_mean          | 4.62         |
# | time/                   |              |
# |    fps                  | 73662        |
# |    iterations           | 33           |
# |    time_elapsed         | 447          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021710282 |
# |    clip_fraction        | 0.0027       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -8.22e-05    |
# |    std                  | 0.845        |
# |    value_loss           | 0.239        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 4.94         |
# | time/                   |              |
# |    fps                  | 73427        |
# |    iterations           | 34           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024284844 |
# |    clip_fraction        | 0.00667      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | 3.29e-05     |
# |    std                  | 0.84         |
# |    value_loss           | 0.265        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 419         |
# |    ep_rew_mean          | 6.39        |
# | time/                   |             |
# |    fps                  | 73334       |
# |    iterations           | 35          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 35000000    |
# | train/                  |             |
# |    approx_kl            | 0.001975123 |
# |    clip_fraction        | 0.00164     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 102         |
# |    policy_gradient_loss | -6.89e-05   |
# |    std                  | 0.837       |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 44            |
# |    ep_rew_mean          | 0.81          |
# | time/                   |               |
# |    fps                  | 73124         |
# |    iterations           | 36            |
# |    time_elapsed         | 492           |
# |    total_timesteps      | 36000000      |
# | train/                  |               |
# |    approx_kl            | 0.00089079124 |
# |    clip_fraction        | 0.0032        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.48         |
# |    explained_variance   | 0.342         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.125         |
# |    n_updates            | 105           |
# |    policy_gradient_loss | -3.54e-05     |
# |    std                  | 0.833         |
# |    value_loss           | 0.244         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 73016        |
# |    iterations           | 37           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016108379 |
# |    clip_fraction        | 0.00295      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | 3.07e-05     |
# |    std                  | 0.83         |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | 6.33        |
# | time/                   |             |
# |    fps                  | 72230       |
# |    iterations           | 38          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 38000000    |
# | train/                  |             |
# |    approx_kl            | 0.001560452 |
# |    clip_fraction        | 0.0025      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 111         |
# |    policy_gradient_loss | 1.81e-05    |
# |    std                  | 0.827       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | 4.07         |
# | time/                   |              |
# |    fps                  | 71831        |
# |    iterations           | 39           |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022008978 |
# |    clip_fraction        | 0.000944     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -7.9e-05     |
# |    std                  | 0.824        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=2.05 +/- 1.61
# Episode length: 109.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 109          |
# |    mean_reward          | 2.05         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017283459 |
# |    clip_fraction        | 0.000397     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -4.83e-05    |
# |    std                  | 0.822        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | 6.72     |
# | time/              |          |
# |    fps             | 71454    |
# |    iterations      | 40       |
# |    time_elapsed    | 559      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | 2.44         |
# | time/                   |              |
# |    fps                  | 71327        |
# |    iterations           | 41           |
# |    time_elapsed         | 574          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014729116 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 6.1e-06      |
# |    std                  | 0.82         |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | 2.07        |
# | time/                   |             |
# |    fps                  | 71137       |
# |    iterations           | 42          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 42000000    |
# | train/                  |             |
# |    approx_kl            | 0.003071535 |
# |    clip_fraction        | 0.00919     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 123         |
# |    policy_gradient_loss | 0.000124    |
# |    std                  | 0.817       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 888         |
# |    ep_rew_mean          | 14.3        |
# | time/                   |             |
# |    fps                  | 70994       |
# |    iterations           | 43          |
# |    time_elapsed         | 605         |
# |    total_timesteps      | 43000000    |
# | train/                  |             |
# |    approx_kl            | 0.002502556 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 126         |
# |    policy_gradient_loss | 0.000315    |
# |    std                  | 0.812       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 5.92         |
# | time/                   |              |
# |    fps                  | 70694        |
# |    iterations           | 44           |
# |    time_elapsed         | 622          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0042177313 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | 0.00112      |
# |    std                  | 0.809        |
# |    value_loss           | 0.268        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 2.76         |
# | time/                   |              |
# |    fps                  | 70496        |
# |    iterations           | 45           |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013734574 |
# |    clip_fraction        | 0.00379      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -7.73e-06    |
# |    std                  | 0.806        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 921           |
# |    ep_rew_mean          | 15.4          |
# | time/                   |               |
# |    fps                  | 70292         |
# |    iterations           | 46            |
# |    time_elapsed         | 654           |
# |    total_timesteps      | 46000000      |
# | train/                  |               |
# |    approx_kl            | 0.00014587653 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 0.326         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.131         |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -4.71e-05     |
# |    std                  | 0.803         |
# |    value_loss           | 0.264         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 995           |
# |    ep_rew_mean          | 15.7          |
# | time/                   |               |
# |    fps                  | 70220         |
# |    iterations           | 47            |
# |    time_elapsed         | 669           |
# |    total_timesteps      | 47000000      |
# | train/                  |               |
# |    approx_kl            | 0.00040199477 |
# |    clip_fraction        | 0.00154       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 0.283         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.133         |
# |    n_updates            | 138           |
# |    policy_gradient_loss | -3.64e-06     |
# |    std                  | 0.801         |
# |    value_loss           | 0.269         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 5.92         |
# | time/                   |              |
# |    fps                  | 69951        |
# |    iterations           | 48           |
# |    time_elapsed         | 686          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006703471 |
# |    clip_fraction        | 1.4e-05      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.137        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -1.96e-05    |
# |    std                  | 0.798        |
# |    value_loss           | 0.278        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | 3.86         |
# | time/                   |              |
# |    fps                  | 69833        |
# |    iterations           | 49           |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014987944 |
# |    clip_fraction        | 0.00136      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -5.32e-05    |
# |    std                  | 0.796        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=14.22 +/- 4.61
# Episode length: 692.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 692          |
# ...
# |    loss                 | 0.12         |
# |    n_updates            | 249          |
# |    policy_gradient_loss | -4.23e-05    |
# |    std                  | 0.706        |
# |    value_loss           | 0.241        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51           |
# |    ep_rew_mean          | 0.857        |
# | time/                   |              |
# |    fps                  | 66693        |
# |    iterations           | 85           |
# |    time_elapsed         | 1274         |
# |    total_timesteps      | 85000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025191277 |
# |    clip_fraction        | 0.0045       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 252          |
# |    policy_gradient_loss | 5.54e-05     |
# |    std                  | 0.704        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 0.963       |
# | time/                   |             |
# |    fps                  | 66613       |
# |    iterations           | 86          |
# |    time_elapsed         | 1291        |
# |    total_timesteps      | 86000000    |
# | train/                  |             |
# |    approx_kl            | 0.003226315 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 255         |
# |    policy_gradient_loss | 0.000265    |
# |    std                  | 0.701       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 66460        |
# |    iterations           | 87           |
# |    time_elapsed         | 1309         |
# |    total_timesteps      | 87000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015074661 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.137        |
# |    n_updates            | 258          |
# |    policy_gradient_loss | 4.99e-05     |
# |    std                  | 0.699        |
# |    value_loss           | 0.276        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75           |
# |    ep_rew_mean          | 1.38         |
# | time/                   |              |
# |    fps                  | 66428        |
# |    iterations           | 88           |
# |    time_elapsed         | 1324         |
# |    total_timesteps      | 88000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010561947 |
# |    clip_fraction        | 0.000774     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 261          |
# |    policy_gradient_loss | -8.71e-06    |
# |    std                  | 0.697        |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 4.85         |
# | time/                   |              |
# |    fps                  | 66415        |
# |    iterations           | 89           |
# |    time_elapsed         | 1340         |
# |    total_timesteps      | 89000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030749764 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 0.000221     |
# |    std                  | 0.694        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# Eval num_timesteps=90000000, episode_reward=8.72 +/- 3.59
# Episode length: 417.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 417         |
# |    mean_reward          | 8.72        |
# | time/                   |             |
# |    total_timesteps      | 90000000    |
# | train/                  |             |
# |    approx_kl            | 0.002259067 |
# |    clip_fraction        | 0.00656     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 267         |
# |    policy_gradient_loss | 2.83e-05    |
# |    std                  | 0.689       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 830      |
# |    ep_rew_mean     | 14       |
# | time/              |          |
# |    fps             | 66354    |
# |    iterations      | 90       |
# |    time_elapsed    | 1356     |
# |    total_timesteps | 90000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 597          |
# |    ep_rew_mean          | 9.78         |
# | time/                   |              |
# |    fps                  | 66329        |
# |    iterations           | 91           |
# |    time_elapsed         | 1371         |
# |    total_timesteps      | 91000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018073057 |
# |    clip_fraction        | 0.00203      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -4.7e-05     |
# |    std                  | 0.686        |
# |    value_loss           | 0.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 558          |
# |    ep_rew_mean          | 9.38         |
# | time/                   |              |
# |    fps                  | 66301        |
# |    iterations           | 92           |
# |    time_elapsed         | 1387         |
# |    total_timesteps      | 92000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016665853 |
# |    clip_fraction        | 0.000197     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 273          |
# |    policy_gradient_loss | -6.28e-05    |
# |    std                  | 0.684        |
# |    value_loss           | 0.284        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13           |
# |    ep_rew_mean          | 0.218        |
# | time/                   |              |
# |    fps                  | 66286        |
# |    iterations           | 93           |
# |    time_elapsed         | 1403         |
# |    total_timesteps      | 93000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021933615 |
# |    clip_fraction        | 0.00168      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 276          |
# |    policy_gradient_loss | -4.28e-05    |
# |    std                  | 0.681        |
# |    value_loss           | 0.277        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 4.15        |
# | time/                   |             |
# |    fps                  | 66267       |
# |    iterations           | 94          |
# |    time_elapsed         | 1418        |
# |    total_timesteps      | 94000000    |
# | train/                  |             |
# |    approx_kl            | 0.001231949 |
# |    clip_fraction        | 0.00204     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 279         |
# |    policy_gradient_loss | 1.28e-05    |
# |    std                  | 0.679       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | 0.153         |
# | time/                   |               |
# |    fps                  | 66243         |
# |    iterations           | 95            |
# |    time_elapsed         | 1434          |
# |    total_timesteps      | 95000000      |
# | train/                  |               |
# |    approx_kl            | 0.00096427306 |
# |    clip_fraction        | 0.0021        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.06         |
# |    explained_variance   | 0.167         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.139         |
# |    n_updates            | 282           |
# |    policy_gradient_loss | -3.13e-05     |
# |    std                  | 0.677         |
# |    value_loss           | 0.269         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 2.33         |
# | time/                   |              |
# |    fps                  | 66214        |
# |    iterations           | 96           |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 96000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008398901 |
# |    clip_fraction        | 0.000101     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 285          |
# |    policy_gradient_loss | -2.27e-05    |
# |    std                  | 0.676        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 674         |
# |    ep_rew_mean          | 12.2        |
# | time/                   |             |
# |    fps                  | 66188       |
# |    iterations           | 97          |
# |    time_elapsed         | 1465        |
# |    total_timesteps      | 97000000    |
# | train/                  |             |
# |    approx_kl            | 0.005916045 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 288         |
# |    policy_gradient_loss | 0.000822    |
# |    std                  | 0.672       |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 66158        |
# |    iterations           | 98           |
# |    time_elapsed         | 1481         |
# |    total_timesteps      | 98000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017435083 |
# |    clip_fraction        | 0.00316      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.321        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 291          |
# |    policy_gradient_loss | -4.63e-05    |
# |    std                  | 0.668        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 66144        |
# |    iterations           | 99           |
# |    time_elapsed         | 1496         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018061353 |
# |    clip_fraction        | 0.00395      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 294          |
# |    policy_gradient_loss | 5.38e-05     |
# |    std                  | 0.666        |
# |    value_loss           | 0.266        |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=5.11 +/- 2.64
# Episode length: 266.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 266           |
# |    mean_reward          | 5.11          |
# | time/                   |               |
# |    total_timesteps      | 100000000     |
# | train/                  |               |
# |    approx_kl            | 0.00092303695 |
# |    clip_fraction        | 0.000718      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.02         |
# |    explained_variance   | 0.287         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.128         |
# |    n_updates            | 297           |
# |    policy_gradient_loss | -5.42e-05     |
# |    std                  | 0.663         |
# |    value_loss           | 0.261         |
# -------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 540       |
# |    ep_rew_mean     | 8.75      |
# | time/              |           |
# |    fps             | 66108     |
# |    iterations      | 100       |
# |    time_elapsed    | 1512      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent, use_normalized_agent=use_normalized_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -1.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 1.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent, seed=seed)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.725192  20.140509  5.633644                  -0.128
#
#          Std terminal inventory
# RL Agent               3.499659

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent) #, normalize_obs=True)

# %%
inventories = np.arange(-4,5,1)
#inventory_low = - max_inventory
#gradient_inventory = (max_inventory - (-max_inventory)) / 2
inventories_normalised = inventories
#inventories_normalised =(inventories - inventory_low) / gradient_inventory - 1

# %%
#inventories = np.arange(-1,1.25,0.25)
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
print(bid_actions)
# Out:
# [1.2742225, 1.2986836, 1.3250656, 1.3519078, 1.3771133, 1.3986943, 1.4157296, 1.4283979, 1.4373381]

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.08378951644998
# median:  19.568876345628745
# std:  5.650151516210484

# %%
# Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/PPO_1/events.out.tfevents.1761921906.MacBookAir.lan.66204.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/Training_process_rollout_reward.png

# %%
#  Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/PPO_1/events.out.tfevents.1761921906.MacBookAir.lan.66204.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/PPO_1/events.out.tfevents.1761921906.MacBookAir.lan.66204.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-31_15-45-05/Training_process_rewards.png
