# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 10

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x1519aba30>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x153790490>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL  Std PnL Mean terminal inventory  \
# Inventory    2.326632  21.129975  4.80754                   -0.07
#
#           Std terminal inventory
# Inventory               3.089515

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      #initial_inventory = initial_inventory,
                      initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_100_000_000steps_RandomInventory"
# Paths with timestamp
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x154908a90>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env_eval = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env_eval = StableBaselinesTradingEnvironment(trading_env=rl_env_eval)

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env_eval, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-10.          0.         -5.5999999], [ 10.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/PPO_1
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x154908a90> != <mbt_gym.gym.StableBaselinesTradingEnvironment.StableBaselinesTradingEnvironment object at 0x151a080d0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.05     |
# | time/              |          |
# |    fps             | 339031   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.47         |
# | time/                   |              |
# |    fps                  | 113956       |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0014897642 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0408       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.14         |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -5.95e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 0.299        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.62         |
# | time/                   |              |
# |    fps                  | 88183        |
# |    iterations           | 3            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0033032938 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0523       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000653    |
# |    std                  | 0.994        |
# |    value_loss           | 0.276        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 4.95         |
# | time/                   |              |
# |    fps                  | 83325        |
# |    iterations           | 4            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0033120527 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0866       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000593    |
# |    std                  | 0.99         |
# |    value_loss           | 0.287        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.78         |
# | time/                   |              |
# |    fps                  | 81201        |
# |    iterations           | 5            |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029832646 |
# |    clip_fraction        | 0.00844      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000488    |
# |    std                  | 0.987        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.2         |
# | time/                   |             |
# |    fps                  | 79293       |
# |    iterations           | 6           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 6000000     |
# | train/                  |             |
# |    approx_kl            | 0.003097261 |
# |    clip_fraction        | 0.0123      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.000556   |
# |    std                  | 0.983       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.94         |
# | time/                   |              |
# |    fps                  | 77726        |
# |    iterations           | 7            |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0030426015 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.147        |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000464    |
# |    std                  | 0.98         |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.75         |
# | time/                   |              |
# |    fps                  | 76707        |
# |    iterations           | 8            |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031117634 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.000591    |
# |    std                  | 0.976        |
# |    value_loss           | 0.304        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.77        |
# | time/                   |             |
# |    fps                  | 75405       |
# |    iterations           | 9           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.003225868 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.146       |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.000508   |
# |    std                  | 0.97        |
# |    value_loss           | 0.291       |
# -----------------------------------------
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000000, episode_reward=14.73 +/- 5.48
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 14.7        |
# | time/                   |             |
# |    total_timesteps      | 10000000    |
# | train/                  |             |
# |    approx_kl            | 0.003224836 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 27          |
# |    policy_gradient_loss | -0.000485   |
# |    std                  | 0.964       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.22     |
# | time/              |          |
# |    fps             | 73640    |
# |    iterations      | 10       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 9.43        |
# | time/                   |             |
# |    fps                  | 73200       |
# |    iterations           | 11          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 11000000    |
# | train/                  |             |
# |    approx_kl            | 0.003370246 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000539   |
# |    std                  | 0.958       |
# |    value_loss           | 0.291       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.84         |
# | time/                   |              |
# |    fps                  | 73126        |
# |    iterations           | 12           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031615377 |
# |    clip_fraction        | 0.00997      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -0.000541    |
# |    std                  | 0.951        |
# |    value_loss           | 0.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 73206        |
# |    iterations           | 13           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030833231 |
# |    clip_fraction        | 0.00969      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000503    |
# |    std                  | 0.945        |
# |    value_loss           | 0.287        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.2        |
# | time/                   |             |
# |    fps                  | 73221       |
# |    iterations           | 14          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 14000000    |
# | train/                  |             |
# |    approx_kl            | 0.002128772 |
# |    clip_fraction        | 0.00885     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 39          |
# |    policy_gradient_loss | -0.000419   |
# |    std                  | 0.939       |
# |    value_loss           | 0.293       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 73274        |
# |    iterations           | 15           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028299398 |
# |    clip_fraction        | 0.00756      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.000349    |
# |    std                  | 0.933        |
# |    value_loss           | 0.299        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 73277        |
# |    iterations           | 16           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024233002 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000365    |
# |    std                  | 0.928        |
# |    value_loss           | 0.295        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.4         |
# | time/                   |              |
# |    fps                  | 73335        |
# |    iterations           | 17           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026750818 |
# |    clip_fraction        | 0.00683      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000287    |
# |    std                  | 0.923        |
# |    value_loss           | 0.289        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 73335        |
# |    iterations           | 18           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027405613 |
# |    clip_fraction        | 0.0065       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000282    |
# |    std                  | 0.919        |
# |    value_loss           | 0.298        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 72727        |
# |    iterations           | 19           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016220638 |
# |    clip_fraction        | 0.00602      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.000219    |
# |    std                  | 0.914        |
# |    value_loss           | 0.296        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=19.92 +/- 5.31
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.9         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021931161 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000295    |
# |    std                  | 0.907        |
# |    value_loss           | 0.298        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.7     |
# | time/              |          |
# |    fps             | 71949    |
# |    iterations      | 20       |
# |    time_elapsed    | 277      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 71992        |
# |    iterations           | 21           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019705934 |
# |    clip_fraction        | 0.00559      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000202    |
# |    std                  | 0.898        |
# |    value_loss           | 0.289        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 72028        |
# |    iterations           | 22           |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022331723 |
# |    clip_fraction        | 0.00836      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.145        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.000196    |
# |    std                  | 0.892        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 72066        |
# |    iterations           | 23           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022725412 |
# |    clip_fraction        | 0.0053       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.147        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.000178    |
# |    std                  | 0.885        |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 72013        |
# |    iterations           | 24           |
# |    time_elapsed         | 333          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024406814 |
# |    clip_fraction        | 0.00749      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.151        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.000105    |
# |    std                  | 0.879        |
# |    value_loss           | 0.299        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 72044        |
# |    iterations           | 25           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020857982 |
# |    clip_fraction        | 0.00588      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000236    |
# |    std                  | 0.875        |
# |    value_loss           | 0.288        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 72072        |
# |    iterations           | 26           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019495857 |
# |    clip_fraction        | 0.00441      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.145        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000155    |
# |    std                  | 0.869        |
# |    value_loss           | 0.292        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.2         |
# | time/                   |              |
# |    fps                  | 72084        |
# |    iterations           | 27           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024940646 |
# |    clip_fraction        | 0.0054       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.147        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.000267    |
# |    std                  | 0.862        |
# |    value_loss           | 0.295        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 72097        |
# |    iterations           | 28           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022708238 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.145        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000137    |
# |    std                  | 0.859        |
# |    value_loss           | 0.294        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 72102        |
# |    iterations           | 29           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011208709 |
# |    clip_fraction        | 0.0023       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -8.43e-05    |
# |    std                  | 0.853        |
# |    value_loss           | 0.285        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=20.14 +/- 5.84
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.1         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015109327 |
# |    clip_fraction        | 0.0056       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -5.45e-05    |
# |    std                  | 0.848        |
# |    value_loss           | 0.288        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.3     |
# | time/              |          |
# |    fps             | 71862    |
# |    iterations      | 30       |
# |    time_elapsed    | 417      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 71807       |
# |    iterations           | 31          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 31000000    |
# | train/                  |             |
# |    approx_kl            | 0.002032423 |
# |    clip_fraction        | 0.00408     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000142   |
# |    std                  | 0.842       |
# |    value_loss           | 0.295       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 71782        |
# |    iterations           | 32           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019270258 |
# |    clip_fraction        | 0.00197      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -7.49e-05    |
# |    std                  | 0.838        |
# |    value_loss           | 0.294        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 71727        |
# |    iterations           | 33           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013663715 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000197    |
# |    std                  | 0.831        |
# |    value_loss           | 0.295        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.8         |
# | time/                   |              |
# |    fps                  | 71737        |
# |    iterations           | 34           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013190906 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -5.12e-05    |
# |    std                  | 0.825        |
# |    value_loss           | 0.301        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14.8          |
# | time/                   |               |
# |    fps                  | 71745         |
# |    iterations           | 35            |
# |    time_elapsed         | 487           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00082572724 |
# |    clip_fraction        | 0.00476       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.45         |
# |    explained_variance   | 0.184         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.155         |
# |    n_updates            | 102           |
# |    policy_gradient_loss | 1.42e-05      |
# |    std                  | 0.819         |
# |    value_loss           | 0.307         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 71738        |
# |    iterations           | 36           |
# |    time_elapsed         | 501          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013568911 |
# |    clip_fraction        | 0.00475      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.147        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -9.99e-05    |
# |    std                  | 0.814        |
# |    value_loss           | 0.294        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 71732        |
# |    iterations           | 37           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019539476 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.15         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -2.24e-05    |
# |    std                  | 0.81         |
# |    value_loss           | 0.302        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 71766        |
# |    iterations           | 38           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010890083 |
# |    clip_fraction        | 0.000726     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.15         |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -4.22e-05    |
# |    std                  | 0.806        |
# |    value_loss           | 0.298        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.3         |
# | time/                   |              |
# |    fps                  | 71767        |
# |    iterations           | 39           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018467146 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.15         |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -0.000138    |
# |    std                  | 0.802        |
# |    value_loss           | 0.3          |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=19.75 +/- 6.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.7         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020458705 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -0.000112    |
# |    std                  | 0.798        |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 15.7     |
# | time/              |          |
# |    fps             | 71600    |
# |    iterations      | 40       |
# |    time_elapsed    | 558      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 71608        |
# |    iterations           | 41           |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014891821 |
# |    clip_fraction        | 0.00358      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -4.95e-05    |
# |    std                  | 0.792        |
# |    value_loss           | 0.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 71614       |
# |    iterations           | 42          |
# |    time_elapsed         | 586         |
# |    total_timesteps      | 42000000    |
# | train/                  |             |
# |    approx_kl            | 0.005504042 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 123         |
# |    policy_gradient_loss | 0.000762    |
# |    std                  | 0.787       |
# |    value_loss           | 0.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 71600        |
# |    iterations           | 43           |
# |    time_elapsed         | 600          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019406766 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.14         |
# |    n_updates            | 126          |
# |    policy_gradient_loss | 0.000422     |
# |    std                  | 0.782        |
# |    value_loss           | 0.282        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 71589        |
# |    iterations           | 44           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025505587 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | 0.000521     |
# |    std                  | 0.777        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 71438        |
# |    iterations           | 45           |
# |    time_elapsed         | 629          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010906116 |
# |    clip_fraction        | 0.00336      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.156        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | 2.36e-05     |
# |    std                  | 0.772        |
# |    value_loss           | 0.312        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 71109        |
# |    iterations           | 46           |
# |    time_elapsed         | 646          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013484394 |
# |    clip_fraction        | 0.000571     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -5.24e-05    |
# |    std                  | 0.77         |
# |    value_loss           | 0.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 70766        |
# |    iterations           | 47           |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011281436 |
# |    clip_fraction        | 0.00106      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -2.81e-05    |
# |    std                  | 0.766        |
# |    value_loss           | 0.305        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 70740        |
# |    iterations           | 48           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023250566 |
# |    clip_fraction        | 0.003        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -0.000133    |
# |    std                  | 0.763        |
# |    value_loss           | 0.305        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 70747        |
# |    iterations           | 49           |
# |    time_elapsed         | 692          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014370934 |
# |    clip_fraction        | 0.00274      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -8.77e-05    |
# |    std                  | 0.759        |
# |    value_loss           | 0.31         |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.86 +/- 5.80
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# ...
# |    n_updates            | 249           |
# |    policy_gradient_loss | 7.65e-05      |
# |    std                  | 0.634         |
# |    value_loss           | 0.314         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 16.7          |
# | time/                   |               |
# |    fps                  | 69521         |
# |    iterations           | 85            |
# |    time_elapsed         | 1222          |
# |    total_timesteps      | 85000000      |
# | train/                  |               |
# |    approx_kl            | 0.00085924455 |
# |    clip_fraction        | 0.00287       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.16          |
# |    n_updates            | 252           |
# |    policy_gradient_loss | -3.7e-05      |
# |    std                  | 0.631         |
# |    value_loss           | 0.319         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 69526        |
# |    iterations           | 86           |
# |    time_elapsed         | 1236         |
# |    total_timesteps      | 86000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007713919 |
# |    clip_fraction        | 0.00192      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 255          |
# |    policy_gradient_loss | -4.72e-05    |
# |    std                  | 0.629        |
# |    value_loss           | 0.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 69532        |
# |    iterations           | 87           |
# |    time_elapsed         | 1251         |
# |    total_timesteps      | 87000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020239176 |
# |    clip_fraction        | 0.00386      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 258          |
# |    policy_gradient_loss | -5.71e-05    |
# |    std                  | 0.624        |
# |    value_loss           | 0.324        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 69548        |
# |    iterations           | 88           |
# |    time_elapsed         | 1265         |
# |    total_timesteps      | 88000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017172329 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 261          |
# |    policy_gradient_loss | -4.25e-05    |
# |    std                  | 0.62         |
# |    value_loss           | 0.323        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 69568        |
# |    iterations           | 89           |
# |    time_elapsed         | 1279         |
# |    total_timesteps      | 89000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016881125 |
# |    clip_fraction        | 0.00148      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.159        |
# |    n_updates            | 264          |
# |    policy_gradient_loss | -1.01e-05    |
# |    std                  | 0.617        |
# |    value_loss           | 0.318        |
# ------------------------------------------
# Eval num_timesteps=90000000, episode_reward=20.20 +/- 5.70
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.2         |
# | time/                   |              |
# |    total_timesteps      | 90000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018832164 |
# |    clip_fraction        | 0.00289      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.158        |
# |    n_updates            | 267          |
# |    policy_gradient_loss | -8.8e-05     |
# |    std                  | 0.614        |
# |    value_loss           | 0.318        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.2     |
# | time/              |          |
# |    fps             | 69281    |
# |    iterations      | 90       |
# |    time_elapsed    | 1299     |
# |    total_timesteps | 90000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.6         |
# | time/                   |              |
# |    fps                  | 69176        |
# |    iterations           | 91           |
# |    time_elapsed         | 1315         |
# |    total_timesteps      | 91000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016995718 |
# |    clip_fraction        | 0.00486      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 1.24e-05     |
# |    std                  | 0.61         |
# |    value_loss           | 0.315        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 69172        |
# |    iterations           | 92           |
# |    time_elapsed         | 1330         |
# |    total_timesteps      | 92000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019145733 |
# |    clip_fraction        | 0.00675      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.155        |
# |    n_updates            | 273          |
# |    policy_gradient_loss | 9.31e-05     |
# |    std                  | 0.607        |
# |    value_loss           | 0.308        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 69175        |
# |    iterations           | 93           |
# |    time_elapsed         | 1344         |
# |    total_timesteps      | 93000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014503028 |
# |    clip_fraction        | 0.000987     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 276          |
# |    policy_gradient_loss | -5.46e-05    |
# |    std                  | 0.605        |
# |    value_loss           | 0.318        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 69168       |
# |    iterations           | 94          |
# |    time_elapsed         | 1359        |
# |    total_timesteps      | 94000000    |
# | train/                  |             |
# |    approx_kl            | 0.001523019 |
# |    clip_fraction        | 0.00154     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.158       |
# |    n_updates            | 279         |
# |    policy_gradient_loss | -2.54e-05   |
# |    std                  | 0.602       |
# |    value_loss           | 0.315       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 69179        |
# |    iterations           | 95           |
# |    time_elapsed         | 1373         |
# |    total_timesteps      | 95000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015556765 |
# |    clip_fraction        | 0.0077       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 282          |
# |    policy_gradient_loss | 0.000104     |
# |    std                  | 0.6          |
# |    value_loss           | 0.326        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 69156        |
# |    iterations           | 96           |
# |    time_elapsed         | 1388         |
# |    total_timesteps      | 96000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026286792 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 285          |
# |    policy_gradient_loss | 0.000379     |
# |    std                  | 0.596        |
# |    value_loss           | 0.321        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 69158        |
# |    iterations           | 97           |
# |    time_elapsed         | 1402         |
# |    total_timesteps      | 97000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012281324 |
# |    clip_fraction        | 0.00245      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.157        |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -3.31e-05    |
# |    std                  | 0.591        |
# |    value_loss           | 0.317        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 69155        |
# |    iterations           | 98           |
# |    time_elapsed         | 1417         |
# |    total_timesteps      | 98000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012177795 |
# |    clip_fraction        | 0.00319      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.157        |
# |    n_updates            | 291          |
# |    policy_gradient_loss | 2.87e-05     |
# |    std                  | 0.588        |
# |    value_loss           | 0.316        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 69157        |
# |    iterations           | 99           |
# |    time_elapsed         | 1431         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007206348 |
# |    clip_fraction        | 0.00219      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 294          |
# |    policy_gradient_loss | 1.77e-05     |
# |    std                  | 0.585        |
# |    value_loss           | 0.319        |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=20.50 +/- 6.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.5         |
# | time/                   |              |
# |    total_timesteps      | 100000000    |
# | train/                  |              |
# |    approx_kl            | 0.0012623648 |
# |    clip_fraction        | 0.00285      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.157        |
# |    n_updates            | 297          |
# |    policy_gradient_loss | 1.44e-05     |
# |    std                  | 0.583        |
# |    value_loss           | 0.321        |
# ------------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 15.7      |
# | time/              |           |
# |    fps             | 69088     |
# |    iterations      | 100       |
# |    time_elapsed    | 1447      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent, use_normalized_agent=use_normalized_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -1.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 1.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent, seed=seed)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.511707  20.638096  5.545889                   0.692
#
#          Std terminal inventory
# RL Agent               3.351587

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent) #, normalize_obs=True)

# %%
inventories = np.arange(-4,5,1)
#inventory_low = - max_inventory
#gradient_inventory = (max_inventory - (-max_inventory)) / 2
inventories_normalised = inventories
#inventories_normalised =(inventories - inventory_low) / gradient_inventory - 1

# %%
#inventories = np.arange(-1,1.25,0.25)
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
print(bid_actions)
# Out:
# [1.0073813, 1.0698622, 1.1307013, 1.1836219, 1.2256474, 1.256848, 1.2788014, 1.2935599, 1.3031261]

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.637879836183753
# median:  20.20073713807104
# std:  5.504914034660356

# %%
# Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/PPO_1/events.out.tfevents.1761915688.MacBookAir.lan.57975.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/Training_process_rollout_reward.png

# %%
#  Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-30_14-14-22/PPO_1/events.out.tfevents.1761830063.MacBookAir.lan.27166.0" 
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-30_14-14-22/PPO_1/events.out.tfevents.1761830063.MacBookAir.lan.27166.0" 
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/Training_process_rewards.png
