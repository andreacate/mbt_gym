# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 10

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x1680977f0>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16874e800>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL  Std PnL Mean terminal inventory  \
# Inventory    2.326632  21.129975  4.80754                   -0.07
#
#           Std terminal inventory
# Inventory               3.089515

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      #initial_inventory = initial_inventory,
                      initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_50_000_000steps_RandomInventory"
# Paths with timestamp
tensorboard_logdir = f".././CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x16874ff40>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env_eval = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env_eval = StableBaselinesTradingEnvironment(trading_env=rl_env_eval)

# %%
policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[128, 128], vf=[128, 128])]
)

n_epochs = 5
learning_rate = 3e-5
gae_lambda = 0.95
clip_range = 0.1
vf_coef = 0.5
max_grad_norm = 0.2

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-10.          0.         -5.5999999], [ 10.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to .././CJ_models/tensorboard/PPO-learning/CjMm_PPO_50_000_000steps_RandomInventory/2025-11-17_09-29-17/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.92     |
# | time/              |          |
# |    fps             | 570191   |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.44         |
# | time/                   |              |
# |    fps                  | 149488       |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0006998702 |
# |    clip_fraction        | 0.00961      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0313       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.134        |
# |    n_updates            | 5            |
# |    policy_gradient_loss | -0.00031     |
# |    std                  | 0.999        |
# |    value_loss           | 0.275        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 5.13          |
# | time/                   |               |
# |    fps                  | 113597        |
# |    iterations           | 3             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 3000000       |
# | train/                  |               |
# |    approx_kl            | 0.00067434553 |
# |    clip_fraction        | 0.00698       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0414        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.135         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000232     |
# |    std                  | 0.998         |
# |    value_loss           | 0.274         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 5.99        |
# | time/                   |             |
# |    fps                  | 106057      |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 4000000     |
# | train/                  |             |
# |    approx_kl            | 0.000798941 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.0496      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.141       |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.000296   |
# |    std                  | 0.998       |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 5.21          |
# | time/                   |               |
# |    fps                  | 103887        |
# |    iterations           | 5             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 5000000       |
# | train/                  |               |
# |    approx_kl            | 0.00069321226 |
# |    clip_fraction        | 0.00653       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.0637        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.14          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000223     |
# |    std                  | 0.997         |
# |    value_loss           | 0.285         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 6.64          |
# | time/                   |               |
# |    fps                  | 102902        |
# |    iterations           | 6             |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 6000000       |
# | train/                  |               |
# |    approx_kl            | 0.00075866055 |
# |    clip_fraction        | 0.00804       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.0693        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.138         |
# |    n_updates            | 25            |
# |    policy_gradient_loss | -0.000257     |
# |    std                  | 0.996         |
# |    value_loss           | 0.276         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.75         |
# | time/                   |              |
# |    fps                  | 101971       |
# |    iterations           | 7            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0008736116 |
# |    clip_fraction        | 0.0093       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0887       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.14         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000269    |
# |    std                  | 0.996        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.63         |
# | time/                   |              |
# |    fps                  | 93601        |
# |    iterations           | 8            |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007729732 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.095        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.144        |
# |    n_updates            | 35           |
# |    policy_gradient_loss | -0.000216    |
# |    std                  | 0.995        |
# |    value_loss           | 0.288        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 6.8           |
# | time/                   |               |
# |    fps                  | 92157         |
# |    iterations           | 9             |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 9000000       |
# | train/                  |               |
# |    approx_kl            | 0.00079382595 |
# |    clip_fraction        | 0.00709       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.105         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.141         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000221     |
# |    std                  | 0.994         |
# |    value_loss           | 0.284         |
# -------------------------------------------
# Eval num_timesteps=10000000, episode_reward=8.82 +/- 5.24
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 8.82         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007594741 |
# |    clip_fraction        | 0.00633      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.143        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000205    |
# |    std                  | 0.993        |
# |    value_loss           | 0.284        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.33     |
# | time/              |          |
# |    fps             | 90158    |
# |    iterations      | 10       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.96          |
# | time/                   |               |
# |    fps                  | 90200         |
# |    iterations           | 11            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 11000000      |
# | train/                  |               |
# |    approx_kl            | 0.00079778314 |
# |    clip_fraction        | 0.00712       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.141         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.147         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000237     |
# |    std                  | 0.993         |
# |    value_loss           | 0.29          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 6.78          |
# | time/                   |               |
# |    fps                  | 89999         |
# |    iterations           | 12            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 12000000      |
# | train/                  |               |
# |    approx_kl            | 0.00079749804 |
# |    clip_fraction        | 0.00854       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.155         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.143         |
# |    n_updates            | 55            |
# |    policy_gradient_loss | -0.00026      |
# |    std                  | 0.992         |
# |    value_loss           | 0.288         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.31         |
# | time/                   |              |
# |    fps                  | 90035        |
# |    iterations           | 13           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007174761 |
# |    clip_fraction        | 0.00716      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.145        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00024     |
# |    std                  | 0.991        |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.95         |
# | time/                   |              |
# |    fps                  | 90470        |
# |    iterations           | 14           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006918582 |
# |    clip_fraction        | 0.00804      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.148        |
# |    n_updates            | 65           |
# |    policy_gradient_loss | -0.000257    |
# |    std                  | 0.99         |
# |    value_loss           | 0.298        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.33          |
# | time/                   |               |
# |    fps                  | 90540         |
# |    iterations           | 15            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 15000000      |
# | train/                  |               |
# |    approx_kl            | 0.00071238517 |
# |    clip_fraction        | 0.00872       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.191         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.149         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00028      |
# |    std                  | 0.989         |
# |    value_loss           | 0.296         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.65          |
# | time/                   |               |
# |    fps                  | 90822         |
# |    iterations           | 16            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 16000000      |
# | train/                  |               |
# |    approx_kl            | 0.00077496516 |
# |    clip_fraction        | 0.00923       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.199         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.143         |
# |    n_updates            | 75            |
# |    policy_gradient_loss | -0.0003       |
# |    std                  | 0.988         |
# |    value_loss           | 0.288         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.79         |
# | time/                   |              |
# |    fps                  | 91286        |
# |    iterations           | 17           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006889001 |
# |    clip_fraction        | 0.00821      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.146        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000265    |
# |    std                  | 0.987        |
# |    value_loss           | 0.298        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.76         |
# | time/                   |              |
# |    fps                  | 91433        |
# |    iterations           | 18           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007048427 |
# |    clip_fraction        | 0.00867      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.147        |
# |    n_updates            | 85           |
# |    policy_gradient_loss | -0.000283    |
# |    std                  | 0.986        |
# |    value_loss           | 0.298        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.98          |
# | time/                   |               |
# |    fps                  | 90923         |
# |    iterations           | 19            |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 19000000      |
# | train/                  |               |
# |    approx_kl            | 0.00074042514 |
# |    clip_fraction        | 0.00704       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.21          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.147         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000225     |
# |    std                  | 0.985         |
# |    value_loss           | 0.3           |
# -------------------------------------------
# Eval num_timesteps=20000000, episode_reward=15.52 +/- 5.49
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 15.5         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006840201 |
# |    clip_fraction        | 0.00656      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.152        |
# |    n_updates            | 95           |
# |    policy_gradient_loss | -0.000219    |
# |    std                  | 0.983        |
# |    value_loss           | 0.303        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.18     |
# | time/              |          |
# |    fps             | 90356    |
# |    iterations      | 20       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.62         |
# | time/                   |              |
# |    fps                  | 90188        |
# |    iterations           | 21           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006052212 |
# |    clip_fraction        | 0.00598      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.15         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000197    |
# |    std                  | 0.982        |
# |    value_loss           | 0.301        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.27         |
# | time/                   |              |
# |    fps                  | 90418        |
# |    iterations           | 22           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006799842 |
# |    clip_fraction        | 0.00668      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.152        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000229    |
# |    std                  | 0.981        |
# |    value_loss           | 0.304        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.64          |
# | time/                   |               |
# |    fps                  | 90414         |
# |    iterations           | 23            |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 23000000      |
# | train/                  |               |
# |    approx_kl            | 0.00070139905 |
# |    clip_fraction        | 0.00781       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.156         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000247     |
# |    std                  | 0.979         |
# |    value_loss           | 0.312         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.82         |
# | time/                   |              |
# |    fps                  | 90502        |
# |    iterations           | 24           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005989435 |
# |    clip_fraction        | 0.00608      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.158        |
# |    n_updates            | 115          |
# |    policy_gradient_loss | -0.000224    |
# |    std                  | 0.978        |
# |    value_loss           | 0.313        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.83          |
# | time/                   |               |
# |    fps                  | 90841         |
# |    iterations           | 25            |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 25000000      |
# | train/                  |               |
# |    approx_kl            | 0.00063828705 |
# |    clip_fraction        | 0.00641       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.221         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.154         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000213     |
# |    std                  | 0.977         |
# |    value_loss           | 0.311         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10            |
# | time/                   |               |
# |    fps                  | 91031         |
# |    iterations           | 26            |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 26000000      |
# | train/                  |               |
# |    approx_kl            | 0.00058864953 |
# |    clip_fraction        | 0.00554       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.217         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.155         |
# |    n_updates            | 125           |
# |    policy_gradient_loss | -0.000173     |
# |    std                  | 0.976         |
# |    value_loss           | 0.315         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.3          |
# | time/                   |               |
# |    fps                  | 91194         |
# |    iterations           | 27            |
# |    time_elapsed         | 296           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00062742573 |
# |    clip_fraction        | 0.00517       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.22          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.157         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00016      |
# |    std                  | 0.975         |
# |    value_loss           | 0.315         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.1         |
# | time/                   |              |
# |    fps                  | 91334        |
# |    iterations           | 28           |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005824547 |
# |    clip_fraction        | 0.00471      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.156        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.000164    |
# |    std                  | 0.973        |
# |    value_loss           | 0.312        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.3          |
# | time/                   |               |
# |    fps                  | 91429         |
# |    iterations           | 29            |
# |    time_elapsed         | 317           |
# |    total_timesteps      | 29000000      |
# | train/                  |               |
# |    approx_kl            | 0.00066253584 |
# |    clip_fraction        | 0.00638       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.221         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.156         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000224     |
# |    std                  | 0.972         |
# |    value_loss           | 0.31          |
# -------------------------------------------
# Eval num_timesteps=30000000, episode_reward=18.72 +/- 5.84
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 18.7          |
# | time/                   |               |
# |    total_timesteps      | 30000000      |
# | train/                  |               |
# |    approx_kl            | 0.00057516346 |
# |    clip_fraction        | 0.00564       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.21          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.159         |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -0.000195     |
# |    std                  | 0.971         |
# |    value_loss           | 0.316         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.2     |
# | time/              |          |
# |    fps             | 91238    |
# |    iterations      | 30       |
# |    time_elapsed    | 328      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 91376        |
# |    iterations           | 31           |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006529472 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.155        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000208    |
# |    std                  | 0.97         |
# |    value_loss           | 0.313        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 91483        |
# |    iterations           | 32           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005385275 |
# |    clip_fraction        | 0.00451      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.157        |
# |    n_updates            | 155          |
# |    policy_gradient_loss | -0.000158    |
# |    std                  | 0.968        |
# |    value_loss           | 0.319        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 91580        |
# |    iterations           | 33           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007134134 |
# |    clip_fraction        | 0.00788      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.156        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 0.967        |
# |    value_loss           | 0.313        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 91722        |
# |    iterations           | 34           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005795817 |
# |    clip_fraction        | 0.00408      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.16         |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -0.000139    |
# |    std                  | 0.966        |
# |    value_loss           | 0.32         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.8          |
# | time/                   |               |
# |    fps                  | 91786         |
# |    iterations           | 35            |
# |    time_elapsed         | 381           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00065787975 |
# |    clip_fraction        | 0.00602       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.215         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.162         |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000205     |
# |    std                  | 0.964         |
# |    value_loss           | 0.323         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 91780        |
# |    iterations           | 36           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005817534 |
# |    clip_fraction        | 0.0037       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.161        |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -0.000124    |
# |    std                  | 0.963        |
# |    value_loss           | 0.324        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 91870        |
# |    iterations           | 37           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006307536 |
# |    clip_fraction        | 0.00414      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.162        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00014     |
# |    std                  | 0.961        |
# |    value_loss           | 0.327        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.7          |
# | time/                   |               |
# |    fps                  | 91960         |
# |    iterations           | 38            |
# |    time_elapsed         | 413           |
# |    total_timesteps      | 38000000      |
# | train/                  |               |
# |    approx_kl            | 0.00061678345 |
# |    clip_fraction        | 0.00364       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.76         |
# |    explained_variance   | 0.209         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.162         |
# |    n_updates            | 185           |
# |    policy_gradient_loss | -0.00013      |
# |    std                  | 0.96          |
# |    value_loss           | 0.325         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 91969        |
# |    iterations           | 39           |
# |    time_elapsed         | 424          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006302684 |
# |    clip_fraction        | 0.00286      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.163        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -9.85e-05    |
# |    std                  | 0.959        |
# |    value_loss           | 0.327        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.57 +/- 5.66
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.6         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006737738 |
# |    clip_fraction        | 0.00354      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.157        |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.000119    |
# |    std                  | 0.957        |
# |    value_loss           | 0.317        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    fps             | 91578    |
# |    iterations      | 40       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.9          |
# | time/                   |               |
# |    fps                  | 91649         |
# |    iterations           | 41            |
# |    time_elapsed         | 447           |
# |    total_timesteps      | 41000000      |
# | train/                  |               |
# |    approx_kl            | 0.00068513735 |
# |    clip_fraction        | 0.00368       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.203         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.166         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000124     |
# |    std                  | 0.956         |
# |    value_loss           | 0.33          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.5          |
# | time/                   |               |
# |    fps                  | 91769         |
# |    iterations           | 42            |
# |    time_elapsed         | 457           |
# |    total_timesteps      | 42000000      |
# | train/                  |               |
# |    approx_kl            | 0.00057181425 |
# |    clip_fraction        | 0.00408       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.199         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.163         |
# |    n_updates            | 205           |
# |    policy_gradient_loss | -0.000136     |
# |    std                  | 0.955         |
# |    value_loss           | 0.327         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 91873        |
# |    iterations           | 43           |
# |    time_elapsed         | 468          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005515771 |
# |    clip_fraction        | 0.0028       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.166        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -9.99e-05    |
# |    std                  | 0.954        |
# |    value_loss           | 0.327        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.5          |
# | time/                   |               |
# |    fps                  | 91933         |
# |    iterations           | 44            |
# |    time_elapsed         | 478           |
# |    total_timesteps      | 44000000      |
# | train/                  |               |
# |    approx_kl            | 0.00057417306 |
# |    clip_fraction        | 0.00243       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.211         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.164         |
# |    n_updates            | 215           |
# |    policy_gradient_loss | -9.52e-05     |
# |    std                  | 0.953         |
# |    value_loss           | 0.328         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14            |
# | time/                   |               |
# |    fps                  | 92007         |
# |    iterations           | 45            |
# |    time_elapsed         | 489           |
# |    total_timesteps      | 45000000      |
# | train/                  |               |
# |    approx_kl            | 0.00062863366 |
# |    clip_fraction        | 0.00267       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.201         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.161         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -9.39e-05     |
# |    std                  | 0.952         |
# |    value_loss           | 0.323         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 91932        |
# |    iterations           | 46           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0004673361 |
# |    clip_fraction        | 0.00173      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.164        |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -7.35e-05    |
# |    std                  | 0.951        |
# |    value_loss           | 0.325        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.1          |
# | time/                   |               |
# |    fps                  | 91985         |
# |    iterations           | 47            |
# |    time_elapsed         | 510           |
# |    total_timesteps      | 47000000      |
# | train/                  |               |
# |    approx_kl            | 0.00065702887 |
# |    clip_fraction        | 0.00318       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.193         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.161         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000104     |
# |    std                  | 0.949         |
# |    value_loss           | 0.326         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.9          |
# | time/                   |               |
# |    fps                  | 92084         |
# |    iterations           | 48            |
# |    time_elapsed         | 521           |
# |    total_timesteps      | 48000000      |
# | train/                  |               |
# |    approx_kl            | 0.00061674544 |
# |    clip_fraction        | 0.00467       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.203         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.167         |
# |    n_updates            | 235           |
# |    policy_gradient_loss | -0.000158     |
# |    std                  | 0.948         |
# |    value_loss           | 0.337         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.8          |
# | time/                   |               |
# |    fps                  | 92164         |
# |    iterations           | 49            |
# |    time_elapsed         | 531           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00041412842 |
# |    clip_fraction        | 0.00114       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.197         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.161         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -4.53e-05     |
# |    std                  | 0.947         |
# |    value_loss           | 0.323         |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.14 +/- 6.55
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 19.1          |
# | time/                   |               |
# |    total_timesteps      | 50000000      |
# | train/                  |               |
# |    approx_kl            | 0.00025190078 |
# |    clip_fraction        | 1.46e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.19          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.165         |
# |    n_updates            | 245           |
# |    policy_gradient_loss | -1.35e-05     |
# |    std                  | 0.946         |
# |    value_loss           | 0.331         |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    fps             | 92037    |
# |    iterations      | 50       |
# |    time_elapsed    | 543      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent, use_normalized_agent=use_normalized_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -1.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 1.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././CJ_models/PPO-best/CjMm_PPO_50_000_000steps_RandomInventory/2025-11-17_09-29-17/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent, seed=seed)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.517048  20.561604  5.594715                   0.231
#
#          Std terminal inventory
# RL Agent               3.798373

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent) #, normalize_obs=True)

# %%
inventories = np.arange(-4,5,1)
#inventory_low = - max_inventory
#gradient_inventory = (max_inventory - (-max_inventory)) / 2
inventories_normalised = inventories
#inventories_normalised =(inventories - inventory_low) / gradient_inventory - 1

# %%
#inventories = np.arange(-1,1.25,0.25)
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
print(bid_actions)
# Out:
# [np.float32(1.1733779), np.float32(1.199368), np.float32(1.2215333), np.float32(1.2392287), np.float32(1.2524593), np.float32(1.2616186), np.float32(1.267159), np.float32(1.269453), np.float32(1.2688756)]

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././CJ_models/PPO-best/CjMm_PPO_50_000_000steps_RandomInventory/2025-11-17_09-29-17/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././CJ_models/PPO-best/CjMm_PPO_50_000_000steps_RandomInventory/2025-11-17_09-29-17/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.535224064103108
# median:  19.947911224388434
# std:  5.572210973034011

# %%
# Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/PPO_1/events.out.tfevents.1761915688.MacBookAir.lan.57975.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[53], line 4
#       2 event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/PPO_1/events.out.tfevents.1761915688.MacBookAir.lan.57975.0"
#       3 # Load the data
# ----> 4 ea = event_accumulator.EventAccumulator(event_file)
#       5 ea.Reload()
#       6 # Extract the rollout/ep_rew_mean data
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_accumulator.py:312, in EventAccumulator.__init__(self, path, size_guidance, compression_bps, purge_orphaned_data)
#     310 self._generator_mutex = threading.Lock()
#     311 self.path = path
# --> 312 self._generator = _GeneratorFromPath(path)
#     314 self._compression_bps = compression_bps
#     315 self.purge_orphaned_data = purge_orphaned_data
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_accumulator.py:945, in _GeneratorFromPath(path)
#     943     raise ValueError("path must be a valid string")
#     944 if io_wrapper.IsSummaryEventsFile(path):
# --> 945     return event_file_loader.LegacyEventFileLoader(path)
#     946 else:
#     947     return directory_watcher.DirectoryWatcher(
#     948         path,
#     949         event_file_loader.LegacyEventFileLoader,
#     950         io_wrapper.IsSummaryEventsFile,
#     951     )
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_file_loader.py:136, in RawEventFileLoader.__init__(self, file_path, detect_file_replacement)
#     134 self._detect_file_replacement = detect_file_replacement
#     135 self._file_size = None
# --> 136 self._iterator = _make_tf_record_iterator(self._file_path)
#     137 if self._detect_file_replacement and not hasattr(
#     138     self._iterator, "reopen"
#     139 ):
#     140     logger.warning(
#     141         "File replacement detection requested, but not enabled because "
#     142         "TF record iterator impl does not support reopening. This "
#     143         "functionality requires TensorFlow 2.9+"
#     144     )
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_file_loader.py:59, in _make_tf_record_iterator(file_path)
#      55 if tf.__version__ == "stub":
#      56     # TODO(#1711): Reshape stub implementation to fit tf_record_iterator API
#      57     # rather than needlessly emulating the old PyRecordReader_New API.
#      58     logger.debug("Opening a stub record reader pointing at %s", file_path)
# ---> 59     return _PyRecordReaderIterator(
#      60         tf.pywrap_tensorflow.PyRecordReader_New, file_path
#      61     )
#      62 # If PyRecordReader exists, use it, otherwise use tf_record_iterator().
#      63 # Check old first, then new, since tf_record_iterator existed previously but
#      64 # only gained the semantics we need at the time PyRecordReader was removed.
#    (...)
#      67 # support for TF 2.1 and prior, and find a non-deprecated replacement for
#      68 # tf.compat.v1.io.tf_record_iterator.
#      69 try:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_file_loader.py:96, in _PyRecordReaderIterator.__init__(self, py_record_reader_new, file_path)
#      89 """Constructs a _PyRecordReaderIterator for the given file path.
#      90
#      91 Args:
#      92   py_record_reader_new: pywrap_tensorflow.PyRecordReader_New
#      93   file_path: file path of the tfrecord file to read
#      94 """
#      95 with tf.compat.v1.errors.raise_exception_on_not_ok_status() as status:
# ---> 96     self._reader = py_record_reader_new(
#      97         tf.compat.as_bytes(file_path), 0, tf.compat.as_bytes(""), status
#      98     )
#      99 if not self._reader:
#     100     raise IOError(
#     101         "Failed to open a record reader pointing to %s" % file_path
#     102     )
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/tensorboard/compat/tensorflow_stub/pywrap_tensorflow.py:177, in PyRecordReader_New.__init__(self, filename, start_offset, compression_type, status)
#     173     raise errors.NotFoundError(
#     174         None, None, "No filename provided, cannot read Events"
#     175     )
#     176 if not gfile.exists(filename):
# --> 177     raise errors.NotFoundError(
#     178         None,
#     179         None,
#     180         "{} does not point to valid Events file".format(filename),
#     181     )
#     182 if start_offset:
#     183     raise errors.UnimplementedError(
#     184         None, None, "start offset not supported by compat reader"
#     185     )
#
# NotFoundError: b'./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/PPO_1/events.out.tfevents.1761915688.MacBookAir.lan.57975.0' does not point to valid Events file

# %%
#  Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-30_14-14-22/PPO_1/events.out.tfevents.1761830063.MacBookAir.lan.27166.0" 
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-30_14-14-22/PPO_1/events.out.tfevents.1761830063.MacBookAir.lan.27166.0" 
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomInventory/2025-10-31_14-01-26/Training_process_rewards.png
