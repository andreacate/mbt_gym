# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x13639bd30>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x137e80130>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065896  21.133681  4.809688                  -0.071
#
#           Std terminal inventory
# Inventory               3.106116

# %% [markdown]
# ### Rinforncement Learning

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %% [markdown]
# #### Optuna

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler

# %%
use_normalized_agent = False

# %%
def objective(trial):
    """
    Objective function for Optuna to optimize PPO hyperparameters.
    
    Parameters
    ----------
    trial : optuna.Trial
        A trial object that suggests hyperparameters
        
    Returns
    -------
    float
        Mean reward from evaluation episodes
    """
    batch_size_divisor = 100 

    # Suggest hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-3, log=True)
    n_epochs = trial.suggest_int("n_epochs", 3, 10)
    # batch_size_divisor = trial.suggest_int("batch_size_divisor", 5, 20)
    # gamma = trial.suggest_float("gamma", 0.9, 0.999)
    gae_lambda = trial.suggest_float("gae_lambda", 0.9, 0.99)
    clip_range = trial.suggest_float("clip_range", 0.1, 0.3)
    ent_coef = trial.suggest_float("ent_coef", 0.0, 0.1)
    vf_coef = trial.suggest_float("vf_coef", 0.1, 1.0)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 1.0)
    
    # Network architecture
    n_layers = trial.suggest_int("n_layers", 1, 3)
    layer_size = trial.suggest_categorical("layer_size", [128, 256, 512])
    activation = trial.suggest_categorical("activation", ["tanh", "relu"])
    
    # Build network architecture
    net_arch = []
    for _ in range(n_layers):
        net_arch.append(layer_size)
    
    activation_fn = nn.Tanh if activation == "tanh" else nn.ReLU
    
    policy_kwargs = dict(
        activation_fn=activation_fn,
        net_arch=dict(pi=net_arch.copy(), vf=net_arch.copy())
    )
    
    # Create environment for this trial
    num_trajectories = 1000
    reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
    rl_env_trial = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
    sb_rl_env_trial = StableBaselinesTradingEnvironment(trading_env=rl_env_trial)
    sb_rl_env_trial = VecMonitor(sb_rl_env_trial)
    
    # Create model with suggested hyperparameters
    model = PPO(
        policy='MlpPolicy',
        env=sb_rl_env_trial,
        learning_rate=learning_rate,
        n_epochs=n_epochs,
        batch_size=int(n_steps * num_trajectories / batch_size_divisor),
        n_steps=int(n_steps),
        # gamma=gamma,
        gae_lambda=gae_lambda,
        clip_range=clip_range,
        ent_coef=ent_coef,
        vf_coef=vf_coef,
        max_grad_norm=max_grad_norm,
        policy_kwargs=policy_kwargs,
        verbose=0,
        device="cpu"
    )
    
    # Create evaluation callback with pruning
    eval_freq = 100_000  # Evaluate every 50k steps
    n_eval_episodes = 256
    
    # Custom callback for Optuna pruning
    class OptunaEvalCallback(EvalCallback):
        def __init__(self, trial, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.trial = trial
            self.eval_idx = 0
            
        def _on_step(self) -> bool:
            result = super()._on_step()
            
            if len(self.evaluations_results) > 0:
                # Report intermediate value
                mean_reward = self.evaluations_results[-1]
                self.trial.report(mean_reward, self.eval_idx)
                self.eval_idx += 1
                
                # Prune trial if needed
                if self.trial.should_prune():
                    raise optuna.TrialPruned()
            
            return result
    
    eval_callback = OptunaEvalCallback(
        trial=trial,
        eval_env=sb_rl_env_trial,
        n_eval_episodes=n_eval_episodes,
        eval_freq=eval_freq,
        deterministic=True,
        verbose=0
    )
    
    try:
        # Train for a limited number of steps (you can adjust this)
        total_timesteps = 1_000_000  
        model.learn(total_timesteps=total_timesteps, callback=eval_callback)
        
        # Final evaluation
        rl_env_eval = get_rl_env_visualization(num_trajectories=1000)
        ppo_agent = SbAgent(
            model, 
            reduced_training_indices=reduced_training_indices, 
            env=rl_env_eval, 
            use_normalized_agent=use_normalized_agent
        )
        
        observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(
            env=rl_env_eval, 
            rl_agent=ppo_agent
        )
        
        mean_reward = rewards_rl.sum(axis=-1).mean()
        
    except optuna.TrialPruned:
        raise
    except Exception as e:
        print(f"Trial failed with error: {e}")
        return float('-inf')
    finally:
        # Clean up
        sb_rl_env_trial.close()
    
    return mean_reward

# %%
# Create study
study = optuna.create_study(
    direction="maximize",
    study_name="ppo_mm_optimization",
    sampler=TPESampler(seed=seed),
    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=10)
)

# Optimize
n_trials = 50  # Number of trials to run
study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Print results
print("Best trial:")
print(f"  Value (mean reward): {study.best_trial.value}")
print(f"  Params: ")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-02 09:04:05,551] A new study created in memory with name: ppo_mm_optimization
#   0%|          | 0/50 [00:00<?, ?it/s]
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# [I 2025-11-02 09:05:10,944] Trial 0 finished with value: -0.7994821203360537 and parameters: {'learning_rate': 5.6115164153345e-05, 'n_epochs': 10, 'gae_lambda': 0.9658794547630265, 'clip_range': 0.21973169683940733, 'ent_coef': 0.015601864044243652, 'vf_coef': 0.2403950683025824, 'max_grad_norm': 0.3406585285177396, 'n_layers': 3, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 0 with value: -0.7994821203360537.
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# [I 2025-11-02 09:05:46,642] Trial 1 finished with value: -2.75065961356088 and parameters: {'learning_rate': 2.6587543983272695e-05, 'n_epochs': 4, 'gae_lambda': 0.9165064058868091, 'clip_range': 0.16084844859190756, 'ent_coef': 0.052475643163223784, 'vf_coef': 0.4887505167779042, 'max_grad_norm': 0.5038603981386293, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 0 with value: -0.7994821203360537.
# [I 2025-11-02 09:06:04,893] Trial 2 finished with value: -0.6847223930721283 and parameters: {'learning_rate': 2.5081156860452307e-05, 'n_epochs': 7, 'gae_lambda': 0.9533173111975838, 'clip_range': 0.10929008254399955, 'ent_coef': 0.06075448519014384, 'vf_coef': 0.2534717113185624, 'max_grad_norm': 0.3455361150896957, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:06:12,173] Trial 3 finished with value: -2.7732640932903867 and parameters: {'learning_rate': 7.591104805282687e-05, 'n_epochs': 3, 'gae_lambda': 0.9445659219100143, 'clip_range': 0.10687770422304368, 'ent_coef': 0.0909320402078782, 'vf_coef': 0.33290198344001526, 'max_grad_norm': 0.7637655990477873, 'n_layers': 1, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:06:49,129] Trial 4 finished with value: -0.9763510908384118 and parameters: {'learning_rate': 0.0007568292060167617, 'n_epochs': 10, 'gae_lambda': 0.9538109980929976, 'clip_range': 0.28437484700462334, 'ent_coef': 0.00884925020519195, 'vf_coef': 0.27638457617723067, 'max_grad_norm': 0.33165910223737666, 'n_layers': 1, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:06:54,793] Trial 5 finished with value: -3.1548147954595853 and parameters: {'learning_rate': 0.00012172847081122418, 'n_epochs': 4, 'gae_lambda': 0.9721977282678635, 'clip_range': 0.11491012873595417, 'ent_coef': 0.09868869366005173, 'vf_coef': 0.7950202923669917, 'max_grad_norm': 0.43910097707392065, 'n_layers': 1, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:07:09,988] Trial 6 finished with value: -1.8099388796213634 and parameters: {'learning_rate': 5.2111245957882584e-05, 'n_epochs': 3, 'gae_lambda': 0.9776793083288035, 'clip_range': 0.22465962536551157, 'ent_coef': 0.03308980248526492, 'vf_coef': 0.15720251525742127, 'max_grad_norm': 0.5176876252009636, 'n_layers': 1, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:07:48,768] Trial 7 finished with value: -1.9638019383428071 and parameters: {'learning_rate': 0.0002669866674274458, 'n_epochs': 9, 'gae_lambda': 0.9505149477812547, 'clip_range': 0.2541934359909122, 'ent_coef': 0.04937955963643908, 'vf_coef': 0.5704595464437947, 'max_grad_norm': 0.5992787128509847, 'n_layers': 1, 'layer_size': 512, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:07:54,566] Trial 8 finished with value: -1.737391263431175 and parameters: {'learning_rate': 0.0006533305220227731, 'n_epochs': 4, 'gae_lambda': 0.9369344630732067, 'clip_range': 0.25111022770860975, 'ent_coef': 0.022879816549162248, 'vf_coef': 0.1692819188459137, 'max_grad_norm': 0.5028260170396376, 'n_layers': 1, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:08:25,404] Trial 9 finished with value: -3.552951721192846 and parameters: {'learning_rate': 2.3612399244412595e-05, 'n_epochs': 10, 'gae_lambda': 0.9485408017724085, 'clip_range': 0.2614880310328125, 'ent_coef': 0.08960912999234932, 'vf_coef': 0.3862031274746775, 'max_grad_norm': 0.37703634716937373, 'n_layers': 1, 'layer_size': 512, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:08:42,009] Trial 10 finished with value: -1.6960808883087575 and parameters: {'learning_rate': 1.1176284636053914e-05, 'n_epochs': 7, 'gae_lambda': 0.9006792587384664, 'clip_range': 0.16407187717261953, 'ent_coef': 0.06782238915155511, 'vf_coef': 0.9168983157542662, 'max_grad_norm': 0.9718395221617938, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:09:16,959] Trial 11 finished with value: -3.5153297244963286 and parameters: {'learning_rate': 3.175008554406566e-05, 'n_epochs': 7, 'gae_lambda': 0.965897137249062, 'clip_range': 0.18687125435128227, 'ent_coef': 0.06393098071381706, 'vf_coef': 0.5876347747627798, 'max_grad_norm': 0.30481501323711774, 'n_layers': 3, 'layer_size': 256, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:10:06,621] Trial 12 finished with value: -1.501857259295049 and parameters: {'learning_rate': 0.00018883592183913727, 'n_epochs': 8, 'gae_lambda': 0.9883351838410724, 'clip_range': 0.19920826243394285, 'ent_coef': 0.007200605006513351, 'vf_coef': 0.13022729644102476, 'max_grad_norm': 0.7624171687628818, 'n_layers': 3, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:10:28,222] Trial 13 finished with value: -3.552951721192846 and parameters: {'learning_rate': 1.018044647029514e-05, 'n_epochs': 6, 'gae_lambda': 0.9315592312512025, 'clip_range': 0.14390825353701686, 'ent_coef': 0.031223493592211653, 'vf_coef': 0.44943419485132763, 'max_grad_norm': 0.6792287430566037, 'n_layers': 2, 'layer_size': 256, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:10:49,715] Trial 14 finished with value: -2.450068269982111 and parameters: {'learning_rate': 4.8728276744942214e-05, 'n_epochs': 6, 'gae_lambda': 0.9625187766801306, 'clip_range': 0.219597199484184, 'ent_coef': 0.0741153191179948, 'vf_coef': 0.24040415887768585, 'max_grad_norm': 0.43525338788163437, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:11:15,594] Trial 15 finished with value: -3.553018130936221 and parameters: {'learning_rate': 1.6878798031759015e-05, 'n_epochs': 8, 'gae_lambda': 0.9858806733790018, 'clip_range': 0.1387600957079071, 'ent_coef': 0.044682724190322445, 'vf_coef': 0.6755216196437901, 'max_grad_norm': 0.957031347612733, 'n_layers': 2, 'layer_size': 256, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:11:35,962] Trial 16 finished with value: -3.548247716560086 and parameters: {'learning_rate': 9.702342352167721e-05, 'n_epochs': 9, 'gae_lambda': 0.9599882075376948, 'clip_range': 0.21992816888392483, 'ent_coef': 0.022234635690112775, 'vf_coef': 0.3414554074834852, 'max_grad_norm': 0.4036455635594384, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:12:02,531] Trial 17 finished with value: -2.513685812374214 and parameters: {'learning_rate': 4.602805641690311e-05, 'n_epochs': 9, 'gae_lambda': 0.9264271754961697, 'clip_range': 0.17865365648251066, 'ent_coef': 0.0587292010719356, 'vf_coef': 0.10032815749327828, 'max_grad_norm': 0.6115022936482708, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:12:24,831] Trial 18 finished with value: -3.270393084650097 and parameters: {'learning_rate': 0.0002061529311645373, 'n_epochs': 5, 'gae_lambda': 0.9742169002969783, 'clip_range': 0.12876989798666075, 'ent_coef': 0.07607218311836937, 'vf_coef': 0.22992381790419794, 'max_grad_norm': 0.30343203097921667, 'n_layers': 2, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:12:51,252] Trial 19 finished with value: -2.596733220808129 and parameters: {'learning_rate': 1.795453879112875e-05, 'n_epochs': 8, 'gae_lambda': 0.9391602606172105, 'clip_range': 0.28745910960918913, 'ent_coef': 0.0015021211625687314, 'vf_coef': 0.4402500847784149, 'max_grad_norm': 0.8561186812818374, 'n_layers': 2, 'layer_size': 256, 'activation': 'relu'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:13:24,457] Trial 20 finished with value: -2.062615352928468 and parameters: {'learning_rate': 6.956776471156056e-05, 'n_epochs': 10, 'gae_lambda': 0.9601780610396634, 'clip_range': 0.2363449727504512, 'ent_coef': 0.03843083322892902, 'vf_coef': 0.6999071524898571, 'max_grad_norm': 0.5457247242708846, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:15:07,228] Trial 21 finished with value: -0.7885890063870127 and parameters: {'learning_rate': 0.0009009433940248854, 'n_epochs': 10, 'gae_lambda': 0.9544916752750314, 'clip_range': 0.29767901427351084, 'ent_coef': 0.011143165626931737, 'vf_coef': 0.24893862350665297, 'max_grad_norm': 0.3558544445503152, 'n_layers': 2, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:16:37,383] Trial 22 finished with value: -2.6352770981080353 and parameters: {'learning_rate': 0.00037998800008875577, 'n_epochs': 9, 'gae_lambda': 0.9558614402056078, 'clip_range': 0.2969334728374174, 'ent_coef': 0.018688048761933578, 'vf_coef': 0.29238658078513335, 'max_grad_norm': 0.37389032756677826, 'n_layers': 2, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:18:17,161] Trial 23 finished with value: -2.1365128708930863 and parameters: {'learning_rate': 0.0004676150464719635, 'n_epochs': 10, 'gae_lambda': 0.9701444668862061, 'clip_range': 0.19822061590490597, 'ent_coef': 0.0150424030312886, 'vf_coef': 0.22255181701722396, 'max_grad_norm': 0.4356020118529637, 'n_layers': 2, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: -0.6847223930721283.
# [I 2025-11-02 09:18:40,483] Trial 24 finished with value: 0.07409913052939517 and parameters: {'learning_rate': 0.0009804810129566863, 'n_epochs': 8, 'gae_lambda': 0.9813471037131086, 'clip_range': 0.26880910096726557, 'ent_coef': 0.0002943420307404618, 'vf_coef': 0.40347660744242353, 'max_grad_norm': 0.35915998941295146, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 24 with value: 0.07409913052939517.
# [I 2025-11-02 09:19:00,592] Trial 25 finished with value: 0.4581430879832674 and parameters: {'learning_rate': 0.0008949365115903307, 'n_epochs': 7, 'gae_lambda': 0.9791668398670226, 'clip_range': 0.27387105459748573, 'ent_coef': 0.001400547293144927, 'vf_coef': 0.3697509167008145, 'max_grad_norm': 0.448416402922794, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:19:16,485] Trial 26 finished with value: -0.8617520461170344 and parameters: {'learning_rate': 0.0004753445520144763, 'n_epochs': 7, 'gae_lambda': 0.9812627965631453, 'clip_range': 0.26631302915133914, 'ent_coef': 0.0012506438478166238, 'vf_coef': 0.39384023995427686, 'max_grad_norm': 0.460408299364221, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:19:33,148] Trial 27 finished with value: -3.1144885605506425 and parameters: {'learning_rate': 0.0009277186099924034, 'n_epochs': 6, 'gae_lambda': 0.9823515083240494, 'clip_range': 0.2743005936118466, 'ent_coef': 0.028163879169751597, 'vf_coef': 0.49945759333916606, 'max_grad_norm': 0.3998039947735723, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:19:51,599] Trial 28 finished with value: -0.6506563100628171 and parameters: {'learning_rate': 0.0005797831577287758, 'n_epochs': 8, 'gae_lambda': 0.9890983613222457, 'clip_range': 0.2478092518679871, 'ent_coef': 0.044619668295986875, 'vf_coef': 0.3527037728732783, 'max_grad_norm': 0.5526777662349849, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:20:14,292] Trial 29 finished with value: -0.6074069603452904 and parameters: {'learning_rate': 0.0005990629496257147, 'n_epochs': 8, 'gae_lambda': 0.9880020982730529, 'clip_range': 0.2397818335027754, 'ent_coef': 0.001479155257881599, 'vf_coef': 0.6204267748885388, 'max_grad_norm': 0.5459861634885728, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:20:41,168] Trial 30 finished with value: 0.299942188949089 and parameters: {'learning_rate': 0.0003030012253057976, 'n_epochs': 8, 'gae_lambda': 0.9765724444658218, 'clip_range': 0.27324589661361226, 'ent_coef': 0.0016195344119939864, 'vf_coef': 0.6460931328708275, 'max_grad_norm': 0.7067119715574984, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 25 with value: 0.4581430879832674.
# [I 2025-11-02 09:21:03,546] Trial 31 finished with value: 0.8298229017807618 and parameters: {'learning_rate': 0.00034638355009592825, 'n_epochs': 8, 'gae_lambda': 0.9793467575878533, 'clip_range': 0.27639710736866113, 'ent_coef': 0.0011346018686685592, 'vf_coef': 0.6488501721350908, 'max_grad_norm': 0.7109436691324318, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:21:23,360] Trial 32 finished with value: -0.9222867026734197 and parameters: {'learning_rate': 0.0003369578810127263, 'n_epochs': 7, 'gae_lambda': 0.9788448250042259, 'clip_range': 0.2733020215869465, 'ent_coef': 0.007937125795369974, 'vf_coef': 0.7044932756080396, 'max_grad_norm': 0.707323143164855, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:21:46,154] Trial 33 finished with value: -1.0075746398764704 and parameters: {'learning_rate': 0.0001787979341654584, 'n_epochs': 8, 'gae_lambda': 0.9678598918975686, 'clip_range': 0.2819369368731024, 'ent_coef': 0.013554507949667205, 'vf_coef': 0.5379086917528844, 'max_grad_norm': 0.7515963437005115, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:22:11,987] Trial 34 finished with value: 0.07485901271895658 and parameters: {'learning_rate': 0.0002799366742921887, 'n_epochs': 9, 'gae_lambda': 0.9730168517090307, 'clip_range': 0.2659393193021056, 'ent_coef': 0.0003341680205846476, 'vf_coef': 0.8096039060102123, 'max_grad_norm': 0.8485486111334242, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:22:36,637] Trial 35 finished with value: -0.6314663349513822 and parameters: {'learning_rate': 0.00026493598755400504, 'n_epochs': 9, 'gae_lambda': 0.9722633294619482, 'clip_range': 0.23245915501679565, 'ent_coef': 0.006655757324817017, 'vf_coef': 0.84713627234663, 'max_grad_norm': 0.8154797764991244, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:22:56,413] Trial 36 finished with value: -1.2953703881219627 and parameters: {'learning_rate': 0.0001359727207083058, 'n_epochs': 7, 'gae_lambda': 0.9755799753523974, 'clip_range': 0.2839732403442228, 'ent_coef': 0.019530826028425853, 'vf_coef': 0.76809532270711, 'max_grad_norm': 0.8982966811826884, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:23:21,073] Trial 37 finished with value: -1.607698690166064 and parameters: {'learning_rate': 0.00038621703966515544, 'n_epochs': 9, 'gae_lambda': 0.965107546965609, 'clip_range': 0.25853662340452316, 'ent_coef': 0.026026926684638848, 'vf_coef': 0.9107571400686467, 'max_grad_norm': 0.7173711372286158, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:23:36,119] Trial 38 finished with value: -3.099395740127054 and parameters: {'learning_rate': 0.00025431294621816147, 'n_epochs': 5, 'gae_lambda': 0.9836023019472158, 'clip_range': 0.2998492440183398, 'ent_coef': 0.014440186587425937, 'vf_coef': 0.9933324058295099, 'max_grad_norm': 0.8041721919998338, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:23:48,311] Trial 39 finished with value: -0.04902123782074442 and parameters: {'learning_rate': 0.0001372214594255907, 'n_epochs': 6, 'gae_lambda': 0.9772933125169166, 'clip_range': 0.24479878190181986, 'ent_coef': 0.007139894728447753, 'vf_coef': 0.6326430543082293, 'max_grad_norm': 0.6559910248270697, 'n_layers': 2, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 31 with value: 0.8298229017807618.
# [I 2025-11-02 09:24:07,291] Trial 40 finished with value: 1.04834970621497 and parameters: {'learning_rate': 0.00032596444584444376, 'n_epochs': 7, 'gae_lambda': 0.9703646882271225, 'clip_range': 0.28182536740911146, 'ent_coef': 0.004219108116345265, 'vf_coef': 0.7574463364363383, 'max_grad_norm': 0.9005571442716023, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 40 with value: 1.04834970621497.
# [I 2025-11-02 09:24:27,085] Trial 41 finished with value: 1.1852421376519338 and parameters: {'learning_rate': 0.0003183007021121478, 'n_epochs': 7, 'gae_lambda': 0.9715008270919541, 'clip_range': 0.278707602668491, 'ent_coef': 0.0042480157458374725, 'vf_coef': 0.7505433607286623, 'max_grad_norm': 0.9053510080756035, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 41 with value: 1.1852421376519338.
# [I 2025-11-02 09:24:46,422] Trial 42 finished with value: 1.3743850858738864 and parameters: {'learning_rate': 0.0007164985623251524, 'n_epochs': 7, 'gae_lambda': 0.9668645306030904, 'clip_range': 0.27905151329646016, 'ent_coef': 0.005696677626333107, 'vf_coef': 0.7402735047715143, 'max_grad_norm': 0.9261826846723813, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:25:05,947] Trial 43 finished with value: -0.14836718269923738 and parameters: {'learning_rate': 0.000724512336558594, 'n_epochs': 7, 'gae_lambda': 0.9683424329729151, 'clip_range': 0.28679150075572535, 'ent_coef': 0.011919429235070778, 'vf_coef': 0.7484316451407756, 'max_grad_norm': 0.9269191530464627, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:25:20,944] Trial 44 finished with value: 1.232244445393904 and parameters: {'learning_rate': 0.0004696843351530402, 'n_epochs': 5, 'gae_lambda': 0.9584406489647949, 'clip_range': 0.25526842864561033, 'ent_coef': 0.007514939769304805, 'vf_coef': 0.8516554436571632, 'max_grad_norm': 0.9941904724511201, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:25:35,603] Trial 45 finished with value: -2.3342956091112055 and parameters: {'learning_rate': 0.00048044468494676143, 'n_epochs': 5, 'gae_lambda': 0.9468056941908599, 'clip_range': 0.2566130645804288, 'ent_coef': 0.018199127868830444, 'vf_coef': 0.8638095114600512, 'max_grad_norm': 0.9984567869222567, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:25:53,011] Trial 46 finished with value: 1.3322662513460912 and parameters: {'learning_rate': 0.0004079291293868257, 'n_epochs': 6, 'gae_lambda': 0.9575776977464296, 'clip_range': 0.2850843756945614, 'ent_coef': 0.005376853586975371, 'vf_coef': 0.7513447562588839, 'max_grad_norm': 0.9009620468993608, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:26:10,564] Trial 47 finished with value: 1.1228129379811354 and parameters: {'learning_rate': 0.0005363405384858443, 'n_epochs': 5, 'gae_lambda': 0.9580175547129862, 'clip_range': 0.2919551174148078, 'ent_coef': 0.010455876595848717, 'vf_coef': 0.7361246515457289, 'max_grad_norm': 0.9031341678616693, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:26:24,542] Trial 48 finished with value: 0.33894075205631646 and parameters: {'learning_rate': 0.0005364131521903811, 'n_epochs': 4, 'gae_lambda': 0.9414305081027163, 'clip_range': 0.2911852546054325, 'ent_coef': 0.010466703550584698, 'vf_coef': 0.8181212423960852, 'max_grad_norm': 0.9428182613569945, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# [I 2025-11-02 09:26:41,384] Trial 49 finished with value: -1.7882387954297363 and parameters: {'learning_rate': 0.0007228305595491431, 'n_epochs': 5, 'gae_lambda': 0.9513198848798938, 'clip_range': 0.29039896122489356, 'ent_coef': 0.025973308229020248, 'vf_coef': 0.8988834217614239, 'max_grad_norm': 0.9978329161549377, 'n_layers': 3, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 42 with value: 1.3743850858738864.
# Best trial:
#   Value (mean reward): 1.3743850858738864
#   Params:
#     learning_rate: 0.0007164985623251524
#     n_epochs: 7
#     gae_lambda: 0.9668645306030904
#     clip_range: 0.27905151329646016
#     ent_coef: 0.005696677626333107
#     vf_coef: 0.7402735047715143
#     max_grad_norm: 0.9261826846723813
#     n_layers: 3
#     layer_size: 128
#     activation: tanh

# %%
# Get the study results as a DataFrame
df = study.trials_dataframe()

# 1. Optimization History Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot all trial values
ax.scatter(df['number'], df['value'], alpha=0.5, label='Trial values')

# Plot best value so far (cumulative best)
best_values = df['value'].cummax()
ax.plot(df['number'], best_values, 'r-', linewidth=2, label='Best value so far')

ax.set_xlabel('Trial Number')
ax.set_ylabel('Objective Value (Mean Reward)')
ax.set_title('Optimization History')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Get best parameters
best_params = study.best_trial.params

batch_size_divisor = 100

# Extract parameters
learning_rate = best_params["learning_rate"]
n_epochs = best_params["n_epochs"]
# batch_size_divisor = best_params["batch_size_divisor"]
#gamma = best_params["gamma"]
gae_lambda = best_params["gae_lambda"]
clip_range = best_params["clip_range"]
ent_coef = best_params["ent_coef"]
vf_coef = best_params["vf_coef"]
max_grad_norm = best_params["max_grad_norm"]
n_layers = best_params["n_layers"]
layer_size = best_params["layer_size"]
activation = best_params["activation"]

# Build network architecture
net_arch = [layer_size] * n_layers
activation_fn = nn.Tanh if activation == "tanh" else nn.ReLU

policy_kwargs = dict(
    activation_fn=activation_fn,
    net_arch=[dict(pi=net_arch.copy(), vf=net_arch.copy())]
)

# Create final model
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
sb_rl_env = VecMonitor(sb_rl_env)

# Generate paths
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_Optuna_Best"
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# Create model with best parameters
model = PPO(
    policy='MlpPolicy',
    env=sb_rl_env,
    learning_rate=learning_rate,
    n_epochs=n_epochs,
    batch_size=int(n_steps * num_trajectories / batch_size_divisor),
    n_steps=int(n_steps),
    # gamma=gamma,
    gae_lambda=gae_lambda,
    clip_range=clip_range,
    ent_coef=ent_coef,
    vf_coef=vf_coef,
    max_grad_norm=max_grad_norm,
    policy_kwargs=policy_kwargs,
    tensorboard_log=tensorboard_logdir,
    verbose=1,
    device="cpu"
)

# Train with full timesteps
callback = EvalCallback(
    eval_env=sb_rl_env,
    n_eval_episodes=256,
    best_model_save_path=best_model_path,
    deterministic=True
)

model.learn(total_timesteps=50_000_000, callback=callback)
# Out:
# Using cpu device
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/PPO_1
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.09     |
# | time/              |          |
# |    fps             | 458670   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.14         |
# | time/                   |              |
# |    fps                  | 84156        |
# |    iterations           | 2            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0051740324 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00215      |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.239        |
# |    n_updates            | 7            |
# |    policy_gradient_loss | -0.000649    |
# |    std                  | 0.997        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.63         |
# | time/                   |              |
# |    fps                  | 67206        |
# |    iterations           | 3            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0053944523 |
# |    clip_fraction        | 0.00872      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0635       |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.248        |
# |    n_updates            | 14           |
# |    policy_gradient_loss | -0.000689    |
# |    std                  | 0.994        |
# |    value_loss           | 0.347        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.58         |
# | time/                   |              |
# |    fps                  | 62008        |
# |    iterations           | 4            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0045161806 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.239        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.00043     |
# |    std                  | 0.991        |
# |    value_loss           | 0.359        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.23         |
# | time/                   |              |
# |    fps                  | 58599        |
# |    iterations           | 5            |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0055015422 |
# |    clip_fraction        | 0.00984      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.245        |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.000799    |
# |    std                  | 0.986        |
# |    value_loss           | 0.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.38        |
# | time/                   |             |
# |    fps                  | 55411       |
# |    iterations           | 6           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 6000000     |
# | train/                  |             |
# |    approx_kl            | 0.005474703 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.25        |
# |    n_updates            | 35          |
# |    policy_gradient_loss | -0.000821   |
# |    std                  | 0.982       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10          |
# | time/                   |             |
# |    fps                  | 52881       |
# |    iterations           | 7           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.005440902 |
# |    clip_fraction        | 0.0101      |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.255       |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00081    |
# |    std                  | 0.976       |
# |    value_loss           | 0.359       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 51435        |
# |    iterations           | 8            |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0057092286 |
# |    clip_fraction        | 0.00906      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.258        |
# |    n_updates            | 49           |
# |    policy_gradient_loss | -0.000714    |
# |    std                  | 0.967        |
# |    value_loss           | 0.356        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 50554       |
# |    iterations           | 9           |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.005354409 |
# |    clip_fraction        | 0.00902     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.257       |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.000595   |
# |    std                  | 0.961       |
# |    value_loss           | 0.368       |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=18.65 +/- 5.33
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 18.7        |
# | time/                   |             |
# |    total_timesteps      | 10000000    |
# | train/                  |             |
# |    approx_kl            | 0.005055395 |
# |    clip_fraction        | 0.00797     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.258       |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -0.000586   |
# |    std                  | 0.954       |
# |    value_loss           | 0.367       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    fps             | 49286    |
# |    iterations      | 10       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 48610       |
# |    iterations           | 11          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 11000000    |
# | train/                  |             |
# |    approx_kl            | 0.005971242 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.269       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000763   |
# |    std                  | 0.944       |
# |    value_loss           | 0.365       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.2        |
# | time/                   |             |
# |    fps                  | 48093       |
# |    iterations           | 12          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.004647035 |
# |    clip_fraction        | 0.00818     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.26        |
# |    n_updates            | 77          |
# |    policy_gradient_loss | -0.000487   |
# |    std                  | 0.941       |
# |    value_loss           | 0.368       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 47670        |
# |    iterations           | 13           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0045865756 |
# |    clip_fraction        | 0.00798      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.258        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000575    |
# |    std                  | 0.931        |
# |    value_loss           | 0.361        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 47244        |
# |    iterations           | 14           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0048143724 |
# |    clip_fraction        | 0.0087       |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.257        |
# |    n_updates            | 91           |
# |    policy_gradient_loss | -0.000518    |
# |    std                  | 0.922        |
# |    value_loss           | 0.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 46996        |
# |    iterations           | 15           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0037251946 |
# |    clip_fraction        | 0.00592      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.267        |
# |    n_updates            | 98           |
# |    policy_gradient_loss | -0.00031     |
# |    std                  | 0.915        |
# |    value_loss           | 0.377        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 46716        |
# |    iterations           | 16           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0040410254 |
# |    clip_fraction        | 0.00611      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.253        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000309    |
# |    std                  | 0.907        |
# |    value_loss           | 0.349        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 46465        |
# |    iterations           | 17           |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0043156897 |
# |    clip_fraction        | 0.00764      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.256        |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.000179    |
# |    std                  | 0.899        |
# |    value_loss           | 0.351        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 13.9       |
# | time/                   |            |
# |    fps                  | 46286      |
# |    iterations           | 18         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 18000000   |
# | train/                  |            |
# |    approx_kl            | 0.00405921 |
# |    clip_fraction        | 0.00641    |
# |    clip_range           | 0.279      |
# |    entropy_loss         | -2.62      |
# |    explained_variance   | 0.197      |
# |    learning_rate        | 0.000716   |
# |    loss                 | 0.273      |
# |    n_updates            | 119        |
# |    policy_gradient_loss | -0.000247  |
# |    std                  | 0.894      |
# |    value_loss           | 0.37       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 14.1       |
# | time/                   |            |
# |    fps                  | 46122      |
# |    iterations           | 19         |
# |    time_elapsed         | 411        |
# |    total_timesteps      | 19000000   |
# | train/                  |            |
# |    approx_kl            | 0.00444275 |
# |    clip_fraction        | 0.00549    |
# |    clip_range           | 0.279      |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 0.197      |
# |    learning_rate        | 0.000716   |
# |    loss                 | 0.251      |
# |    n_updates            | 126        |
# |    policy_gradient_loss | -0.000434  |
# |    std                  | 0.888      |
# |    value_loss           | 0.374      |
# ----------------------------------------
# Eval num_timesteps=20000000, episode_reward=21.23 +/- 5.17
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21.2         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0041370015 |
# |    clip_fraction        | 0.00387      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.26         |
# |    n_updates            | 133          |
# |    policy_gradient_loss | -0.000144    |
# |    std                  | 0.882        |
# |    value_loss           | 0.361        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 15.3     |
# | time/              |          |
# |    fps             | 45855    |
# |    iterations      | 20       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.8        |
# | time/                   |             |
# |    fps                  | 45852       |
# |    iterations           | 21          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 21000000    |
# | train/                  |             |
# |    approx_kl            | 0.002787246 |
# |    clip_fraction        | 0.00482     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.248       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -5.43e-05   |
# |    std                  | 0.877       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.6         |
# | time/                   |              |
# |    fps                  | 45770        |
# |    iterations           | 22           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030381458 |
# |    clip_fraction        | 0.00375      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.249        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -8.07e-05    |
# |    std                  | 0.872        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 45689       |
# |    iterations           | 23          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 23000000    |
# | train/                  |             |
# |    approx_kl            | 0.004095195 |
# |    clip_fraction        | 0.00844     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.268       |
# |    n_updates            | 154         |
# |    policy_gradient_loss | -7.68e-05   |
# |    std                  | 0.865       |
# |    value_loss           | 0.365       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 45499        |
# |    iterations           | 24           |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032556122 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.265        |
# |    n_updates            | 161          |
# |    policy_gradient_loss | -0.000196    |
# |    std                  | 0.858        |
# |    value_loss           | 0.365        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 45330       |
# |    iterations           | 25          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 25000000    |
# | train/                  |             |
# |    approx_kl            | 0.004122664 |
# |    clip_fraction        | 0.0064      |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.27        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000136   |
# |    std                  | 0.847       |
# |    value_loss           | 0.382       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16           |
# | time/                   |              |
# |    fps                  | 45249        |
# |    iterations           | 26           |
# |    time_elapsed         | 574          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024878206 |
# |    clip_fraction        | 0.00573      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.261        |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -9.74e-05    |
# |    std                  | 0.841        |
# |    value_loss           | 0.361        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 45188       |
# |    iterations           | 27          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 27000000    |
# | train/                  |             |
# |    approx_kl            | 0.002616681 |
# |    clip_fraction        | 0.00437     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.244       |
# |    n_updates            | 182         |
# |    policy_gradient_loss | -6.11e-05   |
# |    std                  | 0.832       |
# |    value_loss           | 0.358       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 45164        |
# |    iterations           | 28           |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028246173 |
# |    clip_fraction        | 0.00345      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.25         |
# |    n_updates            | 189          |
# |    policy_gradient_loss | -0.000102    |
# |    std                  | 0.824        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 45129        |
# |    iterations           | 29           |
# |    time_elapsed         | 642          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027504428 |
# |    clip_fraction        | 0.00443      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.243        |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -9.32e-05    |
# |    std                  | 0.81         |
# |    value_loss           | 0.361        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=20.14 +/- 5.44
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.1         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029367039 |
# |    clip_fraction        | 0.00511      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.264        |
# |    n_updates            | 203          |
# |    policy_gradient_loss | -0.000158    |
# |    std                  | 0.802        |
# |    value_loss           | 0.354        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.7     |
# | time/              |          |
# |    fps             | 44937    |
# |    iterations      | 30       |
# |    time_elapsed    | 667      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 44894       |
# |    iterations           | 31          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 31000000    |
# | train/                  |             |
# |    approx_kl            | 0.002944227 |
# |    clip_fraction        | 0.00185     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.251       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -9.03e-05   |
# |    std                  | 0.794       |
# |    value_loss           | 0.359       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 44889        |
# |    iterations           | 32           |
# |    time_elapsed         | 712          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022129836 |
# |    clip_fraction        | 0.00262      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.266        |
# |    n_updates            | 217          |
# |    policy_gradient_loss | -3.17e-05    |
# |    std                  | 0.785        |
# |    value_loss           | 0.376        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 44881        |
# |    iterations           | 33           |
# |    time_elapsed         | 735          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028811472 |
# |    clip_fraction        | 0.00414      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.258        |
# |    n_updates            | 224          |
# |    policy_gradient_loss | 9.59e-05     |
# |    std                  | 0.781        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 44838        |
# |    iterations           | 34           |
# |    time_elapsed         | 758          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033182115 |
# |    clip_fraction        | 0.00601      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.253        |
# |    n_updates            | 231          |
# |    policy_gradient_loss | -2.56e-06    |
# |    std                  | 0.773        |
# |    value_loss           | 0.372        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 44788        |
# |    iterations           | 35           |
# |    time_elapsed         | 781          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0035250774 |
# |    clip_fraction        | 0.00358      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.257        |
# |    n_updates            | 238          |
# |    policy_gradient_loss | -6.5e-05     |
# |    std                  | 0.764        |
# |    value_loss           | 0.364        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 16.3        |
# | time/                   |             |
# |    fps                  | 44754       |
# |    iterations           | 36          |
# |    time_elapsed         | 804         |
# |    total_timesteps      | 36000000    |
# | train/                  |             |
# |    approx_kl            | 0.004363241 |
# |    clip_fraction        | 0.00589     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.259       |
# |    n_updates            | 245         |
# |    policy_gradient_loss | -8.03e-05   |
# |    std                  | 0.754       |
# |    value_loss           | 0.369       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 44727       |
# |    iterations           | 37          |
# |    time_elapsed         | 827         |
# |    total_timesteps      | 37000000    |
# | train/                  |             |
# |    approx_kl            | 0.003286504 |
# |    clip_fraction        | 0.00563     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.257       |
# |    n_updates            | 252         |
# |    policy_gradient_loss | -3.71e-05   |
# |    std                  | 0.744       |
# |    value_loss           | 0.366       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 44693        |
# |    iterations           | 38           |
# |    time_elapsed         | 850          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022680974 |
# |    clip_fraction        | 0.00305      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.249        |
# |    n_updates            | 259          |
# |    policy_gradient_loss | -4.16e-05    |
# |    std                  | 0.743        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 44655        |
# |    iterations           | 39           |
# |    time_elapsed         | 873          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0035358241 |
# |    clip_fraction        | 0.0045       |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.264        |
# |    n_updates            | 266          |
# |    policy_gradient_loss | 2.82e-05     |
# |    std                  | 0.74         |
# |    value_loss           | 0.376        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.55 +/- 5.40
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 20.5        |
# | time/                   |             |
# |    total_timesteps      | 40000000    |
# | train/                  |             |
# |    approx_kl            | 0.004057877 |
# |    clip_fraction        | 0.00481     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.246       |
# |    n_updates            | 273         |
# |    policy_gradient_loss | -9.47e-05   |
# |    std                  | 0.734       |
# |    value_loss           | 0.358       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 44574    |
# |    iterations      | 40       |
# |    time_elapsed    | 897      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 44526       |
# |    iterations           | 41          |
# |    time_elapsed         | 920         |
# |    total_timesteps      | 41000000    |
# | train/                  |             |
# |    approx_kl            | 0.007969443 |
# |    clip_fraction        | 0.00816     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.257       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000177    |
# |    std                  | 0.727       |
# |    value_loss           | 0.367       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 44518        |
# |    iterations           | 42           |
# |    time_elapsed         | 943          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0044536926 |
# |    clip_fraction        | 0.00745      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.254        |
# |    n_updates            | 287          |
# |    policy_gradient_loss | 6.04e-05     |
# |    std                  | 0.718        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 44481        |
# |    iterations           | 43           |
# |    time_elapsed         | 966          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028990551 |
# |    clip_fraction        | 0.00377      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.256        |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -9.93e-05    |
# |    std                  | 0.718        |
# |    value_loss           | 0.358        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 44487        |
# |    iterations           | 44           |
# |    time_elapsed         | 989          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025137437 |
# |    clip_fraction        | 0.00385      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.257        |
# |    n_updates            | 301          |
# |    policy_gradient_loss | 1.8e-05      |
# |    std                  | 0.713        |
# |    value_loss           | 0.368        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.9         |
# | time/                   |              |
# |    fps                  | 44466        |
# |    iterations           | 45           |
# |    time_elapsed         | 1011         |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0037908342 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.242        |
# |    n_updates            | 308          |
# |    policy_gradient_loss | 0.000304     |
# |    std                  | 0.71         |
# |    value_loss           | 0.357        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 44441        |
# |    iterations           | 46           |
# |    time_elapsed         | 1035         |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033215387 |
# |    clip_fraction        | 0.00379      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.257        |
# |    n_updates            | 315          |
# |    policy_gradient_loss | -9.83e-05    |
# |    std                  | 0.706        |
# |    value_loss           | 0.365        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 44397        |
# |    iterations           | 47           |
# |    time_elapsed         | 1058         |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0037374145 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.259        |
# |    n_updates            | 322          |
# |    policy_gradient_loss | -8.71e-05    |
# |    std                  | 0.702        |
# |    value_loss           | 0.365        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 44370       |
# |    iterations           | 48          |
# |    time_elapsed         | 1081        |
# |    total_timesteps      | 48000000    |
# | train/                  |             |
# |    approx_kl            | 0.004516633 |
# |    clip_fraction        | 0.00477     |
# |    clip_range           | 0.279       |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.000716    |
# |    loss                 | 0.27        |
# |    n_updates            | 329         |
# |    policy_gradient_loss | -5.31e-05   |
# |    std                  | 0.696       |
# |    value_loss           | 0.377       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 44329        |
# |    iterations           | 49           |
# |    time_elapsed         | 1105         |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031310725 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.248        |
# |    n_updates            | 336          |
# |    policy_gradient_loss | 7.84e-05     |
# |    std                  | 0.696        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.39 +/- 5.70
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.4         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031923335 |
# |    clip_fraction        | 0.00818      |
# |    clip_range           | 0.279        |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.000716     |
# |    loss                 | 0.267        |
# |    n_updates            | 343          |
# |    policy_gradient_loss | 0.000105     |
# |    std                  | 0.693        |
# |    value_loss           | 0.372        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 17       |
# | time/              |          |
# |    fps             | 44239    |
# |    iterations      | 50       |
# |    time_elapsed    | 1130     |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.873256  19.739903  5.691088                    0.45
#
#          Std terminal inventory
# RL Agent                3.33009

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0]])
    else:
        state = np.array([[inventory,0.5,100]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  19.59445232923573
# median:  19.113762979531778
# std:  5.59766327277686

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/PPO_1/events.out.tfevents.1762073236.MacBookAir.lan.8340.1"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/PPO_1/events.out.tfevents.1762073236.MacBookAir.lan.8340.1"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/PPO_1/events.out.tfevents.1762073236.MacBookAir.lan.8340.1"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_Optuna_Best/2025-11-02_09-47-16/Training_process_rewards.png
