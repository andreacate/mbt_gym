# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 5
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 100
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x133017940>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x1353b69e0>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory     2.06632  21.487223  4.845374                  -0.095
#
#           Std terminal inventory
# Inventory               2.909291

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_prove_time_steps_100_100M"
# Paths with timestamp
tensorboard_logdir = f".././CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x13540e530>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)

n_epochs = 10
learning_rate = 3e-4
gae_lambda = 0.95
clip_range = 0.2
vf_coef = 0.5
max_grad_norm = 0.5

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }


#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

#callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999], [ 20.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to .././CJ_models/tensorboard/PPO-learning/CjMm_PPO_prove_time_steps_100_100M/2025-12-04_18-00-00/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 5.87     |
# | time/              |          |
# |    fps             | 345324   |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100000   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 6.78        |
# | time/                   |             |
# |    fps                  | 45711       |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 200000      |
# | train/                  |             |
# |    approx_kl            | 0.004264706 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.00711     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.777       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 1.02        |
# |    value_loss           | 1.91        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 7.07       |
# | time/                   |            |
# |    fps                  | 35501      |
# |    iterations           | 3          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 300000     |
# | train/                  |            |
# |    approx_kl            | 0.00425697 |
# |    clip_fraction        | 0.0322     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.159      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.908      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00221   |
# |    std                  | 1.03       |
# |    value_loss           | 2.15       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.81         |
# | time/                   |              |
# |    fps                  | 32554        |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 400000       |
# | train/                  |              |
# |    approx_kl            | 0.0040709088 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.936        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00252     |
# |    std                  | 1.04         |
# |    value_loss           | 2.17         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 7.85        |
# | time/                   |             |
# |    fps                  | 29650       |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 500000      |
# | train/                  |             |
# |    approx_kl            | 0.003607887 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.831       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 1.05        |
# |    value_loss           | 1.98        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 8.59         |
# | time/                   |              |
# |    fps                  | 28358        |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 600000       |
# | train/                  |              |
# |    approx_kl            | 0.0049308958 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.825        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00297     |
# |    std                  | 1.06         |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 9.59         |
# | time/                   |              |
# |    fps                  | 27546        |
# |    iterations           | 7            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 700000       |
# | train/                  |              |
# |    approx_kl            | 0.0044628438 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.813        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00227     |
# |    std                  | 1.06         |
# |    value_loss           | 1.88         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 9.83       |
# | time/                   |            |
# |    fps                  | 26644      |
# |    iterations           | 8          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 800000     |
# | train/                  |            |
# |    approx_kl            | 0.00467307 |
# |    clip_fraction        | 0.0339     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.528      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.751      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00269   |
# |    std                  | 1.07       |
# |    value_loss           | 1.79       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 26027       |
# |    iterations           | 9           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 900000      |
# | train/                  |             |
# |    approx_kl            | 0.004854612 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.768       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00262    |
# |    std                  | 1.07        |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 10.2        |
# | time/                   |             |
# |    fps                  | 25914       |
# |    iterations           | 10          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 1000000     |
# | train/                  |             |
# |    approx_kl            | 0.003990483 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.725       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00221    |
# |    std                  | 1.07        |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 25804       |
# |    iterations           | 11          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 1100000     |
# | train/                  |             |
# |    approx_kl            | 0.005100231 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.77        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00658     |
# |    std                  | 1.08        |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 25733        |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 1200000      |
# | train/                  |              |
# |    approx_kl            | 0.0039339233 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.99        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.761        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 1.08         |
# |    value_loss           | 1.79         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 25669        |
# |    iterations           | 13           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 1300000      |
# | train/                  |              |
# |    approx_kl            | 0.0027117971 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.762        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000774    |
# |    std                  | 1.09         |
# |    value_loss           | 1.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 25556        |
# |    iterations           | 14           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 1400000      |
# | train/                  |              |
# |    approx_kl            | 0.0055207764 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.767        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 1.09         |
# |    value_loss           | 1.85         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 25500       |
# |    iterations           | 15          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 1500000     |
# | train/                  |             |
# |    approx_kl            | 0.003366933 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.733       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00122    |
# |    std                  | 1.09        |
# |    value_loss           | 1.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 25458       |
# |    iterations           | 16          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.003749061 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.812       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00181    |
# |    std                  | 1.09        |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 25432       |
# |    iterations           | 17          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 1700000     |
# | train/                  |             |
# |    approx_kl            | 0.003751111 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.817       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 1.1         |
# |    value_loss           | 1.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 25401        |
# |    iterations           | 18           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 1800000      |
# | train/                  |              |
# |    approx_kl            | 0.0036215156 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.77         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 1.1          |
# |    value_loss           | 1.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 25341        |
# |    iterations           | 19           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 1900000      |
# | train/                  |              |
# |    approx_kl            | 0.0032799705 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.834        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.0041       |
# |    std                  | 1.1          |
# |    value_loss           | 1.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.8         |
# | time/                   |              |
# |    fps                  | 25304        |
# |    iterations           | 20           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007393962 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.751        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.000153     |
# |    std                  | 1.11         |
# |    value_loss           | 1.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 25260        |
# |    iterations           | 21           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 2100000      |
# | train/                  |              |
# |    approx_kl            | 0.0023558177 |
# |    clip_fraction        | 0.00994      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.737        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000652    |
# |    std                  | 1.11         |
# |    value_loss           | 1.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 25206        |
# |    iterations           | 22           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 2200000      |
# | train/                  |              |
# |    approx_kl            | 0.0022579504 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.758        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00643      |
# |    std                  | 1.11         |
# |    value_loss           | 1.83         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 25178        |
# |    iterations           | 23           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 2300000      |
# | train/                  |              |
# |    approx_kl            | 0.0051200786 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.755        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 1.11         |
# |    value_loss           | 1.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 25158       |
# |    iterations           | 24          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 2400000     |
# | train/                  |             |
# |    approx_kl            | 0.001132333 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.811       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -5.49e-05   |
# |    std                  | 1.12        |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 25142        |
# |    iterations           | 25           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 2500000      |
# | train/                  |              |
# |    approx_kl            | 0.0016303107 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.945        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000306    |
# |    std                  | 1.12         |
# |    value_loss           | 1.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 25129        |
# |    iterations           | 26           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 2600000      |
# | train/                  |              |
# |    approx_kl            | 0.0018436816 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.807        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.00109      |
# |    std                  | 1.13         |
# |    value_loss           | 1.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 25121        |
# |    iterations           | 27           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 2700000      |
# | train/                  |              |
# |    approx_kl            | 0.0009622979 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.829        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.0119       |
# |    std                  | 1.13         |
# |    value_loss           | 1.94         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 25109        |
# |    iterations           | 28           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 2800000      |
# | train/                  |              |
# |    approx_kl            | 0.0042204685 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.872        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 2.56e-05     |
# |    std                  | 1.13         |
# |    value_loss           | 2.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 25061        |
# |    iterations           | 29           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 2900000      |
# | train/                  |              |
# |    approx_kl            | 0.0014818453 |
# |    clip_fraction        | 0.0077       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.833        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -1.42e-05    |
# |    std                  | 1.14         |
# |    value_loss           | 1.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 25049        |
# |    iterations           | 30           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0018447252 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.852        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -7.01e-06    |
# |    std                  | 1.14         |
# |    value_loss           | 1.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 24920       |
# |    iterations           | 31          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 3100000     |
# | train/                  |             |
# |    approx_kl            | 0.004328291 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.803       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0131      |
# |    std                  | 1.15        |
# |    value_loss           | 1.9         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 24763        |
# |    iterations           | 32           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 3200000      |
# | train/                  |              |
# |    approx_kl            | 0.0022386883 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.793        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 2.52e-05     |
# |    std                  | 1.15         |
# |    value_loss           | 1.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.8         |
# | time/                   |              |
# |    fps                  | 24681        |
# |    iterations           | 33           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 3300000      |
# | train/                  |              |
# |    approx_kl            | 0.0019144036 |
# |    clip_fraction        | 0.00487      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.877        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 7.54e-05     |
# |    std                  | 1.15         |
# |    value_loss           | 1.99         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 14.3        |
# | time/                   |             |
# |    fps                  | 24577       |
# |    iterations           | 34          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 3400000     |
# | train/                  |             |
# |    approx_kl            | 0.053379524 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.831       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.022       |
# |    std                  | 1.16        |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 24573       |
# |    iterations           | 35          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 3500000     |
# | train/                  |             |
# |    approx_kl            | 0.001937416 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.931       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000408    |
# |    std                  | 1.17        |
# |    value_loss           | 2.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 24595       |
# |    iterations           | 36          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 3600000     |
# | train/                  |             |
# |    approx_kl            | 0.002751044 |
# |    clip_fraction        | 0.00903     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.907       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00012    |
# |    std                  | 1.17        |
# |    value_loss           | 2           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 24641        |
# |    iterations           | 37           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 3700000      |
# | train/                  |              |
# |    approx_kl            | 0.0011334938 |
# |    clip_fraction        | 0.00233      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.876        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -6.08e-06    |
# |    std                  | 1.18         |
# |    value_loss           | 1.96         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 24670        |
# |    iterations           | 38           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 3800000      |
# | train/                  |              |
# |    approx_kl            | 0.0005730624 |
# |    clip_fraction        | 0.00697      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.846        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000226     |
# |    std                  | 1.19         |
# |    value_loss           | 2.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 24717        |
# |    iterations           | 39           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 3900000      |
# | train/                  |              |
# |    approx_kl            | 0.0031185388 |
# |    clip_fraction        | 0.00868      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.747        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.9          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000427    |
# |    std                  | 1.19         |
# |    value_loss           | 2.07         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 24757       |
# |    iterations           | 40          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 4000000     |
# | train/                  |             |
# |    approx_kl            | 0.001605878 |
# |    clip_fraction        | 0.00225     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.863       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -7.9e-05    |
# |    std                  | 1.19        |
# |    value_loss           | 1.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 24760       |
# |    iterations           | 41          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 4100000     |
# | train/                  |             |
# |    approx_kl            | 0.003510448 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.867       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000297    |
# |    std                  | 1.2         |
# |    value_loss           | 2           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 24784        |
# |    iterations           | 42           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 4200000      |
# | train/                  |              |
# |    approx_kl            | 0.0008702036 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.862        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00114      |
# |    std                  | 1.2          |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 24823        |
# |    iterations           | 43           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 4300000      |
# | train/                  |              |
# |    approx_kl            | 0.0004096119 |
# |    clip_fraction        | 0.00424      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.21        |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.887        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000256     |
# |    std                  | 1.21         |
# |    value_loss           | 2.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 24836       |
# |    iterations           | 44          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 4400000     |
# | train/                  |             |
# |    approx_kl            | 0.001843128 |
# |    clip_fraction        | 0.00491     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.869       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 3.65e-05    |
# |    std                  | 1.21        |
# |    value_loss           | 2.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 24865        |
# |    iterations           | 45           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 4500000      |
# | train/                  |              |
# |    approx_kl            | 0.0014701736 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.864        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000591     |
# |    std                  | 1.22         |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 24892        |
# |    iterations           | 46           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 4600000      |
# | train/                  |              |
# |    approx_kl            | 0.0010437297 |
# |    clip_fraction        | 0.00745      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.872        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 3.44e-05     |
# |    std                  | 1.22         |
# |    value_loss           | 2.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 24922        |
# |    iterations           | 47           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 4700000      |
# | train/                  |              |
# |    approx_kl            | 0.0013900562 |
# |    clip_fraction        | 0.00572      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.747        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.922        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000202    |
# |    std                  | 1.22         |
# |    value_loss           | 2.03         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 24896        |
# |    iterations           | 48           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0020757546 |
# |    clip_fraction        | 0.00647      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.869        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000104    |
# |    std                  | 1.23         |
# |    value_loss           | 1.97         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 24925        |
# |    iterations           | 49           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 4900000      |
# | train/                  |              |
# |    approx_kl            | 0.0003841032 |
# |    clip_fraction        | 0.00224      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.875        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000163     |
# |    std                  | 1.23         |
# |    value_loss           | 2.05         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 24951        |
# |    iterations           | 50           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0021053012 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.854        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000677     |
# |    std                  | 1.24         |
# |    value_loss           | 1.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 24959        |
# |    iterations           | 51           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 5100000      |
# | train/                  |              |
# |    approx_kl            | 0.0037340913 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.818        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.000322     |
# |    std                  | 1.24         |
# |    value_loss           | 1.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 24978       |
# |    iterations           | 52          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 5200000     |
# | train/                  |             |
# |    approx_kl            | 0.002686363 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# ...
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 23360       |
# |    iterations           | 984         |
# |    time_elapsed         | 4212        |
# |    total_timesteps      | 98400000    |
# | train/                  |             |
# |    approx_kl            | 0.018779092 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.53        |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 9830        |
# |    policy_gradient_loss | 0.00598     |
# |    std                  | 0.0251      |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 23360       |
# |    iterations           | 985         |
# |    time_elapsed         | 4216        |
# |    total_timesteps      | 98500000    |
# | train/                  |             |
# |    approx_kl            | 0.012796405 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.54        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 9840        |
# |    policy_gradient_loss | 0.00791     |
# |    std                  | 0.025       |
# |    value_loss           | 2.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 23360       |
# |    iterations           | 986         |
# |    time_elapsed         | 4220        |
# |    total_timesteps      | 98600000    |
# | train/                  |             |
# |    approx_kl            | 0.009239725 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.55        |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 9850        |
# |    policy_gradient_loss | 0.00418     |
# |    std                  | 0.0248      |
# |    value_loss           | 2.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 23360        |
# |    iterations           | 987          |
# |    time_elapsed         | 4225         |
# |    total_timesteps      | 98700000     |
# | train/                  |              |
# |    approx_kl            | 0.0029134112 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 4.55         |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 9860         |
# |    policy_gradient_loss | 0.00934      |
# |    std                  | 0.0248       |
# |    value_loss           | 2.19         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 20.7       |
# | time/                   |            |
# |    fps                  | 23360      |
# |    iterations           | 988        |
# |    time_elapsed         | 4229       |
# |    total_timesteps      | 98800000   |
# | train/                  |            |
# |    approx_kl            | 0.00963598 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.56       |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07       |
# |    n_updates            | 9870       |
# |    policy_gradient_loss | 0.00915    |
# |    std                  | 0.0248     |
# |    value_loss           | 2.13       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 21.1       |
# | time/                   |            |
# |    fps                  | 23360      |
# |    iterations           | 989        |
# |    time_elapsed         | 4233       |
# |    total_timesteps      | 98900000   |
# | train/                  |            |
# |    approx_kl            | 0.01275005 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.56       |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 9880       |
# |    policy_gradient_loss | 0.00821    |
# |    std                  | 0.0247     |
# |    value_loss           | 2.23       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 21.2         |
# | time/                   |              |
# |    fps                  | 23359        |
# |    iterations           | 990          |
# |    time_elapsed         | 4238         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0059566973 |
# |    clip_fraction        | 0.0954       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 4.56         |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 9890         |
# |    policy_gradient_loss | 0.00347      |
# |    std                  | 0.0247       |
# |    value_loss           | 2.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 23360       |
# |    iterations           | 991         |
# |    time_elapsed         | 4242        |
# |    total_timesteps      | 99100000    |
# | train/                  |             |
# |    approx_kl            | 0.013109053 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.57        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 9900        |
# |    policy_gradient_loss | 0.00523     |
# |    std                  | 0.0246      |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 23360       |
# |    iterations           | 992         |
# |    time_elapsed         | 4246        |
# |    total_timesteps      | 99200000    |
# | train/                  |             |
# |    approx_kl            | 0.006908825 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.58        |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 9910        |
# |    policy_gradient_loss | 0.00565     |
# |    std                  | 0.0244      |
# |    value_loss           | 2.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 21.5       |
# | time/                   |            |
# |    fps                  | 23361      |
# |    iterations           | 993        |
# |    time_elapsed         | 4250       |
# |    total_timesteps      | 99300000   |
# | train/                  |            |
# |    approx_kl            | 0.06490709 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.59       |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07       |
# |    n_updates            | 9920       |
# |    policy_gradient_loss | 0.0117     |
# |    std                  | 0.0243     |
# |    value_loss           | 2.14       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 23361       |
# |    iterations           | 994         |
# |    time_elapsed         | 4254        |
# |    total_timesteps      | 99400000    |
# | train/                  |             |
# |    approx_kl            | 0.008081616 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.6         |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 9930        |
# |    policy_gradient_loss | 0.00623     |
# |    std                  | 0.0241      |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 23362       |
# |    iterations           | 995         |
# |    time_elapsed         | 4258        |
# |    total_timesteps      | 99500000    |
# | train/                  |             |
# |    approx_kl            | 0.008164389 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.62        |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 9940        |
# |    policy_gradient_loss | 0.0049      |
# |    std                  | 0.024       |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 23363       |
# |    iterations           | 996         |
# |    time_elapsed         | 4263        |
# |    total_timesteps      | 99600000    |
# | train/                  |             |
# |    approx_kl            | 0.013158257 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.63        |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 9950        |
# |    policy_gradient_loss | 0.00623     |
# |    std                  | 0.0239      |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 23362       |
# |    iterations           | 997         |
# |    time_elapsed         | 4267        |
# |    total_timesteps      | 99700000    |
# | train/                  |             |
# |    approx_kl            | 0.009734946 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.64        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 9960        |
# |    policy_gradient_loss | 0.0067      |
# |    std                  | 0.0238      |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 23363       |
# |    iterations           | 998         |
# |    time_elapsed         | 4271        |
# |    total_timesteps      | 99800000    |
# | train/                  |             |
# |    approx_kl            | 0.008570816 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.64        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 9970        |
# |    policy_gradient_loss | 0.00695     |
# |    std                  | 0.0238      |
# |    value_loss           | 2.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 21.1         |
# | time/                   |              |
# |    fps                  | 23363        |
# |    iterations           | 999          |
# |    time_elapsed         | 4275         |
# |    total_timesteps      | 99900000     |
# | train/                  |              |
# |    approx_kl            | 0.0071461527 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 4.65         |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 9980         |
# |    policy_gradient_loss | 0.0061       |
# |    std                  | 0.0237       |
# |    value_loss           | 2.22         |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=21.01 +/- 5.02
# Episode length: 100.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 100          |
# |    mean_reward          | 21           |
# | time/                   |              |
# |    total_timesteps      | 100000000    |
# | train/                  |              |
# |    approx_kl            | 0.0055519156 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 4.66         |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 9990         |
# |    policy_gradient_loss | 0.00682      |
# |    std                  | 0.0235       |
# |    value_loss           | 2.21         |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 21.4      |
# | time/              |           |
# |    fps             | 23363     |
# |    iterations      | 1000      |
# |    time_elapsed    | 4280      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Loading the model

# %%
# best_model_path = (
#     ".//CJ_models/PPO-best/CjMm_PPO_prove_time_steps_100/2025-12-03_10-29-45/best_model.zip"
# )

# model = PPO.load(best_model_path, env=sb_rl_env)

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
use_normalized_agent = False

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
#os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+04 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+04 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././CJ_models/PPO-best/CjMm_PPO_prove_time_steps_100_100M/2025-12-04_18-00-00/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
results_rl, fig, tot_rewards = generate_results_table_and_hist_rl_fast(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread  Mean PnL   Std PnL  PnL CI 95% low  PnL CI 95% high  \
# RL Agent     2.303401  21.22982  5.016091       20.918548        21.541092
#
#           Mean terminal inventory  Std terminal inventory
# RL Agent                   -1.371                2.891256

# %%
results_rl
# Out:
#           Mean spread  Mean PnL   Std PnL  PnL CI 95% low  PnL CI 95% high  \
# RL Agent     2.303401  21.22982  5.016091       20.918548        21.541092
#
#           Mean terminal inventory  Std terminal inventory
# RL Agent                   -1.371                2.891256

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././CJ_models/PPO-best/CjMm_PPO_prove_time_steps_100_100M/2025-12-04_18-00-00/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././CJ_models/PPO-best/CjMm_PPO_prove_time_steps_100_100M/2025-12-04_18-00-00/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
#       2 print('mean: ',np.mean(total_rewards))
#       3 print('median: ',np.median(total_rewards))
#
# NameError: name 'rewards_rl' is not defined

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"

# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_rollout_reward.png
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load the event file
event_file= "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_eval_reward.png
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# === Load rollout rewards ===
rollout_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_rewards.png
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
