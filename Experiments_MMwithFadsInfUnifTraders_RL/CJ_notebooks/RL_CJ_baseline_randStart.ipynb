# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16849b730>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16b3ab2b0>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065896  21.133681  4.809688                  -0.071
#
#           Std terminal inventory
# Inventory               3.106116

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = True,
                      normalise_observation_space = True,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = True

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_New_Baseline_50Msteps_NormaActionObs"
# Paths with timestamp
tensorboard_logdir = f".././CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(-1.0, 1.0, (2,), float32)
# [-1. -1.] [1. 1.]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x16b4b02b0>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[128, 128], vf=[128, 128])]
)

n_epochs = 5
learning_rate = 3e-5
gae_lambda = 0.95
clip_range = 0.1
vf_coef = 0.5
max_grad_norm = 0.2

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box(-1.0, 1.0, (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to .././CJ_models/tensorboard/PPO-learning/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.14     |
# | time/              |          |
# |    fps             | 564440   |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.07          |
# | time/                   |               |
# |    fps                  | 158249        |
# |    iterations           | 2             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 2000000       |
# | train/                  |               |
# |    approx_kl            | 0.00011198434 |
# |    clip_fraction        | 2e-07         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0602        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.113         |
# |    n_updates            | 5             |
# |    policy_gradient_loss | -2.97e-05     |
# |    std                  | 0.999         |
# |    value_loss           | 0.235         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.73         |
# | time/                   |              |
# |    fps                  | 128188       |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 9.884861e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0508       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.111        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -2.68e-05    |
# |    std                  | 0.997        |
# |    value_loss           | 0.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.28         |
# | time/                   |              |
# |    fps                  | 113984       |
# |    iterations           | 4            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 6.424024e-05 |
# |    clip_fraction        | 2e-07        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0415       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.115        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -2.01e-05    |
# |    std                  | 0.996        |
# |    value_loss           | 0.233        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.95          |
# | time/                   |               |
# |    fps                  | 109709        |
# |    iterations           | 5             |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 5000000       |
# | train/                  |               |
# |    approx_kl            | 0.00013292236 |
# |    clip_fraction        | 1.2e-06       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.039         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.11          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -3.4e-05      |
# |    std                  | 0.995         |
# |    value_loss           | 0.224         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.71          |
# | time/                   |               |
# |    fps                  | 107307        |
# |    iterations           | 6             |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 6000000       |
# | train/                  |               |
# |    approx_kl            | 5.2382256e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.0396        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.116         |
# |    n_updates            | 25            |
# |    policy_gradient_loss | -2e-05        |
# |    std                  | 0.993         |
# |    value_loss           | 0.229         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.44        |
# | time/                   |             |
# |    fps                  | 105996      |
# |    iterations           | 7           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 1.24044e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0399      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.118       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -1.04e-05   |
# |    std                  | 0.992       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1e+03          |
# |    ep_rew_mean          | 8.54           |
# | time/                   |                |
# |    fps                  | 104468         |
# |    iterations           | 8              |
# |    time_elapsed         | 76             |
# |    total_timesteps      | 8000000        |
# | train/                  |                |
# |    approx_kl            | 0.000115874616 |
# |    clip_fraction        | 6e-07          |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -2.82          |
# |    explained_variance   | 0.0421         |
# |    learning_rate        | 3e-05          |
# |    loss                 | 0.119          |
# |    n_updates            | 35             |
# |    policy_gradient_loss | -2.95e-05      |
# |    std                  | 0.991          |
# |    value_loss           | 0.236          |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.95          |
# | time/                   |               |
# |    fps                  | 103822        |
# |    iterations           | 9             |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 9000000       |
# | train/                  |               |
# |    approx_kl            | 0.00012540339 |
# |    clip_fraction        | 2e-07         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.0424        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.118         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -3.03e-05     |
# |    std                  | 0.989         |
# |    value_loss           | 0.232         |
# -------------------------------------------
# Eval num_timesteps=10000000, episode_reward=14.13 +/- 5.84
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 14.1          |
# | time/                   |               |
# |    total_timesteps      | 10000000      |
# | train/                  |               |
# |    approx_kl            | 6.9517395e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.0444        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.113         |
# |    n_updates            | 45            |
# |    policy_gradient_loss | -1.93e-05     |
# |    std                  | 0.988         |
# |    value_loss           | 0.229         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.38     |
# | time/              |          |
# |    fps             | 101930   |
# |    iterations      | 10       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.76          |
# | time/                   |               |
# |    fps                  | 101451        |
# |    iterations           | 11            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 11000000      |
# | train/                  |               |
# |    approx_kl            | 0.00018556815 |
# |    clip_fraction        | 2.4e-06       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.0454        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.113         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -3.86e-05     |
# |    std                  | 0.987         |
# |    value_loss           | 0.229         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.49          |
# | time/                   |               |
# |    fps                  | 100926        |
# |    iterations           | 12            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 12000000      |
# | train/                  |               |
# |    approx_kl            | 3.7012713e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.0469        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.119         |
# |    n_updates            | 55            |
# |    policy_gradient_loss | -1.18e-05     |
# |    std                  | 0.986         |
# |    value_loss           | 0.235         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.65          |
# | time/                   |               |
# |    fps                  | 100822        |
# |    iterations           | 13            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 13000000      |
# | train/                  |               |
# |    approx_kl            | 6.2004125e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.0526        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.112         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -1.78e-05     |
# |    std                  | 0.984         |
# |    value_loss           | 0.226         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.64         |
# | time/                   |              |
# |    fps                  | 100530       |
# |    iterations           | 14           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 9.407679e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0542       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.112        |
# |    n_updates            | 65           |
# |    policy_gradient_loss | -7.62e-06    |
# |    std                  | 0.983        |
# |    value_loss           | 0.226        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.26          |
# | time/                   |               |
# |    fps                  | 100348        |
# |    iterations           | 15            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 15000000      |
# | train/                  |               |
# |    approx_kl            | 9.4896735e-05 |
# |    clip_fraction        | 2e-07         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 0.0574        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.119         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -1.91e-05     |
# |    std                  | 0.982         |
# |    value_loss           | 0.234         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.62          |
# | time/                   |               |
# |    fps                  | 100296        |
# |    iterations           | 16            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 16000000      |
# | train/                  |               |
# |    approx_kl            | 0.00010479294 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 0.0628        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.111         |
# |    n_updates            | 75            |
# |    policy_gradient_loss | -2.18e-05     |
# |    std                  | 0.981         |
# |    value_loss           | 0.222         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.66         |
# | time/                   |              |
# |    fps                  | 100138       |
# |    iterations           | 17           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 8.095563e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.116        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -1.72e-05    |
# |    std                  | 0.979        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.42          |
# | time/                   |               |
# |    fps                  | 100000        |
# |    iterations           | 18            |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 18000000      |
# | train/                  |               |
# |    approx_kl            | 0.00013711113 |
# |    clip_fraction        | 2e-07         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.0635        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.12          |
# |    n_updates            | 85            |
# |    policy_gradient_loss | -2.84e-05     |
# |    std                  | 0.978         |
# |    value_loss           | 0.238         |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1e+03          |
# |    ep_rew_mean          | 7.87           |
# | time/                   |                |
# |    fps                  | 99996          |
# |    iterations           | 19             |
# |    time_elapsed         | 190            |
# |    total_timesteps      | 19000000       |
# | train/                  |                |
# |    approx_kl            | 1.12996395e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -2.79          |
# |    explained_variance   | 0.0672         |
# |    learning_rate        | 3e-05          |
# |    loss                 | 0.123          |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -1.11e-05      |
# |    std                  | 0.976          |
# |    value_loss           | 0.246          |
# --------------------------------------------
# Eval num_timesteps=20000000, episode_reward=16.05 +/- 5.89
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 16.1          |
# | time/                   |               |
# |    total_timesteps      | 20000000      |
# | train/                  |               |
# |    approx_kl            | 1.4768482e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.0769        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.113         |
# |    n_updates            | 95            |
# |    policy_gradient_loss | -1.3e-05      |
# |    std                  | 0.975         |
# |    value_loss           | 0.229         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.01     |
# | time/              |          |
# |    fps             | 99310    |
# |    iterations      | 20       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.7           |
# | time/                   |               |
# |    fps                  | 99330         |
# |    iterations           | 21            |
# |    time_elapsed         | 211           |
# |    total_timesteps      | 21000000      |
# | train/                  |               |
# |    approx_kl            | 1.7812477e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.0735        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.118         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -1.32e-05     |
# |    std                  | 0.974         |
# |    value_loss           | 0.236         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.13         |
# | time/                   |              |
# |    fps                  | 99300        |
# |    iterations           | 22           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 7.556136e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.0758       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -2.5e-05     |
# |    std                  | 0.972        |
# |    value_loss           | 0.235        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.71          |
# | time/                   |               |
# |    fps                  | 99247         |
# |    iterations           | 23            |
# |    time_elapsed         | 231           |
# |    total_timesteps      | 23000000      |
# | train/                  |               |
# |    approx_kl            | 3.5526835e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.0712        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.117         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -1.17e-05     |
# |    std                  | 0.971         |
# |    value_loss           | 0.237         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.09         |
# | time/                   |              |
# |    fps                  | 99182        |
# |    iterations           | 24           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 6.763404e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.0771       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.124        |
# |    n_updates            | 115          |
# |    policy_gradient_loss | -4.85e-06    |
# |    std                  | 0.97         |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.27         |
# | time/                   |              |
# |    fps                  | 99054        |
# |    iterations           | 25           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 8.453338e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.081        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -1.97e-05    |
# |    std                  | 0.969        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.58          |
# | time/                   |               |
# |    fps                  | 98997         |
# |    iterations           | 26            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 26000000      |
# | train/                  |               |
# |    approx_kl            | 0.00014174644 |
# |    clip_fraction        | 1.6e-06       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.082         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.117         |
# |    n_updates            | 125           |
# |    policy_gradient_loss | -2.47e-05     |
# |    std                  | 0.968         |
# |    value_loss           | 0.236         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.29          |
# | time/                   |               |
# |    fps                  | 98942         |
# |    iterations           | 27            |
# |    time_elapsed         | 272           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00010284347 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.0877        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.114         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -1.66e-05     |
# |    std                  | 0.967         |
# |    value_loss           | 0.227         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.12         |
# | time/                   |              |
# |    fps                  | 98906        |
# |    iterations           | 28           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0001628861 |
# |    clip_fraction        | 1.4e-06      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0865       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -2.84e-05    |
# |    std                  | 0.965        |
# |    value_loss           | 0.234        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.02        |
# | time/                   |             |
# |    fps                  | 98768       |
# |    iterations           | 29          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 29000000    |
# | train/                  |             |
# |    approx_kl            | 8.16094e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.087       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.119       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -1.69e-05   |
# |    std                  | 0.964       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# Eval num_timesteps=30000000, episode_reward=16.07 +/- 5.78
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 16.1          |
# | time/                   |               |
# |    total_timesteps      | 30000000      |
# | train/                  |               |
# |    approx_kl            | 1.3295734e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.76         |
# |    explained_variance   | 0.0949        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.114         |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -9.84e-06     |
# |    std                  | 0.963         |
# |    value_loss           | 0.232         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.11     |
# | time/              |          |
# |    fps             | 98318    |
# |    iterations      | 30       |
# |    time_elapsed    | 305      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.29         |
# | time/                   |              |
# |    fps                  | 98261        |
# |    iterations           | 31           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 8.763195e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.0952       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -2e-05       |
# |    std                  | 0.962        |
# |    value_loss           | 0.232        |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1e+03          |
# |    ep_rew_mean          | 7.27           |
# | time/                   |                |
# |    fps                  | 98211          |
# |    iterations           | 32             |
# |    time_elapsed         | 325            |
# |    total_timesteps      | 32000000       |
# | train/                  |                |
# |    approx_kl            | 1.22667825e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -2.76          |
# |    explained_variance   | 0.09           |
# |    learning_rate        | 3e-05          |
# |    loss                 | 0.121          |
# |    n_updates            | 155            |
# |    policy_gradient_loss | -8.21e-06      |
# |    std                  | 0.961          |
# |    value_loss           | 0.243          |
# --------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.37        |
# | time/                   |             |
# |    fps                  | 98196       |
# |    iterations           | 33          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 33000000    |
# | train/                  |             |
# |    approx_kl            | 0.000272692 |
# |    clip_fraction        | 2.18e-05    |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.0913      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.115       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -3.48e-05   |
# |    std                  | 0.96        |
# |    value_loss           | 0.232       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.76         |
# | time/                   |              |
# |    fps                  | 98081        |
# |    iterations           | 34           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 6.178146e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.0894       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -1.71e-05    |
# |    std                  | 0.958        |
# |    value_loss           | 0.236        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.13          |
# | time/                   |               |
# |    fps                  | 97884         |
# |    iterations           | 35            |
# |    time_elapsed         | 357           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00010361754 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.0882        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.119         |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -2.37e-05     |
# |    std                  | 0.957         |
# |    value_loss           | 0.239         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.97         |
# | time/                   |              |
# |    fps                  | 97772        |
# |    iterations           | 36           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 6.185954e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.0855       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.119        |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -1.23e-05    |
# |    std                  | 0.956        |
# |    value_loss           | 0.238        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.99          |
# | time/                   |               |
# |    fps                  | 97717         |
# |    iterations           | 37            |
# |    time_elapsed         | 378           |
# |    total_timesteps      | 37000000      |
# | train/                  |               |
# |    approx_kl            | 9.7009535e-05 |
# |    clip_fraction        | 2.6e-06       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.0849        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.12          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -2.41e-05     |
# |    std                  | 0.955         |
# |    value_loss           | 0.238         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.28          |
# | time/                   |               |
# |    fps                  | 97627         |
# |    iterations           | 38            |
# |    time_elapsed         | 389           |
# |    total_timesteps      | 38000000      |
# | train/                  |               |
# |    approx_kl            | 3.4900328e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.0859        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.12          |
# |    n_updates            | 185           |
# |    policy_gradient_loss | -1.68e-05     |
# |    std                  | 0.953         |
# |    value_loss           | 0.24          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.76         |
# | time/                   |              |
# |    fps                  | 97582        |
# |    iterations           | 39           |
# |    time_elapsed         | 399          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 7.882249e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0834       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.122        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -6.94e-06    |
# |    std                  | 0.952        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=16.48 +/- 5.41
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 16.5          |
# | time/                   |               |
# |    total_timesteps      | 40000000      |
# | train/                  |               |
# |    approx_kl            | 3.6693902e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.0869        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.115         |
# |    n_updates            | 195           |
# |    policy_gradient_loss | -1.1e-05      |
# |    std                  | 0.951         |
# |    value_loss           | 0.234         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.24     |
# | time/              |          |
# |    fps             | 97242    |
# |    iterations      | 40       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.76         |
# | time/                   |              |
# |    fps                  | 97225        |
# |    iterations           | 41           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 3.870522e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0857       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.12         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -1.16e-05    |
# |    std                  | 0.95         |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.99          |
# | time/                   |               |
# |    fps                  | 97216         |
# |    iterations           | 42            |
# |    time_elapsed         | 432           |
# |    total_timesteps      | 42000000      |
# | train/                  |               |
# |    approx_kl            | 2.4574623e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.0909        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.118         |
# |    n_updates            | 205           |
# |    policy_gradient_loss | -1.08e-05     |
# |    std                  | 0.949         |
# |    value_loss           | 0.238         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.42          |
# | time/                   |               |
# |    fps                  | 97181         |
# |    iterations           | 43            |
# |    time_elapsed         | 442           |
# |    total_timesteps      | 43000000      |
# | train/                  |               |
# |    approx_kl            | 2.8313525e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.0944        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.117         |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -1.03e-05     |
# |    std                  | 0.948         |
# |    value_loss           | 0.232         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.21         |
# | time/                   |              |
# |    fps                  | 97099        |
# |    iterations           | 44           |
# |    time_elapsed         | 453          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 3.414715e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0942       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.121        |
# |    n_updates            | 215          |
# |    policy_gradient_loss | -1.18e-05    |
# |    std                  | 0.946        |
# |    value_loss           | 0.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.96         |
# | time/                   |              |
# |    fps                  | 97078        |
# |    iterations           | 45           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 4.642589e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.096        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.118        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -1.1e-05     |
# |    std                  | 0.945        |
# |    value_loss           | 0.236        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.79         |
# | time/                   |              |
# |    fps                  | 97062        |
# |    iterations           | 46           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 9.712211e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -6.09e-06    |
# |    std                  | 0.944        |
# |    value_loss           | 0.235        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.98         |
# | time/                   |              |
# |    fps                  | 97039        |
# |    iterations           | 47           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 5.482012e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.0965       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.117        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -1.82e-05    |
# |    std                  | 0.943        |
# |    value_loss           | 0.234        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.21         |
# | time/                   |              |
# |    fps                  | 97018        |
# |    iterations           | 48           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 4.963244e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.0956       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.12         |
# |    n_updates            | 235          |
# |    policy_gradient_loss | -1.35e-05    |
# |    std                  | 0.942        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.49          |
# | time/                   |               |
# |    fps                  | 96759         |
# |    iterations           | 49            |
# |    time_elapsed         | 506           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 1.0819552e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.72         |
# |    explained_variance   | 0.0938        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.121         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -1.04e-05     |
# |    std                  | 0.941         |
# |    value_loss           | 0.244         |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=16.49 +/- 5.86
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 16.5         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0002391672 |
# |    clip_fraction        | 2.06e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.0947       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.115        |
# |    n_updates            | 245          |
# |    policy_gradient_loss | -2.69e-05    |
# |    std                  | 0.939        |
# |    value_loss           | 0.233        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.15     |
# | time/              |          |
# |    fps             | 96452    |
# |    iterations      | 50       |
# |    time_elapsed    | 518      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent     1.58381  19.940361  5.127717                  -0.581
#
#          Std terminal inventory
# RL Agent               5.178942

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(-1.0, 1.0, (2,), float32)
# Low bounds: [-1. -1.]
# High bounds: [1. 1.]
#
# Original Trading Environment Action Space:
# Shape: Box(-1.0, 1.0, (2,), float32)
# Low bounds: [-1. -1.]
# High bounds: [1. 1.]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0]])
    else:
        state = np.array([[inventory,0.5,100]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

        # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.01408451149459
# median:  20.068329799997123
# std:  5.26950933968977

# %%
# Load the event file
event_file = ".././CJ_models/tensorboard/PPO-learning/CjMm_New_Baseline_50Msteps/2025-11-16_10-09-35/PPO_1/events.out.tfevents.1763284176.MacBookAir.lan.26982.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = ".././CJ_models/tensorboard/PPO-learning/CjMm_New_Baseline_50Msteps/2025-11-16_10-09-35/PPO_1/events.out.tfevents.1763284176.MacBookAir.lan.26982.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = ".././CJ_models/tensorboard/PPO-learning/CjMm_New_Baseline_50Msteps/2025-11-16_10-09-35/PPO_1/events.out.tfevents.1763284176.MacBookAir.lan.26982.0"
# Load the data
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././CJ_models/PPO-best/CjMm_New_Baseline_50Msteps_NormaActionObs/2025-11-17_13-41-08/Training_process_rewards.png
