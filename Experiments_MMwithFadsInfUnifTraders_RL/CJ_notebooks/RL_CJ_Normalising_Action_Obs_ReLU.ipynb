# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 1
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x1530ab010>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x154dbdd80>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065891  20.955802  4.978397                   0.155
#
#           Std terminal inventory
# Inventory               3.186059

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = True,
                      normalise_observation_space = True,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
#aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# Before normalization self.action_space.low [0. 0.]
# Before normalization self.action_space.high [4.6051702 4.6051702]

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_50_000_000steps_NormalisedActionObs"
# Paths with timestamp
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(-1.0, 1.0, (2,), float32)
# [-1. -1.] [1. 1.]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x153109f60>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box(-1.0, 1.0, (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.11     |
# | time/              |          |
# |    fps             | 393861   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.7          |
# | time/                   |              |
# |    fps                  | 108421       |
# |    iterations           | 2            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0014930362 |
# |    clip_fraction        | 0.00139      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00379      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -9.79e-05    |
# |    std                  | 0.993        |
# |    value_loss           | 0.236        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.22         |
# | time/                   |              |
# |    fps                  | 88384        |
# |    iterations           | 3            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0016678122 |
# |    clip_fraction        | 0.000757     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.00367      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -9.05e-05    |
# |    std                  | 0.986        |
# |    value_loss           | 0.231        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.25         |
# | time/                   |              |
# |    fps                  | 79414        |
# |    iterations           | 4            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0004577064 |
# |    clip_fraction        | 2.3e-05      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.00327      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -4.36e-05    |
# |    std                  | 0.98         |
# |    value_loss           | 0.242        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.19         |
# | time/                   |              |
# |    fps                  | 76301        |
# |    iterations           | 5            |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0022574007 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.00429      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000106    |
# |    std                  | 0.971        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.51         |
# | time/                   |              |
# |    fps                  | 74541        |
# |    iterations           | 6            |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0021218196 |
# |    clip_fraction        | 0.0019       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.00979      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000109    |
# |    std                  | 0.965        |
# |    value_loss           | 0.238        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.78        |
# | time/                   |             |
# |    fps                  | 73889       |
# |    iterations           | 7           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.001418469 |
# |    clip_fraction        | 0.00164     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.000113   |
# |    std                  | 0.959       |
# |    value_loss           | 0.225       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.84         |
# | time/                   |              |
# |    fps                  | 72930        |
# |    iterations           | 8            |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0005921266 |
# |    clip_fraction        | 9.7e-05      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.019        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.112        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -9.27e-05    |
# |    std                  | 0.95         |
# |    value_loss           | 0.227        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.66        |
# | time/                   |             |
# |    fps                  | 72505       |
# |    iterations           | 9           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.002408566 |
# |    clip_fraction        | 0.00217     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.000109   |
# |    std                  | 0.941       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=17.01 +/- 6.30
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 17           |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013483516 |
# |    clip_fraction        | 0.000422     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.0291       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -5.94e-05    |
# |    std                  | 0.934        |
# |    value_loss           | 0.239        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.5      |
# | time/              |          |
# |    fps             | 71089    |
# |    iterations      | 10       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.84         |
# | time/                   |              |
# |    fps                  | 70919        |
# |    iterations           | 11           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013455793 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.0387       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -9.33e-05    |
# |    std                  | 0.928        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.06         |
# | time/                   |              |
# |    fps                  | 70697        |
# |    iterations           | 12           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014472974 |
# |    clip_fraction        | 0.000593     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.0486       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -8.38e-05    |
# |    std                  | 0.92         |
# |    value_loss           | 0.237        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.97          |
# | time/                   |               |
# |    fps                  | 70633         |
# |    iterations           | 13            |
# |    time_elapsed         | 184           |
# |    total_timesteps      | 13000000      |
# | train/                  |               |
# |    approx_kl            | 0.00025058593 |
# |    clip_fraction        | 1.33e-06      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.66         |
# |    explained_variance   | 0.0559        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.121         |
# |    n_updates            | 36            |
# |    policy_gradient_loss | -4.56e-05     |
# |    std                  | 0.912         |
# |    value_loss           | 0.244         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.71         |
# | time/                   |              |
# |    fps                  | 70335        |
# |    iterations           | 14           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020855512 |
# |    clip_fraction        | 0.0025       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.0608       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -7.98e-05    |
# |    std                  | 0.907        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.95          |
# | time/                   |               |
# |    fps                  | 70182         |
# |    iterations           | 15            |
# |    time_elapsed         | 213           |
# |    total_timesteps      | 15000000      |
# | train/                  |               |
# |    approx_kl            | 0.00064326974 |
# |    clip_fraction        | 4.7e-05       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.64         |
# |    explained_variance   | 0.07          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.119         |
# |    n_updates            | 42            |
# |    policy_gradient_loss | -6.44e-05     |
# |    std                  | 0.9           |
# |    value_loss           | 0.238         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.48         |
# | time/                   |              |
# |    fps                  | 69842        |
# |    iterations           | 16           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015411522 |
# |    clip_fraction        | 0.00144      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.0731       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000119    |
# |    std                  | 0.893        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.58         |
# | time/                   |              |
# |    fps                  | 69585        |
# |    iterations           | 17           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014174682 |
# |    clip_fraction        | 0.00104      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.0771       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -9.8e-05     |
# |    std                  | 0.887        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.29         |
# | time/                   |              |
# |    fps                  | 69336        |
# |    iterations           | 18           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019380001 |
# |    clip_fraction        | 0.00164      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.0787       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -9.81e-05    |
# |    std                  | 0.879        |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.81        |
# | time/                   |             |
# |    fps                  | 69113       |
# |    iterations           | 19          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 19000000    |
# | train/                  |             |
# |    approx_kl            | 0.001801917 |
# |    clip_fraction        | 0.000802    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -6.05e-05   |
# |    std                  | 0.873       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# Eval num_timesteps=20000000, episode_reward=17.79 +/- 5.91
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 17.8         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017081574 |
# |    clip_fraction        | 0.00217      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.0868       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.00015     |
# |    std                  | 0.867        |
# |    value_loss           | 0.252        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.94     |
# | time/              |          |
# |    fps             | 68192    |
# |    iterations      | 20       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.78         |
# | time/                   |              |
# |    fps                  | 67880        |
# |    iterations           | 21           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013627907 |
# |    clip_fraction        | 0.000973     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.0835       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -6.21e-05    |
# |    std                  | 0.862        |
# |    value_loss           | 0.241        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 9.61        |
# | time/                   |             |
# |    fps                  | 67731       |
# |    iterations           | 22          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 22000000    |
# | train/                  |             |
# |    approx_kl            | 0.000834328 |
# |    clip_fraction        | 0.000196    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.0866      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -5.81e-05   |
# |    std                  | 0.856       |
# |    value_loss           | 0.237       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.17         |
# | time/                   |              |
# |    fps                  | 67580        |
# |    iterations           | 23           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015961124 |
# |    clip_fraction        | 0.00123      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.0899       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.0001      |
# |    std                  | 0.85         |
# |    value_loss           | 0.247        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.67         |
# | time/                   |              |
# |    fps                  | 67639        |
# |    iterations           | 24           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015853967 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.0904       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -7.52e-05    |
# |    std                  | 0.844        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.89         |
# | time/                   |              |
# |    fps                  | 67698        |
# |    iterations           | 25           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013159583 |
# |    clip_fraction        | 0.000393     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.0991       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -7.77e-05    |
# |    std                  | 0.837        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 9.76        |
# | time/                   |             |
# |    fps                  | 67726       |
# |    iterations           | 26          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 26000000    |
# | train/                  |             |
# |    approx_kl            | 0.002094458 |
# |    clip_fraction        | 0.002       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.0998      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.000106   |
# |    std                  | 0.832       |
# |    value_loss           | 0.239       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.4          |
# | time/                   |              |
# |    fps                  | 67761        |
# |    iterations           | 27           |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020173113 |
# |    clip_fraction        | 0.00295      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.0992       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.000219    |
# |    std                  | 0.826        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 67641        |
# |    iterations           | 28           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021665727 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -9.85e-05    |
# |    std                  | 0.821        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.33          |
# | time/                   |               |
# |    fps                  | 67644         |
# |    iterations           | 29            |
# |    time_elapsed         | 428           |
# |    total_timesteps      | 29000000      |
# | train/                  |               |
# |    approx_kl            | 0.00075251213 |
# |    clip_fraction        | 0.000192      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.44         |
# |    explained_variance   | 0.111         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.117         |
# |    n_updates            | 84            |
# |    policy_gradient_loss | -6.29e-05     |
# |    std                  | 0.814         |
# |    value_loss           | 0.235         |
# -------------------------------------------
# Eval num_timesteps=30000000, episode_reward=17.34 +/- 5.70
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 17.3         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009872678 |
# |    clip_fraction        | 0.000305     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -6.26e-05    |
# |    std                  | 0.807        |
# |    value_loss           | 0.238        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.7     |
# | time/              |          |
# |    fps             | 67442    |
# |    iterations      | 30       |
# |    time_elapsed    | 444      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.36         |
# | time/                   |              |
# |    fps                  | 67518        |
# |    iterations           | 31           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016406312 |
# |    clip_fraction        | 0.00115      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -7.93e-05    |
# |    std                  | 0.801        |
# |    value_loss           | 0.247        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.91         |
# | time/                   |              |
# |    fps                  | 67491        |
# |    iterations           | 32           |
# |    time_elapsed         | 474          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010060004 |
# |    clip_fraction        | 0.000268     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -7.59e-05    |
# |    std                  | 0.794        |
# |    value_loss           | 0.233        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 67530        |
# |    iterations           | 33           |
# |    time_elapsed         | 488          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008945075 |
# |    clip_fraction        | 0.000838     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -8.96e-05    |
# |    std                  | 0.787        |
# |    value_loss           | 0.242        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.72         |
# | time/                   |              |
# |    fps                  | 67570        |
# |    iterations           | 34           |
# |    time_elapsed         | 503          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013621158 |
# |    clip_fraction        | 0.000894     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -9.89e-05    |
# |    std                  | 0.782        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.46         |
# | time/                   |              |
# |    fps                  | 67552        |
# |    iterations           | 35           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0003598724 |
# |    clip_fraction        | 1.23e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -6.44e-05    |
# |    std                  | 0.775        |
# |    value_loss           | 0.239        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.2          |
# | time/                   |               |
# |    fps                  | 67548         |
# |    iterations           | 36            |
# |    time_elapsed         | 532           |
# |    total_timesteps      | 36000000      |
# | train/                  |               |
# |    approx_kl            | 0.00088705437 |
# |    clip_fraction        | 0.000648      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.32         |
# |    explained_variance   | 0.106         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.125         |
# |    n_updates            | 105           |
# |    policy_gradient_loss | -8.81e-05     |
# |    std                  | 0.768         |
# |    value_loss           | 0.253         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 67608        |
# |    iterations           | 37           |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013184876 |
# |    clip_fraction        | 0.00214      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000145    |
# |    std                  | 0.761        |
# |    value_loss           | 0.241        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.62         |
# | time/                   |              |
# |    fps                  | 67617        |
# |    iterations           | 38           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019871949 |
# |    clip_fraction        | 0.00104      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -8.08e-05    |
# |    std                  | 0.755        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.7         |
# | time/                   |              |
# |    fps                  | 67658        |
# |    iterations           | 39           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017511193 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.117        |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -8.23e-05    |
# |    std                  | 0.749        |
# |    value_loss           | 0.235        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=18.33 +/- 5.66
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 18.3          |
# | time/                   |               |
# |    total_timesteps      | 40000000      |
# | train/                  |               |
# |    approx_kl            | 0.00046136306 |
# |    clip_fraction        | 0.000174      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.25         |
# |    explained_variance   | 0.126         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.127         |
# |    n_updates            | 117           |
# |    policy_gradient_loss | -3.07e-05     |
# |    std                  | 0.744         |
# |    value_loss           | 0.252         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.6     |
# | time/              |          |
# |    fps             | 67434    |
# |    iterations      | 40       |
# |    time_elapsed    | 593      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 60313        |
# |    iterations           | 41           |
# |    time_elapsed         | 679          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014632419 |
# |    clip_fraction        | 0.000571     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -5.88e-05    |
# |    std                  | 0.739        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 60273        |
# |    iterations           | 42           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016643504 |
# |    clip_fraction        | 0.00125      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -7.65e-05    |
# |    std                  | 0.734        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 60329        |
# |    iterations           | 43           |
# |    time_elapsed         | 712          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015003205 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 126          |
# |    policy_gradient_loss | -9.39e-05    |
# |    std                  | 0.728        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 60547        |
# |    iterations           | 44           |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013647138 |
# |    clip_fraction        | 0.000763     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -0.000111    |
# |    std                  | 0.722        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.5          |
# | time/                   |               |
# |    fps                  | 60746         |
# |    iterations           | 45            |
# |    time_elapsed         | 740           |
# |    total_timesteps      | 45000000      |
# | train/                  |               |
# |    approx_kl            | 0.00077977905 |
# |    clip_fraction        | 0.000423      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.18         |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.127         |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -7.4e-05      |
# |    std                  | 0.717         |
# |    value_loss           | 0.258         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 60970        |
# |    iterations           | 46           |
# |    time_elapsed         | 754          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012777157 |
# |    clip_fraction        | 0.000795     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -7.47e-05    |
# |    std                  | 0.711        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 61126        |
# |    iterations           | 47           |
# |    time_elapsed         | 768          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015824819 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -7.88e-05    |
# |    std                  | 0.706        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.7         |
# | time/                   |              |
# |    fps                  | 61292        |
# |    iterations           | 48           |
# |    time_elapsed         | 783          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007809109 |
# |    clip_fraction        | 0.00045      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -6.31e-05    |
# |    std                  | 0.701        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11           |
# | time/                   |              |
# |    fps                  | 61305        |
# |    iterations           | 49           |
# |    time_elapsed         | 799          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023092313 |
# |    clip_fraction        | 0.00316      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00017     |
# |    std                  | 0.696        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=17.87 +/- 5.93
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 17.9         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007609896 |
# |    clip_fraction        | 0.00233      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.161        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -0.000144    |
# |    std                  | 0.69         |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.7     |
# | time/              |          |
# |    fps             | 61232    |
# |    iterations      | 50       |
# |    time_elapsed    | 816      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env)

# %%
aux_rl_env = get_rl_env(num_trajectories=5)
# Out:
# Before normalization self.action_space.low [0. 0.]
# Before normalization self.action_space.high [4.6051702 4.6051702]

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(aux_rl_env, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/trajectory_plot.png

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory(env=sb_rl_env, agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist(vec_env=sb_rl_env, agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread  Mean PnL  Std PnL Mean terminal inventory  \
# Inventory    3.396543  0.832736  2.25989                    -1.0
#
#           Std terminal inventory
# Inventory                    0.0

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(-1.0, 1.0, (2,), float32)
# Low bounds: [-1. -1.]
# High bounds: [1. 1.]
#
# Original Trading Environment Action Space:
# Shape: Box(-1.0, 1.0, (2,), float32)
# Low bounds: [-1. -1.]
# High bounds: [1. 1.]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  0.7345274940581754
# median:  0.0
# std:  2.155046392043606

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_50_000_000steps_NormalisedActionObs/PPO_1/events.out.tfevents.1761656855.MacBookAir.lan.56474.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_50_000_000steps_NormalisedActionObs/PPO_1/events.out.tfevents.1761656855.MacBookAir.lan.56474.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_50_000_000steps_NormalisedActionObs/PPO_1/events.out.tfevents.1761656855.MacBookAir.lan.56474.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_50_000_000steps_NormalisedActionObs/2025-10-28_14-42-35/Training_process_rewards.png
