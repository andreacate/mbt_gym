# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 5
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x162f062f0>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x164a03e80>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065896  21.133681  4.809688                  -0.071
#
#           Std terminal inventory
# Inventory               3.106116

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 500_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_100_000_000steps_Entropy"
# Paths with timestamp
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x17f933670>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)

n_epochs = 10
learning_rate = 3e-4
gae_lambda = 0.95
clip_range = 0.2
vf_coef = 0.5
max_grad_norm = 0.5

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }


#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

#callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999], [ 20.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.81     |
# | time/              |          |
# |    fps             | 306243   |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.03         |
# | time/                   |              |
# |    fps                  | 106810       |
# |    iterations           | 2            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0023501688 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0298       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000282    |
# |    std                  | 0.996        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.66         |
# | time/                   |              |
# |    fps                  | 83415        |
# |    iterations           | 3            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0034688306 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0642       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000617    |
# |    std                  | 0.991        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.52         |
# | time/                   |              |
# |    fps                  | 76464        |
# |    iterations           | 4            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032923885 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.099        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000566    |
# |    std                  | 0.987        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 6.64        |
# | time/                   |             |
# |    fps                  | 74116       |
# |    iterations           | 5           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.003126993 |
# |    clip_fraction        | 0.00973     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.000569   |
# |    std                  | 0.983       |
# |    value_loss           | 0.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.7          |
# | time/                   |              |
# |    fps                  | 72487        |
# |    iterations           | 6            |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0034490048 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.176        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000472    |
# |    std                  | 0.979        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.65         |
# | time/                   |              |
# |    fps                  | 71869        |
# |    iterations           | 7            |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032447535 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000532    |
# |    std                  | 0.975        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.08         |
# | time/                   |              |
# |    fps                  | 71750        |
# |    iterations           | 8            |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029610707 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.000521    |
# |    std                  | 0.97         |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.9          |
# | time/                   |              |
# |    fps                  | 71629        |
# |    iterations           | 9            |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0034444302 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000625    |
# |    std                  | 0.964        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=16.22 +/- 4.74
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 16.2         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031309705 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.000457    |
# |    std                  | 0.959        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    fps             | 70631    |
# |    iterations      | 10       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 69309        |
# |    iterations           | 11           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033756006 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0006      |
# |    std                  | 0.955        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 69381       |
# |    iterations           | 12          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.003004504 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 33          |
# |    policy_gradient_loss | -0.0005     |
# |    std                  | 0.948       |
# |    value_loss           | 0.241       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 69492       |
# |    iterations           | 13          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 13000000    |
# | train/                  |             |
# |    approx_kl            | 0.003325311 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.000562   |
# |    std                  | 0.941       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 69138        |
# |    iterations           | 14           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026458448 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.000589    |
# |    std                  | 0.934        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 67595        |
# |    iterations           | 15           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029391865 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.00041     |
# |    std                  | 0.927        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 67690       |
# |    iterations           | 16          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 16000000    |
# | train/                  |             |
# |    approx_kl            | 0.002660858 |
# |    clip_fraction        | 0.0076      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.000273   |
# |    std                  | 0.922       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.4         |
# | time/                   |              |
# |    fps                  | 67897        |
# |    iterations           | 17           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026753373 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000453    |
# |    std                  | 0.918        |
# |    value_loss           | 0.259        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 67445        |
# |    iterations           | 18           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025863207 |
# |    clip_fraction        | 0.00744      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000361    |
# |    std                  | 0.911        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 67104        |
# |    iterations           | 19           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028799246 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.00043     |
# |    std                  | 0.904        |
# |    value_loss           | 0.245        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=21.04 +/- 4.71
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21           |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021998035 |
# |    clip_fraction        | 0.00669      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.115        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000371    |
# |    std                  | 0.897        |
# |    value_loss           | 0.23         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    fps             | 66490    |
# |    iterations      | 20       |
# |    time_elapsed    | 300      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 66129        |
# |    iterations           | 21           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032208797 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000278    |
# |    std                  | 0.892        |
# |    value_loss           | 0.238        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 66222        |
# |    iterations           | 22           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026108571 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.00018     |
# |    std                  | 0.888        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.6        |
# | time/                   |             |
# |    fps                  | 66192       |
# |    iterations           | 23          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 23000000    |
# | train/                  |             |
# |    approx_kl            | 0.002386721 |
# |    clip_fraction        | 0.00695     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 66          |
# |    policy_gradient_loss | -0.0002     |
# |    std                  | 0.883       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 66245        |
# |    iterations           | 24           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024190177 |
# |    clip_fraction        | 0.00721      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -8.74e-05    |
# |    std                  | 0.877        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 66250        |
# |    iterations           | 25           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019511916 |
# |    clip_fraction        | 0.0037       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000223    |
# |    std                  | 0.872        |
# |    value_loss           | 0.242        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.6         |
# | time/                   |              |
# |    fps                  | 65962        |
# |    iterations           | 26           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017141051 |
# |    clip_fraction        | 0.00611      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -9.99e-05    |
# |    std                  | 0.864        |
# |    value_loss           | 0.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 65645        |
# |    iterations           | 27           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023858969 |
# |    clip_fraction        | 0.00775      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 0.86         |
# |    value_loss           | 0.238        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 65486        |
# |    iterations           | 28           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024669433 |
# |    clip_fraction        | 0.0066       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000186    |
# |    std                  | 0.856        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 65438        |
# |    iterations           | 29           |
# |    time_elapsed         | 443          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021123115 |
# |    clip_fraction        | 0.00375      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000206    |
# |    std                  | 0.853        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=20.45 +/- 5.22
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.5         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018324517 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.000183    |
# |    std                  | 0.85         |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.1     |
# | time/              |          |
# |    fps             | 65292    |
# |    iterations      | 30       |
# |    time_elapsed    | 459      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.7        |
# | time/                   |             |
# |    fps                  | 65382       |
# |    iterations           | 31          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 31000000    |
# | train/                  |             |
# |    approx_kl            | 0.002180485 |
# |    clip_fraction        | 0.00236     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -9.41e-05   |
# |    std                  | 0.846       |
# |    value_loss           | 0.247       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 65482        |
# |    iterations           | 32           |
# |    time_elapsed         | 488          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018298815 |
# |    clip_fraction        | 0.00331      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -0.000184    |
# |    std                  | 0.841        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 65468        |
# |    iterations           | 33           |
# |    time_elapsed         | 504          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021996433 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -6.52e-05    |
# |    std                  | 0.836        |
# |    value_loss           | 0.245        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 64986        |
# |    iterations           | 34           |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032787826 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 99           |
# |    policy_gradient_loss | 6.88e-05     |
# |    std                  | 0.831        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 15.6          |
# | time/                   |               |
# |    fps                  | 65026         |
# |    iterations           | 35            |
# |    time_elapsed         | 538           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00042078196 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.46         |
# |    explained_variance   | 0.16          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.129         |
# |    n_updates            | 102           |
# |    policy_gradient_loss | -5.35e-05     |
# |    std                  | 0.826         |
# |    value_loss           | 0.249         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 65006        |
# |    iterations           | 36           |
# |    time_elapsed         | 553          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014946086 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -6.49e-05    |
# |    std                  | 0.821        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 65065        |
# |    iterations           | 37           |
# |    time_elapsed         | 568          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011800581 |
# |    clip_fraction        | 0.00203      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000115    |
# |    std                  | 0.817        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 15            |
# | time/                   |               |
# |    fps                  | 65096         |
# |    iterations           | 38            |
# |    time_elapsed         | 583           |
# |    total_timesteps      | 38000000      |
# | train/                  |               |
# |    approx_kl            | 0.00096516794 |
# |    clip_fraction        | 0.000517      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.43         |
# |    explained_variance   | 0.157         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.125         |
# |    n_updates            | 111           |
# |    policy_gradient_loss | -1.49e-05     |
# |    std                  | 0.814         |
# |    value_loss           | 0.255         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 15.9          |
# | time/                   |               |
# |    fps                  | 65156         |
# |    iterations           | 39            |
# |    time_elapsed         | 598           |
# |    total_timesteps      | 39000000      |
# | train/                  |               |
# |    approx_kl            | 0.00056036876 |
# |    clip_fraction        | 0.00433       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.42         |
# |    explained_variance   | 0.16          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.124         |
# |    n_updates            | 114           |
# |    policy_gradient_loss | -2.49e-05     |
# |    std                  | 0.807         |
# |    value_loss           | 0.252         |
# -------------------------------------------
# Eval num_timesteps=40000000, episode_reward=21.11 +/- 5.24
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21.1         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014493188 |
# |    clip_fraction        | 0.00258      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -6.26e-05    |
# |    std                  | 0.804        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.1     |
# | time/              |          |
# |    fps             | 64956    |
# |    iterations      | 40       |
# |    time_elapsed    | 615      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 64527        |
# |    iterations           | 41           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013959428 |
# |    clip_fraction        | 0.00245      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000163    |
# |    std                  | 0.799        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 64417        |
# |    iterations           | 42           |
# |    time_elapsed         | 651          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015504792 |
# |    clip_fraction        | 0.00389      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -4.04e-05    |
# |    std                  | 0.794        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 64456        |
# |    iterations           | 43           |
# |    time_elapsed         | 667          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0039678714 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 126          |
# |    policy_gradient_loss | 0.000174     |
# |    std                  | 0.79         |
# |    value_loss           | 0.256        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 64370        |
# |    iterations           | 44           |
# |    time_elapsed         | 683          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013359616 |
# |    clip_fraction        | 0.00484      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -7.82e-05    |
# |    std                  | 0.785        |
# |    value_loss           | 0.263        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 64323        |
# |    iterations           | 45           |
# |    time_elapsed         | 699          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029834472 |
# |    clip_fraction        | 0.00849      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -1.6e-05     |
# |    std                  | 0.78         |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 64160        |
# |    iterations           | 46           |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014432622 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -5.61e-05    |
# |    std                  | 0.775        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 64038        |
# |    iterations           | 47           |
# |    time_elapsed         | 733          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011544848 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -5.06e-05    |
# |    std                  | 0.772        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 63889        |
# |    iterations           | 48           |
# |    time_elapsed         | 751          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0003985556 |
# |    clip_fraction        | 0.00231      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -3.71e-05    |
# |    std                  | 0.768        |
# |    value_loss           | 0.268        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 63836        |
# |    iterations           | 49           |
# |    time_elapsed         | 767          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017666338 |
# |    clip_fraction        | 0.0017       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | 3.72e-05     |
# |    std                  | 0.763        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.59 +/- 5.77
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.6         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008830841 |
# |    clip_fraction        | 0.00143      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.176        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -4.59e-06    |
# |    std                  | 0.757        |
# |    value_loss           | 0.269        |
# ------------------------------------------
# ...
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.13       |
# |    n_updates            | 1449       |
# |    policy_gradient_loss | 0.000211   |
# |    std                  | 0.148      |
# |    value_loss           | 0.26       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 62502        |
# |    iterations           | 485          |
# |    time_elapsed         | 7759         |
# |    total_timesteps      | 485000000    |
# | train/                  |              |
# |    approx_kl            | 0.0017406049 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.99         |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 1452         |
# |    policy_gradient_loss | 0.000249     |
# |    std                  | 0.147        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 62506       |
# |    iterations           | 486         |
# |    time_elapsed         | 7775        |
# |    total_timesteps      | 486000000   |
# | train/                  |             |
# |    approx_kl            | 0.003004782 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1           |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 1455        |
# |    policy_gradient_loss | 0.00058     |
# |    std                  | 0.147       |
# |    value_loss           | 0.267       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 62512        |
# |    iterations           | 487          |
# |    time_elapsed         | 7790         |
# |    total_timesteps      | 487000000    |
# | train/                  |              |
# |    approx_kl            | 0.0030471864 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.01         |
# |    explained_variance   | 0.415        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1458         |
# |    policy_gradient_loss | 0.000405     |
# |    std                  | 0.146        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.8         |
# | time/                   |              |
# |    fps                  | 62518        |
# |    iterations           | 488          |
# |    time_elapsed         | 7805         |
# |    total_timesteps      | 488000000    |
# | train/                  |              |
# |    approx_kl            | 0.0025282812 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.01         |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 1461         |
# |    policy_gradient_loss | 0.00136      |
# |    std                  | 0.146        |
# |    value_loss           | 0.269        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 62522        |
# |    iterations           | 489          |
# |    time_elapsed         | 7821         |
# |    total_timesteps      | 489000000    |
# | train/                  |              |
# |    approx_kl            | 0.0019442549 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1464         |
# |    policy_gradient_loss | 0.000247     |
# |    std                  | 0.145        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# Eval num_timesteps=490000000, episode_reward=21.02 +/- 5.36
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21           |
# | time/                   |              |
# |    total_timesteps      | 490000000    |
# | train/                  |              |
# |    approx_kl            | 0.0011155966 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 1467         |
# |    policy_gradient_loss | -1.89e-06    |
# |    std                  | 0.145        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 21.3      |
# | time/              |           |
# |    fps             | 62512     |
# |    iterations      | 490       |
# |    time_elapsed    | 7838      |
# |    total_timesteps | 490000000 |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 62517        |
# |    iterations           | 491          |
# |    time_elapsed         | 7853         |
# |    total_timesteps      | 491000000    |
# | train/                  |              |
# |    approx_kl            | 0.0013121201 |
# |    clip_fraction        | 0.000667     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.03         |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -3.27e-06    |
# |    std                  | 0.145        |
# |    value_loss           | 0.263        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 62520        |
# |    iterations           | 492          |
# |    time_elapsed         | 7869         |
# |    total_timesteps      | 492000000    |
# | train/                  |              |
# |    approx_kl            | 0.0028846276 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.03         |
# |    explained_variance   | 0.451        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 1473         |
# |    policy_gradient_loss | 0.000262     |
# |    std                  | 0.144        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 62526        |
# |    iterations           | 493          |
# |    time_elapsed         | 7884         |
# |    total_timesteps      | 493000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022472115 |
# |    clip_fraction        | 0.00643      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.04         |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1476         |
# |    policy_gradient_loss | 2.01e-05     |
# |    std                  | 0.144        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 62530        |
# |    iterations           | 494          |
# |    time_elapsed         | 7900         |
# |    total_timesteps      | 494000000    |
# | train/                  |              |
# |    approx_kl            | 0.0039314823 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.04         |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.137        |
# |    n_updates            | 1479         |
# |    policy_gradient_loss | 0.000567     |
# |    std                  | 0.144        |
# |    value_loss           | 0.266        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 19.8         |
# | time/                   |              |
# |    fps                  | 62536        |
# |    iterations           | 495          |
# |    time_elapsed         | 7915         |
# |    total_timesteps      | 495000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022738795 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.05         |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 1482         |
# |    policy_gradient_loss | 0.000649     |
# |    std                  | 0.143        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 62538        |
# |    iterations           | 496          |
# |    time_elapsed         | 7931         |
# |    total_timesteps      | 496000000    |
# | train/                  |              |
# |    approx_kl            | 0.0021930763 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.05         |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 1485         |
# |    policy_gradient_loss | 0.000231     |
# |    std                  | 0.143        |
# |    value_loss           | 0.269        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 62542       |
# |    iterations           | 497         |
# |    time_elapsed         | 7946        |
# |    total_timesteps      | 497000000   |
# | train/                  |             |
# |    approx_kl            | 0.005094931 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.06        |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 1488        |
# |    policy_gradient_loss | 0.000611    |
# |    std                  | 0.142       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 62546        |
# |    iterations           | 498          |
# |    time_elapsed         | 7962         |
# |    total_timesteps      | 498000000    |
# | train/                  |              |
# |    approx_kl            | 0.0040452317 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.06         |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1491         |
# |    policy_gradient_loss | 0.000748     |
# |    std                  | 0.142        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 20.4       |
# | time/                   |            |
# |    fps                  | 62551      |
# |    iterations           | 499        |
# |    time_elapsed         | 7977       |
# |    total_timesteps      | 499000000  |
# | train/                  |            |
# |    approx_kl            | 0.00250395 |
# |    clip_fraction        | 0.0133     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.07       |
# |    explained_variance   | 0.516      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 1494       |
# |    policy_gradient_loss | 0.000228   |
# |    std                  | 0.142      |
# |    value_loss           | 0.273      |
# ----------------------------------------
# Eval num_timesteps=500000000, episode_reward=20.51 +/- 5.31
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.5         |
# | time/                   |              |
# |    total_timesteps      | 500000000    |
# | train/                  |              |
# |    approx_kl            | 0.0009999159 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.08         |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1497         |
# |    policy_gradient_loss | 0.000263     |
# |    std                  | 0.141        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 21.1      |
# | time/              |           |
# |    fps             | 62541     |
# |    iterations      | 500       |
# |    time_elapsed    | 7994      |
# |    total_timesteps | 500000000 |
# ----------------------------------

# %% [markdown]
# ### Loading the model

# %%
best_model_path = (
    ".././CJ_models/PPO-best/"
    "CjMm_PPO_500_000_000steps_Baseline/2025-10-23_11-40-14/best_model.zip"
)

model = PPO.load(best_model_path, env=sb_rl_env)

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
use_normalized_agent = False

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
#os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[31], line 9
#       7 # Save the figure to the best model path
#       8 plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
# ----> 9 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      10 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# NotADirectoryError: [Errno 20] Not a directory: '.././CJ_models/PPO-best/CjMm_PPO_500_000_000steps_Baseline/2025-10-23_11-40-14/best_model.zip/trajectory_plot.png'

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=100000)

# %%
results_rl, fig, tot_rewards = generate_results_table_and_hist_rl_fast(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread   Mean PnL   Std PnL  Mean terminal inventory  \
# RL Agent     2.112121  20.983418  5.367125                  1.48547
#
#           Std terminal inventory
# RL Agent                3.815166

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent     2.11211  20.953393  5.147275                   1.394
#
#          Std terminal inventory
# RL Agent               3.811662

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.948843860235755
# median:  20.840570149041866
# std:  5.367270262413599

# %%
# Load the event file
event_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"

# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_rollout_reward.png

# %%
# Load the event file
event_file= "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/PPO_1/events.out.tfevents.1761212415.MacBookAir.lan.59416.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_Entropy/2025-10-23_11-40-14/Training_process_rewards.png
