# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 10

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x1684b7d90>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16a8b01c0>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL  Std PnL Mean terminal inventory  \
# Inventory    2.326632  21.129975  4.80754                   -0.07
#
#           Std terminal inventory
# Inventory               3.089515

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "CjMm_PPO_100_000_000steps_RandomStart"
# Paths with timestamp
tensorboard_logdir = f"./CJ_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./CJ_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x16a949090>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-10.          0.         -5.5999999], [ 10.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 875      |
# |    ep_rew_mean     | 5.51     |
# | time/              |          |
# |    fps             | 387658   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 2.6          |
# | time/                   |              |
# |    fps                  | 114001       |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0023929519 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0346       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0958       |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000382    |
# |    std                  | 0.996        |
# |    value_loss           | 0.218        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 546          |
# |    ep_rew_mean          | 4.35         |
# | time/                   |              |
# |    fps                  | 93574        |
# |    iterations           | 3            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0036144387 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0403       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0873       |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000643    |
# |    std                  | 0.993        |
# |    value_loss           | 0.176        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | 1.76         |
# | time/                   |              |
# |    fps                  | 83963        |
# |    iterations           | 4            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031957682 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.055        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0944       |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000701    |
# |    std                  | 0.988        |
# |    value_loss           | 0.192        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57           |
# |    ep_rew_mean          | 0.63         |
# | time/                   |              |
# |    fps                  | 78640        |
# |    iterations           | 5            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032942097 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0643       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0799       |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000671    |
# |    std                  | 0.982        |
# |    value_loss           | 0.162        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 2           |
# | time/                   |             |
# |    fps                  | 77091       |
# |    iterations           | 6           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 6000000     |
# | train/                  |             |
# |    approx_kl            | 0.003090305 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.0925      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.1         |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.000571   |
# |    std                  | 0.979       |
# |    value_loss           | 0.209       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 7.68         |
# | time/                   |              |
# |    fps                  | 76131        |
# |    iterations           | 7            |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031081678 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0815       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0993       |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000561    |
# |    std                  | 0.974        |
# |    value_loss           | 0.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 420         |
# |    ep_rew_mean          | 4.32        |
# | time/                   |             |
# |    fps                  | 72988       |
# |    iterations           | 8           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 8000000     |
# | train/                  |             |
# |    approx_kl            | 0.003016612 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 21          |
# |    policy_gradient_loss | -0.000581   |
# |    std                  | 0.968       |
# |    value_loss           | 0.21        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 738          |
# |    ep_rew_mean          | 7.01         |
# | time/                   |              |
# |    fps                  | 72549        |
# |    iterations           | 9            |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0034331612 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0943       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0907       |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000711    |
# |    std                  | 0.962        |
# |    value_loss           | 0.183        |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=1.45 +/- 0.83
# Episode length: 84.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 84           |
# |    mean_reward          | 1.45         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030812495 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0978       |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.000604    |
# |    std                  | 0.957        |
# |    value_loss           | 0.198        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 3.03     |
# | time/              |          |
# |    fps             | 72333    |
# |    iterations      | 10       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 71818        |
# |    iterations           | 11           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030858174 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0771       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0824       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000822    |
# |    std                  | 0.949        |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 71703        |
# |    iterations           | 12           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034296536 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0915       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0848       |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -0.000609    |
# |    std                  | 0.943        |
# |    value_loss           | 0.171        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81          |
# |    ep_rew_mean          | 0.705       |
# | time/                   |             |
# |    fps                  | 71628       |
# |    iterations           | 13          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 13000000    |
# | train/                  |             |
# |    approx_kl            | 0.002814065 |
# |    clip_fraction        | 0.0094      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0971      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.000478   |
# |    std                  | 0.938       |
# |    value_loss           | 0.195       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | 4.69         |
# | time/                   |              |
# |    fps                  | 71222        |
# |    iterations           | 14           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0035909158 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.0843       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0892       |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.000822    |
# |    std                  | 0.931        |
# |    value_loss           | 0.176        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 71188        |
# |    iterations           | 15           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030509767 |
# |    clip_fraction        | 0.00868      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.107        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.00049     |
# |    std                  | 0.927        |
# |    value_loss           | 0.217        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 834          |
# |    ep_rew_mean          | 9.75         |
# | time/                   |              |
# |    fps                  | 71138        |
# |    iterations           | 16           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030525164 |
# |    clip_fraction        | 0.00819      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.117        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000474    |
# |    std                  | 0.923        |
# |    value_loss           | 0.235        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | 1.34        |
# | time/                   |             |
# |    fps                  | 71147       |
# |    iterations           | 17          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 17000000    |
# | train/                  |             |
# |    approx_kl            | 0.002832887 |
# |    clip_fraction        | 0.00736     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.000398   |
# |    std                  | 0.919       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22           |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 71252        |
# |    iterations           | 18           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023597092 |
# |    clip_fraction        | 0.00836      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.112        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000217    |
# |    std                  | 0.915        |
# |    value_loss           | 0.228        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 2.93         |
# | time/                   |              |
# |    fps                  | 71269        |
# |    iterations           | 19           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029103118 |
# |    clip_fraction        | 0.00828      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.0641       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0932       |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.000236    |
# |    std                  | 0.908        |
# |    value_loss           | 0.187        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=2.18 +/- 1.42
# Episode length: 101.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 101          |
# |    mean_reward          | 2.18         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028658921 |
# |    clip_fraction        | 0.00639      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.092        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.103        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000365    |
# |    std                  | 0.904        |
# |    value_loss           | 0.204        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 1.93     |
# | time/              |          |
# |    fps             | 71243    |
# |    iterations      | 20       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 473          |
# |    ep_rew_mean          | 6.66         |
# | time/                   |              |
# |    fps                  | 71319        |
# |    iterations           | 21           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026302417 |
# |    clip_fraction        | 0.00904      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.107        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000346    |
# |    std                  | 0.898        |
# |    value_loss           | 0.217        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 70274        |
# |    iterations           | 22           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030079442 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.107        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -1.99e-05    |
# |    std                  | 0.894        |
# |    value_loss           | 0.208        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 69733        |
# |    iterations           | 23           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025654878 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.111        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.000147    |
# |    std                  | 0.892        |
# |    value_loss           | 0.22         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 69819        |
# |    iterations           | 24           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024659445 |
# |    clip_fraction        | 0.00453      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.00016     |
# |    std                  | 0.889        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93            |
# |    ep_rew_mean          | 1.14          |
# | time/                   |               |
# |    fps                  | 69475         |
# |    iterations           | 25            |
# |    time_elapsed         | 359           |
# |    total_timesteps      | 25000000      |
# | train/                  |               |
# |    approx_kl            | 0.00050596596 |
# |    clip_fraction        | 0.00461       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.6          |
# |    explained_variance   | 0.187         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.125         |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.000165     |
# |    std                  | 0.886         |
# |    value_loss           | 0.247         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 911          |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 69442        |
# |    iterations           | 26           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015330716 |
# |    clip_fraction        | 0.007        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.105        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000207    |
# |    std                  | 0.881        |
# |    value_loss           | 0.213        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.205        |
# | time/                   |              |
# |    fps                  | 69406        |
# |    iterations           | 27           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011940792 |
# |    clip_fraction        | 0.00561      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | 8.97e-06     |
# |    std                  | 0.877        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 1.51         |
# | time/                   |              |
# |    fps                  | 69403        |
# |    iterations           | 28           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021470094 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.00021     |
# |    std                  | 0.872        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21           |
# |    ep_rew_mean          | 0.346        |
# | time/                   |              |
# |    fps                  | 69370        |
# |    iterations           | 29           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024074842 |
# |    clip_fraction        | 0.00506      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000101    |
# |    std                  | 0.869        |
# |    value_loss           | 0.243        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=3.88 +/- 2.30
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 3.88         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018847007 |
# |    clip_fraction        | 0.00563      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.000109    |
# |    std                  | 0.866        |
# |    value_loss           | 0.229        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91       |
# |    ep_rew_mean     | 1.4      |
# | time/              |          |
# |    fps             | 69294    |
# |    iterations      | 30       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82           |
# |    ep_rew_mean          | 1.29         |
# | time/                   |              |
# |    fps                  | 69248        |
# |    iterations           | 31           |
# |    time_elapsed         | 447          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014192213 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000107    |
# |    std                  | 0.863        |
# |    value_loss           | 0.247        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 2.84        |
# | time/                   |             |
# |    fps                  | 69251       |
# |    iterations           | 32          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 32000000    |
# | train/                  |             |
# |    approx_kl            | 0.002738847 |
# |    clip_fraction        | 0.0037      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 93          |
# |    policy_gradient_loss | -5.71e-05   |
# |    std                  | 0.86        |
# |    value_loss           | 0.226       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.81         |
# | time/                   |              |
# |    fps                  | 69232        |
# |    iterations           | 33           |
# |    time_elapsed         | 476          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024945887 |
# |    clip_fraction        | 0.00275      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.301        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -5.89e-05    |
# |    std                  | 0.857        |
# |    value_loss           | 0.229        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 4.61         |
# | time/                   |              |
# |    fps                  | 69230        |
# |    iterations           | 34           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018016476 |
# |    clip_fraction        | 0.00336      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -6.4e-05     |
# |    std                  | 0.854        |
# |    value_loss           | 0.259        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 419         |
# |    ep_rew_mean          | 6.92        |
# | time/                   |             |
# |    fps                  | 69237       |
# |    iterations           | 35          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 35000000    |
# | train/                  |             |
# |    approx_kl            | 0.001975023 |
# |    clip_fraction        | 0.00316     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 102         |
# |    policy_gradient_loss | -4.1e-05    |
# |    std                  | 0.85        |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 44            |
# |    ep_rew_mean          | 0.5           |
# | time/                   |               |
# |    fps                  | 69208         |
# |    iterations           | 36            |
# |    time_elapsed         | 520           |
# |    total_timesteps      | 36000000      |
# | train/                  |               |
# |    approx_kl            | 0.00019044639 |
# |    clip_fraction        | 2e-06         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.51         |
# |    explained_variance   | 0.356         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.126         |
# |    n_updates            | 105           |
# |    policy_gradient_loss | 1.51e-05      |
# |    std                  | 0.848         |
# |    value_loss           | 0.248         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 13.8         |
# | time/                   |              |
# |    fps                  | 69204        |
# |    iterations           | 37           |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013502866 |
# |    clip_fraction        | 0.000171     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -2.49e-05    |
# |    std                  | 0.846        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 5.75         |
# | time/                   |              |
# |    fps                  | 69187        |
# |    iterations           | 38           |
# |    time_elapsed         | 549          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015195829 |
# |    clip_fraction        | 0.000226     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 111          |
# |    policy_gradient_loss | 5.39e-05     |
# |    std                  | 0.845        |
# |    value_loss           | 0.281        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | 3.82         |
# | time/                   |              |
# |    fps                  | 69153        |
# |    iterations           | 39           |
# |    time_elapsed         | 563          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018627178 |
# |    clip_fraction        | 0.00509      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -0.000103    |
# |    std                  | 0.842        |
# |    value_loss           | 0.229        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=2.03 +/- 1.46
# Episode length: 109.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 109           |
# |    mean_reward          | 2.03          |
# | time/                   |               |
# |    total_timesteps      | 40000000      |
# | train/                  |               |
# |    approx_kl            | 0.00054596754 |
# |    clip_fraction        | 0.0257        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.49         |
# |    explained_variance   | 0.148         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.122         |
# |    n_updates            | 117           |
# |    policy_gradient_loss | 0.000499      |
# |    std                  | 0.839         |
# |    value_loss           | 0.246         |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | 6.49     |
# | time/              |          |
# |    fps             | 69090    |
# |    iterations      | 40       |
# |    time_elapsed    | 578      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 69056        |
# |    iterations           | 41           |
# |    time_elapsed         | 593          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024320697 |
# |    clip_fraction        | 0.00421      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000142    |
# |    std                  | 0.837        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 69013        |
# |    iterations           | 42           |
# |    time_elapsed         | 608          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0040734853 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.289        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | 6.16e-05     |
# |    std                  | 0.833        |
# |    value_loss           | 0.231        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 888           |
# |    ep_rew_mean          | 14.8          |
# | time/                   |               |
# |    fps                  | 69004         |
# |    iterations           | 43            |
# |    time_elapsed         | 623           |
# |    total_timesteps      | 43000000      |
# | train/                  |               |
# |    approx_kl            | 0.00038648976 |
# |    clip_fraction        | 0.00256       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.47         |
# |    explained_variance   | 0.414         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.126         |
# |    n_updates            | 126           |
# |    policy_gradient_loss | 3.57e-05      |
# |    std                  | 0.832         |
# |    value_loss           | 0.253         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 6.23         |
# | time/                   |              |
# |    fps                  | 68976        |
# |    iterations           | 44           |
# |    time_elapsed         | 637          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021929566 |
# |    clip_fraction        | 0.00235      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -8.86e-05    |
# |    std                  | 0.828        |
# |    value_loss           | 0.268        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 3.23         |
# | time/                   |              |
# |    fps                  | 68973        |
# |    iterations           | 45           |
# |    time_elapsed         | 652          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013299217 |
# |    clip_fraction        | 0.000697     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.393        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -1.19e-06    |
# |    std                  | 0.825        |
# |    value_loss           | 0.252        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 921          |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 68923        |
# |    iterations           | 46           |
# |    time_elapsed         | 667          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014150816 |
# |    clip_fraction        | 0.00956      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | 0.000121     |
# |    std                  | 0.822        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 995          |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 68932        |
# |    iterations           | 47           |
# |    time_elapsed         | 681          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 9.615631e-05 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.356        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.141        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | 2.84e-05     |
# |    std                  | 0.819        |
# |    value_loss           | 0.272        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 5.98         |
# | time/                   |              |
# |    fps                  | 68910        |
# |    iterations           | 48           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024733657 |
# |    clip_fraction        | 0.00609      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | 2.7e-05      |
# |    std                  | 0.817        |
# |    value_loss           | 0.273        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 208           |
# |    ep_rew_mean          | 3.33          |
# | time/                   |               |
# |    fps                  | 68897         |
# |    iterations           | 49            |
# |    time_elapsed         | 711           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00084101467 |
# |    clip_fraction        | 0.000972      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.43         |
# |    explained_variance   | 0.166         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.14          |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -2.9e-05      |
# |    std                  | 0.816         |
# |    value_loss           | 0.267         |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=1.80 +/- 1.63
# Episode length: 93.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 93          |
# |    mean_reward          | 1.8         |
# | time/                   |             |
# |    total_timesteps      | 50000000    |
# | train/                  |             |
# |    approx_kl            | 0.000769746 |
# |    clip_fraction        | 0.000452    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 147         |
# |    policy_gradient_loss | 1.35e-05    |
# |    std                  | 0.813       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ...
# |    loss                 | 0.134        |
# |    n_updates            | 249          |
# |    policy_gradient_loss | -2.37e-05    |
# |    std                  | 0.721        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51           |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 66486        |
# |    iterations           | 85           |
# |    time_elapsed         | 1278         |
# |    total_timesteps      | 85000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014545169 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.305        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 252          |
# |    policy_gradient_loss | 1.96e-05     |
# |    std                  | 0.718        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 0.896        |
# | time/                   |              |
# |    fps                  | 66502        |
# |    iterations           | 86           |
# |    time_elapsed         | 1293         |
# |    total_timesteps      | 86000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026529436 |
# |    clip_fraction        | 0.00958      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 255          |
# |    policy_gradient_loss | 4.68e-06     |
# |    std                  | 0.717        |
# |    value_loss           | 0.286        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 66521        |
# |    iterations           | 87           |
# |    time_elapsed         | 1307         |
# |    total_timesteps      | 87000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008610279 |
# |    clip_fraction        | 9.8e-05      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.151        |
# |    n_updates            | 258          |
# |    policy_gradient_loss | -1.68e-05    |
# |    std                  | 0.716        |
# |    value_loss           | 0.284        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75           |
# |    ep_rew_mean          | 1.46         |
# | time/                   |              |
# |    fps                  | 66527        |
# |    iterations           | 88           |
# |    time_elapsed         | 1322         |
# |    total_timesteps      | 88000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010455383 |
# |    clip_fraction        | 0.00188      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 261          |
# |    policy_gradient_loss | 1.13e-05     |
# |    std                  | 0.714        |
# |    value_loss           | 0.276        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 4.84         |
# | time/                   |              |
# |    fps                  | 66549        |
# |    iterations           | 89           |
# |    time_elapsed         | 1337         |
# |    total_timesteps      | 89000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008022853 |
# |    clip_fraction        | 0.00592      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 4.7e-06      |
# |    std                  | 0.712        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# Eval num_timesteps=90000000, episode_reward=8.42 +/- 3.32
# Episode length: 417.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 417           |
# |    mean_reward          | 8.42          |
# | time/                   |               |
# |    total_timesteps      | 90000000      |
# | train/                  |               |
# |    approx_kl            | 0.00070230884 |
# |    clip_fraction        | 0.000528      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.15         |
# |    explained_variance   | 0.328         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.138         |
# |    n_updates            | 267           |
# |    policy_gradient_loss | -1.65e-05     |
# |    std                  | 0.709         |
# |    value_loss           | 0.276         |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 830      |
# |    ep_rew_mean     | 14.4     |
# | time/              |          |
# |    fps             | 66516    |
# |    iterations      | 90       |
# |    time_elapsed    | 1353     |
# |    total_timesteps | 90000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 979          |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 66489        |
# |    iterations           | 91           |
# |    time_elapsed         | 1368         |
# |    total_timesteps      | 91000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023368353 |
# |    clip_fraction        | 0.00691      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -6.3e-05     |
# |    std                  | 0.705        |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 884          |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 66431        |
# |    iterations           | 92           |
# |    time_elapsed         | 1384         |
# |    total_timesteps      | 92000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014746408 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 273          |
# |    policy_gradient_loss | -2.72e-05    |
# |    std                  | 0.7          |
# |    value_loss           | 0.282        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13           |
# |    ep_rew_mean          | 0.188        |
# | time/                   |              |
# |    fps                  | 66396        |
# |    iterations           | 93           |
# |    time_elapsed         | 1400         |
# |    total_timesteps      | 93000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012465194 |
# |    clip_fraction        | 0.00177      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.137        |
# |    n_updates            | 276          |
# |    policy_gradient_loss | -6.44e-05    |
# |    std                  | 0.698        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | 4.22         |
# | time/                   |              |
# |    fps                  | 66409        |
# |    iterations           | 94           |
# |    time_elapsed         | 1415         |
# |    total_timesteps      | 94000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016346956 |
# |    clip_fraction        | 0.000652     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 279          |
# |    policy_gradient_loss | -7.72e-05    |
# |    std                  | 0.696        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | 0.218       |
# | time/                   |             |
# |    fps                  | 66429       |
# |    iterations           | 95          |
# |    time_elapsed         | 1430        |
# |    total_timesteps      | 95000000    |
# | train/                  |             |
# |    approx_kl            | 0.005005663 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 282         |
# |    policy_gradient_loss | 0.000477    |
# |    std                  | 0.691       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 2.96        |
# | time/                   |             |
# |    fps                  | 66460       |
# |    iterations           | 96          |
# |    time_elapsed         | 1444        |
# |    total_timesteps      | 96000000    |
# | train/                  |             |
# |    approx_kl            | 0.002355655 |
# |    clip_fraction        | 0.00735     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 285         |
# |    policy_gradient_loss | 8.51e-05    |
# |    std                  | 0.69        |
# |    value_loss           | 0.284       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 674          |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 66493        |
# |    iterations           | 97           |
# |    time_elapsed         | 1458         |
# |    total_timesteps      | 97000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014017374 |
# |    clip_fraction        | 0.00175      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -5.02e-05    |
# |    std                  | 0.687        |
# |    value_loss           | 0.247        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 66465        |
# |    iterations           | 98           |
# |    time_elapsed         | 1474         |
# |    total_timesteps      | 98000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012480745 |
# |    clip_fraction        | 0.00821      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 291          |
# |    policy_gradient_loss | 9.9e-05      |
# |    std                  | 0.684        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 66493        |
# |    iterations           | 99           |
# |    time_elapsed         | 1488         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009604048 |
# |    clip_fraction        | 0.000349     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -2.09e-05    |
# |    std                  | 0.683        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=5.13 +/- 2.80
# Episode length: 266.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 266          |
# |    mean_reward          | 5.13         |
# | time/                   |              |
# |    total_timesteps      | 100000000    |
# | train/                  |              |
# |    approx_kl            | 0.0007010715 |
# |    clip_fraction        | 0.000262     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 297          |
# |    policy_gradient_loss | -2.51e-05    |
# |    std                  | 0.681        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 540       |
# |    ep_rew_mean     | 9.58      |
# | time/              |           |
# |    fps             | 66441     |
# |    iterations      | 100       |
# |    time_elapsed    | 1505      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent, use_normalized_agent=use_normalized_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -1.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 1.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent, seed=seed)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent, use_normalized_agent=use_normalized_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.933688  19.386863  5.744241                   1.873
#
#          Std terminal inventory
# RL Agent                3.31555

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent) #, normalize_obs=True)

# %%
inventories = np.arange(-4,5,1)
#inventory_low = - max_inventory
#gradient_inventory = (max_inventory - (-max_inventory)) / 2
inventories_normalised = inventories
#inventories_normalised =(inventories - inventory_low) / gradient_inventory - 1

# %%
#inventories = np.arange(-1,1.25,0.25)
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,0.5]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
print(bid_actions)
# Out:
# [0.0, 0.0, 0.020174924, 0.06945335, 0.122808084, 0.17033273, 0.20494929, 0.22619537, 0.23732848]

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  19.301064598920945
# median:  18.9775974544005
# std:  5.661631751136943

# %%
# Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/PPO_1/events.out.tfevents.1761833309.MacBookAir.lan.30671.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/Training_process_rollout_reward.png

# %%
#  Load the event file
event_file="./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/PPO_1/events.out.tfevents.1761833309.MacBookAir.lan.30671.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
    
rollout_file = "./CJ_models/tensorboard/PPO-learning/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/PPO_1/events.out.tfevents.1761833309.MacBookAir.lan.30671.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./CJ_models/PPO-best/CjMm_PPO_100_000_000steps_RandomStart/2025-10-30_15-08-28/Training_process_rewards.png
