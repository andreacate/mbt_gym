# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
import os
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %% [markdown]
# ### Parameters

# %%
seed_value = 3 
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 10.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
total_arrivals = 30.0
# OU parameters
u0 = 0.0
xi = 1.0

# %%
# Replace your compute_psi function with this:
def compute_aux_integral_for_psi():
    """Compute the integral needed to rescale psi, matching Adrien's implementation."""
    # This matches Adrien's compute_integral_related_to_psi
    time_grid = np.linspace(0, terminal_time, n_steps)
    
    def v(t):
        return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))
    
    # Compute exp(γ²/2 * v(t)) for each time point
    integrand_values = np.exp((gamma * sigma * fads_proportion)**2 / 2 * v(time_grid))
    
    # Return T * mean(integrand)
    return terminal_time * np.mean(integrand_values)

# Now compute psi correctly
aux_integral = compute_aux_integral_for_psi()
psi = (total_arrivals * terminal_time - phi * terminal_time) / aux_integral

print(f"aux_integral: {aux_integral}")
print(f"psi value: {psi}")
# Out:
# aux_integral: 10.08990691848612
# psi value: 14.866341306397885

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
fi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
fi_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=fi_env)
print(fi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x164797eb0>

# %%
plot_trajectory_extended(fi_env, fi_agent)

# %%
plot_trajectory(fi_env, fi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_env_fi = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_agent_fi = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=vec_env_fi)

print(vec_env_fi.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x165b756c0>

# %%
observations_fi, actions_fi, rewards_fi = generate_trajectory(vec_env_fi, vec_agent_fi)
# Out:
# /Users/andrea/Desktop/gitProject/mbt_gym/Experiments_MMwithFadsInfUnifTraders_RL/../mbt_gym/agents/BaselineAgents.py:451: UserWarning: MM agent is quoting a negative spread
#   warnings.warn("MM agent is quoting a negative spread")

# %%
results_fi, fig_fi, total_rewards_fi = generate_results_table_and_hist(vec_env=vec_env_fi,agent=vec_agent_fi)

# %%
results_fi
# Out:
#           Mean spread    Mean PnL    Std PnL Mean terminal inventory  \
# Inventory    2.092324  211.005599  15.373266                   -0.01
#
#           Std terminal inventory
# Inventory               3.053834

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "FIMm_PPO_100_000_000steps_Baseline"

# Paths with timestamp
tensorboard_logdir = f"./Full_Info_models/tensorboard/PPO-learning-FI/{experiment_name}/{run_id}/"
best_model_path = f"./Full_Info_models/PPO-best-FI/{experiment_name}/{run_id}"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes = 256, #200 before  (n_eval_episodes)
                       best_model_save_path = best_model_path, 
                       deterministic=True)


#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.           0.         -12.51928806 -10.        ], [ 20.          10.         112.51928711  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -34.7    |
# | time/              |          |
# |    fps             | 389290   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.21        |
# | time/                   |              |
# |    fps                  | 114120       |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0037927828 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0229       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.27         |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 0.996        |
# |    value_loss           | 9.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 96514        |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0040773787 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.77         |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.99         |
# |    value_loss           | 8.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 30.1         |
# | time/                   |              |
# |    fps                  | 88618        |
# |    iterations           | 4            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0042363326 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43         |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.985        |
# |    value_loss           | 7.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 85089       |
# |    iterations           | 5           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.004177069 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.13        |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.98        |
# |    value_loss           | 6.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 65.9         |
# | time/                   |              |
# |    fps                  | 82916        |
# |    iterations           | 6            |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0038191732 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64         |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000492    |
# |    std                  | 0.975        |
# |    value_loss           | 5.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 79.5         |
# | time/                   |              |
# |    fps                  | 80933        |
# |    iterations           | 7            |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0057627005 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01         |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.97         |
# |    value_loss           | 4.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 84.7         |
# | time/                   |              |
# |    fps                  | 79588        |
# |    iterations           | 8            |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0044995854 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67         |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.961        |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 92.8        |
# | time/                   |             |
# |    fps                  | 78528       |
# |    iterations           | 9           |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.005135463 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.954       |
# |    value_loss           | 3.04        |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=148.95 +/- 9.89
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 149          |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0053930786 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.00036     |
# |    std                  | 0.944        |
# |    value_loss           | 2.6          |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 98       |
# | time/              |          |
# |    fps             | 76674    |
# |    iterations      | 10       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 75877        |
# |    iterations           | 11           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0048730928 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -4.27e-05    |
# |    std                  | 0.938        |
# |    value_loss           | 2.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 75154        |
# |    iterations           | 12           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0057581584 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 33           |
# |    policy_gradient_loss | 0.00496      |
# |    std                  | 0.933        |
# |    value_loss           | 2.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 74493       |
# |    iterations           | 13          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 13000000    |
# | train/                  |             |
# |    approx_kl            | 0.004347826 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00135    |
# |    std                  | 0.926       |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 73718       |
# |    iterations           | 14          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 14000000    |
# | train/                  |             |
# |    approx_kl            | 0.003962624 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 39          |
# |    policy_gradient_loss | -0.000386   |
# |    std                  | 0.916       |
# |    value_loss           | 2.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 73253       |
# |    iterations           | 15          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 15000000    |
# | train/                  |             |
# |    approx_kl            | 0.004776284 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.908       |
# |    value_loss           | 2.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 72309        |
# |    iterations           | 16           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031253486 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -6.81e-05    |
# |    std                  | 0.9          |
# |    value_loss           | 2.22         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 131        |
# | time/                   |            |
# |    fps                  | 71000      |
# |    iterations           | 17         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 17000000   |
# | train/                  |            |
# |    approx_kl            | 0.00450957 |
# |    clip_fraction        | 0.0487     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.62      |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05       |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.00156   |
# |    std                  | 0.895      |
# |    value_loss           | 2.15       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 70471        |
# |    iterations           | 18           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025584276 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 51           |
# |    policy_gradient_loss | 0.000417     |
# |    std                  | 0.888        |
# |    value_loss           | 2.09         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 70370       |
# |    iterations           | 19          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 19000000    |
# | train/                  |             |
# |    approx_kl            | 0.004277622 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.882       |
# |    value_loss           | 2.07        |
# -----------------------------------------
# Eval num_timesteps=20000000, episode_reward=208.99 +/- 13.78
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 209         |
# | time/                   |             |
# |    total_timesteps      | 20000000    |
# | train/                  |             |
# |    approx_kl            | 0.003058026 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 57          |
# |    policy_gradient_loss | -0.00138    |
# |    std                  | 0.876       |
# |    value_loss           | 2.07        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    fps             | 69818    |
# |    iterations      | 20       |
# |    time_elapsed    | 286      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 69745        |
# |    iterations           | 21           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034039442 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00134     |
# |    std                  | 0.87         |
# |    value_loss           | 2.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 69630        |
# |    iterations           | 22           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0039997483 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.863        |
# |    value_loss           | 2.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 69540        |
# |    iterations           | 23           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034290173 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.859        |
# |    value_loss           | 2.11         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 69507       |
# |    iterations           | 24          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 24000000    |
# | train/                  |             |
# |    approx_kl            | 0.003577076 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 69          |
# |    policy_gradient_loss | -0.000789   |
# |    std                  | 0.852       |
# |    value_loss           | 2.09        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 69452        |
# |    iterations           | 25           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032819286 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000794    |
# |    std                  | 0.846        |
# |    value_loss           | 2.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 69385        |
# |    iterations           | 26           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030124153 |
# |    clip_fraction        | 0.00769      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07         |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000657    |
# |    std                  | 0.84         |
# |    value_loss           | 2.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 69320        |
# |    iterations           | 27           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027602876 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.000296    |
# |    std                  | 0.835        |
# |    value_loss           | 2.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 69225        |
# |    iterations           | 28           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024212752 |
# |    clip_fraction        | 0.00739      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.712        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000435    |
# |    std                  | 0.831        |
# |    value_loss           | 2.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 69193        |
# |    iterations           | 29           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016939228 |
# |    clip_fraction        | 0.00552      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 0.828        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=207.36 +/- 16.72
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 207          |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020823984 |
# |    clip_fraction        | 0.00428      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.000385    |
# |    std                  | 0.824        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    fps             | 68854    |
# |    iterations      | 30       |
# |    time_elapsed    | 435      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 68811        |
# |    iterations           | 31           |
# |    time_elapsed         | 450          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024345932 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000262    |
# |    std                  | 0.817        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 68621        |
# |    iterations           | 32           |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027389384 |
# |    clip_fraction        | 0.00375      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -0.00017     |
# |    std                  | 0.811        |
# |    value_loss           | 2.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 68211        |
# |    iterations           | 33           |
# |    time_elapsed         | 483          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013795139 |
# |    clip_fraction        | 0.000727     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.772        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.808        |
# |    value_loss           | 2.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 68084        |
# |    iterations           | 34           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014696484 |
# |    clip_fraction        | 0.00071      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.000188    |
# |    std                  | 0.801        |
# |    value_loss           | 2.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 68001        |
# |    iterations           | 35           |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015964635 |
# |    clip_fraction        | 0.00416      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -4.3e-05     |
# |    std                  | 0.797        |
# |    value_loss           | 2.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 67764       |
# |    iterations           | 36          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 36000000    |
# | train/                  |             |
# |    approx_kl            | 0.002355791 |
# |    clip_fraction        | 0.00196     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 105         |
# |    policy_gradient_loss | -8.56e-05   |
# |    std                  | 0.793       |
# |    value_loss           | 2.31        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 164        |
# | time/                   |            |
# |    fps                  | 67633      |
# |    iterations           | 37         |
# |    time_elapsed         | 547        |
# |    total_timesteps      | 37000000   |
# | train/                  |            |
# |    approx_kl            | 0.00246594 |
# |    clip_fraction        | 0.00739    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.37      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 108        |
# |    policy_gradient_loss | -8.66e-05  |
# |    std                  | 0.788      |
# |    value_loss           | 2.28       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 66998        |
# |    iterations           | 38           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019559874 |
# |    clip_fraction        | 0.00837      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -8.19e-05    |
# |    std                  | 0.783        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 66906        |
# |    iterations           | 39           |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0042734733 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 114          |
# |    policy_gradient_loss | 0.000253     |
# |    std                  | 0.779        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=200.53 +/- 17.16
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 201          |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022718636 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 117          |
# |    policy_gradient_loss | 0.00201      |
# |    std                  | 0.774        |
# |    value_loss           | 2.25         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    fps             | 66589    |
# |    iterations      | 40       |
# |    time_elapsed    | 600      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 66473        |
# |    iterations           | 41           |
# |    time_elapsed         | 616          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005856173 |
# |    clip_fraction        | 0.00683      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000153    |
# |    std                  | 0.766        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 66263       |
# |    iterations           | 42          |
# |    time_elapsed         | 633         |
# |    total_timesteps      | 42000000    |
# | train/                  |             |
# |    approx_kl            | 0.000939361 |
# |    clip_fraction        | 7.17e-05    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 123         |
# |    policy_gradient_loss | -0.000145   |
# |    std                  | 0.761       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 66026        |
# |    iterations           | 43           |
# |    time_elapsed         | 651          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020231456 |
# |    clip_fraction        | 0.000968     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 126          |
# |    policy_gradient_loss | -0.00014     |
# |    std                  | 0.76         |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 65709        |
# |    iterations           | 44           |
# |    time_elapsed         | 669          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017800366 |
# |    clip_fraction        | 0.00251      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -8.04e-05    |
# |    std                  | 0.757        |
# |    value_loss           | 2.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 65285        |
# |    iterations           | 45           |
# |    time_elapsed         | 689          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022868877 |
# |    clip_fraction        | 0.00203      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000174    |
# |    std                  | 0.754        |
# |    value_loss           | 2.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 65247        |
# |    iterations           | 46           |
# |    time_elapsed         | 705          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018950182 |
# |    clip_fraction        | 0.00227      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11         |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -9.11e-05    |
# |    std                  | 0.751        |
# |    value_loss           | 2.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 65042        |
# |    iterations           | 47           |
# |    time_elapsed         | 722          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014029264 |
# |    clip_fraction        | 0.000534     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -6.51e-05    |
# |    std                  | 0.748        |
# |    value_loss           | 2.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 64475        |
# |    iterations           | 48           |
# |    time_elapsed         | 744          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009773625 |
# |    clip_fraction        | 0.00173      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -0.00018     |
# |    std                  | 0.742        |
# |    value_loss           | 2.2          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 164           |
# | time/                   |               |
# |    fps                  | 64297         |
# |    iterations           | 49            |
# |    time_elapsed         | 762           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00049001677 |
# |    clip_fraction        | 9.33e-06      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.24         |
# |    explained_variance   | 0.822         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.11          |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -8.65e-05     |
# |    std                  | 0.739         |
# |    value_loss           | 2.21          |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=202.90 +/- 16.04
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 203           |
# | time/                   |               |
# |    total_timesteps      | 50000000      |
# | train/                  |               |
# |    approx_kl            | 0.00094185316 |
# |    clip_fraction        | 0.00153       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.23         |
# |    explained_variance   | 0.819         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.13          |
# |    n_updates            | 147           |
# |    policy_gradient_loss | -0.000147     |
# |    std                  | 0.734         |
# |    value_loss           | 2.23          |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    fps             | 63960    |
# ...
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 249        |
# |    policy_gradient_loss | 0.00536    |
# |    std                  | 0.637      |
# |    value_loss           | 2.22       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 60195       |
# |    iterations           | 85          |
# |    time_elapsed         | 1412        |
# |    total_timesteps      | 85000000    |
# | train/                  |             |
# |    approx_kl            | 0.009230057 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 252         |
# |    policy_gradient_loss | 0.00571     |
# |    std                  | 0.635       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 60165       |
# |    iterations           | 86          |
# |    time_elapsed         | 1429        |
# |    total_timesteps      | 86000000    |
# | train/                  |             |
# |    approx_kl            | 0.001840085 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 255         |
# |    policy_gradient_loss | 0.000692    |
# |    std                  | 0.631       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 60125       |
# |    iterations           | 87          |
# |    time_elapsed         | 1446        |
# |    total_timesteps      | 87000000    |
# | train/                  |             |
# |    approx_kl            | 0.003041278 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 258         |
# |    policy_gradient_loss | 0.00014     |
# |    std                  | 0.627       |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 60094       |
# |    iterations           | 88          |
# |    time_elapsed         | 1464        |
# |    total_timesteps      | 88000000    |
# | train/                  |             |
# |    approx_kl            | 0.002240614 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 261         |
# |    policy_gradient_loss | 0.000257    |
# |    std                  | 0.625       |
# |    value_loss           | 2.28        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 60084        |
# |    iterations           | 89           |
# |    time_elapsed         | 1481         |
# |    total_timesteps      | 89000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019730434 |
# |    clip_fraction        | 0.00436      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 264          |
# |    policy_gradient_loss | -0.000248    |
# |    std                  | 0.622        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# Eval num_timesteps=90000000, episode_reward=202.41 +/- 16.80
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 202          |
# | time/                   |              |
# |    total_timesteps      | 90000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013206309 |
# |    clip_fraction        | 0.00251      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 267          |
# |    policy_gradient_loss | -8.33e-05    |
# |    std                  | 0.62         |
# |    value_loss           | 2.22         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    fps             | 59897    |
# |    iterations      | 90       |
# |    time_elapsed    | 1502     |
# |    total_timesteps | 90000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 59852        |
# |    iterations           | 91           |
# |    time_elapsed         | 1520         |
# |    total_timesteps      | 91000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020963973 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000109    |
# |    std                  | 0.617        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 59813        |
# |    iterations           | 92           |
# |    time_elapsed         | 1538         |
# |    total_timesteps      | 92000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011856656 |
# |    clip_fraction        | 0.000129     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 273          |
# |    policy_gradient_loss | -4.14e-05    |
# |    std                  | 0.616        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 59802        |
# |    iterations           | 93           |
# |    time_elapsed         | 1555         |
# |    total_timesteps      | 93000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015069807 |
# |    clip_fraction        | 0.00436      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 276          |
# |    policy_gradient_loss | 2.29e-05     |
# |    std                  | 0.614        |
# |    value_loss           | 2.28         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 179           |
# | time/                   |               |
# |    fps                  | 59799         |
# |    iterations           | 94            |
# |    time_elapsed         | 1571          |
# |    total_timesteps      | 94000000      |
# | train/                  |               |
# |    approx_kl            | 0.00021819887 |
# |    clip_fraction        | 0.000651      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.86         |
# |    explained_variance   | 0.837         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.13          |
# |    n_updates            | 279           |
# |    policy_gradient_loss | -5.68e-05     |
# |    std                  | 0.612         |
# |    value_loss           | 2.29          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 59791        |
# |    iterations           | 95           |
# |    time_elapsed         | 1588         |
# |    total_timesteps      | 95000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015837208 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 282          |
# |    policy_gradient_loss | -1.51e-05    |
# |    std                  | 0.61         |
# |    value_loss           | 2.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 59778        |
# |    iterations           | 96           |
# |    time_elapsed         | 1605         |
# |    total_timesteps      | 96000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014524496 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 285          |
# |    policy_gradient_loss | -4.75e-05    |
# |    std                  | 0.608        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 59788        |
# |    iterations           | 97           |
# |    time_elapsed         | 1622         |
# |    total_timesteps      | 97000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006624657 |
# |    clip_fraction        | 0.0015       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -2.91e-05    |
# |    std                  | 0.605        |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 59786        |
# |    iterations           | 98           |
# |    time_elapsed         | 1639         |
# |    total_timesteps      | 98000000     |
# | train/                  |              |
# |    approx_kl            | 0.0003038305 |
# |    clip_fraction        | 0.000955     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 291          |
# |    policy_gradient_loss | -6.55e-05    |
# |    std                  | 0.603        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 59788        |
# |    iterations           | 99           |
# |    time_elapsed         | 1655         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018503653 |
# |    clip_fraction        | 0.00174      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -0.000107    |
# |    std                  | 0.602        |
# |    value_loss           | 2.29         |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=205.75 +/- 18.17
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 206         |
# | time/                   |             |
# |    total_timesteps      | 100000000   |
# | train/                  |             |
# |    approx_kl            | 0.001251667 |
# |    clip_fraction        | 4.3e-05     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 297         |
# |    policy_gradient_loss | -6.98e-05   |
# |    std                  | 0.601       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 179       |
# | time/              |           |
# |    fps             | 59699     |
# |    iterations      | 100       |
# |    time_elapsed    | 1675      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.1251929e+05 -2.0000000e+01  0.0000000e+00 -1.2519288e+01
#  -1.0000000e+01 -1.0000000e+01  0.0000000e+00  0.0000000e+00], [1.1251929e+05 2.0000000e+01 1.0000000e+01 1.1251929e+02 1.0000000e+01
#  1.0000000e+01 6.0000000e+01 6.0000000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread    Mean PnL    Std PnL Mean terminal inventory  \
# RL Agent    2.605474  204.774116  17.125426                   0.335
#
#          Std terminal inventory
# RL Agent               2.200176

# %% [markdown]
# ### Bid/Ask spread vs Inventory

# %%
def plot_actions_vs_fad_colored(observations, actions, max_traj=None):
    """
    Plot ask (solid markers) and bid (dashed markers) spreads vs fad (Ut),
    with inventory as color shading, looping over multiple trajectories.
    
    Parameters
    ----------
    observations : np.ndarray
        Shape (n_traj, 7, T+1)
    actions : np.ndarray
        Shape (n_traj, 2, T)
    max_traj : int or None
        Maximum number of trajectories to include (default: all)
    """
    n_traj = observations.shape[0]
    print(f"Total trajectories available: {n_traj}")
    if max_traj is None:
        max_traj = n_traj

    all_fad = []
    all_inv = []
    all_ask = []
    all_bid = []

    # Collect data from multiple trajectories
    for traj_idx in range(min(max_traj, n_traj)):
        print(f"Processing trajectory {traj_idx+1}/{min(max_traj, n_traj)}")
        obs = observations[traj_idx, :, :-1]  # (7, T)
        acts = actions[traj_idx]              # (2, T)
        #[INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
        fad = obs[3]          # fad Ut
        inventory = obs[0]    # inventory Q
        bid_spread = acts[0]
        ask_spread = acts[1]

        all_fad.append(fad)
        all_inv.append(inventory)
        all_ask.append(ask_spread)
        all_bid.append(bid_spread)

    # Flatten all trajectories into 1D arrays
    fad = np.concatenate(all_fad)
    inventory = np.concatenate(all_inv)
    ask_spread = np.concatenate(all_ask)
    bid_spread = np.concatenate(all_bid)

    # Plot
    plt.figure(figsize=(10, 6))

    sc1 = plt.scatter(fad, ask_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Ask spread", marker="o", s=10)
    sc2 = plt.scatter(fad, bid_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Bid spread", marker="x", s=10)

    plt.xlabel("Fad $U_t$")
    plt.ylabel("Spread")
    plt.title("Bid/Ask Spreads vs Fad with Inventory Coloring (all trajectories)")
    plt.legend()
    cbar = plt.colorbar(sc1)
    cbar.set_label("Inventory $Q$")
    plt.grid(True)
    plt.show()

# %%
plot_actions_vs_fad_colored(observations_rl, actions_rl, 10)
# Out:
# Total trajectories available: 1000
# Processing trajectory 1/10
# Processing trajectory 2/10
# Processing trajectory 3/10
# Processing trajectory 4/10
# Processing trajectory 5/10
# Processing trajectory 6/10
# Processing trajectory 7/10
# Processing trajectory 8/10
# Processing trajectory 9/10
# Processing trajectory 10/10

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0,0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory,0.5,100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
full_info_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Full Information action
fi_bid_actions = []
fi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = full_info_agent.get_action(np.array([[0,inventory,0.5,100,0]])).reshape(-1)
    fi_bid_actions.append(bid_action)
    fi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, fi_bid_actions, label="bid (FI)", color="k", linestyle="--")
ax.plot(inventories, fi_ask_actions, label="ask (FI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Full Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and FI agents
def plot_policy_time_dependence(ppo_agent, fi_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context
    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        fi_bids = []
        fi_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get FI agent's actions
            fi_bid, fi_ask = fi_agent.get_action(np.array([[0, inv, t, price, fad]])).reshape(-1)
            fi_bids.append(fi_bid)
            fi_asks.append(fi_ask)

        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, fi_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, fi_asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, full_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context

        # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, t, price, fad ]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)

        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))

        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))

    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, full_info_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/policy_time_dependence.png

# %%
# Load the event file
event_file= "./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/PPO_1/events.out.tfevents.1762344680.Andreas-MacBook-Air.local.31177.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/Training_process.png

# %%
# === Load rollout rewards ===
# Load the event file
rollout_file= "./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/PPO_1/events.out.tfevents.1762344680.Andreas-MacBook-Air.local.31177.0"

ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()
print("Eval tags:", ea_eval.Tags())

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Eval tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-11-05_13-11-19/Training_process_rewards.png
