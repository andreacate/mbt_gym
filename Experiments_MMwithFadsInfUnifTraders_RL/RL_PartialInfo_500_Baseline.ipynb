# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,

                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
pi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=pi_env)
print(pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x14e0b7a30>

# %%
plot_trajectory_extended(pi_env, pi_agent)

# %%
plot_trajectory(pi_env, pi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_pi_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=vec_pi_env)

print(vec_pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x14f39d8a0>

# %%
observations_pi, actions_pi, rewards_pi = generate_trajectory(vec_pi_env, vec_pi_agent)

# %%
results_pi, fig_pi, total_rewards_pi = generate_results_table_and_hist(vec_env=vec_pi_env,agent=vec_pi_agent)

# %%
results_pi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.145828  4.880012                  -0.095
#
#           Std terminal inventory
# Inventory               3.106441

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "PIMm_PPO_500_000_000steps_Baseline"
# Paths with timestamp
tensorboard_logdir = f"./Partial_Info_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./Partial_Info_models/PPO-best/{experiment_name}/{run_id}/"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes = 256, #200 before  (n_eval_episodes)
                       #eval_freq=200_000,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = 500_000_000, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.95     |
# | time/              |          |
# |    fps             | 394515   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.93         |
# | time/                   |              |
# |    fps                  | 119368       |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031612697 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000493    |
# |    std                  | 0.996        |
# |    value_loss           | 0.277        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.19         |
# | time/                   |              |
# |    fps                  | 97169        |
# |    iterations           | 3            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0033000626 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.00067     |
# |    std                  | 0.993        |
# |    value_loss           | 0.256        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.61         |
# | time/                   |              |
# |    fps                  | 88617        |
# |    iterations           | 4            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0033625911 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000414    |
# |    std                  | 0.989        |
# |    value_loss           | 0.263        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 6.08        |
# | time/                   |             |
# |    fps                  | 84022       |
# |    iterations           | 5           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.003377774 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.000614   |
# |    std                  | 0.984       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.81         |
# | time/                   |              |
# |    fps                  | 81383        |
# |    iterations           | 6            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032057897 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.00062     |
# |    std                  | 0.98         |
# |    value_loss           | 0.268        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.12        |
# | time/                   |             |
# |    fps                  | 79593       |
# |    iterations           | 7           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.003468297 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.00056    |
# |    std                  | 0.975       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.72         |
# | time/                   |              |
# |    fps                  | 78365        |
# |    iterations           | 8            |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031047412 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.000599    |
# |    std                  | 0.971        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.96        |
# | time/                   |             |
# |    fps                  | 77343       |
# |    iterations           | 9           |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.003128069 |
# |    clip_fraction        | 0.00946     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.000422   |
# |    std                  | 0.968       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=16.17 +/- 4.84
# Episode length: 1000.00 +/- 0.00
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 1e+03     |
# |    mean_reward          | 16.2      |
# | time/                   |           |
# |    total_timesteps      | 10000000  |
# | train/                  |           |
# |    approx_kl            | 0.0036219 |
# |    clip_fraction        | 0.0148    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.77     |
# |    explained_variance   | 0.231     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.127     |
# |    n_updates            | 27        |
# |    policy_gradient_loss | -0.000397 |
# |    std                  | 0.962     |
# |    value_loss           | 0.254     |
# ---------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.2     |
# | time/              |          |
# |    fps             | 75455    |
# |    iterations      | 10       |
# |    time_elapsed    | 132      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.1         |
# | time/                   |              |
# |    fps                  | 74783        |
# |    iterations           | 11           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034555472 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000627    |
# |    std                  | 0.955        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10           |
# | time/                   |              |
# |    fps                  | 73593        |
# |    iterations           | 12           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031286415 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -0.000376    |
# |    std                  | 0.951        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 72585        |
# |    iterations           | 13           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031645738 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000437    |
# |    std                  | 0.946        |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 71986        |
# |    iterations           | 14           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028208992 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.238        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.000308    |
# |    std                  | 0.939        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 71384       |
# |    iterations           | 15          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 15000000    |
# | train/                  |             |
# |    approx_kl            | 0.002977611 |
# |    clip_fraction        | 0.00881     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00029    |
# |    std                  | 0.934       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 70698        |
# |    iterations           | 16           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029480536 |
# |    clip_fraction        | 0.00687      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000376    |
# |    std                  | 0.929        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.4         |
# | time/                   |              |
# |    fps                  | 69585        |
# |    iterations           | 17           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024313976 |
# |    clip_fraction        | 0.00506      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000307    |
# |    std                  | 0.924        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 69326       |
# |    iterations           | 18          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 18000000    |
# | train/                  |             |
# |    approx_kl            | 0.002433918 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 51          |
# |    policy_gradient_loss | -0.000216   |
# |    std                  | 0.92        |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 13.1       |
# | time/                   |            |
# |    fps                  | 69412      |
# |    iterations           | 19         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 19000000   |
# | train/                  |            |
# |    approx_kl            | 0.00300587 |
# |    clip_fraction        | 0.0104     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | 0.216      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.123      |
# |    n_updates            | 54         |
# |    policy_gradient_loss | -0.000387  |
# |    std                  | 0.914      |
# |    value_loss           | 0.249      |
# ----------------------------------------
# Eval num_timesteps=20000000, episode_reward=20.98 +/- 5.06
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21           |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027814712 |
# |    clip_fraction        | 0.00751      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000235    |
# |    std                  | 0.907        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.8     |
# | time/              |          |
# |    fps             | 69196    |
# |    iterations      | 20       |
# |    time_elapsed    | 289      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 69356        |
# |    iterations           | 21           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027912743 |
# |    clip_fraction        | 0.00849      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000261    |
# |    std                  | 0.901        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 69518       |
# |    iterations           | 22          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 22000000    |
# | train/                  |             |
# |    approx_kl            | 0.002478661 |
# |    clip_fraction        | 0.00438     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -9.44e-05   |
# |    std                  | 0.896       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 69628        |
# |    iterations           | 23           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023445655 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.000255    |
# |    std                  | 0.892        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 69735       |
# |    iterations           | 24          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 24000000    |
# | train/                  |             |
# |    approx_kl            | 0.002701125 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 69          |
# |    policy_gradient_loss | -0.000241   |
# |    std                  | 0.888       |
# |    value_loss           | 0.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.3         |
# | time/                   |              |
# |    fps                  | 69753        |
# |    iterations           | 25           |
# |    time_elapsed         | 358          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027037908 |
# |    clip_fraction        | 0.006        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000343    |
# |    std                  | 0.883        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 69901        |
# |    iterations           | 26           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019973032 |
# |    clip_fraction        | 0.00385      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000198    |
# |    std                  | 0.878        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 70037        |
# |    iterations           | 27           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022118972 |
# |    clip_fraction        | 0.00546      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -6.36e-05    |
# |    std                  | 0.871        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 70097        |
# |    iterations           | 28           |
# |    time_elapsed         | 399          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021190748 |
# |    clip_fraction        | 0.00309      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000127    |
# |    std                  | 0.865        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 70229       |
# |    iterations           | 29          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 29000000    |
# | train/                  |             |
# |    approx_kl            | 0.001273759 |
# |    clip_fraction        | 0.00163     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 84          |
# |    policy_gradient_loss | 3.38e-05    |
# |    std                  | 0.862       |
# |    value_loss           | 0.25        |
# -----------------------------------------
# Eval num_timesteps=30000000, episode_reward=20.30 +/- 5.30
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 20.3        |
# | time/                   |             |
# |    total_timesteps      | 30000000    |
# | train/                  |             |
# |    approx_kl            | 0.004585474 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 87          |
# |    policy_gradient_loss | 0.000494    |
# |    std                  | 0.854       |
# |    value_loss           | 0.244       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.6     |
# | time/              |          |
# |    fps             | 70023    |
# |    iterations      | 30       |
# |    time_elapsed    | 428      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.8        |
# | time/                   |             |
# |    fps                  | 70083       |
# |    iterations           | 31          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 31000000    |
# | train/                  |             |
# |    approx_kl            | 0.001985033 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.000358    |
# |    std                  | 0.848       |
# |    value_loss           | 0.241       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 70147        |
# |    iterations           | 32           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013850406 |
# |    clip_fraction        | 0.00531      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -7.89e-05    |
# |    std                  | 0.842        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 70209       |
# |    iterations           | 33          |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 33000000    |
# | train/                  |             |
# |    approx_kl            | 0.001019327 |
# |    clip_fraction        | 0.00129     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -4.79e-05   |
# |    std                  | 0.838       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.8         |
# | time/                   |              |
# |    fps                  | 70245        |
# |    iterations           | 34           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005898089 |
# |    clip_fraction        | 0.00393      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -6.5e-05     |
# |    std                  | 0.834        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 70329        |
# |    iterations           | 35           |
# |    time_elapsed         | 497          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021374444 |
# |    clip_fraction        | 0.00233      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -9.82e-05    |
# |    std                  | 0.83         |
# |    value_loss           | 0.252        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 70381        |
# |    iterations           | 36           |
# |    time_elapsed         | 511          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013186198 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -2.58e-05    |
# |    std                  | 0.825        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 70335        |
# |    iterations           | 37           |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015525921 |
# |    clip_fraction        | 0.0012       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -3.27e-05    |
# |    std                  | 0.821        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 70338        |
# |    iterations           | 38           |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007964143 |
# |    clip_fraction        | 0.000555     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -2.67e-05    |
# |    std                  | 0.817        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 70380       |
# |    iterations           | 39          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 39000000    |
# | train/                  |             |
# |    approx_kl            | 0.001765294 |
# |    clip_fraction        | 0.00312     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 114         |
# |    policy_gradient_loss | -5.37e-05   |
# |    std                  | 0.813       |
# |    value_loss           | 0.26        |
# -----------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.80 +/- 5.22
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.8         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016117373 |
# |    clip_fraction        | 0.000912     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.12         |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -5.41e-05    |
# |    std                  | 0.809        |
# |    value_loss           | 0.245        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 15.7     |
# | time/              |          |
# |    fps             | 70211    |
# |    iterations      | 40       |
# |    time_elapsed    | 569      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 70248        |
# |    iterations           | 41           |
# |    time_elapsed         | 583          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032442226 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000184     |
# |    std                  | 0.805        |
# |    value_loss           | 0.242        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 70286        |
# |    iterations           | 42           |
# |    time_elapsed         | 597          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013584429 |
# |    clip_fraction        | 0.00336      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -9.76e-05    |
# |    std                  | 0.8          |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 70358        |
# |    iterations           | 43           |
# |    time_elapsed         | 611          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017395215 |
# |    clip_fraction        | 0.000486     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 126          |
# |    policy_gradient_loss | -4.74e-05    |
# |    std                  | 0.797        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 70416        |
# |    iterations           | 44           |
# |    time_elapsed         | 624          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013764173 |
# |    clip_fraction        | 0.000907     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -4.99e-05    |
# |    std                  | 0.794        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 70461        |
# |    iterations           | 45           |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014202964 |
# |    clip_fraction        | 0.00114      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -4.54e-05    |
# |    std                  | 0.791        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 70501        |
# |    iterations           | 46           |
# |    time_elapsed         | 652          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017323373 |
# |    clip_fraction        | 0.000357     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -6.17e-05    |
# |    std                  | 0.789        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 70533        |
# |    iterations           | 47           |
# |    time_elapsed         | 666          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017694102 |
# |    clip_fraction        | 0.000697     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -3.75e-05    |
# |    std                  | 0.787        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 70574        |
# |    iterations           | 48           |
# |    time_elapsed         | 680          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019571558 |
# |    clip_fraction        | 0.00109      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -7.73e-05    |
# |    std                  | 0.784        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 70544        |
# |    iterations           | 49           |
# |    time_elapsed         | 694          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013900797 |
# |    clip_fraction        | 0.000445     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -2.47e-05    |
# |    std                  | 0.782        |
# |    value_loss           | 0.252        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.86 +/- 5.74
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.9         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015386826 |
# |    clip_fraction        | 0.00242      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -0.000152    |
# |    std                  | 0.778        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.4     |
# | time/              |          |
# |    fps             | 70393    |
# |    iterations      | 50       |
# |    time_elapsed    | 710      |
# |    total_timesteps | 50000000 |
# ...
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 1449        |
# |    policy_gradient_loss | 0.000641    |
# |    std                  | 0.15        |
# |    value_loss           | 0.277       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 66739        |
# |    iterations           | 485          |
# |    time_elapsed         | 7267         |
# |    total_timesteps      | 485000000    |
# | train/                  |              |
# |    approx_kl            | 0.0036821172 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.962        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.14         |
# |    n_updates            | 1452         |
# |    policy_gradient_loss | 0.00201      |
# |    std                  | 0.149        |
# |    value_loss           | 0.279        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 66734        |
# |    iterations           | 486          |
# |    time_elapsed         | 7282         |
# |    total_timesteps      | 486000000    |
# | train/                  |              |
# |    approx_kl            | 0.0023468568 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.968        |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.141        |
# |    n_updates            | 1455         |
# |    policy_gradient_loss | 0.000166     |
# |    std                  | 0.149        |
# |    value_loss           | 0.279        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 19.9         |
# | time/                   |              |
# |    fps                  | 66734        |
# |    iterations           | 487          |
# |    time_elapsed         | 7297         |
# |    total_timesteps      | 487000000    |
# | train/                  |              |
# |    approx_kl            | 0.0013731987 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.974        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 1458         |
# |    policy_gradient_loss | 0.000219     |
# |    std                  | 0.149        |
# |    value_loss           | 0.278        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20          |
# | time/                   |             |
# |    fps                  | 66718       |
# |    iterations           | 488         |
# |    time_elapsed         | 7314        |
# |    total_timesteps      | 488000000   |
# | train/                  |             |
# |    approx_kl            | 0.002692263 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.979       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 1461        |
# |    policy_gradient_loss | 0.000914    |
# |    std                  | 0.148       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 66715        |
# |    iterations           | 489          |
# |    time_elapsed         | 7329         |
# |    total_timesteps      | 489000000    |
# | train/                  |              |
# |    approx_kl            | 0.0025758636 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.987        |
# |    explained_variance   | 0.463        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 1464         |
# |    policy_gradient_loss | 0.00045      |
# |    std                  | 0.147        |
# |    value_loss           | 0.273        |
# ------------------------------------------
# Eval num_timesteps=490000000, episode_reward=20.58 +/- 5.70
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.6         |
# | time/                   |              |
# |    total_timesteps      | 490000000    |
# | train/                  |              |
# |    approx_kl            | 0.0015653021 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.994        |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 1467         |
# |    policy_gradient_loss | 9.52e-05     |
# |    std                  | 0.147        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 21.2      |
# | time/              |           |
# |    fps             | 66694     |
# |    iterations      | 490       |
# |    time_elapsed    | 7346      |
# |    total_timesteps | 490000000 |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 66698       |
# |    iterations           | 491         |
# |    time_elapsed         | 7361        |
# |    total_timesteps      | 491000000   |
# | train/                  |             |
# |    approx_kl            | 0.002346138 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.997       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | 0.000564    |
# |    std                  | 0.147       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 66701        |
# |    iterations           | 492          |
# |    time_elapsed         | 7376         |
# |    total_timesteps      | 492000000    |
# | train/                  |              |
# |    approx_kl            | 0.0033140287 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1            |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.141        |
# |    n_updates            | 1473         |
# |    policy_gradient_loss | 0.000454     |
# |    std                  | 0.146        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 66704        |
# |    iterations           | 493          |
# |    time_elapsed         | 7390         |
# |    total_timesteps      | 493000000    |
# | train/                  |              |
# |    approx_kl            | 0.0012732475 |
# |    clip_fraction        | 0.0076       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.01         |
# |    explained_variance   | 0.502        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 1476         |
# |    policy_gradient_loss | 9.36e-05     |
# |    std                  | 0.146        |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 66709        |
# |    iterations           | 494          |
# |    time_elapsed         | 7405         |
# |    total_timesteps      | 494000000    |
# | train/                  |              |
# |    approx_kl            | 0.0028892609 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 1479         |
# |    policy_gradient_loss | 0.000577     |
# |    std                  | 0.145        |
# |    value_loss           | 0.285        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 66711        |
# |    iterations           | 495          |
# |    time_elapsed         | 7420         |
# |    total_timesteps      | 495000000    |
# | train/                  |              |
# |    approx_kl            | 0.0041527012 |
# |    clip_fraction        | 0.0638       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.137        |
# |    n_updates            | 1482         |
# |    policy_gradient_loss | 0.0017       |
# |    std                  | 0.145        |
# |    value_loss           | 0.273        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20           |
# | time/                   |              |
# |    fps                  | 66714        |
# |    iterations           | 496          |
# |    time_elapsed         | 7434         |
# |    total_timesteps      | 496000000    |
# | train/                  |              |
# |    approx_kl            | 0.0055368394 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.03         |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 1485         |
# |    policy_gradient_loss | 0.00139      |
# |    std                  | 0.144        |
# |    value_loss           | 0.282        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 66718        |
# |    iterations           | 497          |
# |    time_elapsed         | 7449         |
# |    total_timesteps      | 497000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022523564 |
# |    clip_fraction        | 0.00528      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.03         |
# |    explained_variance   | 0.49         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 1488         |
# |    policy_gradient_loss | 7.3e-05      |
# |    std                  | 0.144        |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 20.6       |
# | time/                   |            |
# |    fps                  | 66718      |
# |    iterations           | 498        |
# |    time_elapsed         | 7464       |
# |    total_timesteps      | 498000000  |
# | train/                  |            |
# |    approx_kl            | 0.00382814 |
# |    clip_fraction        | 0.0158     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.04       |
# |    explained_variance   | 0.511      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 1491       |
# |    policy_gradient_loss | 0.000218   |
# |    std                  | 0.144      |
# |    value_loss           | 0.275      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 66724       |
# |    iterations           | 499         |
# |    time_elapsed         | 7478        |
# |    total_timesteps      | 499000000   |
# | train/                  |             |
# |    approx_kl            | 0.002538833 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.04        |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 1494        |
# |    policy_gradient_loss | 0.00105     |
# |    std                  | 0.144       |
# |    value_loss           | 0.307       |
# -----------------------------------------
# Eval num_timesteps=500000000, episode_reward=19.84 +/- 5.77
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.8         |
# | time/                   |              |
# |    total_timesteps      | 500000000    |
# | train/                  |              |
# |    approx_kl            | 0.0023511483 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.04         |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.139        |
# |    n_updates            | 1497         |
# |    policy_gradient_loss | 4.47e-05     |
# |    std                  | 0.143        |
# |    value_loss           | 0.278        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 20.8      |
# | time/              |           |
# |    fps             | 66711     |
# |    iterations      | 500       |
# |    time_elapsed    | 7494      |
# |    total_timesteps | 500000000 |
# ----------------------------------

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices)

# %%
aux_rl_env = get_rl_env(num_trajectories=5)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(aux_rl_env, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/trajectory_plot.png

# %%
observations_rl, actions_rl, rewards_rl = generate_trajectory(env=sb_rl_env, agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist(vec_env=sb_rl_env, agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread   Mean PnL Std PnL Mean terminal inventory  \
# Inventory    2.206678  20.452689  5.8323                     0.0
#
#           Std terminal inventory
# Inventory                    0.0

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100,0]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
#ppo_agent.get_action(np.array([[inventory,0.5]]))

# %%
partial_info_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = partial_info_agent.get_action(np.array([[0,inventory,0.5,100,0,0]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (PI)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (PI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Partial Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and closed approx agent
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # PI bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # PI ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, 0]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, 0]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, partial_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, 0]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, 0]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, pi_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.61356674601813
# median:  20.650550144997208
# std:  5.6957740256085465

# %%
# Load the event file
event_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/PPO_1/events.out.tfevents.1761550419.MacBookAir.lan.11117.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/PPO_1/events.out.tfevents.1761550419.MacBookAir.lan.11117.0"    
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/PPO_1/events.out.tfevents.1761550419.MacBookAir.lan.11117.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)
    
# Add baseline line
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_500_000_000steps_Baseline/2025-10-27_08-33-38/Training_process_rewards.png
