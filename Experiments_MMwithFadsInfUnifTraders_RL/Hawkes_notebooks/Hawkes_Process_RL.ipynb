# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
cj_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=cj_env)
print(cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16a393c10>

# %%
plot_trajectory_extended(cj_env, cj_agent)

# %%
plot_trajectory(cj_env, cj_agent, seed = seed)

# %%
num_trajectories = 1000
vec_cj_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_cj = ModifiedCarteaJaimungalMmAgent(env=vec_cj_env)

print(vec_cj_env.model_dynamics
      .midprice_model)
# Out:
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16bf782e0>

# %%
observations_cj, actions_cj, rewards_cj = generate_trajectory(vec_cj_env, vec_cj)

# %%
results_cj, fig_cj, total_rewards_cj = generate_results_table_and_hist(vec_env=vec_cj_env,agent=vec_cj)

# %%
results_cj
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065896  21.133681  4.809688                  -0.071
#
#           Std terminal inventory
# Inventory               3.106116

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
expected_arrival = 30.0
jump_size = 40.0
mean_reversion_speed = 60.0

baseline_arrival_rate = np.array([[(1-jump_size / mean_reversion_speed) * expected_arrival,(1-jump_size / mean_reversion_speed) * expected_arrival ]] )

# %%
print("Baseline arrival rate:", baseline_arrival_rate)
# Out:
# Baseline arrival rate: [[10. 10.]]

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = HawkesArrivalModel(baseline_arrival_rate=baseline_arrival_rate,
                                       jump_size=jump_size,
                                       mean_reversion_speed=mean_reversion_speed,
                                       step_size=terminal_time/n_steps,
                                        num_trajectories=num_trajectories,
                                        seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 200_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "Hawkes_PPO_prove_200"
# Paths with timestamp
tensorboard_logdir = f"./Hawkes_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./Hawkes_models/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x16c1b3b20>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999], [ 20.           1.         105.59999847], (3,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to ./Hawkes_models/tensorboard/PPO-learning/Hawkes_PPO_prove_200/2025-11-17_14-44-57/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 0.295    |
# | time/              |          |
# |    fps             | 354315   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.22       |
# | time/                   |             |
# |    fps                  | 99820       |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 2000000     |
# | train/                  |             |
# |    approx_kl            | 0.002866633 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.0117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.368       |
# |    n_updates            | 3           |
# |    policy_gradient_loss | -0.000129   |
# |    std                  | 0.997       |
# |    value_loss           | 0.766       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.272        |
# | time/                   |              |
# |    fps                  | 85930        |
# |    iterations           | 3            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031342204 |
# |    clip_fraction        | 0.00829      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.372        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000284    |
# |    std                  | 0.993        |
# |    value_loss           | 0.743        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.59         |
# | time/                   |              |
# |    fps                  | 81178        |
# |    iterations           | 4            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0026353642 |
# |    clip_fraction        | 0.00822      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.384        |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000353    |
# |    std                  | 0.989        |
# |    value_loss           | 0.776        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -0.252       |
# | time/                   |              |
# |    fps                  | 79024        |
# |    iterations           | 5            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0027106903 |
# |    clip_fraction        | 0.00533      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.374        |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000285    |
# |    std                  | 0.987        |
# |    value_loss           | 0.762        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -0.11        |
# | time/                   |              |
# |    fps                  | 77395        |
# |    iterations           | 6            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0030091002 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.361        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000344    |
# |    std                  | 0.983        |
# |    value_loss           | 0.727        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 3.67         |
# | time/                   |              |
# |    fps                  | 76087        |
# |    iterations           | 7            |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0027715468 |
# |    clip_fraction        | 0.00946      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.349        |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000376    |
# |    std                  | 0.979        |
# |    value_loss           | 0.711        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.79        |
# | time/                   |             |
# |    fps                  | 74916       |
# |    iterations           | 8           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 8000000     |
# | train/                  |             |
# |    approx_kl            | 0.001705016 |
# |    clip_fraction        | 0.00964     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.344       |
# |    n_updates            | 21          |
# |    policy_gradient_loss | -0.00029    |
# |    std                  | 0.976       |
# |    value_loss           | 0.681       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 2.45         |
# | time/                   |              |
# |    fps                  | 74100        |
# |    iterations           | 9            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0026961975 |
# |    clip_fraction        | 0.00963      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.458        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.356        |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000334    |
# |    std                  | 0.972        |
# |    value_loss           | 0.71         |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=8.68 +/- 10.60
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 8.68         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030771145 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.347        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.000296    |
# |    std                  | 0.968        |
# |    value_loss           | 0.682        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.33     |
# | time/              |          |
# |    fps             | 72747    |
# |    iterations      | 10       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.4          |
# | time/                   |              |
# |    fps                  | 72526        |
# |    iterations           | 11           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027838594 |
# |    clip_fraction        | 0.00632      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.506        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.327        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000309    |
# |    std                  | 0.964        |
# |    value_loss           | 0.648        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.72        |
# | time/                   |             |
# |    fps                  | 72255       |
# |    iterations           | 12          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.002281124 |
# |    clip_fraction        | 0.00892     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 33          |
# |    policy_gradient_loss | -0.000217   |
# |    std                  | 0.958       |
# |    value_loss           | 0.645       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 4.63         |
# | time/                   |              |
# |    fps                  | 72073        |
# |    iterations           | 13           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015152546 |
# |    clip_fraction        | 0.00848      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.32         |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000126    |
# |    std                  | 0.952        |
# |    value_loss           | 0.626        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.45         |
# | time/                   |              |
# |    fps                  | 71928        |
# |    iterations           | 14           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026483221 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.304        |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.000392    |
# |    std                  | 0.948        |
# |    value_loss           | 0.606        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.85         |
# | time/                   |              |
# |    fps                  | 71729        |
# |    iterations           | 15           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026727861 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.301        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.000409    |
# |    std                  | 0.943        |
# |    value_loss           | 0.611        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.54         |
# | time/                   |              |
# |    fps                  | 71544        |
# |    iterations           | 16           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021347932 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.281        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -7.5e-05     |
# |    std                  | 0.939        |
# |    value_loss           | 0.567        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.54         |
# | time/                   |              |
# |    fps                  | 71394        |
# |    iterations           | 17           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025250413 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.282        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000279    |
# |    std                  | 0.935        |
# |    value_loss           | 0.571        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.36         |
# | time/                   |              |
# |    fps                  | 70315        |
# |    iterations           | 18           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030075575 |
# |    clip_fraction        | 0.00852      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.271        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000406    |
# |    std                  | 0.93         |
# |    value_loss           | 0.547        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.01         |
# | time/                   |              |
# |    fps                  | 70120        |
# |    iterations           | 19           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026845862 |
# |    clip_fraction        | 0.00746      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.26         |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.000291    |
# |    std                  | 0.924        |
# |    value_loss           | 0.524        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=17.78 +/- 8.91
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 17.8        |
# | time/                   |             |
# |    total_timesteps      | 20000000    |
# | train/                  |             |
# |    approx_kl            | 0.001936794 |
# |    clip_fraction        | 0.00692     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.254       |
# |    n_updates            | 57          |
# |    policy_gradient_loss | -0.000217   |
# |    std                  | 0.916       |
# |    value_loss           | 0.504       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    fps             | 69620    |
# |    iterations      | 20       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 69577        |
# |    iterations           | 21           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022792672 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.245        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -2.38e-05    |
# |    std                  | 0.909        |
# |    value_loss           | 0.488        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.7         |
# | time/                   |              |
# |    fps                  | 69523        |
# |    iterations           | 22           |
# |    time_elapsed         | 316          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026259143 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.237        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.000179    |
# |    std                  | 0.906        |
# |    value_loss           | 0.476        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 69450        |
# |    iterations           | 23           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023828559 |
# |    clip_fraction        | 0.00748      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.231        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -9.34e-05    |
# |    std                  | 0.9          |
# |    value_loss           | 0.464        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 69371        |
# |    iterations           | 24           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025046705 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.232        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -5.33e-05    |
# |    std                  | 0.894        |
# |    value_loss           | 0.465        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 69305       |
# |    iterations           | 25          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 25000000    |
# | train/                  |             |
# |    approx_kl            | 0.002825135 |
# |    clip_fraction        | 0.00719     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.231       |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -9.73e-05   |
# |    std                  | 0.888       |
# |    value_loss           | 0.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 69215        |
# |    iterations           | 26           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013321291 |
# |    clip_fraction        | 0.00309      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.224        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000111    |
# |    std                  | 0.883        |
# |    value_loss           | 0.446        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.5         |
# | time/                   |              |
# |    fps                  | 69169        |
# |    iterations           | 27           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022336144 |
# |    clip_fraction        | 0.0051       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.224        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -3.58e-05    |
# |    std                  | 0.877        |
# |    value_loss           | 0.439        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 69115        |
# |    iterations           | 28           |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022859196 |
# |    clip_fraction        | 0.00782      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.399        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.224        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000116    |
# |    std                  | 0.871        |
# |    value_loss           | 0.441        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 69087        |
# |    iterations           | 29           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016320469 |
# |    clip_fraction        | 0.00211      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.214        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -8.21e-05    |
# |    std                  | 0.866        |
# |    value_loss           | 0.437        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=18.31 +/- 7.79
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 18.3         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034621295 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.35         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.21         |
# |    n_updates            | 87           |
# |    policy_gradient_loss | 0.000307     |
# |    std                  | 0.859        |
# |    value_loss           | 0.42         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    fps             | 68739    |
# |    iterations      | 30       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 68706        |
# |    iterations           | 31           |
# |    time_elapsed         | 451          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013465108 |
# |    clip_fraction        | 0.00485      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.207        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -3.15e-05    |
# |    std                  | 0.854        |
# |    value_loss           | 0.421        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 68658        |
# |    iterations           | 32           |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018730474 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.221        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -7.5e-05     |
# |    std                  | 0.849        |
# |    value_loss           | 0.442        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 68611        |
# |    iterations           | 33           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011898678 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.208        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | 0.000214     |
# |    std                  | 0.842        |
# |    value_loss           | 0.422        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 68594        |
# |    iterations           | 34           |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021377634 |
# |    clip_fraction        | 0.00534      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.215        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.00017     |
# |    std                  | 0.835        |
# |    value_loss           | 0.432        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 68605       |
# |    iterations           | 35          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 35000000    |
# | train/                  |             |
# |    approx_kl            | 0.001554241 |
# |    clip_fraction        | 0.00236     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 102         |
# |    policy_gradient_loss | -4.55e-05   |
# |    std                  | 0.83        |
# |    value_loss           | 0.415       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 68602        |
# |    iterations           | 36           |
# |    time_elapsed         | 524          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012275195 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.22         |
# |    n_updates            | 105          |
# |    policy_gradient_loss | 1.6e-05      |
# |    std                  | 0.827        |
# |    value_loss           | 0.437        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.2         |
# | time/                   |              |
# |    fps                  | 68598        |
# |    iterations           | 37           |
# |    time_elapsed         | 539          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016827484 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.216        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -2.7e-05     |
# |    std                  | 0.824        |
# |    value_loss           | 0.433        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.8         |
# | time/                   |              |
# |    fps                  | 68571        |
# |    iterations           | 38           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015600028 |
# |    clip_fraction        | 0.00257      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.206        |
# |    n_updates            | 111          |
# |    policy_gradient_loss | 2.68e-05     |
# |    std                  | 0.821        |
# |    value_loss           | 0.416        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 68550       |
# |    iterations           | 39          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 39000000    |
# | train/                  |             |
# |    approx_kl            | 0.001382442 |
# |    clip_fraction        | 0.00159     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 114         |
# |    policy_gradient_loss | -8.85e-05   |
# |    std                  | 0.818       |
# |    value_loss           | 0.411       |
# -----------------------------------------
# Eval num_timesteps=40000000, episode_reward=19.35 +/- 8.06
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.4         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015948502 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.206        |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -0.000105    |
# |    std                  | 0.814        |
# |    value_loss           | 0.41         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 15.2     |
# | time/              |          |
# |    fps             | 68209    |
# |    iterations      | 40       |
# |    time_elapsed    | 586      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 68162        |
# |    iterations           | 41           |
# |    time_elapsed         | 601          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018250974 |
# |    clip_fraction        | 0.00292      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.206        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000124    |
# |    std                  | 0.81         |
# |    value_loss           | 0.414        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.8         |
# | time/                   |              |
# |    fps                  | 68097        |
# |    iterations           | 42           |
# |    time_elapsed         | 616          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005999562 |
# |    clip_fraction        | 0.00154      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.201        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -1.22e-05    |
# |    std                  | 0.807        |
# |    value_loss           | 0.405        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 68025        |
# |    iterations           | 43           |
# |    time_elapsed         | 632          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009393031 |
# |    clip_fraction        | 0.0024       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.207        |
# |    n_updates            | 126          |
# |    policy_gradient_loss | 4.58e-06     |
# |    std                  | 0.805        |
# |    value_loss           | 0.418        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 67994        |
# |    iterations           | 44           |
# |    time_elapsed         | 647          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014596529 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.21         |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -4.53e-05    |
# |    std                  | 0.801        |
# |    value_loss           | 0.426        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 67991        |
# |    iterations           | 45           |
# |    time_elapsed         | 661          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019157972 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.206        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | 0.000105     |
# |    std                  | 0.796        |
# |    value_loss           | 0.403        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 67979        |
# |    iterations           | 46           |
# |    time_elapsed         | 676          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019930594 |
# |    clip_fraction        | 0.00568      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.199        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | 0.000138     |
# |    std                  | 0.791        |
# |    value_loss           | 0.394        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14.1          |
# | time/                   |               |
# |    fps                  | 67962         |
# |    iterations           | 47            |
# |    time_elapsed         | 691           |
# |    total_timesteps      | 47000000      |
# | train/                  |               |
# |    approx_kl            | 0.00084884063 |
# |    clip_fraction        | 0.00126       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.36         |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.203         |
# |    n_updates            | 138           |
# |    policy_gradient_loss | -7.36e-05     |
# |    std                  | 0.787         |
# |    value_loss           | 0.409         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 67931        |
# |    iterations           | 48           |
# |    time_elapsed         | 706          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016066007 |
# |    clip_fraction        | 0.00304      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.203        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -9.85e-05    |
# |    std                  | 0.783        |
# |    value_loss           | 0.415        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 67911        |
# |    iterations           | 49           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010728526 |
# |    clip_fraction        | 0.00272      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.201        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -2.43e-05    |
# |    std                  | 0.777        |
# |    value_loss           | 0.403        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=18.18 +/- 8.37
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 18.2         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016328174 |
# |    clip_fraction        | 0.00319      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.208        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -3.76e-05    |
# |    std                  | 0.772        |
# |    value_loss           | 0.417        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# ...
# |    n_updates            | 549          |
# |    policy_gradient_loss | -2.24e-05    |
# |    std                  | 0.43         |
# |    value_loss           | 0.467        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 66044        |
# |    iterations           | 185          |
# |    time_elapsed         | 2801         |
# |    total_timesteps      | 185000000    |
# | train/                  |              |
# |    approx_kl            | 0.0013150059 |
# |    clip_fraction        | 0.00428      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.295        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.231        |
# |    n_updates            | 552          |
# |    policy_gradient_loss | 3.79e-05     |
# |    std                  | 0.429        |
# |    value_loss           | 0.468        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 66042        |
# |    iterations           | 186          |
# |    time_elapsed         | 2816         |
# |    total_timesteps      | 186000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022922643 |
# |    clip_fraction        | 0.00985      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.225        |
# |    n_updates            | 555          |
# |    policy_gradient_loss | 0.000179     |
# |    std                  | 0.428        |
# |    value_loss           | 0.447        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 66046       |
# |    iterations           | 187         |
# |    time_elapsed         | 2831        |
# |    total_timesteps      | 187000000   |
# | train/                  |             |
# |    approx_kl            | 0.001189542 |
# |    clip_fraction        | 0.00121     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.231       |
# |    n_updates            | 558         |
# |    policy_gradient_loss | -7.58e-06   |
# |    std                  | 0.427       |
# |    value_loss           | 0.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 66027        |
# |    iterations           | 188          |
# |    time_elapsed         | 2847         |
# |    total_timesteps      | 188000000    |
# | train/                  |              |
# |    approx_kl            | 0.0014916728 |
# |    clip_fraction        | 0.00168      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.227        |
# |    n_updates            | 561          |
# |    policy_gradient_loss | -3.59e-05    |
# |    std                  | 0.426        |
# |    value_loss           | 0.451        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.2         |
# | time/                   |              |
# |    fps                  | 66022        |
# |    iterations           | 189          |
# |    time_elapsed         | 2862         |
# |    total_timesteps      | 189000000    |
# | train/                  |              |
# |    approx_kl            | 0.0011904251 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.232        |
# |    n_updates            | 564          |
# |    policy_gradient_loss | -1.72e-05    |
# |    std                  | 0.424        |
# |    value_loss           | 0.466        |
# ------------------------------------------
# Eval num_timesteps=190000000, episode_reward=18.43 +/- 8.42
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 18.4         |
# | time/                   |              |
# |    total_timesteps      | 190000000    |
# | train/                  |              |
# |    approx_kl            | 0.0016440994 |
# |    clip_fraction        | 0.00656      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.232        |
# |    n_updates            | 567          |
# |    policy_gradient_loss | 6.08e-05     |
# |    std                  | 0.422        |
# |    value_loss           | 0.459        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 17.4      |
# | time/              |           |
# |    fps             | 65987     |
# |    iterations      | 190       |
# |    time_elapsed    | 2879      |
# |    total_timesteps | 190000000 |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 65998        |
# |    iterations           | 191          |
# |    time_elapsed         | 2893         |
# |    total_timesteps      | 191000000    |
# | train/                  |              |
# |    approx_kl            | 0.0013690457 |
# |    clip_fraction        | 0.00697      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.233        |
# |    n_updates            | 570          |
# |    policy_gradient_loss | 0.00014      |
# |    std                  | 0.42         |
# |    value_loss           | 0.463        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 65999        |
# |    iterations           | 192          |
# |    time_elapsed         | 2909         |
# |    total_timesteps      | 192000000    |
# | train/                  |              |
# |    approx_kl            | 0.0033418138 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.23         |
# |    n_updates            | 573          |
# |    policy_gradient_loss | 0.000371     |
# |    std                  | 0.418        |
# |    value_loss           | 0.464        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 66009        |
# |    iterations           | 193          |
# |    time_elapsed         | 2923         |
# |    total_timesteps      | 193000000    |
# | train/                  |              |
# |    approx_kl            | 0.0032304495 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.219        |
# |    n_updates            | 576          |
# |    policy_gradient_loss | 0.000113     |
# |    std                  | 0.416        |
# |    value_loss           | 0.44         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 66013        |
# |    iterations           | 194          |
# |    time_elapsed         | 2938         |
# |    total_timesteps      | 194000000    |
# | train/                  |              |
# |    approx_kl            | 0.0015779227 |
# |    clip_fraction        | 0.00281      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.295        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.226        |
# |    n_updates            | 579          |
# |    policy_gradient_loss | 2.82e-05     |
# |    std                  | 0.414        |
# |    value_loss           | 0.453        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 66023        |
# |    iterations           | 195          |
# |    time_elapsed         | 2953         |
# |    total_timesteps      | 195000000    |
# | train/                  |              |
# |    approx_kl            | 0.0020799704 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.311        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.227        |
# |    n_updates            | 582          |
# |    policy_gradient_loss | 0.000284     |
# |    std                  | 0.412        |
# |    value_loss           | 0.453        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 66026        |
# |    iterations           | 196          |
# |    time_elapsed         | 2968         |
# |    total_timesteps      | 196000000    |
# | train/                  |              |
# |    approx_kl            | 0.0044723013 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.232        |
# |    n_updates            | 585          |
# |    policy_gradient_loss | 0.000429     |
# |    std                  | 0.41         |
# |    value_loss           | 0.458        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 66038        |
# |    iterations           | 197          |
# |    time_elapsed         | 2983         |
# |    total_timesteps      | 197000000    |
# | train/                  |              |
# |    approx_kl            | 0.0018461819 |
# |    clip_fraction        | 0.0049       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.226        |
# |    n_updates            | 588          |
# |    policy_gradient_loss | 5.13e-05     |
# |    std                  | 0.408        |
# |    value_loss           | 0.453        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 16            |
# | time/                   |               |
# |    fps                  | 66044         |
# |    iterations           | 198           |
# |    time_elapsed         | 2997          |
# |    total_timesteps      | 198000000     |
# | train/                  |               |
# |    approx_kl            | 0.00064312015 |
# |    clip_fraction        | 0.00219       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.325         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.243         |
# |    n_updates            | 591           |
# |    policy_gradient_loss | 2.06e-05      |
# |    std                  | 0.406         |
# |    value_loss           | 0.486         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 66049        |
# |    iterations           | 199          |
# |    time_elapsed         | 3012         |
# |    total_timesteps      | 199000000    |
# | train/                  |              |
# |    approx_kl            | 0.0016541844 |
# |    clip_fraction        | 0.00304      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.228        |
# |    n_updates            | 594          |
# |    policy_gradient_loss | 3.31e-06     |
# |    std                  | 0.404        |
# |    value_loss           | 0.464        |
# ------------------------------------------
# Eval num_timesteps=200000000, episode_reward=17.94 +/- 9.04
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 17.9         |
# | time/                   |              |
# |    total_timesteps      | 200000000    |
# | train/                  |              |
# |    approx_kl            | 0.0019371856 |
# |    clip_fraction        | 0.00517      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.234        |
# |    n_updates            | 597          |
# |    policy_gradient_loss | 7.79e-05     |
# |    std                  | 0.403        |
# |    value_loss           | 0.47         |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 17        |
# | time/              |           |
# |    fps             | 66012     |
# |    iterations      | 200       |
# |    time_elapsed    | 3029      |
# |    total_timesteps | 200000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = HawkesArrivalModel(step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 1.000e+02
#  1.000e+02], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL  Std PnL Mean terminal inventory  \
# RL Agent    2.263322  18.934113  8.80197                   0.837
#
#          Std terminal inventory
# RL Agent               5.734844

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0]])
    else:
        state = np.array([[inventory,0.5,100]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

        # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  18.712993589803364
# median:  17.744694202020085
# std:  8.24524188695223

# %%
# Load the event file
event_file = "./Hawkes_models/tensorboard/PPO-learning/Hawkes_PPO_prove_10/2025-11-03_14-13-23/PPO_1/events.out.tfevents.1762175604.Andreas-MacBook-Air.local.49531.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = "./Hawkes_models/tensorboard/PPO-learning/Hawkes_PPO_prove_200/2025-11-17_14-44-57/PPO_1/events.out.tfevents.1763387099.MacBookAir.lan.3794.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = "./Hawkes_models/tensorboard/PPO-learning/Hawkes_PPO_prove_200/2025-11-17_14-44-57/PPO_1/events.out.tfevents.1763387099.MacBookAir.lan.3794.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Hawkes_models/PPO-best/Hawkes_PPO_prove_200/2025-11-17_14-44-57/Training_process_rewards.png
