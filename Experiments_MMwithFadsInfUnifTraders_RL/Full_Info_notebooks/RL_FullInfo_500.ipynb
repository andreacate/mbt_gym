# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
import os
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %% [markdown]
# ### Parameters

# %%
seed_value = 3 
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
as_env = get_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
as_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=as_env)
print(as_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x10347f970>

# %%
plot_trajectory_extended(as_env, as_agent)

# %%
plot_trajectory(as_env, as_agent, seed = seed)

# %%
num_trajectories = 1000
vec_env = get_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_as = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=vec_env)

print(vec_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x147ed5ff0>

# %%
observations_fi, actions_fi, rewards_fi = generate_trajectory(vec_env, vec_as)

# %%
results_fi, fig_fi, total_rewards_fi = generate_results_table_and_hist(vec_env=vec_env,agent=vec_as)

# %%
results_fi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.329476  5.109129                   0.084
#
#           Std terminal inventory
# Inventory               3.210131

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %%
# Monitor sb_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "FIMm_PPO_500_000_000steps_Baseline"

# Paths with timestamp
tensorboard_logdir = f"./Full_Info_models/tensorboard/PPO-learning-FI/{experiment_name}/{run_id}/"
best_model_path = f"./Full_Info_models/PPO-best-FI/{experiment_name}/{run_id}"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes = 256, #200 before  (n_eval_episodes)
                       best_model_save_path = best_model_path, 
                       deterministic=True)


#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = 500_000_000, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_09-37-37/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.78     |
# | time/              |          |
# |    fps             | 297184   |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.66         |
# | time/                   |              |
# |    fps                  | 94494        |
# |    iterations           | 2            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031478486 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.088        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000187    |
# |    std                  | 0.998        |
# |    value_loss           | 0.272        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.59         |
# | time/                   |              |
# |    fps                  | 82402        |
# |    iterations           | 3            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029801123 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000456    |
# |    std                  | 0.994        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.49         |
# | time/                   |              |
# |    fps                  | 75933        |
# |    iterations           | 4            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0024814694 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000346    |
# |    std                  | 0.99         |
# |    value_loss           | 0.249        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.6          |
# | time/                   |              |
# |    fps                  | 73810        |
# |    iterations           | 5            |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029640098 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000533    |
# |    std                  | 0.986        |
# |    value_loss           | 0.266        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.19         |
# | time/                   |              |
# |    fps                  | 72784        |
# |    iterations           | 6            |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0033317427 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.00065     |
# |    std                  | 0.981        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.48        |
# | time/                   |             |
# |    fps                  | 71307       |
# |    iterations           | 7           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.003088628 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.000649   |
# |    std                  | 0.976       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.8          |
# | time/                   |              |
# |    fps                  | 70829        |
# |    iterations           | 8            |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0025229766 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.000515    |
# |    std                  | 0.97         |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 69937        |
# |    iterations           | 9            |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0027001598 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000479    |
# |    std                  | 0.965        |
# |    value_loss           | 0.263        |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=15.85 +/- 3.95
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 15.8         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034607153 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.00059     |
# |    std                  | 0.959        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.95     |
# | time/              |          |
# |    fps             | 68440    |
# |    iterations      | 10       |
# |    time_elapsed    | 146      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.96         |
# | time/                   |              |
# |    fps                  | 68622        |
# |    iterations           | 11           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026098606 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000468    |
# |    std                  | 0.955        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 69008       |
# |    iterations           | 12          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.002805824 |
# |    clip_fraction        | 0.00971     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 33          |
# |    policy_gradient_loss | -0.00048    |
# |    std                  | 0.949       |
# |    value_loss           | 0.247       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.8        |
# | time/                   |             |
# |    fps                  | 69148       |
# |    iterations           | 13          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 13000000    |
# | train/                  |             |
# |    approx_kl            | 0.002618859 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.000395   |
# |    std                  | 0.944       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 69144        |
# |    iterations           | 14           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027229444 |
# |    clip_fraction        | 0.00637      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.000287    |
# |    std                  | 0.939        |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 68965        |
# |    iterations           | 15           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026664988 |
# |    clip_fraction        | 0.0099       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 42           |
# |    policy_gradient_loss | -0.000367    |
# |    std                  | 0.934        |
# |    value_loss           | 0.259        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 68614        |
# |    iterations           | 16           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022182507 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000247    |
# |    std                  | 0.929        |
# |    value_loss           | 0.249        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 68404        |
# |    iterations           | 17           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028840774 |
# |    clip_fraction        | 0.00911      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000486    |
# |    std                  | 0.924        |
# |    value_loss           | 0.239        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.5         |
# | time/                   |              |
# |    fps                  | 68119        |
# |    iterations           | 18           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0028105918 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.000482    |
# |    std                  | 0.92         |
# |    value_loss           | 0.244        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 67992        |
# |    iterations           | 19           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024579298 |
# |    clip_fraction        | 0.00687      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.000385    |
# |    std                  | 0.916        |
# |    value_loss           | 0.241        |
# ------------------------------------------
# Eval num_timesteps=20000000, episode_reward=21.17 +/- 5.08
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21.2         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031738724 |
# |    clip_fraction        | 0.00817      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000334    |
# |    std                  | 0.912        |
# |    value_loss           | 0.244        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.8     |
# | time/              |          |
# |    fps             | 67802    |
# |    iterations      | 20       |
# |    time_elapsed    | 294      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 67787        |
# |    iterations           | 21           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016126225 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.123        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -3.06e-05    |
# |    std                  | 0.909        |
# |    value_loss           | 0.245        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 67578        |
# |    iterations           | 22           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022441421 |
# |    clip_fraction        | 0.00536      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.000186    |
# |    std                  | 0.905        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 67787       |
# |    iterations           | 23          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 23000000    |
# | train/                  |             |
# |    approx_kl            | 0.002852836 |
# |    clip_fraction        | 0.00674     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 66          |
# |    policy_gradient_loss | -0.000294   |
# |    std                  | 0.903       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.3         |
# | time/                   |              |
# |    fps                  | 68015        |
# |    iterations           | 24           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019016808 |
# |    clip_fraction        | 0.00512      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.000176    |
# |    std                  | 0.9          |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.3         |
# | time/                   |              |
# |    fps                  | 68192        |
# |    iterations           | 25           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021513863 |
# |    clip_fraction        | 0.00187      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.899        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 68309        |
# |    iterations           | 26           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009416066 |
# |    clip_fraction        | 0.00353      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.126        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000224    |
# |    std                  | 0.896        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.7         |
# | time/                   |              |
# |    fps                  | 68456        |
# |    iterations           | 27           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024614336 |
# |    clip_fraction        | 0.00291      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.000203    |
# |    std                  | 0.894        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 68611       |
# |    iterations           | 28          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 28000000    |
# | train/                  |             |
# |    approx_kl            | 0.001948545 |
# |    clip_fraction        | 0.00229     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 81          |
# |    policy_gradient_loss | -0.00015    |
# |    std                  | 0.892       |
# |    value_loss           | 0.262       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 68756        |
# |    iterations           | 29           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022215904 |
# |    clip_fraction        | 0.00109      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -9.13e-05    |
# |    std                  | 0.89         |
# |    value_loss           | 0.262        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=21.10 +/- 6.31
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 21.1        |
# | time/                   |             |
# |    total_timesteps      | 30000000    |
# | train/                  |             |
# |    approx_kl            | 0.002291924 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 87          |
# |    policy_gradient_loss | -0.00011    |
# |    std                  | 0.887       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.7     |
# | time/              |          |
# |    fps             | 68624    |
# |    iterations      | 30       |
# |    time_elapsed    | 437      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 68754        |
# |    iterations           | 31           |
# |    time_elapsed         | 450          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023121408 |
# |    clip_fraction        | 0.00189      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000116    |
# |    std                  | 0.885        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 68879        |
# |    iterations           | 32           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015246804 |
# |    clip_fraction        | 0.00209      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -7.79e-05    |
# |    std                  | 0.883        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 68964        |
# |    iterations           | 33           |
# |    time_elapsed         | 478          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017652987 |
# |    clip_fraction        | 0.00101      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -3.53e-05    |
# |    std                  | 0.881        |
# |    value_loss           | 0.274        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 69034        |
# |    iterations           | 34           |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020689382 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -3.16e-05    |
# |    std                  | 0.879        |
# |    value_loss           | 0.276        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 69148        |
# |    iterations           | 35           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006780693 |
# |    clip_fraction        | 0.000479     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -2.69e-05    |
# |    std                  | 0.876        |
# |    value_loss           | 0.271        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 69240        |
# |    iterations           | 36           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010138709 |
# |    clip_fraction        | 0.00118      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | 3.06e-06     |
# |    std                  | 0.873        |
# |    value_loss           | 0.271        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 69320        |
# |    iterations           | 37           |
# |    time_elapsed         | 533          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015182747 |
# |    clip_fraction        | 0.00199      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -2.59e-05    |
# |    std                  | 0.867        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 69392       |
# |    iterations           | 38          |
# |    time_elapsed         | 547         |
# |    total_timesteps      | 38000000    |
# | train/                  |             |
# |    approx_kl            | 0.002130971 |
# |    clip_fraction        | 0.00584     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 111         |
# |    policy_gradient_loss | -1.05e-05   |
# |    std                  | 0.863       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16           |
# | time/                   |              |
# |    fps                  | 69471        |
# |    iterations           | 39           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029992643 |
# |    clip_fraction        | 0.00729      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -9.72e-06    |
# |    std                  | 0.856        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.25 +/- 4.90
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.3         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0041204016 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 117          |
# |    policy_gradient_loss | 0.000557     |
# |    std                  | 0.852        |
# |    value_loss           | 0.259        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 15.6     |
# | time/              |          |
# |    fps             | 69318    |
# |    iterations      | 40       |
# |    time_elapsed    | 577      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 69399        |
# |    iterations           | 41           |
# |    time_elapsed         | 590          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018398429 |
# |    clip_fraction        | 0.0031       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -3.12e-05    |
# |    std                  | 0.848        |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 69451        |
# |    iterations           | 42           |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007623552 |
# |    clip_fraction        | 0.000738     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -3.64e-05    |
# |    std                  | 0.842        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 69444        |
# |    iterations           | 43           |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031780298 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 126          |
# |    policy_gradient_loss | 8.25e-05     |
# |    std                  | 0.836        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 69351        |
# |    iterations           | 44           |
# |    time_elapsed         | 634          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021596798 |
# |    clip_fraction        | 0.00667      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | 2.63e-05     |
# |    std                  | 0.83         |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 69222        |
# |    iterations           | 45           |
# |    time_elapsed         | 650          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020606217 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -1.42e-05    |
# |    std                  | 0.825        |
# |    value_loss           | 0.269        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 16.2          |
# | time/                   |               |
# |    fps                  | 69272         |
# |    iterations           | 46            |
# |    time_elapsed         | 664           |
# |    total_timesteps      | 46000000      |
# | train/                  |               |
# |    approx_kl            | 0.00040221895 |
# |    clip_fraction        | 0.000731      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.45         |
# |    explained_variance   | 0.177         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.131         |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -2.46e-05     |
# |    std                  | 0.823         |
# |    value_loss           | 0.267         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 69314        |
# |    iterations           | 47           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018500587 |
# |    clip_fraction        | 0.000872     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -5.34e-05    |
# |    std                  | 0.82         |
# |    value_loss           | 0.261        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 69381       |
# |    iterations           | 48          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 48000000    |
# | train/                  |             |
# |    approx_kl            | 0.001195542 |
# |    clip_fraction        | 0.00135     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 141         |
# |    policy_gradient_loss | -3.12e-05   |
# |    std                  | 0.818       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 15.5         |
# | time/                   |              |
# |    fps                  | 69385        |
# |    iterations           | 49           |
# |    time_elapsed         | 706          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018345068 |
# |    clip_fraction        | 0.000546     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -2.55e-05    |
# |    std                  | 0.815        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=20.20 +/- 5.05
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.2         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0017946943 |
# |    clip_fraction        | 0.000515     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -8.95e-06    |
# |    std                  | 0.813        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# ...
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 1449         |
# |    policy_gradient_loss | 0.000338     |
# |    std                  | 0.149        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 68077        |
# |    iterations           | 485          |
# |    time_elapsed         | 7124         |
# |    total_timesteps      | 485000000    |
# | train/                  |              |
# |    approx_kl            | 0.0023199457 |
# |    clip_fraction        | 0.00923      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.972        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.132        |
# |    n_updates            | 1452         |
# |    policy_gradient_loss | 0.000123     |
# |    std                  | 0.148        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 68082        |
# |    iterations           | 486          |
# |    time_elapsed         | 7138         |
# |    total_timesteps      | 486000000    |
# | train/                  |              |
# |    approx_kl            | 0.0025159991 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.98         |
# |    explained_variance   | 0.42         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 1455         |
# |    policy_gradient_loss | 0.000164     |
# |    std                  | 0.148        |
# |    value_loss           | 0.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.2         |
# | time/                   |              |
# |    fps                  | 68087        |
# |    iterations           | 487          |
# |    time_elapsed         | 7152         |
# |    total_timesteps      | 487000000    |
# | train/                  |              |
# |    approx_kl            | 0.0013155416 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.984        |
# |    explained_variance   | 0.37         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 1458         |
# |    policy_gradient_loss | -1.87e-05    |
# |    std                  | 0.148        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 68091        |
# |    iterations           | 488          |
# |    time_elapsed         | 7166         |
# |    total_timesteps      | 488000000    |
# | train/                  |              |
# |    approx_kl            | 0.0023300515 |
# |    clip_fraction        | 0.00919      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.989        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 1461         |
# |    policy_gradient_loss | 0.000149     |
# |    std                  | 0.147        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.1         |
# | time/                   |              |
# |    fps                  | 68088        |
# |    iterations           | 489          |
# |    time_elapsed         | 7181         |
# |    total_timesteps      | 489000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022543394 |
# |    clip_fraction        | 0.00909      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.997        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 1464         |
# |    policy_gradient_loss | 0.000189     |
# |    std                  | 0.147        |
# |    value_loss           | 0.265        |
# ------------------------------------------
# Eval num_timesteps=490000000, episode_reward=21.05 +/- 5.60
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21.1         |
# | time/                   |              |
# |    total_timesteps      | 490000000    |
# | train/                  |              |
# |    approx_kl            | 0.0022814674 |
# |    clip_fraction        | 0.00865      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1            |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 1467         |
# |    policy_gradient_loss | 9.65e-05     |
# |    std                  | 0.147        |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 21.1      |
# | time/              |           |
# |    fps             | 68071     |
# |    iterations      | 490       |
# |    time_elapsed    | 7198      |
# |    total_timesteps | 490000000 |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 68074       |
# |    iterations           | 491         |
# |    time_elapsed         | 7212        |
# |    total_timesteps      | 491000000   |
# | train/                  |             |
# |    approx_kl            | 0.004224074 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.01        |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | 0.000508    |
# |    std                  | 0.146       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 68070        |
# |    iterations           | 492          |
# |    time_elapsed         | 7227         |
# |    total_timesteps      | 492000000    |
# | train/                  |              |
# |    approx_kl            | 0.0054624616 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 1473         |
# |    policy_gradient_loss | 0.000671     |
# |    std                  | 0.145        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 68068        |
# |    iterations           | 493          |
# |    time_elapsed         | 7242         |
# |    total_timesteps      | 493000000    |
# | train/                  |              |
# |    approx_kl            | 0.0028267868 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.02         |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 1476         |
# |    policy_gradient_loss | 0.000537     |
# |    std                  | 0.145        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 68068        |
# |    iterations           | 494          |
# |    time_elapsed         | 7257         |
# |    total_timesteps      | 494000000    |
# | train/                  |              |
# |    approx_kl            | 0.0062731123 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.03         |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 1479         |
# |    policy_gradient_loss | 0.00121      |
# |    std                  | 0.144        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 21.6        |
# | time/                   |             |
# |    fps                  | 68067       |
# |    iterations           | 495         |
# |    time_elapsed         | 7272        |
# |    total_timesteps      | 495000000   |
# | train/                  |             |
# |    approx_kl            | 0.003016782 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.04        |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 1482        |
# |    policy_gradient_loss | 0.000631    |
# |    std                  | 0.144       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 22           |
# | time/                   |              |
# |    fps                  | 68066        |
# |    iterations           | 496          |
# |    time_elapsed         | 7286         |
# |    total_timesteps      | 496000000    |
# | train/                  |              |
# |    approx_kl            | 0.0015740463 |
# |    clip_fraction        | 0.00619      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.04         |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 1485         |
# |    policy_gradient_loss | 0.0001       |
# |    std                  | 0.143        |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 68063       |
# |    iterations           | 497         |
# |    time_elapsed         | 7302        |
# |    total_timesteps      | 497000000   |
# | train/                  |             |
# |    approx_kl            | 0.003591254 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.05        |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 1488        |
# |    policy_gradient_loss | 0.000314    |
# |    std                  | 0.143       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.1         |
# | time/                   |              |
# |    fps                  | 68060        |
# |    iterations           | 498          |
# |    time_elapsed         | 7317         |
# |    total_timesteps      | 498000000    |
# | train/                  |              |
# |    approx_kl            | 0.0012106014 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.05         |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 1491         |
# |    policy_gradient_loss | 0.000285     |
# |    std                  | 0.143        |
# |    value_loss           | 0.257        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 68048       |
# |    iterations           | 499         |
# |    time_elapsed         | 7333        |
# |    total_timesteps      | 499000000   |
# | train/                  |             |
# |    approx_kl            | 0.002648616 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.06        |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 1494        |
# |    policy_gradient_loss | 0.000301    |
# |    std                  | 0.143       |
# |    value_loss           | 0.256       |
# -----------------------------------------
# Eval num_timesteps=500000000, episode_reward=20.55 +/- 5.44
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20.6         |
# | time/                   |              |
# |    total_timesteps      | 500000000    |
# | train/                  |              |
# |    approx_kl            | 0.0019312094 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.06         |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 1497         |
# |    policy_gradient_loss | 0.000202     |
# |    std                  | 0.142        |
# |    value_loss           | 0.258        |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 21.2      |
# | time/              |           |
# |    fps             | 67992     |
# |    iterations      | 500       |
# |    time_elapsed    | 7353      |
# |    total_timesteps | 500000000 |
# ----------------------------------

# %% [markdown]
# ### Loading the model

# %%
best_model_path = (
    ".././Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Opt/2025-10-26_09-37-37/best_model.zip"
)

model = PPO.load(best_model_path, env=sb_rl_env)

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
use_normalized_agent = False

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
#os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[28], line 9
#       7 # Save the figure to the best model path
#       8 plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
# ----> 9 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      10 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# NotADirectoryError: [Errno 20] Not a directory: '.././Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Opt/2025-10-26_09-37-37/best_model.zip/trajectory_plot.png'

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=100000)

# %%
results_rl, fig, tot_rewards = generate_results_table_and_hist_rl_fast(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread   Mean PnL   Std PnL  Mean terminal inventory  \
# RL Agent     2.136071  21.180931  5.212142                  0.24378
#
#           Std terminal inventory
# RL Agent                3.451115

# %%
results, fig, total_rewards = generate_results_table_and_hist_rl(vec_env=vec_env, rl_agent=ppo_agent)

# %%
results
# Out:
#          Mean spread  Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.208628  20.83092  5.548454                   0.313
#
#          Std terminal inventory
# RL Agent               3.892946

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100,0]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
#ppo_agent.get_action(np.array([[inventory,0.5]]))

# %%
full_info_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=get_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = full_info_agent.get_action(np.array([[0,inventory,0.5,100,0]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_09-37-37/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and closed approx agent
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, 0]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL FI δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL FI δ^ask")
    ax4.set_title("FI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, full_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, 0]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)

    # Setting titles and labels
    ax1.set_title("RL FI δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL FI δ^ask")
    ax4.set_title("FI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, full_info_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_09-37-37/policy_time_dependence.png

# %%
# Load the event file
event_file= "./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_09-37-37/PPO_1/events.out.tfevents.1761467858.MacBookAir.lan.93550.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_11-54-23/Training_process.png

# %%
print(ea.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
# Load the event file
rollout_file= "./Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_09-37-37/PPO_1/events.out.tfevents.1761467858.MacBookAir.lan.93550.0"
# Load the data
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()
print("Eval tags:", ea_eval.Tags())

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Eval tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_500_000_000steps_Baseline/2025-10-26_11-54-23/Training_process_rewards.png
