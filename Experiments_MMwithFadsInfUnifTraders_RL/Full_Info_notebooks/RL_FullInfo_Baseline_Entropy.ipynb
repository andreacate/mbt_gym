# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
import os
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %% [markdown]
# ### Parameters

# %%
seed_value = 3 
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
fi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
fi_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=fi_env)
print(fi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x167f8f2b0>

# %%
plot_trajectory_extended(fi_env, fi_agent)

# %%
plot_trajectory(fi_env, fi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_env_fi = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_agent_fi = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=vec_env_fi)

print(vec_env_fi.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x168776c80>

# %%
observations_fi, actions_fi, rewards_fi = generate_trajectory(vec_env_fi, vec_agent_fi)

# %%
results_fi, fig_fi, total_rewards_fi = generate_results_table_and_hist(vec_env=vec_env_fi,agent=vec_agent_fi)

# %%
results_fi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.329476  5.109129                   0.084
#
#           Std terminal inventory
# Inventory               3.210131

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "FIMm_PPO_50_000_000steps_newBaseline_Entropy"

# Paths with timestamp
tensorboard_logdir = f".././Full_Info_models/tensorboard/PPO-learning-FI/{experiment_name}/{run_id}/"
best_model_path = f".././Full_Info_models/PPO-best-FI/{experiment_name}/{run_id}"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[128, 128], vf=[128, 128])]
)

n_epochs = 5
learning_rate = 3e-5
gae_lambda = 0.95
clip_range = 0.1
vf_coef = 0.5
max_grad_norm = 0.2
entropy_coef = 0.05

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
              "ent_coef": entropy_coef
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to .././Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_50_000_000steps_newBaseline_Entropy/2025-11-18_09-03-39/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.79     |
# | time/              |          |
# |    fps             | 583665   |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 5.93          |
# | time/                   |               |
# |    fps                  | 151377        |
# |    iterations           | 2             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 2000000       |
# | train/                  |               |
# |    approx_kl            | 0.00079852436 |
# |    clip_fraction        | 0.0102        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.00323       |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0205       |
# |    n_updates            | 5             |
# |    policy_gradient_loss | -0.000316     |
# |    std                  | 1             |
# |    value_loss           | 0.249         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 6.21          |
# | time/                   |               |
# |    fps                  | 123181        |
# |    iterations           | 3             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 3000000       |
# | train/                  |               |
# |    approx_kl            | 0.00073477277 |
# |    clip_fraction        | 0.00923       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0241        |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.00903      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000295     |
# |    std                  | 1             |
# |    value_loss           | 0.268         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 5.4         |
# | time/                   |             |
# |    fps                  | 112323      |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 4000000     |
# | train/                  |             |
# |    approx_kl            | 0.000811247 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.0491      |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0232     |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.000308   |
# |    std                  | 1           |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.08         |
# | time/                   |              |
# |    fps                  | 106865       |
# |    iterations           | 5            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007907149 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0789       |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0131      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000299    |
# |    std                  | 1.01         |
# |    value_loss           | 0.263        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.6         |
# | time/                   |             |
# |    fps                  | 102876      |
# |    iterations           | 6           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 6000000     |
# | train/                  |             |
# |    approx_kl            | 0.000790303 |
# |    clip_fraction        | 0.00874     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0151     |
# |    n_updates            | 25          |
# |    policy_gradient_loss | -0.000254   |
# |    std                  | 1.01        |
# |    value_loss           | 0.255       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.13         |
# | time/                   |              |
# |    fps                  | 102087       |
# |    iterations           | 7            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007645701 |
# |    clip_fraction        | 0.00824      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0142      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000234    |
# |    std                  | 1.01         |
# |    value_loss           | 0.256        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.33         |
# | time/                   |              |
# |    fps                  | 101239       |
# |    iterations           | 8            |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007822166 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0173      |
# |    n_updates            | 35           |
# |    policy_gradient_loss | -0.000243    |
# |    std                  | 1.01         |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.03          |
# | time/                   |               |
# |    fps                  | 100462        |
# |    iterations           | 9             |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 9000000       |
# | train/                  |               |
# |    approx_kl            | 0.00076291565 |
# |    clip_fraction        | 0.00933       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.176         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0153       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00027      |
# |    std                  | 1.01          |
# |    value_loss           | 0.254         |
# -------------------------------------------
# Eval num_timesteps=10000000, episode_reward=9.39 +/- 4.13
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 9.39         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007888315 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0135      |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.00029     |
# |    std                  | 1.01         |
# |    value_loss           | 0.262        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.55     |
# | time/              |          |
# |    fps             | 98671    |
# |    iterations      | 10       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.21         |
# | time/                   |              |
# |    fps                  | 98602        |
# |    iterations           | 11           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008054683 |
# |    clip_fraction        | 0.00842      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0108      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000233    |
# |    std                  | 1.02         |
# |    value_loss           | 0.262        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.12          |
# | time/                   |               |
# |    fps                  | 98598         |
# |    iterations           | 12            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 12000000      |
# | train/                  |               |
# |    approx_kl            | 0.00080583134 |
# |    clip_fraction        | 0.00823       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.229         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0126       |
# |    n_updates            | 55            |
# |    policy_gradient_loss | -0.000223     |
# |    std                  | 1.02          |
# |    value_loss           | 0.26          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.48          |
# | time/                   |               |
# |    fps                  | 98620         |
# |    iterations           | 13            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 13000000      |
# | train/                  |               |
# |    approx_kl            | 0.00078029296 |
# |    clip_fraction        | 0.00963       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.236         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0188       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000253     |
# |    std                  | 1.02          |
# |    value_loss           | 0.257         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.42          |
# | time/                   |               |
# |    fps                  | 96493         |
# |    iterations           | 14            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 14000000      |
# | train/                  |               |
# |    approx_kl            | 0.00080439204 |
# |    clip_fraction        | 0.00888       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.247         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0147       |
# |    n_updates            | 65            |
# |    policy_gradient_loss | -0.000237     |
# |    std                  | 1.02          |
# |    value_loss           | 0.263         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.53         |
# | time/                   |              |
# |    fps                  | 96387        |
# |    iterations           | 15           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008186641 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0104      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00028     |
# |    std                  | 1.02         |
# |    value_loss           | 0.267        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.38          |
# | time/                   |               |
# |    fps                  | 96214         |
# |    iterations           | 16            |
# |    time_elapsed         | 166           |
# |    total_timesteps      | 16000000      |
# | train/                  |               |
# |    approx_kl            | 0.00077984564 |
# |    clip_fraction        | 0.00975       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0.259         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0164       |
# |    n_updates            | 75            |
# |    policy_gradient_loss | -0.000275     |
# |    std                  | 1.02          |
# |    value_loss           | 0.261         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.66         |
# | time/                   |              |
# |    fps                  | 96387        |
# |    iterations           | 17           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007721138 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.014       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000241    |
# |    std                  | 1.02         |
# |    value_loss           | 0.262        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.17          |
# | time/                   |               |
# |    fps                  | 96434         |
# |    iterations           | 18            |
# |    time_elapsed         | 186           |
# |    total_timesteps      | 18000000      |
# | train/                  |               |
# |    approx_kl            | 0.00081306545 |
# |    clip_fraction        | 0.0103        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.266         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0149       |
# |    n_updates            | 85            |
# |    policy_gradient_loss | -0.000275     |
# |    std                  | 1.03          |
# |    value_loss           | 0.267         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.1          |
# | time/                   |               |
# |    fps                  | 96050         |
# |    iterations           | 19            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 19000000      |
# | train/                  |               |
# |    approx_kl            | 0.00077033543 |
# |    clip_fraction        | 0.00815       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.27          |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.015        |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000228     |
# |    std                  | 1.03          |
# |    value_loss           | 0.262         |
# -------------------------------------------
# Eval num_timesteps=20000000, episode_reward=16.65 +/- 4.92
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 16.6         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007743368 |
# |    clip_fraction        | 0.00783      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.00644     |
# |    n_updates            | 95           |
# |    policy_gradient_loss | -0.00021     |
# |    std                  | 1.03         |
# |    value_loss           | 0.271        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.72     |
# | time/              |          |
# |    fps             | 95646    |
# |    iterations      | 20       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 95351        |
# |    iterations           | 21           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007514586 |
# |    clip_fraction        | 0.00826      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0155      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000248    |
# |    std                  | 1.03         |
# |    value_loss           | 0.259        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 95444        |
# |    iterations           | 22           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006773119 |
# |    clip_fraction        | 0.00921      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0104      |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000253    |
# |    std                  | 1.03         |
# |    value_loss           | 0.269        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 95627        |
# |    iterations           | 23           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006723836 |
# |    clip_fraction        | 0.00641      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0136      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000184    |
# |    std                  | 1.03         |
# |    value_loss           | 0.262        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.2        |
# | time/                   |             |
# |    fps                  | 95494       |
# |    iterations           | 24          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 24000000    |
# | train/                  |             |
# |    approx_kl            | 0.000699819 |
# |    clip_fraction        | 0.00615     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0129     |
# |    n_updates            | 115         |
# |    policy_gradient_loss | -0.000178   |
# |    std                  | 1.03        |
# |    value_loss           | 0.264       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.6          |
# | time/                   |               |
# |    fps                  | 95396         |
# |    iterations           | 25            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 25000000      |
# | train/                  |               |
# |    approx_kl            | 0.00069350307 |
# |    clip_fraction        | 0.00569       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0.248         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0153       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000154     |
# |    std                  | 1.03          |
# |    value_loss           | 0.26          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.79          |
# | time/                   |               |
# |    fps                  | 95441         |
# |    iterations           | 26            |
# |    time_elapsed         | 272           |
# |    total_timesteps      | 26000000      |
# | train/                  |               |
# |    approx_kl            | 0.00067745365 |
# |    clip_fraction        | 0.00761       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.25          |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0143       |
# |    n_updates            | 125           |
# |    policy_gradient_loss | -0.000214     |
# |    std                  | 1.04          |
# |    value_loss           | 0.26          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.8          |
# | time/                   |               |
# |    fps                  | 95287         |
# |    iterations           | 27            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00067034794 |
# |    clip_fraction        | 0.00905       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.255         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0143       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000256     |
# |    std                  | 1.04          |
# |    value_loss           | 0.263         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.9          |
# | time/                   |               |
# |    fps                  | 95240         |
# |    iterations           | 28            |
# |    time_elapsed         | 293           |
# |    total_timesteps      | 28000000      |
# | train/                  |               |
# |    approx_kl            | 0.00066229433 |
# |    clip_fraction        | 0.00729       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.212         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0207       |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -0.000224     |
# |    std                  | 1.04          |
# |    value_loss           | 0.254         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.7        |
# | time/                   |             |
# |    fps                  | 95273       |
# |    iterations           | 29          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 29000000    |
# | train/                  |             |
# |    approx_kl            | 0.000675212 |
# |    clip_fraction        | 0.00666     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0163     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000214   |
# |    std                  | 1.04        |
# |    value_loss           | 0.26        |
# -----------------------------------------
# Eval num_timesteps=30000000, episode_reward=20.15 +/- 5.37
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 20.1          |
# | time/                   |               |
# |    total_timesteps      | 30000000      |
# | train/                  |               |
# |    approx_kl            | 0.00069010287 |
# |    clip_fraction        | 0.00641       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0.237         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0117       |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -0.000193     |
# |    std                  | 1.04          |
# |    value_loss           | 0.27          |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.8     |
# | time/              |          |
# |    fps             | 94967    |
# |    iterations      | 30       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.5          |
# | time/                   |               |
# |    fps                  | 94937         |
# |    iterations           | 31            |
# |    time_elapsed         | 326           |
# |    total_timesteps      | 31000000      |
# | train/                  |               |
# |    approx_kl            | 0.00068746856 |
# |    clip_fraction        | 0.00516       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0169       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000148     |
# |    std                  | 1.04          |
# |    value_loss           | 0.255         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.7          |
# | time/                   |               |
# |    fps                  | 94901         |
# |    iterations           | 32            |
# |    time_elapsed         | 337           |
# |    total_timesteps      | 32000000      |
# | train/                  |               |
# |    approx_kl            | 0.00071110413 |
# |    clip_fraction        | 0.00646       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0.217         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0164       |
# |    n_updates            | 155           |
# |    policy_gradient_loss | -0.00019      |
# |    std                  | 1.04          |
# |    value_loss           | 0.26          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.5         |
# | time/                   |              |
# |    fps                  | 94590        |
# |    iterations           | 33           |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006654303 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0166      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000154    |
# |    std                  | 1.05         |
# |    value_loss           | 0.263        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.4          |
# | time/                   |               |
# |    fps                  | 94699         |
# |    iterations           | 34            |
# |    time_elapsed         | 359           |
# |    total_timesteps      | 34000000      |
# | train/                  |               |
# |    approx_kl            | 0.00072917726 |
# |    clip_fraction        | 0.00595       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.93         |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0125       |
# |    n_updates            | 165           |
# |    policy_gradient_loss | -0.000166     |
# |    std                  | 1.05          |
# |    value_loss           | 0.266         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.7          |
# | time/                   |               |
# |    fps                  | 94751         |
# |    iterations           | 35            |
# |    time_elapsed         | 369           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00061967113 |
# |    clip_fraction        | 0.00383       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.93         |
# |    explained_variance   | 0.232         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0142       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -9.35e-05     |
# |    std                  | 1.05          |
# |    value_loss           | 0.269         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.9          |
# | time/                   |               |
# |    fps                  | 94836         |
# |    iterations           | 36            |
# |    time_elapsed         | 379           |
# |    total_timesteps      | 36000000      |
# | train/                  |               |
# |    approx_kl            | 0.00066401483 |
# |    clip_fraction        | 0.00425       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.93         |
# |    explained_variance   | 0.207         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0171       |
# |    n_updates            | 175           |
# |    policy_gradient_loss | -0.000118     |
# |    std                  | 1.05          |
# |    value_loss           | 0.261         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.3          |
# | time/                   |               |
# |    fps                  | 94872         |
# |    iterations           | 37            |
# |    time_elapsed         | 389           |
# |    total_timesteps      | 37000000      |
# | train/                  |               |
# |    approx_kl            | 0.00055925583 |
# |    clip_fraction        | 0.00121       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.94         |
# |    explained_variance   | 0.21          |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.014        |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -3.31e-05     |
# |    std                  | 1.05          |
# |    value_loss           | 0.267         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.7          |
# | time/                   |               |
# |    fps                  | 94935         |
# |    iterations           | 38            |
# |    time_elapsed         | 400           |
# |    total_timesteps      | 38000000      |
# | train/                  |               |
# |    approx_kl            | 0.00062753644 |
# |    clip_fraction        | 0.00381       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.94         |
# |    explained_variance   | 0.189         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0171       |
# |    n_updates            | 185           |
# |    policy_gradient_loss | -0.000117     |
# |    std                  | 1.05          |
# |    value_loss           | 0.262         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.6         |
# | time/                   |              |
# |    fps                  | 94940        |
# |    iterations           | 39           |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006590164 |
# |    clip_fraction        | 0.00398      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0163      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000107    |
# |    std                  | 1.05         |
# |    value_loss           | 0.261        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.65 +/- 5.01
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 20.7        |
# | time/                   |             |
# |    total_timesteps      | 40000000    |
# | train/                  |             |
# |    approx_kl            | 0.000523147 |
# |    clip_fraction        | 0.0023      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.013      |
# |    n_updates            | 195         |
# |    policy_gradient_loss | -4.99e-05   |
# |    std                  | 1.06        |
# |    value_loss           | 0.268       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    fps             | 94711    |
# |    iterations      | 40       |
# |    time_elapsed    | 422      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 94579        |
# |    iterations           | 41           |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005620925 |
# |    clip_fraction        | 0.00232      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0165      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -6.31e-05    |
# |    std                  | 1.06         |
# |    value_loss           | 0.266        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.7          |
# | time/                   |               |
# |    fps                  | 94671         |
# |    iterations           | 42            |
# |    time_elapsed         | 443           |
# |    total_timesteps      | 42000000      |
# | train/                  |               |
# |    approx_kl            | 0.00061454065 |
# |    clip_fraction        | 0.00502       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.95         |
# |    explained_variance   | 0.194         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0174       |
# |    n_updates            | 205           |
# |    policy_gradient_loss | -0.000146     |
# |    std                  | 1.06          |
# |    value_loss           | 0.263         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13            |
# | time/                   |               |
# |    fps                  | 94775         |
# |    iterations           | 43            |
# |    time_elapsed         | 453           |
# |    total_timesteps      | 43000000      |
# | train/                  |               |
# |    approx_kl            | 0.00054533104 |
# |    clip_fraction        | 0.00299       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.95         |
# |    explained_variance   | 0.211         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0139       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -9.09e-05     |
# |    std                  | 1.06          |
# |    value_loss           | 0.269         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.1          |
# | time/                   |               |
# |    fps                  | 94794         |
# |    iterations           | 44            |
# |    time_elapsed         | 464           |
# |    total_timesteps      | 44000000      |
# | train/                  |               |
# |    approx_kl            | 0.00047615689 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.96         |
# |    explained_variance   | 0.223         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0143       |
# |    n_updates            | 215           |
# |    policy_gradient_loss | -2.56e-05     |
# |    std                  | 1.06          |
# |    value_loss           | 0.267         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.6          |
# | time/                   |               |
# |    fps                  | 94905         |
# |    iterations           | 45            |
# |    time_elapsed         | 474           |
# |    total_timesteps      | 45000000      |
# | train/                  |               |
# |    approx_kl            | 0.00050010544 |
# |    clip_fraction        | 0.00228       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.96         |
# |    explained_variance   | 0.21          |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0119       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -7.39e-05     |
# |    std                  | 1.06          |
# |    value_loss           | 0.27          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 94797        |
# |    iterations           | 46           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0004731479 |
# |    clip_fraction        | 0.0023       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0124      |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -6.67e-05    |
# |    std                  | 1.06         |
# |    value_loss           | 0.269        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.3          |
# | time/                   |               |
# |    fps                  | 94883         |
# |    iterations           | 47            |
# |    time_elapsed         | 495           |
# |    total_timesteps      | 47000000      |
# | train/                  |               |
# |    approx_kl            | 0.00041257107 |
# |    clip_fraction        | 0.00172       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.96         |
# |    explained_variance   | 0.207         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0138       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -4.78e-05     |
# |    std                  | 1.07          |
# |    value_loss           | 0.27          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 95011        |
# |    iterations           | 48           |
# |    time_elapsed         | 505          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006184951 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0103      |
# |    n_updates            | 235          |
# |    policy_gradient_loss | -0.000139    |
# |    std                  | 1.07         |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 95107        |
# |    iterations           | 49           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005296646 |
# |    clip_fraction        | 0.00222      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0139      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -5.2e-05     |
# |    std                  | 1.07         |
# |    value_loss           | 0.272        |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=20.52 +/- 5.02
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 20.5          |
# | time/                   |               |
# |    total_timesteps      | 50000000      |
# | train/                  |               |
# |    approx_kl            | 0.00045901025 |
# |    clip_fraction        | 0.00239       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.97         |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0148       |
# |    n_updates            | 245           |
# |    policy_gradient_loss | -6.28e-05     |
# |    std                  | 1.07          |
# |    value_loss           | 0.269         |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 14.5     |
# | time/              |          |
# |    fps             | 94865    |
# |    iterations      | 50       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././Full_Info_models/PPO-best-FI/FIMm_PPO_50_000_000steps_newBaseline_Entropy/2025-11-18_09-03-39/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.580673  20.375021  5.577366                  -0.042
#
#          Std terminal inventory
# RL Agent               3.896439

# %% [markdown]
# ### Bid/Ask spread vs Inventory

# %%
def plot_actions_vs_fad_colored(observations, actions, max_traj=None):
    """
    Plot ask (solid markers) and bid (dashed markers) spreads vs fad (Ut),
    with inventory as color shading, looping over multiple trajectories.
    
    Parameters
    ----------
    observations : np.ndarray
        Shape (n_traj, 7, T+1)
    actions : np.ndarray
        Shape (n_traj, 2, T)
    max_traj : int or None
        Maximum number of trajectories to include (default: all)
    """
    n_traj = observations.shape[0]
    print(f"Total trajectories available: {n_traj}")
    if max_traj is None:
        max_traj = n_traj

    all_fad = []
    all_inv = []
    all_ask = []
    all_bid = []

    # Collect data from multiple trajectories
    for traj_idx in range(min(max_traj, n_traj)):
        print(f"Processing trajectory {traj_idx+1}/{min(max_traj, n_traj)}")
        obs = observations[traj_idx, :, :-1]  # (7, T)
        acts = actions[traj_idx]              # (2, T)
        #[INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
        fad = obs[3]          # fad Ut
        inventory = obs[0]    # inventory Q
        bid_spread = acts[0]
        ask_spread = acts[1]

        all_fad.append(fad)
        all_inv.append(inventory)
        all_ask.append(ask_spread)
        all_bid.append(bid_spread)

    # Flatten all trajectories into 1D arrays
    fad = np.concatenate(all_fad)
    inventory = np.concatenate(all_inv)
    ask_spread = np.concatenate(all_ask)
    bid_spread = np.concatenate(all_bid)

    # Plot
    plt.figure(figsize=(10, 6))

    sc1 = plt.scatter(fad, ask_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Ask spread", marker="o", s=10)
    sc2 = plt.scatter(fad, bid_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Bid spread", marker="x", s=10)

    plt.xlabel("Fad $U_t$")
    plt.ylabel("Spread")
    plt.title("Bid/Ask Spreads vs Fad with Inventory Coloring (all trajectories)")
    plt.legend()
    cbar = plt.colorbar(sc1)
    cbar.set_label("Inventory $Q$")
    plt.grid(True)
    plt.show()

# %%
plot_actions_vs_fad_colored(observations_rl, actions_rl, 10)
# Out:
# Total trajectories available: 1000
# Processing trajectory 1/10
# Processing trajectory 2/10
# Processing trajectory 3/10
# Processing trajectory 4/10
# Processing trajectory 5/10
# Processing trajectory 6/10
# Processing trajectory 7/10
# Processing trajectory 8/10
# Processing trajectory 9/10
# Processing trajectory 10/10

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0,0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory,0.5,100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
full_info_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Full Information action
fi_bid_actions = []
fi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = full_info_agent.get_action(np.array([[0,inventory,0.5,100,0]])).reshape(-1)
    fi_bid_actions.append(bid_action)
    fi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, fi_bid_actions, label="bid (FI)", color="k", linestyle="--")
ax.plot(inventories, fi_ask_actions, label="ask (FI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Full Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././Full_Info_models/PPO-best-FI/FIMm_PPO_50_000_000steps_newBaseline_Entropy/2025-11-18_09-03-39/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and FI agents
def plot_policy_time_dependence(ppo_agent, fi_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        fi_bids = []
        fi_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get FI agent's actions
            fi_bid, fi_ask = fi_agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            fi_bids.append(fi_bid)
            fi_asks.append(fi_ask)

        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, fi_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, fi_asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, full_info_agent)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 plot_policy_time_dependence(ppo_agent, full_info_agent)
#
# Cell In[46], line 50, in plot_policy_time_dependence(ppo_agent, fi_agent)
#      47     normalized_time = t
#      49 # Get PPO agent's actions
# ---> 50 rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
#      51 rl_bids.append(rl_bid)
#      52 rl_asks.append(rl_ask)
#
# File ~/Desktop/gitProject/mbt_gym/Experiments_MMwithFadsInfUnifTraders_RL/Full_Info_notebooks/../../mbt_gym/agents/SbAgent.py:44, in SbAgent.get_action(self, state)
#      34 def get_action(self, state: np.ndarray) -> np.ndarray:
#      35     # TODO: handle reduced training state space if needed (attention to the dimension reduced state or not?)
#      36     # If the current env is NOT normalized but the model was trained on normalized obs,
#    (...)
#      42
#      43     # Get action from model
# ---> 44     action = self.model.predict(state, deterministic=True)[0].reshape(state.shape[0], self.num_actions)
#      46     # If the current env (for evaluation) is NOT normalized but the model outputs normalized actions,
#      47     # we need to denormalize them
#      48     if not self.env.normalise_action_space_ and self.use_normalized_agent and hasattr(self.env, 'normalise_action'):
#      49         #print("check")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)
#     542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:404, in is_vectorized_observation(observation, observation_space)
#     402 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     403     if isinstance(observation_space, space_type):
# --> 404         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     405 else:
#     406     # for-else happens if no break is called
#     407     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:271, in is_vectorized_box_observation(observation, observation_space)
#     269     return True
#     270 else:
# --> 271     raise ValueError(
#     272         f"Error: Unexpected observation shape {observation.shape} for "
#     273         + f"Box environment, please use {observation_space.shape} "
#     274         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     275     )
#
# ValueError: Error: Unexpected observation shape (1, 3) for Box environment, please use (4,) or (n_env, 4) for the observation shape.

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

        # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, t]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)

        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))

        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))

    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, full_info_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Full_Info_models/PPO-best-FI/FIMm_PPO_100_000_000steps_Baseline/2025-10-23_10-25-27/policy_time_dependence.png

# %%
# Load the event file
event_file= ".././Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_50_000_000steps_newBaseline/2025-11-16_18-13-43/PPO_1/events.out.tfevents.1763313225.MacBookAir.lan.37154.0"
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 34
#      32 # Save the figure to the best model path
#      33 plot_filename = os.path.join(best_model_path, "Training_process.png")
# ---> 34 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      35 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Full_Info_models/PPO-best-FI/FIMm_PPO_50_000_000steps_newBaseline/2025-11-16_18-13-43/Training_process.png'

# %%
# === Load rollout rewards ===
rollout_file= ".././Full_Info_models/tensorboard/PPO-learning-FI/FIMm_PPO_50_000_000steps_newBaseline/2025-11-16_18-13-43/PPO_1/events.out.tfevents.1763313225.MacBookAir.lan.37154.0"
# Load the data
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()
print("Eval tags:", ea_eval.Tags())

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Eval tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 51
#      49 # Save the figure
#      50 plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
# ---> 51 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      52 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Full_Info_models/PPO-best-FI/FIMm_PPO_50_000_000steps_newBaseline/2025-11-16_18-13-43/Training_process_rewards.png'
