# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
import os
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3 import DDPG
from stable_baselines3 import SAC
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor
from stable_baselines3.common.vec_env import VecNormalize

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %% [markdown]
# ### Parameters

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
fi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
fi_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=fi_env)
print(fi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x14fc97c70>

# %%
plot_trajectory_extended(fi_env, fi_agent)

# %%
plot_trajectory(fi_env, fi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_env_fi = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_agent_fi = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=vec_env_fi)

print(vec_env_fi.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x15235d450>

# %%
observations_fi, actions_fi, rewards_fi = generate_trajectory(vec_env_fi, vec_agent_fi)

# %%
results_fi, fig_fi, total_rewards_fi = generate_results_table_and_hist(vec_env=vec_env_fi,agent=vec_agent_fi)

# %%
results_fi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.259366  4.896308                  -0.098
#
#           Std terminal inventory
# Inventory               3.100386

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### SAC

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "FIMm_SAC_50_000_000steps" 

# Paths with timestamp
tensorboard_logdir = f".././Full_Info_models/tensorboard/SAC-learning-FI/{experiment_name}/{run_id}/"
best_model_path = f".././Full_Info_models/SAC-best-FI/{experiment_name}/{run_id}/"

# %%
policy_kwargs = dict(net_arch=dict(pi=[256, 256], qf=[256, 256]))

# SAC is an off-policy algorithm and uses a replay buffer. Its parameters are different.
SAC_params = {
    "policy": 'MlpPolicy', 
    "env": sb_rl_env, 
    "verbose": 1, 
    "tensorboard_log": tensorboard_logdir,
    "policy_kwargs": policy_kwargs,
    "buffer_size": 1_000_000,     # Size of the replay buffer. 1M is a good default.
    "batch_size": 256,            # Number of samples from the buffer for each update.
    "learning_starts": 10000,     # How many steps to collect before starting to learn.
    "gamma": 0.99,                # Discount factor.
    "tau": 0.005,                 # The soft update coefficient for target networks.
    "learning_rate": 3e-4,        # Learning rate, often 0.0003 for SAC.
}

callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       best_model_save_path=best_model_path, 
                       deterministic=True)

callback = EvalCallback(**callback_params)

model = SAC(**SAC_params, device="cpu")
# Out:
# Using cpu device

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to .././Full_Info_models/tensorboard/SAC-learning-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 121714   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 87.2     |
# |    critic_loss     | 79.7     |
# |    ent_coef        | 1.34     |
# |    ent_coef_loss   | -2.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 989      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 121670   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 121658   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 121649   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 121637   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 121626   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 121615   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 121603   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 121594   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 121585   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 121576   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 121567   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 121558   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 121548   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 121538   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 121529   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 121519   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 121510   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 121500   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 121468   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 121455   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 121445   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 121434   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 121420   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 121410   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 121400   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 121390   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 121380   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 121370   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 121359   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 121349   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 121339   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 121329   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 121319   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 121311   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 121301   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 121292   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 121281   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 121269   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 121256   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 121244   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 121231   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 121220   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 121210   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 121195   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 121153   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 121084   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 121058   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 121038   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 121017   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 120973   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 120943   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 120918   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 120902   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 120884   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 120837   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 120805   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 120784   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 120761   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 120732   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 120702   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 120684   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 120668   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 120644   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 120618   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 120591   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 120579   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 120554   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 120534   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 120512   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 120487   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 120462   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 120437   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 120418   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 120402   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 120382   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 120318   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 120295   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 120238   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 120196   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 120173   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 120159   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 120147   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 120134   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 120121   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 120108   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 120096   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 120087   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 120077   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 120061   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 120042   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 120029   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 120019   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 120005   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 119993   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 119980   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 119968   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 119959   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 119950   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 119940   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 119931   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 119921   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 119912   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 119904   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 119894   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 119885   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 119877   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 119868   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 119861   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 119854   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 119843   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 119833   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 119825   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 119815   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 119806   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 119797   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 119789   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 119780   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 119772   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 119763   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 119755   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 119746   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 119737   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 119729   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 119720   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 504      |
# |    fps             | 119709   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 119699   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 119688   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 119669   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 119658   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 119650   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 119641   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 119631   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 119622   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 119612   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 544      |
# |    fps             | 119603   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 548      |
# |    fps             | 119594   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 119585   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 556      |
# |    fps             | 119576   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 119568   |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ---------------------------------
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49816    |
# |    fps             | 109905   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49820    |
# |    fps             | 109904   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49824    |
# |    fps             | 109904   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49828    |
# |    fps             | 109904   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49832    |
# |    fps             | 109903   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49836    |
# |    fps             | 109903   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49840    |
# |    fps             | 109902   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49844    |
# |    fps             | 109902   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49848    |
# |    fps             | 109902   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49852    |
# |    fps             | 109901   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49856    |
# |    fps             | 109901   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49860    |
# |    fps             | 109900   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49864    |
# |    fps             | 109900   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49868    |
# |    fps             | 109899   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49872    |
# |    fps             | 109899   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49876    |
# |    fps             | 109898   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49880    |
# |    fps             | 109898   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49884    |
# |    fps             | 109897   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49888    |
# |    fps             | 109897   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49892    |
# |    fps             | 109896   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49896    |
# |    fps             | 109896   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49900    |
# |    fps             | 109896   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49904    |
# |    fps             | 109895   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49908    |
# |    fps             | 109894   |
# |    time_elapsed    | 454      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49912    |
# |    fps             | 109886   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49916    |
# |    fps             | 109885   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49920    |
# |    fps             | 109878   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49924    |
# |    fps             | 109877   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49928    |
# |    fps             | 109867   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49932    |
# |    fps             | 109867   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49936    |
# |    fps             | 109863   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49940    |
# |    fps             | 109862   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49944    |
# |    fps             | 109861   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49948    |
# |    fps             | 109860   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49952    |
# |    fps             | 109860   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49956    |
# |    fps             | 109859   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49960    |
# |    fps             | 109859   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49964    |
# |    fps             | 109858   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49968    |
# |    fps             | 109858   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49972    |
# |    fps             | 109858   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49976    |
# |    fps             | 109858   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49980    |
# |    fps             | 109857   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49984    |
# |    fps             | 109848   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49988    |
# |    fps             | 109847   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49992    |
# |    fps             | 109843   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 49996    |
# |    fps             | 109840   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.01     |
# | time/              |          |
# |    episodes        | 50000    |
# |    fps             | 109839   |
# |    time_elapsed    | 455      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././Full_Info_models/SAC-best-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    3.659879  16.394641  5.159347                  -0.469
#
#          Std terminal inventory
# RL Agent                0.83249

# %% [markdown]
# ### Bid/Ask spread vs Inventory

# %%
def plot_actions_vs_fad_colored(observations, actions, max_traj=None):
    """
    Plot ask (solid markers) and bid (dashed markers) spreads vs fad (Ut),
    with inventory as color shading, looping over multiple trajectories.
    
    Parameters
    ----------
    observations : np.ndarray
        Shape (n_traj, 7, T+1)
    actions : np.ndarray
        Shape (n_traj, 2, T)
    max_traj : int or None
        Maximum number of trajectories to include (default: all)
    """
    n_traj = observations.shape[0]
    print(f"Total trajectories available: {n_traj}")
    if max_traj is None:
        max_traj = n_traj

    all_fad = []
    all_inv = []
    all_ask = []
    all_bid = []

    # Collect data from multiple trajectories
    for traj_idx in range(min(max_traj, n_traj)):
        print(f"Processing trajectory {traj_idx+1}/{min(max_traj, n_traj)}")
        obs = observations[traj_idx, :, :-1]  # (7, T)
        acts = actions[traj_idx]              # (2, T)
        #[INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FADS_INDEX]
        fad = obs[3]          # fad Ut
        inventory = obs[0]    # inventory Q
        bid_spread = acts[0]
        ask_spread = acts[1]

        all_fad.append(fad)
        all_inv.append(inventory)
        all_ask.append(ask_spread)
        all_bid.append(bid_spread)

    # Flatten all trajectories into 1D arrays
    fad = np.concatenate(all_fad)
    inventory = np.concatenate(all_inv)
    ask_spread = np.concatenate(all_ask)
    bid_spread = np.concatenate(all_bid)

    # Plot
    plt.figure(figsize=(10, 6))

    sc1 = plt.scatter(fad, ask_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Ask spread", marker="o", s=10)
    sc2 = plt.scatter(fad, bid_spread, c=inventory, cmap="viridis",
                      alpha=0.6, label="Bid spread", marker="x", s=10)

    plt.xlabel("Fad $U_t$")
    plt.ylabel("Spread")
    plt.title("Bid/Ask Spreads vs Fad with Inventory Coloring (all trajectories)")
    plt.legend()
    cbar = plt.colorbar(sc1)
    cbar.set_label("Inventory $Q$")
    plt.grid(True)
    plt.show()

# %%
plot_actions_vs_fad_colored(observations_rl, actions_rl, 10)
# Out:
# Total trajectories available: 1000
# Processing trajectory 1/10
# Processing trajectory 2/10
# Processing trajectory 3/10
# Processing trajectory 4/10
# Processing trajectory 5/10
# Processing trajectory 6/10
# Processing trajectory 7/10
# Processing trajectory 8/10
# Processing trajectory 9/10
# Processing trajectory 10/10

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0,0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory,0.5,100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
full_info_agent = OptimizedFullInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Full Information action
fi_bid_actions = []
fi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = full_info_agent.get_action(np.array([[0,inventory,0.5,100,0]])).reshape(-1)
    fi_bid_actions.append(bid_action)
    fi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, fi_bid_actions, label="bid (FI)", color="k", linestyle="--")
ax.plot(inventories, fi_ask_actions, label="ask (FI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Full Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././Full_Info_models/SAC-best-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and FI agents
def plot_policy_time_dependence(ppo_agent, fi_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context


    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        fi_bids = []
        fi_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get FI agent's actions
            fi_bid, fi_ask = fi_agent.get_action(np.array([[0, inv, t, price, fad]])).reshape(-1)
            fi_bids.append(fi_bid)
            fi_asks.append(fi_ask)

        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, fi_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, fi_asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, full_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context
    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context


    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get agent's actions
            bid, ask = agent.get_action(np.array([[0, inv, t, price, fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)

        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))

        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))

    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("FI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("FI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Full Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, full_info_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Full_Info_models/SAC-best-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/policy_time_dependence.png

# %%
# Load the event file
event_file= ".././Full_Info_models/tensorboard/SAC-learning-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/SAC_1/events.out.tfevents.1762950432.Andreas-MacBook-Air.local.75623.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Full_Info_models/SAC-best-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/Training_process.png

# %%
# === Load rollout rewards ===
rollout_file= ".././Full_Info_models/tensorboard/SAC-learning-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/SAC_1/events.out.tfevents.1762950432.Andreas-MacBook-Air.local.75623.0"
# Load the data
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()
print("Eval tags:", ea_eval.Tags())

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_fi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Eval tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/actor_loss', 'train/critic_loss', 'train/ent_coef', 'train/ent_coef_loss', 'train/learning_rate', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/actor_loss', 'train/critic_loss', 'train/ent_coef', 'train/ent_coef_loss', 'train/learning_rate', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././Full_Info_models/SAC-best-FI/FIMm_SAC_50_000_000steps/2025-11-12_13-27-11/Training_process_rewards.png
