# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0
total_arrivals = 30.0

def m(t, eta):
    return u0 * np.exp(-eta * t)

def v(t, eta):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_aux_integral_for_psi_eta(gamma, eta_values, fads_proportion):
    """Compute psi for multiple eta values using the discretized integral version."""
    time_grid = np.linspace(0, terminal_time, n_steps)

    v_t = v(time_grid, eta)
    c = gamma * sigma * fads_proportion
    integrand_values = np.exp((c**2) / 2 * v_t)
    aux_integral = terminal_time * np.mean(integrand_values)
    psi = (total_arrivals * terminal_time - phi * terminal_time) / aux_integral

    return psi

psi = compute_aux_integral_for_psi_eta(gamma, eta, fads_proportion)
print("psi value:", psi)
# Out:
# psi value: 14.872343376978963

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,

                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
pi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=pi_env)
print(pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x17b697e20>

# %%
plot_trajectory_extended(pi_env, pi_agent)

# %%
plot_trajectory(pi_env, pi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_pi_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=vec_pi_env)

print(vec_pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x17eb993f0>

# %%
observations_pi, actions_pi, rewards_pi = generate_trajectory(vec_pi_env, vec_pi_agent)

# %%
results_pi, fig_pi, total_rewards_pi = generate_results_table_and_hist(vec_env=vec_pi_env,agent=vec_pi_agent)

# %%
results_pi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.145828  4.880012                  -0.095
#
#           Std terminal inventory
# Inventory               3.106441

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FILTERED_FADS_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "PIMm_PPO_50_000_000steps_Entropy_Callback"
# Paths with timestamp
tensorboard_logdir = f".././Partial_Info_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././Partial_Info_models/PPO-best/{experiment_name}/{run_id}/"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[128, 128], vf=[128, 128])]
)

n_epochs = 5
learning_rate = 3e-5
gae_lambda = 0.95
clip_range = 0.1
vf_coef = 0.5
max_grad_norm = 0.2
#entropy_coefficient = 0.05

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
              #"ent_coef": entropy_coefficient
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

#callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to .././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.99     |
# | time/              |          |
# |    fps             | 682001   |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.37         |
# | time/                   |              |
# |    fps                  | 172927       |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007424028 |
# |    clip_fraction        | 0.0098       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.000733     |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.00451     |
# |    n_updates            | 5            |
# |    policy_gradient_loss | -0.000305    |
# |    std                  | 1            |
# |    value_loss           | 0.268        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.71         |
# | time/                   |              |
# |    fps                  | 138597       |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0008058249 |
# |    clip_fraction        | 0.00784      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00919      |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.00451     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000244    |
# |    std                  | 1            |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 6.74          |
# | time/                   |               |
# |    fps                  | 126025        |
# |    iterations           | 4             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 4000000       |
# | train/                  |               |
# |    approx_kl            | 0.00064258836 |
# |    clip_fraction        | 0.00473       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0241        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0151        |
# |    n_updates            | 15            |
# |    policy_gradient_loss | -0.000157     |
# |    std                  | 1             |
# |    value_loss           | 0.28          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 4.98          |
# | time/                   |               |
# |    fps                  | 118926        |
# |    iterations           | 5             |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 5000000       |
# | train/                  |               |
# |    approx_kl            | 0.00078211323 |
# |    clip_fraction        | 0.00716       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0.0344        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0123        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000249     |
# |    std                  | 1.01          |
# |    value_loss           | 0.258         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.38         |
# | time/                   |              |
# |    fps                  | 114713       |
# |    iterations           | 6            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0008207471 |
# |    clip_fraction        | 0.00843      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0561       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0197       |
# |    n_updates            | 25           |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 1.01         |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.01         |
# | time/                   |              |
# |    fps                  | 112219       |
# |    iterations           | 7            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007716737 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0729       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0277       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000199    |
# |    std                  | 1.01         |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.55          |
# | time/                   |               |
# |    fps                  | 109506        |
# |    iterations           | 8             |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 8000000       |
# | train/                  |               |
# |    approx_kl            | 0.00079013157 |
# |    clip_fraction        | 0.00901       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0.0991        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0331        |
# |    n_updates            | 35            |
# |    policy_gradient_loss | -0.000263     |
# |    std                  | 1.01          |
# |    value_loss           | 0.255         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.55          |
# | time/                   |               |
# |    fps                  | 106200        |
# |    iterations           | 9             |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 9000000       |
# | train/                  |               |
# |    approx_kl            | 0.00080051535 |
# |    clip_fraction        | 0.00772       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0422        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000241     |
# |    std                  | 1.01          |
# |    value_loss           | 0.258         |
# -------------------------------------------
# Eval num_timesteps=10000000, episode_reward=9.14 +/- 5.06
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 9.14         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008235599 |
# |    clip_fraction        | 0.00861      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0439       |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000269    |
# |    std                  | 1.01         |
# |    value_loss           | 0.248        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.7      |
# | time/              |          |
# |    fps             | 103374   |
# |    iterations      | 10       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.59          |
# | time/                   |               |
# |    fps                  | 102721        |
# |    iterations           | 11            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 11000000      |
# | train/                  |               |
# |    approx_kl            | 0.00072916906 |
# |    clip_fraction        | 0.00884       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.15          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0569        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00027      |
# |    std                  | 1.01          |
# |    value_loss           | 0.26          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.14         |
# | time/                   |              |
# |    fps                  | 102270       |
# |    iterations           | 12           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008247257 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.06         |
# |    n_updates            | 55           |
# |    policy_gradient_loss | -0.000345    |
# |    std                  | 1.01         |
# |    value_loss           | 0.252        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.12         |
# | time/                   |              |
# |    fps                  | 101809       |
# |    iterations           | 13           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007918108 |
# |    clip_fraction        | 0.00882      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0672       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000259    |
# |    std                  | 1.01         |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.42         |
# | time/                   |              |
# |    fps                  | 101050       |
# |    iterations           | 14           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007361971 |
# |    clip_fraction        | 0.00632      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0819       |
# |    n_updates            | 65           |
# |    policy_gradient_loss | -0.000192    |
# |    std                  | 1.01         |
# |    value_loss           | 0.268        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 8.17          |
# | time/                   |               |
# |    fps                  | 100922        |
# |    iterations           | 15            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 15000000      |
# | train/                  |               |
# |    approx_kl            | 0.00073727255 |
# |    clip_fraction        | 0.00854       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.0839        |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000267     |
# |    std                  | 1.02          |
# |    value_loss           | 0.257         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.55         |
# | time/                   |              |
# |    fps                  | 100706       |
# |    iterations           | 16           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007268124 |
# |    clip_fraction        | 0.00881      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0937       |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.00027     |
# |    std                  | 1.02         |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.84         |
# | time/                   |              |
# |    fps                  | 100444       |
# |    iterations           | 17           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007488158 |
# |    clip_fraction        | 0.00899      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.1          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000277    |
# |    std                  | 1.02         |
# |    value_loss           | 0.265        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 100146       |
# |    iterations           | 18           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007449981 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.11         |
# |    n_updates            | 85           |
# |    policy_gradient_loss | -0.00027     |
# |    std                  | 1.02         |
# |    value_loss           | 0.265        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.54          |
# | time/                   |               |
# |    fps                  | 99767         |
# |    iterations           | 19            |
# |    time_elapsed         | 190           |
# |    total_timesteps      | 19000000      |
# | train/                  |               |
# |    approx_kl            | 0.00070031977 |
# |    clip_fraction        | 0.00865       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.234         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.115         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000285     |
# |    std                  | 1.02          |
# |    value_loss           | 0.265         |
# -------------------------------------------
# Eval num_timesteps=20000000, episode_reward=16.44 +/- 4.79
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | 16.4       |
# | time/                   |            |
# |    total_timesteps      | 20000000   |
# | train/                  |            |
# |    approx_kl            | 0.00067526 |
# |    clip_fraction        | 0.00807    |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.239      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.119      |
# |    n_updates            | 95         |
# |    policy_gradient_loss | -0.000262  |
# |    std                  | 1.02       |
# |    value_loss           | 0.259      |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.21     |
# | time/              |          |
# |    fps             | 98913    |
# |    iterations      | 20       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.3          |
# | time/                   |               |
# |    fps                  | 98767         |
# |    iterations           | 21            |
# |    time_elapsed         | 212           |
# |    total_timesteps      | 21000000      |
# | train/                  |               |
# |    approx_kl            | 0.00072457443 |
# |    clip_fraction        | 0.0093        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.255         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.135         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000261     |
# |    std                  | 1.02          |
# |    value_loss           | 0.276         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.98         |
# | time/                   |              |
# |    fps                  | 98668        |
# |    iterations           | 22           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007270203 |
# |    clip_fraction        | 0.0093       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000296    |
# |    std                  | 1.01         |
# |    value_loss           | 0.266        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 98504        |
# |    iterations           | 23           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006927304 |
# |    clip_fraction        | 0.00804      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.126        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000261    |
# |    std                  | 1.01         |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.9          |
# | time/                   |               |
# |    fps                  | 98456         |
# |    iterations           | 24            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 24000000      |
# | train/                  |               |
# |    approx_kl            | 0.00067623425 |
# |    clip_fraction        | 0.00871       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.134         |
# |    n_updates            | 115           |
# |    policy_gradient_loss | -0.000259     |
# |    std                  | 1.01          |
# |    value_loss           | 0.27          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.4          |
# | time/                   |               |
# |    fps                  | 98406         |
# |    iterations           | 25            |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 25000000      |
# | train/                  |               |
# |    approx_kl            | 0.00060116115 |
# |    clip_fraction        | 0.00487       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.244         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.132         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000161     |
# |    std                  | 1.01          |
# |    value_loss           | 0.273         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 98146        |
# |    iterations           | 26           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006792586 |
# |    clip_fraction        | 0.00866      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 125          |
# |    policy_gradient_loss | -0.000273    |
# |    std                  | 1.01         |
# |    value_loss           | 0.269        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.1          |
# | time/                   |               |
# |    fps                  | 97846         |
# |    iterations           | 27            |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00068191165 |
# |    clip_fraction        | 0.00578       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.256         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.135         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000179     |
# |    std                  | 1.01          |
# |    value_loss           | 0.274         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 97656        |
# |    iterations           | 28           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006521036 |
# |    clip_fraction        | 0.00442      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.129        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.000142    |
# |    std                  | 1.01         |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 97549        |
# |    iterations           | 29           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006755149 |
# |    clip_fraction        | 0.00646      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.134        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000218    |
# |    std                  | 1.01         |
# |    value_loss           | 0.273        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=19.63 +/- 5.04
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 19.6          |
# | time/                   |               |
# |    total_timesteps      | 30000000      |
# | train/                  |               |
# |    approx_kl            | 0.00057771464 |
# |    clip_fraction        | 0.00546       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.233         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.13          |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -0.000168     |
# |    std                  | 1.01          |
# |    value_loss           | 0.267         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    fps             | 96942    |
# |    iterations      | 30       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.6         |
# | time/                   |              |
# |    fps                  | 96785        |
# |    iterations           | 31           |
# |    time_elapsed         | 320          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006936997 |
# |    clip_fraction        | 0.00636      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000201    |
# |    std                  | 1.01         |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 96726        |
# |    iterations           | 32           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005316684 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.137        |
# |    n_updates            | 155          |
# |    policy_gradient_loss | -0.000166    |
# |    std                  | 1.01         |
# |    value_loss           | 0.278        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.5          |
# | time/                   |               |
# |    fps                  | 96572         |
# |    iterations           | 33            |
# |    time_elapsed         | 341           |
# |    total_timesteps      | 33000000      |
# | train/                  |               |
# |    approx_kl            | 0.00059667707 |
# |    clip_fraction        | 0.00497       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0.221         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.13          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000156     |
# |    std                  | 1.01          |
# |    value_loss           | 0.267         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 96238       |
# |    iterations           | 34          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 34000000    |
# | train/                  |             |
# |    approx_kl            | 0.000570227 |
# |    clip_fraction        | 0.00535     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.134       |
# |    n_updates            | 165         |
# |    policy_gradient_loss | -0.000185   |
# |    std                  | 1.01        |
# |    value_loss           | 0.275       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 96201        |
# |    iterations           | 35           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006670851 |
# |    clip_fraction        | 0.00399      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.132        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000133    |
# |    std                  | 1.01         |
# |    value_loss           | 0.269        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.4         |
# | time/                   |              |
# |    fps                  | 96173        |
# |    iterations           | 36           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006698991 |
# |    clip_fraction        | 0.00446      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.135        |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -0.000147    |
# |    std                  | 1            |
# |    value_loss           | 0.274        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 13.2          |
# | time/                   |               |
# |    fps                  | 96174         |
# |    iterations           | 37            |
# |    time_elapsed         | 384           |
# |    total_timesteps      | 37000000      |
# | train/                  |               |
# |    approx_kl            | 0.00067691255 |
# |    clip_fraction        | 0.00538       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0.209         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.131         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000181     |
# |    std                  | 1             |
# |    value_loss           | 0.27          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.5          |
# | time/                   |               |
# |    fps                  | 96063         |
# |    iterations           | 38            |
# |    time_elapsed         | 395           |
# |    total_timesteps      | 38000000      |
# | train/                  |               |
# |    approx_kl            | 0.00065361254 |
# |    clip_fraction        | 0.00581       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.198         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.131         |
# |    n_updates            | 185           |
# |    policy_gradient_loss | -0.000196     |
# |    std                  | 1             |
# |    value_loss           | 0.269         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 96080        |
# |    iterations           | 39           |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006602402 |
# |    clip_fraction        | 0.00473      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000157    |
# |    std                  | 1            |
# |    value_loss           | 0.27         |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=21.49 +/- 5.21
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 21.5          |
# | time/                   |               |
# |    total_timesteps      | 40000000      |
# | train/                  |               |
# |    approx_kl            | 0.00064156455 |
# |    clip_fraction        | 0.00506       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.191         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.128         |
# |    n_updates            | 195           |
# |    policy_gradient_loss | -0.000159     |
# |    std                  | 1             |
# |    value_loss           | 0.266         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    fps             | 95825    |
# |    iterations      | 40       |
# |    time_elapsed    | 417      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 95833        |
# |    iterations           | 41           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005762245 |
# |    clip_fraction        | 0.00256      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -9.33e-05    |
# |    std                  | 1            |
# |    value_loss           | 0.268        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14.5          |
# | time/                   |               |
# |    fps                  | 95828         |
# |    iterations           | 42            |
# |    time_elapsed         | 438           |
# |    total_timesteps      | 42000000      |
# | train/                  |               |
# |    approx_kl            | 0.00064966315 |
# |    clip_fraction        | 0.00364       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.175         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.131         |
# |    n_updates            | 205           |
# |    policy_gradient_loss | -0.000121     |
# |    std                  | 0.999         |
# |    value_loss           | 0.269         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 95827       |
# |    iterations           | 43          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 43000000    |
# | train/                  |             |
# |    approx_kl            | 0.000586932 |
# |    clip_fraction        | 0.00315     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.135       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000117   |
# |    std                  | 0.998       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 95817        |
# |    iterations           | 44           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006562283 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.138        |
# |    n_updates            | 215          |
# |    policy_gradient_loss | -8.86e-05    |
# |    std                  | 0.998        |
# |    value_loss           | 0.281        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.3         |
# | time/                   |              |
# |    fps                  | 95788        |
# |    iterations           | 45           |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006460621 |
# |    clip_fraction        | 0.00441      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000151    |
# |    std                  | 0.996        |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 95816        |
# |    iterations           | 46           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006163114 |
# |    clip_fraction        | 0.00392      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.134        |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -0.000141    |
# |    std                  | 0.995        |
# |    value_loss           | 0.274        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 95827        |
# |    iterations           | 47           |
# |    time_elapsed         | 490          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006539733 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.137        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.994        |
# |    value_loss           | 0.278        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 95849        |
# |    iterations           | 48           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005116785 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.133        |
# |    n_updates            | 235          |
# |    policy_gradient_loss | -7.84e-05    |
# |    std                  | 0.993        |
# |    value_loss           | 0.272        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14.6          |
# | time/                   |               |
# |    fps                  | 95872         |
# |    iterations           | 49            |
# |    time_elapsed         | 511           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00056057784 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.187         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.132         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -7.67e-05     |
# |    std                  | 0.992         |
# |    value_loss           | 0.27          |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=20.04 +/- 5.76
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 20           |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005159877 |
# |    clip_fraction        | 0.00227      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.133        |
# |    n_updates            | 245          |
# |    policy_gradient_loss | -8e-05       |
# |    std                  | 0.991        |
# |    value_loss           | 0.273        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 13.9     |
# | time/              |          |
# |    fps             | 95641    |
# |    iterations      | 50       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.584683  20.388776  5.665674                  -0.165
#
#          Std terminal inventory
# RL Agent               3.951933

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory, 0, 0, 0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory, 0.5, 100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
partial_info_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Partial Information action
pi_bid_actions = []
pi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = partial_info_agent.get_action(np.array([[0,inventory,0.5,100,0,0]])).reshape(-1)
    pi_bid_actions.append(bid_action)
    pi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, pi_bid_actions, label="bid (PI)", color="k", linestyle="--")
ax.plot(inventories, pi_ask_actions, label="ask (PI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Partial Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and closed approx agent
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # PI bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # PI ask
    
        
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context
    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions 
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, partial_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, filtered_fad]])).reshape(-1)
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, pi_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.381767245747163
# median:  19.836706227447742
# std:  5.654432823988684

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/PPO_1/events.out.tfevents.1763376072.MacBookAir.lan.83954.0"
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/PPO_1/events.out.tfevents.1763376072.MacBookAir.lan.83954.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/PPO_1/events.out.tfevents.1763376072.MacBookAir.lan.83954.0"
# Load the data
# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run

ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)
    
# Add baseline line
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_Entropy_Callback/2025-11-17_11-41-11/Training_process_rewards.png
