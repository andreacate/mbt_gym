# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0
total_arrivals = 30.0

def m(t, eta):
    return u0 * np.exp(-eta * t)

def v(t, eta):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_aux_integral_for_psi_eta(gamma, eta_values, fads_proportion):
    """Compute psi for multiple eta values using the discretized integral version."""
    time_grid = np.linspace(0, terminal_time, n_steps)

    v_t = v(time_grid, eta)
    c = gamma * sigma * fads_proportion
    integrand_values = np.exp((c**2) / 2 * v_t)
    aux_integral = terminal_time * np.mean(integrand_values)
    psi = (total_arrivals * terminal_time - phi * terminal_time) / aux_integral

    return psi

psi = compute_aux_integral_for_psi_eta(gamma, eta, fads_proportion)
print("psi value:", psi)
# Out:
# psi value: 14.872343376978963

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,

                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
pi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=pi_env)
print(pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x16479b1c0>

# %%
plot_trajectory_extended(pi_env, pi_agent)

# %%
plot_trajectory(pi_env, pi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_pi_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=vec_pi_env)

print(vec_pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x166ce94b0>

# %%
observations_pi, actions_pi, rewards_pi = generate_trajectory(vec_pi_env, vec_pi_agent)

# %%
results_pi, fig_pi, total_rewards_pi = generate_results_table_and_hist(vec_env=vec_pi_env,agent=vec_pi_agent)

# %%
results_pi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.145828  4.880012                  -0.095
#
#           Std terminal inventory
# Inventory               3.106441

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      #initial_inventory = initial_inventory,
                      initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FILTERED_FADS_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 50_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "PIMm_PPO_50_000_000steps_randStartTime"
# Paths with timestamp
tensorboard_logdir = f".././Partial_Info_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././Partial_Info_models/PPO-best/{experiment_name}/{run_id}/"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[128, 128], vf=[128, 128])]
)

n_epochs = 5
learning_rate = 3e-5
gae_lambda = 0.95
clip_range = 0.1
vf_coef = 0.5
max_grad_norm = 0.2

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
                }

#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.          0.         -5.5999999 -10.       ], [ 20.           1.         105.59999847  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to .././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.5      |
# | time/              |          |
# |    fps             | 379784   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.27         |
# | time/                   |              |
# |    fps                  | 132298       |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007197313 |
# |    clip_fraction        | 0.00911      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00599     |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 5            |
# |    policy_gradient_loss | -0.000263    |
# |    std                  | 1            |
# |    value_loss           | 0.355        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 5.63          |
# | time/                   |               |
# |    fps                  | 109360        |
# |    iterations           | 3             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 3000000       |
# | train/                  |               |
# |    approx_kl            | 0.00078689976 |
# |    clip_fraction        | 0.00698       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.00418       |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000219     |
# |    std                  | 0.999         |
# |    value_loss           | 0.347         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 5.07          |
# | time/                   |               |
# |    fps                  | 102907        |
# |    iterations           | 4             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 4000000       |
# | train/                  |               |
# |    approx_kl            | 0.00069538114 |
# |    clip_fraction        | 0.00451       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0249        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.183         |
# |    n_updates            | 15            |
# |    policy_gradient_loss | -0.000158     |
# |    std                  | 0.998         |
# |    value_loss           | 0.373         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 3.64          |
# | time/                   |               |
# |    fps                  | 93316         |
# |    iterations           | 5             |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 5000000       |
# | train/                  |               |
# |    approx_kl            | 0.00076666113 |
# |    clip_fraction        | 0.00615       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.0469        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.173         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000195     |
# |    std                  | 0.998         |
# |    value_loss           | 0.353         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 4.99          |
# | time/                   |               |
# |    fps                  | 85653         |
# |    iterations           | 6             |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 6000000       |
# | train/                  |               |
# |    approx_kl            | 0.00078838796 |
# |    clip_fraction        | 0.00722       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.0724        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.172         |
# |    n_updates            | 25            |
# |    policy_gradient_loss | -0.000224     |
# |    std                  | 0.997         |
# |    value_loss           | 0.344         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 4.94         |
# | time/                   |              |
# |    fps                  | 82294        |
# |    iterations           | 7            |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007763483 |
# |    clip_fraction        | 0.00579      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.182        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000175    |
# |    std                  | 0.996        |
# |    value_loss           | 0.366        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.42          |
# | time/                   |               |
# |    fps                  | 83735         |
# |    iterations           | 8             |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 8000000       |
# | train/                  |               |
# |    approx_kl            | 0.00079056126 |
# |    clip_fraction        | 0.00758       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.176         |
# |    n_updates            | 35            |
# |    policy_gradient_loss | -0.000233     |
# |    std                  | 0.995         |
# |    value_loss           | 0.352         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.83         |
# | time/                   |              |
# |    fps                  | 84948        |
# |    iterations           | 9            |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0007735459 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.173        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000186    |
# |    std                  | 0.994        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=8.12 +/- 6.33
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 8.12         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0008195605 |
# |    clip_fraction        | 0.00737      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.165        |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.000235    |
# |    std                  | 0.993        |
# |    value_loss           | 0.329        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.42     |
# | time/              |          |
# |    fps             | 85022    |
# |    iterations      | 10       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.35         |
# | time/                   |              |
# |    fps                  | 85241        |
# |    iterations           | 11           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007179994 |
# |    clip_fraction        | 0.00716      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.17         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000232    |
# |    std                  | 0.992        |
# |    value_loss           | 0.342        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.46          |
# | time/                   |               |
# |    fps                  | 86167         |
# |    iterations           | 12            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 12000000      |
# | train/                  |               |
# |    approx_kl            | 0.00078641146 |
# |    clip_fraction        | 0.0108        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.243         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 55            |
# |    policy_gradient_loss | -0.000324     |
# |    std                  | 0.991         |
# |    value_loss           | 0.341         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.2          |
# | time/                   |              |
# |    fps                  | 86848        |
# |    iterations           | 13           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007720901 |
# |    clip_fraction        | 0.00741      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000224    |
# |    std                  | 0.99         |
# |    value_loss           | 0.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.28         |
# | time/                   |              |
# |    fps                  | 86765        |
# |    iterations           | 14           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007128955 |
# |    clip_fraction        | 0.00592      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.178        |
# |    n_updates            | 65           |
# |    policy_gradient_loss | -0.000191    |
# |    std                  | 0.989        |
# |    value_loss           | 0.359        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.2          |
# | time/                   |              |
# |    fps                  | 87006        |
# |    iterations           | 15           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007131625 |
# |    clip_fraction        | 0.00719      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00023     |
# |    std                  | 0.988        |
# |    value_loss           | 0.345        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.14         |
# | time/                   |              |
# |    fps                  | 87418        |
# |    iterations           | 16           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007176328 |
# |    clip_fraction        | 0.00778      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.172        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.000249    |
# |    std                  | 0.987        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.96          |
# | time/                   |               |
# |    fps                  | 87857         |
# |    iterations           | 17            |
# |    time_elapsed         | 193           |
# |    total_timesteps      | 17000000      |
# | train/                  |               |
# |    approx_kl            | 0.00072736817 |
# |    clip_fraction        | 0.00808       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.271         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000246     |
# |    std                  | 0.986         |
# |    value_loss           | 0.343         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.5           |
# | time/                   |               |
# |    fps                  | 88315         |
# |    iterations           | 18            |
# |    time_elapsed         | 203           |
# |    total_timesteps      | 18000000      |
# | train/                  |               |
# |    approx_kl            | 0.00073485234 |
# |    clip_fraction        | 0.00826       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.281         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.176         |
# |    n_updates            | 85            |
# |    policy_gradient_loss | -0.000241     |
# |    std                  | 0.985         |
# |    value_loss           | 0.351         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 7.83          |
# | time/                   |               |
# |    fps                  | 88702         |
# |    iterations           | 19            |
# |    time_elapsed         | 214           |
# |    total_timesteps      | 19000000      |
# | train/                  |               |
# |    approx_kl            | 0.00071202416 |
# |    clip_fraction        | 0.00747       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.287         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000249     |
# |    std                  | 0.984         |
# |    value_loss           | 0.341         |
# -------------------------------------------
# Eval num_timesteps=20000000, episode_reward=14.98 +/- 6.28
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 15           |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006873919 |
# |    clip_fraction        | 0.00665      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.169        |
# |    n_updates            | 95           |
# |    policy_gradient_loss | -0.000204    |
# |    std                  | 0.983        |
# |    value_loss           | 0.34         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.21     |
# | time/              |          |
# |    fps             | 88530    |
# |    iterations      | 20       |
# |    time_elapsed    | 225      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.49         |
# | time/                   |              |
# |    fps                  | 88819        |
# |    iterations           | 21           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007235077 |
# |    clip_fraction        | 0.00749      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.301        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.18         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000215    |
# |    std                  | 0.981        |
# |    value_loss           | 0.363        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.27         |
# | time/                   |              |
# |    fps                  | 89145        |
# |    iterations           | 22           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0007342631 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000276    |
# |    std                  | 0.98         |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 89461        |
# |    iterations           | 23           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006847038 |
# |    clip_fraction        | 0.0074       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000245    |
# |    std                  | 0.979        |
# |    value_loss           | 0.352        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.58          |
# | time/                   |               |
# |    fps                  | 89670         |
# |    iterations           | 24            |
# |    time_elapsed         | 267           |
# |    total_timesteps      | 24000000      |
# | train/                  |               |
# |    approx_kl            | 0.00070996705 |
# |    clip_fraction        | 0.00937       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.262         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.176         |
# |    n_updates            | 115           |
# |    policy_gradient_loss | -0.000271     |
# |    std                  | 0.978         |
# |    value_loss           | 0.349         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 89974        |
# |    iterations           | 25           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006032131 |
# |    clip_fraction        | 0.0044       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.174        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000139    |
# |    std                  | 0.977        |
# |    value_loss           | 0.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.14         |
# | time/                   |              |
# |    fps                  | 89842        |
# |    iterations           | 26           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006947804 |
# |    clip_fraction        | 0.00804      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.178        |
# |    n_updates            | 125          |
# |    policy_gradient_loss | -0.000248    |
# |    std                  | 0.976        |
# |    value_loss           | 0.357        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 9.71          |
# | time/                   |               |
# |    fps                  | 89934         |
# |    iterations           | 27            |
# |    time_elapsed         | 300           |
# |    total_timesteps      | 27000000      |
# | train/                  |               |
# |    approx_kl            | 0.00066162413 |
# |    clip_fraction        | 0.00475       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.283         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.178         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00016      |
# |    std                  | 0.974         |
# |    value_loss           | 0.354         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.2          |
# | time/                   |               |
# |    fps                  | 90106         |
# |    iterations           | 28            |
# |    time_elapsed         | 310           |
# |    total_timesteps      | 28000000      |
# | train/                  |               |
# |    approx_kl            | 0.00060427946 |
# |    clip_fraction        | 0.00432       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.288         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.173         |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -0.000146     |
# |    std                  | 0.973         |
# |    value_loss           | 0.35          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.8          |
# | time/                   |               |
# |    fps                  | 90302         |
# |    iterations           | 29            |
# |    time_elapsed         | 321           |
# |    total_timesteps      | 29000000      |
# | train/                  |               |
# |    approx_kl            | 0.00068801397 |
# |    clip_fraction        | 0.00655       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.289         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.178         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000216     |
# |    std                  | 0.971         |
# |    value_loss           | 0.353         |
# -------------------------------------------
# Eval num_timesteps=30000000, episode_reward=18.67 +/- 5.80
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 18.7          |
# | time/                   |               |
# |    total_timesteps      | 30000000      |
# | train/                  |               |
# |    approx_kl            | 0.00060399575 |
# |    clip_fraction        | 0.00506       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0.265         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.171         |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -0.00016      |
# |    std                  | 0.97          |
# |    value_loss           | 0.343         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    fps             | 90163    |
# |    iterations      | 30       |
# |    time_elapsed    | 332      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 90346        |
# |    iterations           | 31           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006949189 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.172        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000188    |
# |    std                  | 0.969        |
# |    value_loss           | 0.347        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.4          |
# | time/                   |               |
# |    fps                  | 90516         |
# |    iterations           | 32            |
# |    time_elapsed         | 353           |
# |    total_timesteps      | 32000000      |
# | train/                  |               |
# |    approx_kl            | 0.00054024823 |
# |    clip_fraction        | 0.00518       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.264         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.183         |
# |    n_updates            | 155           |
# |    policy_gradient_loss | -0.000177     |
# |    std                  | 0.968         |
# |    value_loss           | 0.364         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 11.6          |
# | time/                   |               |
# |    fps                  | 90686         |
# |    iterations           | 33            |
# |    time_elapsed         | 363           |
# |    total_timesteps      | 33000000      |
# | train/                  |               |
# |    approx_kl            | 0.00058080646 |
# |    clip_fraction        | 0.00519       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.242         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.168         |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000155     |
# |    std                  | 0.967         |
# |    value_loss           | 0.336         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 90845        |
# |    iterations           | 34           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005783181 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.18         |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -0.000171    |
# |    std                  | 0.965        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.4          |
# | time/                   |               |
# |    fps                  | 90771         |
# |    iterations           | 35            |
# |    time_elapsed         | 385           |
# |    total_timesteps      | 35000000      |
# | train/                  |               |
# |    approx_kl            | 0.00061389356 |
# |    clip_fraction        | 0.00298       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.256         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.175         |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000109     |
# |    std                  | 0.964         |
# |    value_loss           | 0.35          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 90314        |
# |    iterations           | 36           |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006424232 |
# |    clip_fraction        | 0.00417      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.176        |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -0.000144    |
# |    std                  | 0.963        |
# |    value_loss           | 0.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 89969        |
# |    iterations           | 37           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006699033 |
# |    clip_fraction        | 0.00516      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.171        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000181    |
# |    std                  | 0.962        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 89919        |
# |    iterations           | 38           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006607142 |
# |    clip_fraction        | 0.00438      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.177        |
# |    n_updates            | 185          |
# |    policy_gradient_loss | -0.000155    |
# |    std                  | 0.96         |
# |    value_loss           | 0.353        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 90051        |
# |    iterations           | 39           |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006294955 |
# |    clip_fraction        | 0.00416      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.172        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00014     |
# |    std                  | 0.959        |
# |    value_loss           | 0.347        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=20.60 +/- 5.73
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 20.6          |
# | time/                   |               |
# |    total_timesteps      | 40000000      |
# | train/                  |               |
# |    approx_kl            | 0.00057360844 |
# |    clip_fraction        | 0.00465       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.249         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 195           |
# |    policy_gradient_loss | -0.000156     |
# |    std                  | 0.958         |
# |    value_loss           | 0.344         |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.6     |
# | time/              |          |
# |    fps             | 89932    |
# |    iterations      | 40       |
# |    time_elapsed    | 444      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 90076        |
# |    iterations           | 41           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005937805 |
# |    clip_fraction        | 0.0023       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.175        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -8.62e-05    |
# |    std                  | 0.956        |
# |    value_loss           | 0.35         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 12.9          |
# | time/                   |               |
# |    fps                  | 90259         |
# |    iterations           | 42            |
# |    time_elapsed         | 465           |
# |    total_timesteps      | 42000000      |
# | train/                  |               |
# |    approx_kl            | 0.00065418007 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | 0.209         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.171         |
# |    n_updates            | 205           |
# |    policy_gradient_loss | -0.000105     |
# |    std                  | 0.955         |
# |    value_loss           | 0.344         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 90176        |
# |    iterations           | 43           |
# |    time_elapsed         | 476          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005342827 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.181        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000108    |
# |    std                  | 0.954        |
# |    value_loss           | 0.361        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 90259        |
# |    iterations           | 44           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006750274 |
# |    clip_fraction        | 0.00315      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.182        |
# |    n_updates            | 215          |
# |    policy_gradient_loss | -8.21e-05    |
# |    std                  | 0.953        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 90341        |
# |    iterations           | 45           |
# |    time_elapsed         | 498          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005932241 |
# |    clip_fraction        | 0.00392      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.168        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.951        |
# |    value_loss           | 0.334        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 90389        |
# |    iterations           | 46           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005414922 |
# |    clip_fraction        | 0.00356      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.17         |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -0.000129    |
# |    std                  | 0.95         |
# |    value_loss           | 0.342        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.5         |
# | time/                   |              |
# |    fps                  | 90433        |
# |    iterations           | 47           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 47000000     |
# | train/                  |              |
# |    approx_kl            | 0.0006629462 |
# |    clip_fraction        | 0.00374      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.173        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000125    |
# |    std                  | 0.949        |
# |    value_loss           | 0.344        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 90233        |
# |    iterations           | 48           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005484877 |
# |    clip_fraction        | 0.00232      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.172        |
# |    n_updates            | 235          |
# |    policy_gradient_loss | -7.66e-05    |
# |    std                  | 0.948        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 14            |
# | time/                   |               |
# |    fps                  | 90311         |
# |    iterations           | 49            |
# |    time_elapsed         | 542           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00049944164 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 0.235         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.176         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -6.88e-05     |
# |    std                  | 0.946         |
# |    value_loss           | 0.354         |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=19.16 +/- 6.59
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.2         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0005128609 |
# |    clip_fraction        | 0.00182      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.173        |
# |    n_updates            | 245          |
# |    policy_gradient_loss | -8.1e-05     |
# |    std                  | 0.945        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    fps             | 90244    |
# |    iterations      | 50       |
# |    time_elapsed    | 554      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.056e+05 -2.000e+01  0.000e+00 -5.600e+00 -1.000e+01 -1.000e+01
#   0.000e+00  0.000e+00], [1.056e+05 2.000e+01 1.000e+00 1.056e+02 1.000e+01 1.000e+01 6.000e+01
#  6.000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# RL Agent    2.508186  20.570279  5.616189                     0.2
#
#          Std terminal inventory
# RL Agent               3.914077

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory, 0, 0, 0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory, 0.5, 100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
partial_info_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Partial Information action
pi_bid_actions = []
pi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = partial_info_agent.get_action(np.array([[0,inventory,0.5,100,0,0]])).reshape(-1)
    pi_bid_actions.append(bid_action)
    pi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, pi_bid_actions, label="bid (PI)", color="k", linestyle="--")
ax.plot(inventories, pi_ask_actions, label="ask (PI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Partial Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and closed approx agent
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # PI bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # PI ask
    
        
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context
    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions 
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, partial_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, filtered_fad]])).reshape(-1)
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, pi_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  20.56494991236548
# median:  19.931706092775336
# std:  5.601967169270562

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_newBaseline/2025-11-16_19-43-31/PPO_1/events.out.tfevents.1763318612.MacBookAir.lan.42104.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_newBaseline/2025-11-16_19-43-31/PPO_1/events.out.tfevents.1763318612.MacBookAir.lan.42104.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = ".././Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_50_000_000steps_newBaseline/2025-11-16_19-43-31/PPO_1/events.out.tfevents.1763318612.MacBookAir.lan.42104.0"
# Load the data

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run

ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)
    
# Add baseline line
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to .././Partial_Info_models/PPO-best/PIMm_PPO_50_000_000steps_randInventory/2025-11-17_10-13-52/Training_process_rewards.png
