# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
pi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=pi_env)
print(pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x173f92b30>

# %%
plot_trajectory_extended(pi_env, pi_agent)

# %%
plot_trajectory(pi_env, pi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_env_pi = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_agent_pi = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=vec_env_pi)

print(vec_env_pi.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x17516a500>

# %%
observations_pi, actions_pi, rewards_pi = generate_trajectory(vec_env_pi, vec_agent_pi)

# %%
results_pi, fig_pi, total_rewards_pi = generate_results_table_and_hist(vec_env=vec_env_pi,agent=vec_agent_pi)

# %%
results_pi
# Out:
#           Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory    2.065432  21.145828  4.880012                  -0.095
#
#           Std terminal inventory
# Inventory               3.106441

# %% [markdown]
# ### Rinforncement Learning

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %% [markdown]
# #### Optuna

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler

# %%
use_normalized_agent = False

# %%
def objective(trial):
    """
    Objective function for Optuna to optimize PPO hyperparameters.
    
    Parameters
    ----------
    trial : optuna.Trial
        A trial object that suggests hyperparameters
        
    Returns
    -------
    float
        Mean reward from evaluation episodes
    """
    batch_size_divisor = 100 

    # Suggest hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-3, log=True)
    n_epochs = trial.suggest_int("n_epochs", 3, 10)
    # batch_size_divisor = trial.suggest_int("batch_size_divisor", 5, 20)
    # gamma = trial.suggest_float("gamma", 0.9, 0.999)
    gae_lambda = trial.suggest_float("gae_lambda", 0.9, 0.99)
    clip_range = trial.suggest_float("clip_range", 0.1, 0.3)
    ent_coef = trial.suggest_float("ent_coef", 0.0, 0.1)
    vf_coef = trial.suggest_float("vf_coef", 0.1, 1.0)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 1.0)
    
    # Network architecture
    n_layers = trial.suggest_int("n_layers", 1, 3)
    layer_size = trial.suggest_categorical("layer_size", [128, 256, 512])
    activation = trial.suggest_categorical("activation", ["tanh", "relu"])
    
    # Build network architecture
    net_arch = []
    for _ in range(n_layers):
        net_arch.append(layer_size)
    
    activation_fn = nn.Tanh if activation == "tanh" else nn.ReLU
    
    policy_kwargs = dict(
        activation_fn=activation_fn,
        net_arch=dict(pi=net_arch.copy(), vf=net_arch.copy())
    )
    
    # Create environment for this trial
    num_trajectories = 1000
    reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FILTERED_FADS_INDEX]
    rl_env_trial = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
    sb_rl_env_trial = StableBaselinesTradingEnvironment(trading_env=rl_env_trial)
    sb_rl_env_trial = VecMonitor(sb_rl_env_trial)
    
    # Create model with suggested hyperparameters
    model = PPO(
        policy='MlpPolicy',
        env=sb_rl_env_trial,
        learning_rate=learning_rate,
        n_epochs=n_epochs,
        batch_size=int(n_steps * num_trajectories / batch_size_divisor),
        n_steps=int(n_steps),
        # gamma=gamma,
        gae_lambda=gae_lambda,
        clip_range=clip_range,
        ent_coef=ent_coef,
        vf_coef=vf_coef,
        max_grad_norm=max_grad_norm,
        policy_kwargs=policy_kwargs,
        verbose=0,
        device="cpu"
    )
    
    # Create evaluation callback with pruning
    eval_freq = 100_000  # Evaluate every 50k steps
    n_eval_episodes = 256
    
    # Custom callback for Optuna pruning
    class OptunaEvalCallback(EvalCallback):
        def __init__(self, trial, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.trial = trial
            self.eval_idx = 0
            
        def _on_step(self) -> bool:
            result = super()._on_step()
            
            if len(self.evaluations_results) > 0:
                # Report intermediate value
                mean_reward = self.evaluations_results[-1]
                self.trial.report(mean_reward, self.eval_idx)
                self.eval_idx += 1
                
                # Prune trial if needed
                if self.trial.should_prune():
                    raise optuna.TrialPruned()
            
            return result
    
    eval_callback = OptunaEvalCallback(
        trial=trial,
        eval_env=sb_rl_env_trial,
        n_eval_episodes=n_eval_episodes,
        eval_freq=eval_freq,
        deterministic=True,
        verbose=0
    )
    
    try:
        # Train for a limited number of steps 
        total_timesteps = 1_000_000  
        model.learn(total_timesteps=total_timesteps, callback=eval_callback)
        
        # Final evaluation
        rl_env_eval = get_rl_env_visualization(num_trajectories=1000)
        ppo_agent = SbAgent(
            model, 
            reduced_training_indices=reduced_training_indices, 
            env=rl_env_eval, 
            use_normalized_agent=use_normalized_agent
        )
        
        observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(
            env=rl_env_eval, 
            rl_agent=ppo_agent
        )
        
        mean_reward = rewards_rl.sum(axis=-1).mean()
        
    except optuna.TrialPruned:
        raise
    except Exception as e:
        print(f"Trial failed with error: {e}")
        return float('-inf')
    finally:
        # Clean up
        sb_rl_env_trial.close()
    
    return mean_reward

# %%
# Create study
study = optuna.create_study(
    direction="maximize",
    study_name="ppo_mm_optimization",
    sampler=TPESampler(seed=seed),
    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=10)
)

# Optimize
n_trials = 50  # Number of trials to run
study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Print results
print("Best trial:")
print(f"  Value (mean reward): {study.best_trial.value}")
print(f"  Params: ")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-04 09:43:42,305] A new study created in memory with name: ppo_mm_optimization
#   0%|          | 0/50 [00:00<?, ?it/s]
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# [I 2025-11-04 09:44:46,342] Trial 0 finished with value: -1.9254612510718034 and parameters: {'learning_rate': 5.6115164153345e-05, 'n_epochs': 10, 'gae_lambda': 0.9658794547630265, 'clip_range': 0.21973169683940733, 'ent_coef': 0.015601864044243652, 'vf_coef': 0.2403950683025824, 'max_grad_norm': 0.3406585285177396, 'n_layers': 3, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 0 with value: -1.9254612510718034.
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# [I 2025-11-04 09:45:23,004] Trial 1 finished with value: -1.5609551215687107 and parameters: {'learning_rate': 2.6587543983272695e-05, 'n_epochs': 4, 'gae_lambda': 0.9165064058868091, 'clip_range': 0.16084844859190756, 'ent_coef': 0.052475643163223784, 'vf_coef': 0.4887505167779042, 'max_grad_norm': 0.5038603981386293, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 1 with value: -1.5609551215687107.
# [I 2025-11-04 09:45:41,145] Trial 2 finished with value: 0.619217406607685 and parameters: {'learning_rate': 2.5081156860452307e-05, 'n_epochs': 7, 'gae_lambda': 0.9533173111975838, 'clip_range': 0.10929008254399955, 'ent_coef': 0.06075448519014384, 'vf_coef': 0.2534717113185624, 'max_grad_norm': 0.3455361150896957, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:45:48,564] Trial 3 finished with value: -2.6035752455414887 and parameters: {'learning_rate': 7.591104805282687e-05, 'n_epochs': 3, 'gae_lambda': 0.9445659219100143, 'clip_range': 0.10687770422304368, 'ent_coef': 0.0909320402078782, 'vf_coef': 0.33290198344001526, 'max_grad_norm': 0.7637655990477873, 'n_layers': 1, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:46:31,334] Trial 4 finished with value: -3.5443202635241433 and parameters: {'learning_rate': 0.0007568292060167617, 'n_epochs': 10, 'gae_lambda': 0.9538109980929976, 'clip_range': 0.28437484700462334, 'ent_coef': 0.00884925020519195, 'vf_coef': 0.27638457617723067, 'max_grad_norm': 0.33165910223737666, 'n_layers': 1, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:46:36,913] Trial 5 finished with value: -3.4070662739665876 and parameters: {'learning_rate': 0.00012172847081122418, 'n_epochs': 4, 'gae_lambda': 0.9721977282678635, 'clip_range': 0.11491012873595417, 'ent_coef': 0.09868869366005173, 'vf_coef': 0.7950202923669917, 'max_grad_norm': 0.43910097707392065, 'n_layers': 1, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:46:51,865] Trial 6 finished with value: -1.5634264060642131 and parameters: {'learning_rate': 5.2111245957882584e-05, 'n_epochs': 3, 'gae_lambda': 0.9776793083288035, 'clip_range': 0.22465962536551157, 'ent_coef': 0.03308980248526492, 'vf_coef': 0.15720251525742127, 'max_grad_norm': 0.5176876252009636, 'n_layers': 1, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:47:20,841] Trial 7 finished with value: -2.1821878517246103 and parameters: {'learning_rate': 0.0002669866674274458, 'n_epochs': 9, 'gae_lambda': 0.9505149477812547, 'clip_range': 0.2541934359909122, 'ent_coef': 0.04937955963643908, 'vf_coef': 0.5704595464437947, 'max_grad_norm': 0.5992787128509847, 'n_layers': 1, 'layer_size': 512, 'activation': 'relu'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:47:26,570] Trial 8 finished with value: -1.8816559947961684 and parameters: {'learning_rate': 0.0006533305220227731, 'n_epochs': 4, 'gae_lambda': 0.9369344630732067, 'clip_range': 0.25111022770860975, 'ent_coef': 0.022879816549162248, 'vf_coef': 0.1692819188459137, 'max_grad_norm': 0.5028260170396376, 'n_layers': 1, 'layer_size': 128, 'activation': 'tanh'}. Best is trial 2 with value: 0.619217406607685.
# [I 2025-11-04 09:47:58,886] Trial 9 finished with value: 1.6736901655408423 and parameters: {'learning_rate': 2.3612399244412595e-05, 'n_epochs': 10, 'gae_lambda': 0.9485408017724085, 'clip_range': 0.2614880310328125, 'ent_coef': 0.08960912999234932, 'vf_coef': 0.3862031274746775, 'max_grad_norm': 0.37703634716937373, 'n_layers': 1, 'layer_size': 512, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:49:01,751] Trial 10 finished with value: 0.1287514650110801 and parameters: {'learning_rate': 1.1129900578957441e-05, 'n_epochs': 7, 'gae_lambda': 0.9006792587384664, 'clip_range': 0.1780730401083691, 'ent_coef': 0.07805317658160738, 'vf_coef': 0.9168983157542662, 'max_grad_norm': 0.9718395221617938, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:49:19,543] Trial 11 finished with value: -0.5818544600079598 and parameters: {'learning_rate': 1.4863266722865919e-05, 'n_epochs': 7, 'gae_lambda': 0.9305427933399127, 'clip_range': 0.15844769310039725, 'ent_coef': 0.0644536807181071, 'vf_coef': 0.4770028069501593, 'max_grad_norm': 0.3049341687640877, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:49:39,740] Trial 12 finished with value: -2.1167166082634647 and parameters: {'learning_rate': 2.8366598398942914e-05, 'n_epochs': 8, 'gae_lambda': 0.9876478649261872, 'clip_range': 0.2831281260256681, 'ent_coef': 0.07719240123800711, 'vf_coef': 0.38981544556969006, 'max_grad_norm': 0.7660766904417112, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:49:50,757] Trial 13 finished with value: 0.7427059831727874 and parameters: {'learning_rate': 2.434178208106398e-05, 'n_epochs': 6, 'gae_lambda': 0.9578206395774794, 'clip_range': 0.19235922221153873, 'ent_coef': 0.07889480417436115, 'vf_coef': 0.6802063167412771, 'max_grad_norm': 0.4102641222214392, 'n_layers': 2, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:50:11,660] Trial 14 finished with value: -0.8201311563772112 and parameters: {'learning_rate': 0.0001828810418076092, 'n_epochs': 6, 'gae_lambda': 0.9636993384096957, 'clip_range': 0.19735438139573352, 'ent_coef': 0.08204722531866919, 'vf_coef': 0.6931257443280765, 'max_grad_norm': 0.6416757943521861, 'n_layers': 2, 'layer_size': 256, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:51:03,167] Trial 15 finished with value: 0.4778926931773541 and parameters: {'learning_rate': 1.744448810150955e-05, 'n_epochs': 6, 'gae_lambda': 0.927141374665405, 'clip_range': 0.25502473774700773, 'ent_coef': 0.09848505270063299, 'vf_coef': 0.6679190141037926, 'max_grad_norm': 0.42453116186753065, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:51:12,501] Trial 16 finished with value: -1.3491212417120002 and parameters: {'learning_rate': 4.162953495869027e-05, 'n_epochs': 5, 'gae_lambda': 0.9599882075376948, 'clip_range': 0.2193086911662417, 'ent_coef': 0.06519010816022267, 'vf_coef': 0.9386351381323008, 'max_grad_norm': 0.41820478040879927, 'n_layers': 2, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:51:25,713] Trial 17 finished with value: -2.0239864328922845 and parameters: {'learning_rate': 0.00010764587184909161, 'n_epochs': 8, 'gae_lambda': 0.9383711999484685, 'clip_range': 0.14656141552875107, 'ent_coef': 0.08516360131290472, 'vf_coef': 0.6517551711795259, 'max_grad_norm': 0.7229109846508396, 'n_layers': 2, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:52:42,264] Trial 18 finished with value: -2.668157281358007 and parameters: {'learning_rate': 1.1374326866091478e-05, 'n_epochs': 9, 'gae_lambda': 0.9189591793370628, 'clip_range': 0.18876122191450243, 'ent_coef': 0.04176998091281891, 'vf_coef': 0.819272829505109, 'max_grad_norm': 0.9277849857285283, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:52:51,599] Trial 19 finished with value: -2.5473917912175272 and parameters: {'learning_rate': 3.626547465931512e-05, 'n_epochs': 5, 'gae_lambda': 0.989660284596472, 'clip_range': 0.23957060340165892, 'ent_coef': 0.07519244283936566, 'vf_coef': 0.416318369254414, 'max_grad_norm': 0.5773588212952455, 'n_layers': 1, 'layer_size': 256, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:54:08,830] Trial 20 finished with value: -0.8514309667644379 and parameters: {'learning_rate': 2.1216907439465558e-05, 'n_epochs': 9, 'gae_lambda': 0.9761867058618954, 'clip_range': 0.2946858282056984, 'ent_coef': 0.08842603734396455, 'vf_coef': 0.5655593634313054, 'max_grad_norm': 0.403394213520079, 'n_layers': 2, 'layer_size': 512, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:54:26,506] Trial 21 finished with value: 0.9044440803334342 and parameters: {'learning_rate': 2.184077605161389e-05, 'n_epochs': 8, 'gae_lambda': 0.951963212609342, 'clip_range': 0.13092122172970083, 'ent_coef': 0.06404849128806536, 'vf_coef': 0.2562489547218164, 'max_grad_norm': 0.3494501800394404, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:54:44,194] Trial 22 finished with value: -3.552951721192846 and parameters: {'learning_rate': 1.605683656728911e-05, 'n_epochs': 8, 'gae_lambda': 0.9443406098526697, 'clip_range': 0.13080327514913376, 'ent_coef': 0.06682888237861961, 'vf_coef': 0.3484435679235181, 'max_grad_norm': 0.3879989249904576, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:54:58,261] Trial 23 finished with value: -1.6493227369142414 and parameters: {'learning_rate': 7.339958099544768e-05, 'n_epochs': 6, 'gae_lambda': 0.958307906145932, 'clip_range': 0.17798512766409513, 'ent_coef': 0.07068329287099642, 'vf_coef': 0.5032190257272399, 'max_grad_norm': 0.47387387964218036, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:55:20,272] Trial 24 finished with value: 0.19462677058599165 and parameters: {'learning_rate': 3.7615829626240175e-05, 'n_epochs': 10, 'gae_lambda': 0.9701090332080947, 'clip_range': 0.26880910096726557, 'ent_coef': 0.056370310479958066, 'vf_coef': 0.10023590107424135, 'max_grad_norm': 0.5679693137462315, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:55:35,093] Trial 25 finished with value: -0.3255149458296962 and parameters: {'learning_rate': 1.0296407059340443e-05, 'n_epochs': 9, 'gae_lambda': 0.9479045544821041, 'clip_range': 0.1348179004686971, 'ent_coef': 0.09341845827207829, 'vf_coef': 0.7511219379066163, 'max_grad_norm': 0.3807187949673509, 'n_layers': 2, 'layer_size': 128, 'activation': 'relu'}. Best is trial 9 with value: 1.6736901655408423.
# [I 2025-11-04 09:55:53,226] Trial 26 finished with value: 4.094869162276111 and parameters: {'learning_rate': 1.967784889603667e-05, 'n_epochs': 8, 'gae_lambda': 0.9385117687476894, 'clip_range': 0.21406040024500303, 'ent_coef': 0.04437108459102281, 'vf_coef': 0.45348169019204954, 'max_grad_norm': 0.460408299364221, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 09:56:11,242] Trial 27 finished with value: -2.5202948786492256 and parameters: {'learning_rate': 1.6943563568141847e-05, 'n_epochs': 8, 'gae_lambda': 0.9343550277503505, 'clip_range': 0.21090850996915192, 'ent_coef': 0.04216019185596302, 'vf_coef': 0.4267945469007935, 'max_grad_norm': 0.3016348109226875, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 09:56:57,938] Trial 28 finished with value: 0.6378952331403748 and parameters: {'learning_rate': 3.2554398320456656e-05, 'n_epochs': 9, 'gae_lambda': 0.9222557266131862, 'clip_range': 0.22979245957905028, 'ent_coef': 0.029203341397200645, 'vf_coef': 0.3103790823324619, 'max_grad_norm': 0.4707001397491865, 'n_layers': 3, 'layer_size': 256, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 09:59:41,220] Trial 29 finished with value: -2.0355051829446906 and parameters: {'learning_rate': 4.985506943362165e-05, 'n_epochs': 10, 'gae_lambda': 0.9404279606613662, 'clip_range': 0.2118979710045506, 'ent_coef': 0.04442799490927545, 'vf_coef': 0.22451628503086038, 'max_grad_norm': 0.36085775677525894, 'n_layers': 3, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:00:29,158] Trial 30 finished with value: -2.104237192340348 and parameters: {'learning_rate': 7.594162269539242e-05, 'n_epochs': 10, 'gae_lambda': 0.9083138765409795, 'clip_range': 0.23879257761619116, 'ent_coef': 0.0016195344119939864, 'vf_coef': 0.36586037774603813, 'max_grad_norm': 0.8707807597718253, 'n_layers': 3, 'layer_size': 256, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:00:45,291] Trial 31 finished with value: 1.2142375672647046 and parameters: {'learning_rate': 1.9792392991904284e-05, 'n_epochs': 7, 'gae_lambda': 0.9583100118551943, 'clip_range': 0.16761585500576887, 'ent_coef': 0.07231854796737634, 'vf_coef': 0.6069583678837354, 'max_grad_norm': 0.35557858679950194, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:01:00,733] Trial 32 finished with value: 2.0881193860848315 and parameters: {'learning_rate': 2.0308447249589536e-05, 'n_epochs': 7, 'gae_lambda': 0.9648565435002284, 'clip_range': 0.16475701361671571, 'ent_coef': 0.056887566382085315, 'vf_coef': 0.6087046454810192, 'max_grad_norm': 0.3596144960865327, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:01:15,799] Trial 33 finished with value: -0.10836645532255938 and parameters: {'learning_rate': 1.2750053784962032e-05, 'n_epochs': 7, 'gae_lambda': 0.9659305096405618, 'clip_range': 0.17764158782475584, 'ent_coef': 0.05445832705082913, 'vf_coef': 0.593035237484756, 'max_grad_norm': 0.44995045973391257, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:01:31,470] Trial 34 finished with value: -1.2080278208620203 and parameters: {'learning_rate': 2.082615789094892e-05, 'n_epochs': 7, 'gae_lambda': 0.9441161486748615, 'clip_range': 0.1615990285938205, 'ent_coef': 0.03610785465560182, 'vf_coef': 0.48481871958118306, 'max_grad_norm': 0.5310730025691669, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:01:42,922] Trial 35 finished with value: -3.552951721192846 and parameters: {'learning_rate': 2.6881658944404693e-05, 'n_epochs': 5, 'gae_lambda': 0.9640803971689522, 'clip_range': 0.16725758717953015, 'ent_coef': 0.057540150561907984, 'vf_coef': 0.6033656418255018, 'max_grad_norm': 0.33957338310863655, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:03:55,848] Trial 36 finished with value: -2.2785827295857133 and parameters: {'learning_rate': 1.4908858279578034e-05, 'n_epochs': 8, 'gae_lambda': 0.9813258879899436, 'clip_range': 0.15016316906332078, 'ent_coef': 0.04658932119126362, 'vf_coef': 0.5152427985026613, 'max_grad_norm': 0.367885696398641, 'n_layers': 3, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:04:10,870] Trial 37 finished with value: 1.0233942441270438 and parameters: {'learning_rate': 5.999665506981921e-05, 'n_epochs': 7, 'gae_lambda': 0.9564376172929989, 'clip_range': 0.20812027617387913, 'ent_coef': 0.07130416813216851, 'vf_coef': 0.7380333639844244, 'max_grad_norm': 0.47726315896192195, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:04:37,911] Trial 38 finished with value: -0.6521751940557462 and parameters: {'learning_rate': 0.00035157275710089833, 'n_epochs': 7, 'gae_lambda': 0.9692554142103235, 'clip_range': 0.18552886632349685, 'ent_coef': 0.05233720973298527, 'vf_coef': 0.433802473063746, 'max_grad_norm': 0.31931501921566285, 'n_layers': 1, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:04:51,498] Trial 39 finished with value: -3.5397673447669313 and parameters: {'learning_rate': 3.102079299858221e-05, 'n_epochs': 6, 'gae_lambda': 0.9475119337031603, 'clip_range': 0.2697800722024953, 'ent_coef': 0.09175317934535676, 'vf_coef': 0.6195014984908567, 'max_grad_norm': 0.5385091332891606, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:05:08,586] Trial 40 finished with value: -1.7636955263345677 and parameters: {'learning_rate': 1.9117236483506724e-05, 'n_epochs': 9, 'gae_lambda': 0.9317995901835264, 'clip_range': 0.11656573836394968, 'ent_coef': 0.01924190498163436, 'vf_coef': 0.5405650044639554, 'max_grad_norm': 0.44765224389049135, 'n_layers': 1, 'layer_size': 256, 'activation': 'tanh'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:05:23,781] Trial 41 finished with value: -3.552951721192846 and parameters: {'learning_rate': 4.5203758437724246e-05, 'n_epochs': 7, 'gae_lambda': 0.9564920765873447, 'clip_range': 0.20367201740338126, 'ent_coef': 0.07056379376738015, 'vf_coef': 0.7401373983689327, 'max_grad_norm': 0.5007373456522993, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:05:38,652] Trial 42 finished with value: -1.3994400724314182 and parameters: {'learning_rate': 0.00015643535990128392, 'n_epochs': 7, 'gae_lambda': 0.9533718411798571, 'clip_range': 0.1693672651964098, 'ent_coef': 0.05932724263506378, 'vf_coef': 0.8482999418259135, 'max_grad_norm': 0.4746560628229365, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:05:55,480] Trial 43 finished with value: -2.471997954664943 and parameters: {'learning_rate': 7.671856690364751e-05, 'n_epochs': 8, 'gae_lambda': 0.961548324783628, 'clip_range': 0.20023116222289208, 'ent_coef': 0.04983219407038915, 'vf_coef': 0.998214158327376, 'max_grad_norm': 0.382833132616155, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:06:10,629] Trial 44 finished with value: -2.353124640745463 and parameters: {'learning_rate': 5.374976421580044e-05, 'n_epochs': 7, 'gae_lambda': 0.950622920828927, 'clip_range': 0.14608026359780846, 'ent_coef': 0.07147234526991075, 'vf_coef': 0.719540317348418, 'max_grad_norm': 0.6195349889471468, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:06:24,003] Trial 45 finished with value: -3.552951721192846 and parameters: {'learning_rate': 1.3829840573323827e-05, 'n_epochs': 6, 'gae_lambda': 0.9423398002809606, 'clip_range': 0.2091870457933207, 'ent_coef': 0.08413918828627777, 'vf_coef': 0.6313695631507124, 'max_grad_norm': 0.6996696996526477, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:06:44,771] Trial 46 finished with value: 0.24271392885129045 and parameters: {'learning_rate': 2.5666545222852585e-05, 'n_epochs': 7, 'gae_lambda': 0.9554523335667632, 'clip_range': 0.23535604129274737, 'ent_coef': 0.060866601492447214, 'vf_coef': 0.4577624630699176, 'max_grad_norm': 0.33630761187670977, 'n_layers': 1, 'layer_size': 512, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:07:01,842] Trial 47 finished with value: 0.18064111340883623 and parameters: {'learning_rate': 3.1724372877393306e-05, 'n_epochs': 8, 'gae_lambda': 0.9745707970097413, 'clip_range': 0.2630639407521172, 'ent_coef': 0.035798731056368556, 'vf_coef': 0.535328697314428, 'max_grad_norm': 0.43070919647751893, 'n_layers': 3, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:07:10,294] Trial 48 finished with value: -1.2710240119735894 and parameters: {'learning_rate': 2.4056485815178733e-05, 'n_epochs': 5, 'gae_lambda': 0.9685639259877363, 'clip_range': 0.21893797117619382, 'ent_coef': 0.07444022194659813, 'vf_coef': 0.7758585379379077, 'max_grad_norm': 0.4889887700889338, 'n_layers': 2, 'layer_size': 128, 'activation': 'relu'}. Best is trial 26 with value: 4.094869162276111.
# [I 2025-11-04 10:08:50,284] Trial 49 finished with value: 0.033734360250828245 and parameters: {'learning_rate': 1.3182306481602677e-05, 'n_epochs': 6, 'gae_lambda': 0.9808247428709428, 'clip_range': 0.24707011813292612, 'ent_coef': 0.09629739756996203, 'vf_coef': 0.31620939344030746, 'max_grad_norm': 0.40095364903251396, 'n_layers': 3, 'layer_size': 512, 'activation': 'tanh'}. Best is trial 26 with value: 4.094869162276111.
# Best trial:
#   Value (mean reward): 4.094869162276111
#   Params:
#     learning_rate: 1.967784889603667e-05
#     n_epochs: 8
#     gae_lambda: 0.9385117687476894
#     clip_range: 0.21406040024500303
#     ent_coef: 0.04437108459102281
#     vf_coef: 0.45348169019204954
#     max_grad_norm: 0.460408299364221
#     n_layers: 3
#     layer_size: 128
#     activation: relu

# %%
# Get the study results as a DataFrame
df = study.trials_dataframe()

# 1. Optimization History Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot all trial values
ax.scatter(df['number'], df['value'], alpha=0.5, label='Trial values')

# Plot best value so far (cumulative best)
best_values = df['value'].cummax()
ax.plot(df['number'], best_values, 'r-', linewidth=2, label='Best value so far')

ax.set_xlabel('Trial Number')
ax.set_ylabel('Objective Value (Mean Reward)')
ax.set_title('Optimization History')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Get best parameters
best_params = study.best_trial.params

batch_size_divisor = 100

# Extract parameters
learning_rate = best_params["learning_rate"]
n_epochs = best_params["n_epochs"]
# batch_size_divisor = best_params["batch_size_divisor"]
#gamma = best_params["gamma"]
gae_lambda = best_params["gae_lambda"]
clip_range = best_params["clip_range"]
ent_coef = best_params["ent_coef"]
vf_coef = best_params["vf_coef"]
max_grad_norm = best_params["max_grad_norm"]
n_layers = best_params["n_layers"]
layer_size = best_params["layer_size"]
activation = best_params["activation"]

# Build network architecture
net_arch = [layer_size] * n_layers
activation_fn = nn.Tanh if activation == "tanh" else nn.ReLU

policy_kwargs = dict(
    activation_fn=activation_fn,
    net_arch=[dict(pi=net_arch.copy(), vf=net_arch.copy())]
)

# Create final model
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FILTERED_FADS_INDEX]
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
sb_rl_env = VecMonitor(sb_rl_env)

# Generate paths
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "PI_PPO_Optuna_Best"
tensorboard_logdir = f".././Partial_Info_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././Partial_Info_models/PPO-best/{experiment_name}/{run_id}/"

# Create model with best parameters
model = PPO(
    policy='MlpPolicy',
    env=sb_rl_env,
    learning_rate=learning_rate,
    n_epochs=n_epochs,
    batch_size=int(n_steps * num_trajectories / batch_size_divisor),
    n_steps=int(n_steps),
    # gamma=gamma,
    gae_lambda=gae_lambda,
    clip_range=clip_range,
    ent_coef=ent_coef,
    vf_coef=vf_coef,
    max_grad_norm=max_grad_norm,
    policy_kwargs=policy_kwargs,
    tensorboard_log=tensorboard_logdir,
    verbose=1,
    device="cpu"
)

# Train with full timesteps
callback = EvalCallback(
    eval_env=sb_rl_env,
    n_eval_episodes=256,
    best_model_save_path=best_model_path,
    deterministic=True
)

model.learn(total_timesteps=50_000_000, callback=callback)
# Out:
# Using cpu device
# Logging to .././Partial_Info_models/tensorboard/PPO-learning/PI_PPO_Optuna_Best/2025-11-04_10-08-50/PPO_1
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.2      |
# | time/              |          |
# |    fps             | 639308   |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.33         |
# | time/                   |              |
# |    fps                  | 90553        |
# |    iterations           | 2            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0021088147 |
# |    clip_fraction        | 0.00999      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0847       |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | 0.14         |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000363    |
# |    std                  | 1.01         |
# |    value_loss           | 0.596        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 6.75        |
# | time/                   |             |
# |    fps                  | 66209       |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 3000000     |
# | train/                  |             |
# |    approx_kl            | 0.002201588 |
# |    clip_fraction        | 0.00889     |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 1.97e-05    |
# |    loss                 | 0.0756      |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.000348   |
# |    std                  | 1.02        |
# |    value_loss           | 0.475       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8            |
# | time/                   |              |
# |    fps                  | 62084        |
# |    iterations           | 4            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0023662425 |
# |    clip_fraction        | 0.00964      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | 0.0365       |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000446    |
# |    std                  | 1.03         |
# |    value_loss           | 0.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 6.57         |
# | time/                   |              |
# |    fps                  | 61108        |
# |    iterations           | 5            |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0024683347 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | 0.0123       |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.000521    |
# |    std                  | 1.04         |
# |    value_loss           | 0.324        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.16         |
# | time/                   |              |
# |    fps                  | 61278        |
# |    iterations           | 6            |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0024483413 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -9.1e-05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000557    |
# |    std                  | 1.06         |
# |    value_loss           | 0.292        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.59        |
# | time/                   |             |
# |    fps                  | 61392       |
# |    iterations           | 7           |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.002212266 |
# |    clip_fraction        | 0.0097      |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 1.97e-05    |
# |    loss                 | -0.0182     |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.000449   |
# |    std                  | 1.07        |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.34         |
# | time/                   |              |
# |    fps                  | 61641        |
# |    iterations           | 8            |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0025170501 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.246        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0277      |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.000599    |
# |    std                  | 1.08         |
# |    value_loss           | 0.239        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.15         |
# | time/                   |              |
# |    fps                  | 61757        |
# |    iterations           | 9            |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0024518082 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0314      |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.000466    |
# |    std                  | 1.09         |
# |    value_loss           | 0.228        |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=16.23 +/- 4.90
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 16.2         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025134601 |
# |    clip_fraction        | 0.00916      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0371      |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000406    |
# |    std                  | 1.1          |
# |    value_loss           | 0.225        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.59     |
# | time/              |          |
# |    fps             | 61370    |
# |    iterations      | 10       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 61419        |
# |    iterations           | 11           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025185295 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0348      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000506    |
# |    std                  | 1.11         |
# |    value_loss           | 0.218        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.19         |
# | time/                   |              |
# |    fps                  | 61444        |
# |    iterations           | 12           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 12000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022810106 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0348      |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.000484    |
# |    std                  | 1.12         |
# |    value_loss           | 0.217        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 61396        |
# |    iterations           | 13           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020049447 |
# |    clip_fraction        | 0.00803      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0435      |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000342    |
# |    std                  | 1.14         |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 61514        |
# |    iterations           | 14           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023333544 |
# |    clip_fraction        | 0.00921      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0359      |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.000414    |
# |    std                  | 1.15         |
# |    value_loss           | 0.219        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.89         |
# | time/                   |              |
# |    fps                  | 61671        |
# |    iterations           | 15           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019702846 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0466      |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.000251    |
# |    std                  | 1.16         |
# |    value_loss           | 0.208        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 61486        |
# |    iterations           | 16           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021193784 |
# |    clip_fraction        | 0.0096       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0481      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000353    |
# |    std                  | 1.17         |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 61078        |
# |    iterations           | 17           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020687801 |
# |    clip_fraction        | 0.00817      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.047       |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000361    |
# |    std                  | 1.18         |
# |    value_loss           | 0.211        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 60837        |
# |    iterations           | 18           |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015949006 |
# |    clip_fraction        | 0.00548      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0493      |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000146    |
# |    std                  | 1.2          |
# |    value_loss           | 0.204        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 60839       |
# |    iterations           | 19          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 19000000    |
# | train/                  |             |
# |    approx_kl            | 0.002190687 |
# |    clip_fraction        | 0.00888     |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 1.97e-05    |
# |    loss                 | -0.0482     |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00036    |
# |    std                  | 1.21        |
# |    value_loss           | 0.21        |
# -----------------------------------------
# Eval num_timesteps=20000000, episode_reward=21.29 +/- 4.83
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 21.3         |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014371597 |
# |    clip_fraction        | 0.00641      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0484      |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000223    |
# |    std                  | 1.22         |
# |    value_loss           | 0.206        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    fps             | 60528    |
# |    iterations      | 20       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.8         |
# | time/                   |              |
# |    fps                  | 60471        |
# |    iterations           | 21           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015805099 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0595      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000157    |
# |    std                  | 1.24         |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 60404        |
# |    iterations           | 22           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018124892 |
# |    clip_fraction        | 0.00692      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0543      |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000286    |
# |    std                  | 1.25         |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 60625        |
# |    iterations           | 23           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016834975 |
# |    clip_fraction        | 0.00499      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0553      |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -9.37e-05    |
# |    std                  | 1.26         |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 60547        |
# |    iterations           | 24           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016400851 |
# |    clip_fraction        | 0.00577      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.31        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0595      |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -9.91e-05    |
# |    std                  | 1.27         |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.1         |
# | time/                   |              |
# |    fps                  | 60465        |
# |    iterations           | 25           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016563815 |
# |    clip_fraction        | 0.00548      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.33        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0537      |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000199    |
# |    std                  | 1.29         |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 60555        |
# |    iterations           | 26           |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011433538 |
# |    clip_fraction        | 0.00344      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.36        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0632      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -1.43e-05    |
# |    std                  | 1.3          |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 60509        |
# |    iterations           | 27           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 27000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016198478 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.38        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0561      |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000152    |
# |    std                  | 1.32         |
# |    value_loss           | 0.204        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.7         |
# | time/                   |              |
# |    fps                  | 60432        |
# |    iterations           | 28           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014048691 |
# |    clip_fraction        | 0.00487      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.4         |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0596      |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000118    |
# |    std                  | 1.33         |
# |    value_loss           | 0.198        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 60287        |
# |    iterations           | 29           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014104586 |
# |    clip_fraction        | 0.00467      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.42        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0618      |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -6.7e-05     |
# |    std                  | 1.34         |
# |    value_loss           | 0.203        |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=19.95 +/- 5.19
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.9         |
# | time/                   |              |
# |    total_timesteps      | 30000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011627148 |
# |    clip_fraction        | 0.00428      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.44        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0636      |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -2.78e-05    |
# |    std                  | 1.36         |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    fps             | 60138    |
# |    iterations      | 30       |
# |    time_elapsed    | 498      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 60109        |
# |    iterations           | 31           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011846932 |
# |    clip_fraction        | 0.0038       |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.46        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0666      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 1.4e-05      |
# |    std                  | 1.37         |
# |    value_loss           | 0.193        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 59890       |
# |    iterations           | 32          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 32000000    |
# | train/                  |             |
# |    approx_kl            | 0.001200628 |
# |    clip_fraction        | 0.00307     |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 1.97e-05    |
# |    loss                 | -0.0663     |
# |    n_updates            | 248         |
# |    policy_gradient_loss | 4.73e-05    |
# |    std                  | 1.39        |
# |    value_loss           | 0.202       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 59793        |
# |    iterations           | 33           |
# |    time_elapsed         | 551          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0015092838 |
# |    clip_fraction        | 0.00424      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.51        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0596      |
# |    n_updates            | 256          |
# |    policy_gradient_loss | -1.87e-07    |
# |    std                  | 1.4          |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 59702        |
# |    iterations           | 34           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011840428 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.53        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0705      |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 4.79e-05     |
# |    std                  | 1.42         |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 59680        |
# |    iterations           | 35           |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 35000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010216341 |
# |    clip_fraction        | 0.00271      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.55        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0726      |
# |    n_updates            | 272          |
# |    policy_gradient_loss | 2.46e-05     |
# |    std                  | 1.44         |
# |    value_loss           | 0.191        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 59622        |
# |    iterations           | 36           |
# |    time_elapsed         | 603          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014049909 |
# |    clip_fraction        | 0.00389      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0729      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 2.4e-05      |
# |    std                  | 1.45         |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 59651        |
# |    iterations           | 37           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 37000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011378233 |
# |    clip_fraction        | 0.00261      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.59        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0705      |
# |    n_updates            | 288          |
# |    policy_gradient_loss | 6.52e-05     |
# |    std                  | 1.47         |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 59545        |
# |    iterations           | 38           |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 38000000     |
# | train/                  |              |
# |    approx_kl            | 0.0013165199 |
# |    clip_fraction        | 0.00281      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.61        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.071       |
# |    n_updates            | 296          |
# |    policy_gradient_loss | 9.44e-05     |
# |    std                  | 1.48         |
# |    value_loss           | 0.198        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 59545        |
# |    iterations           | 39           |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012516847 |
# |    clip_fraction        | 0.00462      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.64        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0734      |
# |    n_updates            | 304          |
# |    policy_gradient_loss | -6.22e-05    |
# |    std                  | 1.5          |
# |    value_loss           | 0.195        |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=19.62 +/- 5.41
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 19.6         |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012094541 |
# |    clip_fraction        | 0.00319      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.66        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0737      |
# |    n_updates            | 312          |
# |    policy_gradient_loss | 2.64e-05     |
# |    std                  | 1.51         |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11.2     |
# | time/              |          |
# |    fps             | 59411    |
# |    iterations      | 40       |
# |    time_elapsed    | 673      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 59403        |
# |    iterations           | 41           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012492067 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0765      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000143     |
# |    std                  | 1.53         |
# |    value_loss           | 0.195        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 59435        |
# |    iterations           | 42           |
# |    time_elapsed         | 706          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011671208 |
# |    clip_fraction        | 0.00224      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.7         |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0808      |
# |    n_updates            | 328          |
# |    policy_gradient_loss | 4.63e-05     |
# |    std                  | 1.55         |
# |    value_loss           | 0.196        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.5          |
# | time/                   |               |
# |    fps                  | 59483         |
# |    iterations           | 43            |
# |    time_elapsed         | 722           |
# |    total_timesteps      | 43000000      |
# | train/                  |               |
# |    approx_kl            | 0.00088575156 |
# |    clip_fraction        | 0.00183       |
# |    clip_range           | 0.214         |
# |    entropy_loss         | -3.72         |
# |    explained_variance   | 0.146         |
# |    learning_rate        | 1.97e-05      |
# |    loss                 | -0.0812       |
# |    n_updates            | 336           |
# |    policy_gradient_loss | 8.9e-05       |
# |    std                  | 1.56          |
# |    value_loss           | 0.189         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 59649        |
# |    iterations           | 44           |
# |    time_elapsed         | 737          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010751955 |
# |    clip_fraction        | 0.00349      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.74        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0773      |
# |    n_updates            | 344          |
# |    policy_gradient_loss | 2.4e-05      |
# |    std                  | 1.58         |
# |    value_loss           | 0.192        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 59659        |
# |    iterations           | 45           |
# |    time_elapsed         | 754          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0012143332 |
# |    clip_fraction        | 0.00189      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.76        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.077       |
# |    n_updates            | 352          |
# |    policy_gradient_loss | 7.81e-05     |
# |    std                  | 1.59         |
# |    value_loss           | 0.192        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 59727        |
# |    iterations           | 46           |
# |    time_elapsed         | 770          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0009542291 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.78        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0841      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000127     |
# |    std                  | 1.61         |
# |    value_loss           | 0.189        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 59790       |
# |    iterations           | 47          |
# |    time_elapsed         | 786         |
# |    total_timesteps      | 47000000    |
# | train/                  |             |
# |    approx_kl            | 0.001140346 |
# |    clip_fraction        | 0.00275     |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 1.97e-05    |
# |    loss                 | -0.089      |
# |    n_updates            | 368         |
# |    policy_gradient_loss | 7.86e-05    |
# |    std                  | 1.63        |
# |    value_loss           | 0.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 59809        |
# |    iterations           | 48           |
# |    time_elapsed         | 802          |
# |    total_timesteps      | 48000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010994227 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.82        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0724      |
# |    n_updates            | 376          |
# |    policy_gradient_loss | 4.16e-05     |
# |    std                  | 1.65         |
# |    value_loss           | 0.194        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 10.3          |
# | time/                   |               |
# |    fps                  | 59822         |
# |    iterations           | 49            |
# |    time_elapsed         | 819           |
# |    total_timesteps      | 49000000      |
# | train/                  |               |
# |    approx_kl            | 0.00074943824 |
# |    clip_fraction        | 0.00148       |
# |    clip_range           | 0.214         |
# |    entropy_loss         | -3.84         |
# |    explained_variance   | 0.167         |
# |    learning_rate        | 1.97e-05      |
# |    loss                 | -0.0889       |
# |    n_updates            | 384           |
# |    policy_gradient_loss | 9.42e-05      |
# |    std                  | 1.66          |
# |    value_loss           | 0.188         |
# -------------------------------------------
# Eval num_timesteps=50000000, episode_reward=18.14 +/- 5.88
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 18.1         |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011606098 |
# |    clip_fraction        | 0.00334      |
# |    clip_range           | 0.214        |
# |    entropy_loss         | -3.86        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 1.97e-05     |
# |    loss                 | -0.0837      |
# |    n_updates            | 392          |
# |    policy_gradient_loss | 1.25e-05     |
# |    std                  | 1.68         |
# |    value_loss           | 0.187        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.5     |
# | time/              |          |
# |    fps             | 59754    |
# |    iterations      | 50       |
# |    time_elapsed    | 836      |
# |    total_timesteps | 50000000 |
# ---------------------------------

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
# step 1: evaluate
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread   Mean PnL Std PnL Mean terminal inventory  \
# RL Agent    3.238804  18.695855  5.6503                   0.373
#
#          Std terminal inventory
# RL Agent               2.509157

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory,0,0,-1]])
    else:
        state = np.array([[inventory,0.5,100,0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Partial Info action
pi_bid_actions = []
pi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = pi_agent.get_action(np.array([[0,inventory,0.5,100,0,0]])).reshape(-1)
    pi_bid_actions.append(bid_action)
    pi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, pi_bid_actions, label="bid (PI)", color="k", linestyle="--")
ax.plot(inventories, pi_ask_actions, label="ask (PI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Partial Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././Partial_Info_models/PPO-best/PI_PPO_Optuna_Best/2025-11-04_10-08-50/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and PI agents
def plot_policy_time_dependence(ppo_agent, pi_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context


    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        pi_bids = []
        pi_asks = []

        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get PI agent's actions
            pi_bid, pi_ask = pi_agent.get_action(np.array([[0, inv, t, price, fad, fad]])).reshape(-1)
            pi_bids.append(pi_bid)
            pi_asks.append(pi_ask)

        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, pi_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, pi_asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("PI δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus Partial Information agent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, pi_agent)

# %%
def plot_policy_time_dependence(ppo_agent, pi_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        fad_normalized = fad # Assuming no normalization for fad in this context


    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        pi_bids = []
        pi_asks = []
        
        inv_normalised = normalize_inventory(inv, max_inventory, use_normalized=use_normalized_agent, inverse=False)

        # For each time point
        for t in times:
            if use_normalized_agent:
                normalized_time = (t) / (1/2) - 1
            else:   
                normalized_time = t
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv_normalised, normalized_time, price_normalized, fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)

            # Get PI agent's actions
            pi_bid, pi_ask = pi_agent.get_action(np.array([[0, inv, t, price, fad, fad]])).reshape(-1)
            pi_bids.append(pi_bid)
            pi_asks.append(pi_ask)

        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(pi_bids), min(pi_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(pi_bids), max(pi_asks))

        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, pi_bids, pi_asks))

    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, pi_bids, pi_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, pi_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, pi_asks, label=f"Inventory = {inv}", color=colors[inv])

    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus Partial Information agent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, pi_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././Partial_Info_models/PPO-best/PI_PPO_Optuna_Best/2025-11-04_10-08-50/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  18.63940305539305
# median:  18.175452641249777
# std:  5.508660467116675

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PI_PPO_Optuna_Best/2025-11-04_10-08-50/PPO_1/events.out.tfevents.1762247330.MacBookAir.lan.67078.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 35
#      33 # Save the figure to the best model path
#      34 plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
# ---> 35 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      36 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.././Partial_Info_models/PPO-best/PI_PPO_Optuna_Best/2025-11-04_10-56-23/Training_process_rollout_reward.png'

# %%
# Load the event file
event_file = ".././Partial_Info_models/tensorboard/PPO-learning/PI_PPO_Optuna_Best/2025-11-04_10-08-50/PPO_1/events.out.tfevents.1762247330.MacBookAir.lan.67078.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 36
#      34 # Save the figure to the best model path
#      35 plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
# ---> 36 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      37 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.././Partial_Info_models/PPO-best/PI_PPO_Optuna_Best/2025-11-04_10-56-23/Training_process_eval_reward.png'

# %%
# === Load rollout rewards ===
# Load the event file
rollout_file = ".././Partial_Info_models/tensorboard/PPO-learning/PI_PPO_Optuna_Best/2025-11-04_10-08-50/PPO_1/events.out.tfevents.1762247330.MacBookAir.lan.67078.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 50
#      48 # Save the figure
#      49 plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
# ---> 50 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      51 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.././Partial_Info_models/PPO-best/PI_PPO_Optuna_Best/2025-11-04_10-56-23/Training_process_rewards.png'
