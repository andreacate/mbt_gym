# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
seed_value = 5
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 1.0
sigma = 1.0
n_steps = 100
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithCTMCFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
n_states=5

# %%
# OU parameters
u0 = 0.0
xi = 1.0

def m(t):
    return u0 * np.exp(-eta * t)

def v(t):
    return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))

def compute_psi(q):
    c = gamma * sigma * q
    def integrand(t):
        return np.exp(c * m(t) + 0.5 * (c**2) * v(t))
    denom, _ = quad(integrand, 0.0, terminal_time)
    return (30.0 - phi * terminal_time) / denom

# compute psi for each fad proportion
psi = compute_psi(fads_proportion)

print("psi value:", psi)
# Out:
# psi value: 14.872283180889763

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithCTMCFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, n_states=n_states,step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories,phi=phi,
                                                psi=psi,
                                                gamma=gamma, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithCTMCFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, n_states=n_states,step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories,phi=phi,
                                                psi=psi,
                                                gamma=gamma, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, BELIEF_START_INDEX, BELIEF_START_INDEX+1, BELIEF_START_INDEX+2, BELIEF_START_INDEX+3, BELIEF_START_INDEX+4 ]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 10_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "BeyhondKalmanFilter_PPO_prove"
# Paths with timestamp
tensorboard_logdir = f".././BeyhondKalmanFilterModels/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f".././BeyhondKalmanFilterModels/PPO-best/{experiment_name}/{run_id}/"

# %%
print(sb_rl_env.action_space)
print(sb_rl_env.action_space.low, sb_rl_env.action_space.high)
# Out:
# Box(0.0, 4.6051702, (2,), float32)
# [0. 0.] [4.6051702 4.6051702]

# %%
print(sb_rl_env)
# Out:
# <stable_baselines3.common.vec_env.vec_monitor.VecMonitor object at 0x13bf50e50>

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)

n_epochs = 10
learning_rate = 3e-4
gae_lambda = 0.95
clip_range = 0.2
vf_coef = 0.5
max_grad_norm = 0.5

PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":n_epochs,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              "learning_rate": learning_rate,
              "gae_lambda": gae_lambda,
              "clip_range": clip_range,
              "vf_coef": vf_coef,
              "max_grad_norm": max_grad_norm,
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }


#eval_env = get_rl_env(num_trajectories=1)
#eval_env.initial_inventory = 0
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes=n_eval_episodes,
                       #eval_freq=eval_freq,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

#callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %% [markdown]
# ### Training

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.           0.          -4.96000004   0.           0.
#    0.           0.           0.        ], [ 20.           1.         104.95999908   1.           1.
#    1.           1.           1.        ], (8,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)
# Out:
# Logging to .././BeyhondKalmanFilterModels/tensorboard/PPO-learning/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -13.6    |
# | time/              |          |
# |    fps             | 144873   |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100000   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -12.6       |
# | time/                   |             |
# |    fps                  | 30991       |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 200000      |
# | train/                  |             |
# |    approx_kl            | 0.004048753 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -0.0134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.08        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000655   |
# |    std                  | 1.02        |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -10.3        |
# | time/                   |              |
# |    fps                  | 25524        |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 300000       |
# | train/                  |              |
# |    approx_kl            | 0.0039204927 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.28         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 1.04         |
# |    value_loss           | 17.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -7.06       |
# | time/                   |             |
# |    fps                  | 23877       |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.009364027 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.94        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00166    |
# |    std                  | 1.05        |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -4.22        |
# | time/                   |              |
# |    fps                  | 22989        |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 500000       |
# | train/                  |              |
# |    approx_kl            | 0.0049999263 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.55         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00205     |
# |    std                  | 1.07         |
# |    value_loss           | 15.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.25      |
# | time/                   |            |
# |    fps                  | 22697      |
# |    iterations           | 6          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 600000     |
# | train/                  |            |
# |    approx_kl            | 0.00489085 |
# |    clip_fraction        | 0.0561     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.25       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00313   |
# |    std                  | 1.07       |
# |    value_loss           | 14.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.0471      |
# | time/                   |             |
# |    fps                  | 22505       |
# |    iterations           | 7           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 700000      |
# | train/                  |             |
# |    approx_kl            | 0.006169184 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.56        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00291    |
# |    std                  | 1.08        |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.86         |
# | time/                   |              |
# |    fps                  | 22432        |
# |    iterations           | 8            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 800000       |
# | train/                  |              |
# |    approx_kl            | 0.0047479207 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00393     |
# |    std                  | 1.08         |
# |    value_loss           | 11.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 6.99        |
# | time/                   |             |
# |    fps                  | 22440       |
# |    iterations           | 9           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 900000      |
# | train/                  |             |
# |    approx_kl            | 0.005578286 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00517    |
# |    std                  | 1.08        |
# |    value_loss           | 9.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 22345       |
# |    iterations           | 10          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 1000000     |
# | train/                  |             |
# |    approx_kl            | 0.005988472 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00538    |
# |    std                  | 1.08        |
# |    value_loss           | 8.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 22192        |
# |    iterations           | 11           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 1100000      |
# | train/                  |              |
# |    approx_kl            | 0.0063346038 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.48         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00436     |
# |    std                  | 1.08         |
# |    value_loss           | 7.15         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 22213       |
# |    iterations           | 12          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 1200000     |
# | train/                  |             |
# |    approx_kl            | 0.004035144 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00387    |
# |    std                  | 1.09        |
# |    value_loss           | 6.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 21733       |
# |    iterations           | 13          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 1300000     |
# | train/                  |             |
# |    approx_kl            | 0.005575486 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00392    |
# |    std                  | 1.09        |
# |    value_loss           | 5.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 21720       |
# |    iterations           | 14          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 1400000     |
# | train/                  |             |
# |    approx_kl            | 0.005736673 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 1.09        |
# |    value_loss           | 5.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 21694       |
# |    iterations           | 15          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 1500000     |
# | train/                  |             |
# |    approx_kl            | 0.004302346 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00234    |
# |    std                  | 1.1         |
# |    value_loss           | 4.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 17.1         |
# | time/                   |              |
# |    fps                  | 21611        |
# |    iterations           | 16           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 1600000      |
# | train/                  |              |
# |    approx_kl            | 0.0017138708 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 1.1          |
# |    value_loss           | 3.92         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 21617        |
# |    iterations           | 17           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 1700000      |
# | train/                  |              |
# |    approx_kl            | 0.0046749217 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 1.11         |
# |    value_loss           | 3.39         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 17.4       |
# | time/                   |            |
# |    fps                  | 21666      |
# |    iterations           | 18         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 1800000    |
# | train/                  |            |
# |    approx_kl            | 0.00288288 |
# |    clip_fraction        | 0.0277     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.765      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.000768  |
# |    std                  | 1.11       |
# |    value_loss           | 3.07       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 21708       |
# |    iterations           | 19          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 1900000     |
# | train/                  |             |
# |    approx_kl            | 0.002697269 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000111   |
# |    std                  | 1.12        |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 21747       |
# |    iterations           | 20          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 2000000     |
# | train/                  |             |
# |    approx_kl            | 0.002340754 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000405   |
# |    std                  | 1.12        |
# |    value_loss           | 2.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 21780        |
# |    iterations           | 21           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 2100000      |
# | train/                  |              |
# |    approx_kl            | 0.0032345275 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000313    |
# |    std                  | 1.12         |
# |    value_loss           | 2.74         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 21814       |
# |    iterations           | 22          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 2200000     |
# | train/                  |             |
# |    approx_kl            | 0.002263308 |
# |    clip_fraction        | 0.00642     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000481   |
# |    std                  | 1.13        |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 21755       |
# |    iterations           | 23          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 2300000     |
# | train/                  |             |
# |    approx_kl            | 0.002241765 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000543    |
# |    std                  | 1.13        |
# |    value_loss           | 2.76        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.3         |
# | time/                   |              |
# |    fps                  | 21517        |
# |    iterations           | 24           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 2400000      |
# | train/                  |              |
# |    approx_kl            | 0.0024669173 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000317    |
# |    std                  | 1.13         |
# |    value_loss           | 2.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 21262        |
# |    iterations           | 25           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 2500000      |
# | train/                  |              |
# |    approx_kl            | 0.0018864851 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000361    |
# |    std                  | 1.13         |
# |    value_loss           | 2.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.5         |
# | time/                   |              |
# |    fps                  | 21045        |
# |    iterations           | 26           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 2600000      |
# | train/                  |              |
# |    approx_kl            | 0.0036635962 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.00242      |
# |    std                  | 1.14         |
# |    value_loss           | 2.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.8         |
# | time/                   |              |
# |    fps                  | 20848        |
# |    iterations           | 27           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 2700000      |
# | train/                  |              |
# |    approx_kl            | 0.0020808452 |
# |    clip_fraction        | 0.00546      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000207    |
# |    std                  | 1.14         |
# |    value_loss           | 2.79         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 20857        |
# |    iterations           | 28           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 2800000      |
# | train/                  |              |
# |    approx_kl            | 0.0026983395 |
# |    clip_fraction        | 0.00705      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000527    |
# |    std                  | 1.14         |
# |    value_loss           | 2.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.8         |
# | time/                   |              |
# |    fps                  | 20892        |
# |    iterations           | 29           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 2900000      |
# | train/                  |              |
# |    approx_kl            | 0.0013768319 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.817        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000326     |
# |    std                  | 1.15         |
# |    value_loss           | 2.92         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.3         |
# | time/                   |              |
# |    fps                  | 20942        |
# |    iterations           | 30           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0017445406 |
# |    clip_fraction        | 0.00365      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.817        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000224    |
# |    std                  | 1.15         |
# |    value_loss           | 2.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 20961       |
# |    iterations           | 31          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 3100000     |
# | train/                  |             |
# |    approx_kl            | 0.001216728 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -3.94e-05   |
# |    std                  | 1.15        |
# |    value_loss           | 2.93        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 20739        |
# |    iterations           | 32           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 3200000      |
# | train/                  |              |
# |    approx_kl            | 0.0010032849 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00174      |
# |    std                  | 1.16         |
# |    value_loss           | 3.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 20743        |
# |    iterations           | 33           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 3300000      |
# | train/                  |              |
# |    approx_kl            | 0.0023637258 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000164     |
# |    std                  | 1.16         |
# |    value_loss           | 3.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.3         |
# | time/                   |              |
# |    fps                  | 20710        |
# |    iterations           | 34           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 3400000      |
# | train/                  |              |
# |    approx_kl            | 0.0034081414 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 1.16         |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 18.8          |
# | time/                   |               |
# |    fps                  | 20638         |
# |    iterations           | 35            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 3500000       |
# | train/                  |               |
# |    approx_kl            | 0.00058681663 |
# |    clip_fraction        | 0.00611       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.11         |
# |    explained_variance   | 0.812         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.48          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 6.43e-05      |
# |    std                  | 1.17          |
# |    value_loss           | 3.09          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 20497        |
# |    iterations           | 36           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 3600000      |
# | train/                  |              |
# |    approx_kl            | 0.0033952997 |
# |    clip_fraction        | 0.00602      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -6.87e-06    |
# |    std                  | 1.17         |
# |    value_loss           | 3.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 20383       |
# |    iterations           | 37          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 3700000     |
# | train/                  |             |
# |    approx_kl            | 0.003722693 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -1.93e-05   |
# |    std                  | 1.18        |
# |    value_loss           | 3.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.9         |
# | time/                   |              |
# |    fps                  | 20228        |
# |    iterations           | 38           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 3800000      |
# | train/                  |              |
# |    approx_kl            | 0.0032246877 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000222    |
# |    std                  | 1.18         |
# |    value_loss           | 3.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 20130        |
# |    iterations           | 39           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 3900000      |
# | train/                  |              |
# |    approx_kl            | 0.0014495531 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 3.44e-05     |
# |    std                  | 1.19         |
# |    value_loss           | 3.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.3         |
# | time/                   |              |
# |    fps                  | 20101        |
# |    iterations           | 40           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0003264773 |
# |    clip_fraction        | 0.00848      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00026      |
# |    std                  | 1.19         |
# |    value_loss           | 3.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.6         |
# | time/                   |              |
# |    fps                  | 20018        |
# |    iterations           | 41           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 4100000      |
# | train/                  |              |
# |    approx_kl            | 0.0018759512 |
# |    clip_fraction        | 0.00707      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000123    |
# |    std                  | 1.2          |
# |    value_loss           | 3.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 19966        |
# |    iterations           | 42           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 4200000      |
# | train/                  |              |
# |    approx_kl            | 0.0006881942 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000545     |
# |    std                  | 1.21         |
# |    value_loss           | 3.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.2         |
# | time/                   |              |
# |    fps                  | 19945        |
# |    iterations           | 43           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 4300000      |
# | train/                  |              |
# |    approx_kl            | 0.0008646015 |
# |    clip_fraction        | 0.00826      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -1.03e-05    |
# |    std                  | 1.21         |
# |    value_loss           | 3.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 19942        |
# |    iterations           | 44           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 4400000      |
# | train/                  |              |
# |    approx_kl            | 0.0021622982 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.000151     |
# |    std                  | 1.22         |
# |    value_loss           | 3.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 19925        |
# |    iterations           | 45           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 4500000      |
# | train/                  |              |
# |    approx_kl            | 0.0032441292 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000766     |
# |    std                  | 1.22         |
# |    value_loss           | 3.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 19957        |
# |    iterations           | 46           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 4600000      |
# | train/                  |              |
# |    approx_kl            | 0.0009252535 |
# |    clip_fraction        | 0.000432     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000196    |
# |    std                  | 1.22         |
# |    value_loss           | 3.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.6         |
# | time/                   |              |
# |    fps                  | 19956        |
# |    iterations           | 47           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 4700000      |
# | train/                  |              |
# |    approx_kl            | 0.0013702832 |
# |    clip_fraction        | 0.00164      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000212    |
# |    std                  | 1.23         |
# |    value_loss           | 3.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 18.8         |
# | time/                   |              |
# |    fps                  | 19974        |
# |    iterations           | 48           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0018481405 |
# |    clip_fraction        | 0.00499      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -3.04e-05    |
# |    std                  | 1.23         |
# |    value_loss           | 3.08         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 19.8          |
# | time/                   |               |
# |    fps                  | 19995         |
# |    iterations           | 49            |
# |    time_elapsed         | 245           |
# |    total_timesteps      | 4900000       |
# | train/                  |               |
# |    approx_kl            | 0.00027535998 |
# |    clip_fraction        | 0.103         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.812         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.42          |
# |    n_updates            | 480           |
# |    policy_gradient_loss | 0.0082        |
# |    std                  | 1.24          |
# |    value_loss           | 3.12          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 20020        |
# |    iterations           | 50           |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0018148177 |
# |    clip_fraction        | 0.00907      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 1.24         |
# |    value_loss           | 3.01         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 18.6          |
# | time/                   |               |
# |    fps                  | 20029         |
# |    iterations           | 51            |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 5100000       |
# | train/                  |               |
# |    approx_kl            | 0.00073875574 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.801         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.44          |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 0.000177      |
# |    std                  | 1.25          |
# |    value_loss           | 3.1           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 20006       |
# |    iterations           | 52          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 5200000     |
# | train/                  |             |
# |    approx_kl            | 0.001051801 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# ...
# |    time_elapsed         | 433          |
# |    total_timesteps      | 8400000      |
# | train/                  |              |
# |    approx_kl            | 0.0038441934 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.000336    |
# |    std                  | 1.42         |
# |    value_loss           | 2.78         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 19.8        |
# | time/                   |             |
# |    fps                  | 19365       |
# |    iterations           | 85          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 8500000     |
# | train/                  |             |
# |    approx_kl            | 0.007543559 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.000763    |
# |    std                  | 1.43        |
# |    value_loss           | 2.8         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.6         |
# | time/                   |              |
# |    fps                  | 19369        |
# |    iterations           | 86           |
# |    time_elapsed         | 444          |
# |    total_timesteps      | 8600000      |
# | train/                  |              |
# |    approx_kl            | 0.0027634813 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000227    |
# |    std                  | 1.43         |
# |    value_loss           | 2.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.9         |
# | time/                   |              |
# |    fps                  | 19375        |
# |    iterations           | 87           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 8700000      |
# | train/                  |              |
# |    approx_kl            | 0.0007971054 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.00786      |
# |    std                  | 1.44         |
# |    value_loss           | 2.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.5         |
# | time/                   |              |
# |    fps                  | 19358        |
# |    iterations           | 88           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 8800000      |
# | train/                  |              |
# |    approx_kl            | 0.0026223646 |
# |    clip_fraction        | 0.00809      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000481    |
# |    std                  | 1.44         |
# |    value_loss           | 2.82         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 19358       |
# |    iterations           | 89          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 8900000     |
# | train/                  |             |
# |    approx_kl            | 0.002837993 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.000358   |
# |    std                  | 1.45        |
# |    value_loss           | 2.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.8         |
# | time/                   |              |
# |    fps                  | 19342        |
# |    iterations           | 90           |
# |    time_elapsed         | 465          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0013642468 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.3         |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.000307    |
# |    std                  | 1.45         |
# |    value_loss           | 2.73         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20           |
# | time/                   |              |
# |    fps                  | 19346        |
# |    iterations           | 91           |
# |    time_elapsed         | 470          |
# |    total_timesteps      | 9100000      |
# | train/                  |              |
# |    approx_kl            | 0.0117847305 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.3         |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | 0.00372      |
# |    std                  | 1.47         |
# |    value_loss           | 2.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 19348       |
# |    iterations           | 92          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 9200000     |
# | train/                  |             |
# |    approx_kl            | 0.002504303 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.000544    |
# |    std                  | 1.47        |
# |    value_loss           | 2.74        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 22.5         |
# | time/                   |              |
# |    fps                  | 19302        |
# |    iterations           | 93           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 9300000      |
# | train/                  |              |
# |    approx_kl            | 0.0018827973 |
# |    clip_fraction        | 0.00346      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.3         |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00011     |
# |    std                  | 1.48         |
# |    value_loss           | 2.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 19264        |
# |    iterations           | 94           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 9400000      |
# | train/                  |              |
# |    approx_kl            | 0.0022427496 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.31        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000246    |
# |    std                  | 1.48         |
# |    value_loss           | 2.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 19225        |
# |    iterations           | 95           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 9500000      |
# | train/                  |              |
# |    approx_kl            | 0.0010402491 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.31        |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -5.63e-05    |
# |    std                  | 1.5          |
# |    value_loss           | 2.9          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 19221       |
# |    iterations           | 96          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 9600000     |
# | train/                  |             |
# |    approx_kl            | 0.007585025 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.000419    |
# |    std                  | 1.5         |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 19227       |
# |    iterations           | 97          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 9700000     |
# | train/                  |             |
# |    approx_kl            | 0.002742346 |
# |    clip_fraction        | 0.00597     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.000344   |
# |    std                  | 1.51        |
# |    value_loss           | 2.97        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 20.6         |
# | time/                   |              |
# |    fps                  | 19238        |
# |    iterations           | 98           |
# |    time_elapsed         | 509          |
# |    total_timesteps      | 9800000      |
# | train/                  |              |
# |    approx_kl            | 0.0017202221 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000339    |
# |    std                  | 1.52         |
# |    value_loss           | 2.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 19.9         |
# | time/                   |              |
# |    fps                  | 19252        |
# |    iterations           | 99           |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 9900000      |
# | train/                  |              |
# |    approx_kl            | 0.0017992866 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | 0.00137      |
# |    std                  | 1.53         |
# |    value_loss           | 2.87         |
# ------------------------------------------
# Eval num_timesteps=10000000, episode_reward=25.86 +/- 5.59
# Episode length: 100.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 100          |
# |    mean_reward          | 25.9         |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0025134243 |
# |    clip_fraction        | 0.00404      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.000517    |
# |    std                  | 1.53         |
# |    value_loss           | 2.81         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    fps             | 19238    |
# |    iterations      | 100      |
# |    time_elapsed    | 519      |
# |    total_timesteps | 10000000 |
# ---------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithCTMCFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, n_states=n_states,step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories,phi=phi,
                                                psi=psi,
                                                gamma=gamma, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=1)

# %%
use_normalized_agent = False

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
#os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.0496e+04 -2.0000e+01  0.0000e+00 -4.9600e+00  0.0000e+00  0.0000e+00
#   0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00], [1.0496e+04 2.0000e+01 1.0000e+00 1.0496e+02 4.0000e+00 1.0000e+00
#  1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 6.0000e+01 6.0000e+01], (12,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
results_rl, fig, tot_rewards = generate_results_table_and_hist_rl_fast(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#           Mean spread   Mean PnL   Std PnL  PnL CI 95% low  PnL CI 95% high  \
# RL Agent     2.279435  26.508677  5.541201       26.164819        26.852534
#
#           Mean terminal inventory  Std terminal inventory
# RL Agent                    1.259                 2.18264

# %%
results_rl
# Out:
#           Mean spread   Mean PnL   Std PnL  PnL CI 95% low  PnL CI 95% high  \
# RL Agent     2.279435  26.508677  5.541201       26.164819        26.852534
#
#           Mean terminal inventory  Std terminal inventory
# RL Agent                    1.259                 2.18264

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5,100,1/10,2/10,4/10,2/10,1/10]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
cj_agent = ModifiedCarteaJaimungalMmAgent(env=get_closed_form_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, cj_bid_actions, label="bid (CJ)", color="k", linestyle="--")
ax.plot(inventories, cj_ask_actions, label="ask (CJ)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Cartea-Jaimungal")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to .././BeyhondKalmanFilterModels/PPO-best/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/policy_comparison.png

# %% [markdown]
# ### Dependence of policy on time

# %%
# Function to create the plot comparing PPO and CJ agents
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, cj_agent)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plot_policy_time_dependence(ppo_agent, cj_agent)
#
# Cell In[39], line 41, in plot_policy_time_dependence(ppo_agent, cj_agent)
#      38 normalized_time = t/terminal_time  # Normalize time to [0,1]
#      40 # Get PPO agent's actions
# ---> 41 rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
#      42 rl_bids.append(rl_bid)
#      43 rl_asks.append(rl_ask)
#
# File ~/Desktop/gitProject/mbt_gym/Experiments_MMwithFadsInfUnifTraders_RL/BeyhondKalmanFilter/../../mbt_gym/agents/SbAgent.py:44, in SbAgent.get_action(self, state)
#      34 def get_action(self, state: np.ndarray) -> np.ndarray:
#      35     # TODO: handle reduced training state space if needed (attention to the dimension reduced state or not?)
#      36     # If the current env is NOT normalized but the model was trained on normalized obs,
#    (...)
#      42
#      43     # Get action from model
# ---> 44     action = self.model.predict(state, deterministic=True)[0].reshape(state.shape[0], self.num_actions)
#      46     # If the current env (for evaluation) is NOT normalized but the model outputs normalized actions,
#      47     # we need to denormalize them
#      48     if not self.env.normalise_action_space_ and self.use_normalized_agent and hasattr(self.env, 'normalise_action'):
#      49         #print("check")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)
#     542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:404, in is_vectorized_observation(observation, observation_space)
#     402 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     403     if isinstance(observation_space, space_type):
# --> 404         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     405 else:
#     406     # for-else happens if no break is called
#     407     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:271, in is_vectorized_box_observation(observation, observation_space)
#     269     return True
#     270 else:
# --> 271     raise ValueError(
#     272         f"Error: Unexpected observation shape {observation.shape} for "
#     273         + f"Box environment, please use {observation_space.shape} "
#     274         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     275     )
#
# ValueError: Error: Unexpected observation shape (1, 3) for Box environment, please use (8,) or (n_env, 8) for the observation shape.

# %%
def plot_policy_time_dependence(ppo_agent, cj_agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        cj_bids = []
        cj_asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get CJ agent's actions
            cj_bid, cj_ask = cj_agent.get_action(np.array([[0, inv, normalized_time]])).reshape(-1)
            cj_bids.append(cj_bid)
            cj_asks.append(cj_ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(cj_bids), min(cj_asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(cj_bids), max(cj_asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, cj_bids, cj_asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, cj_bids, cj_asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, cj_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, cj_asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL δ^bid")
    ax2.set_title("CJP δ^bid")
    ax3.set_title("RL δ^ask")
    ax4.set_title("CJP δ^ask")
    
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus CarteaJaimungalAgent as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, cj_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 5
#       2 os.makedirs(best_model_path, exist_ok=True)
#       4 # Create the plot
# ----> 5 fig = plot_policy_time_dependence(ppo_agent, cj_agent)
#       7 # Save the figure to the best model path
#       8 plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
#
# Cell In[41], line 47, in plot_policy_time_dependence(ppo_agent, cj_agent)
#      44 normalized_time = t/terminal_time  # Normalize time to [0,1]
#      46 # Get PPO agent's actions
# ---> 47 rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price]])).reshape(-1)
#      48 rl_bids.append(rl_bid)
#      49 rl_asks.append(rl_ask)
#
# File ~/Desktop/gitProject/mbt_gym/Experiments_MMwithFadsInfUnifTraders_RL/BeyhondKalmanFilter/../../mbt_gym/agents/SbAgent.py:44, in SbAgent.get_action(self, state)
#      34 def get_action(self, state: np.ndarray) -> np.ndarray:
#      35     # TODO: handle reduced training state space if needed (attention to the dimension reduced state or not?)
#      36     # If the current env is NOT normalized but the model was trained on normalized obs,
#    (...)
#      42
#      43     # Get action from model
# ---> 44     action = self.model.predict(state, deterministic=True)[0].reshape(state.shape[0], self.num_actions)
#      46     # If the current env (for evaluation) is NOT normalized but the model outputs normalized actions,
#      47     # we need to denormalize them
#      48     if not self.env.normalise_action_space_ and self.use_normalized_agent and hasattr(self.env, 'normalise_action'):
#      49         #print("check")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)
#     542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:404, in is_vectorized_observation(observation, observation_space)
#     402 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     403     if isinstance(observation_space, space_type):
# --> 404         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     405 else:
#     406     # for-else happens if no break is called
#     407     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:271, in is_vectorized_box_observation(observation, observation_space)
#     269     return True
#     270 else:
# --> 271     raise ValueError(
#     272         f"Error: Unexpected observation shape {observation.shape} for "
#     273         + f"Box environment, please use {observation_space.shape} "
#     274         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     275     )
#
# ValueError: Error: Unexpected observation shape (1, 3) for Box environment, please use (6,) or (n_env, 6) for the observation shape.

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
#       2 print('mean: ',np.mean(total_rewards))
#       3 print('median: ',np.median(total_rewards))
#
# NameError: name 'rewards_rl' is not defined

# %%
# Load the event file
#Experiments_MMwithFadsInfUnifTraders_RL/BeyhondKalmanFilterModels/tensorboard/PPO-learning/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/PPO_1/events.out.tfevents.1770240315.Andreas-MacBook-Air.local.53063.0
event_file = ".././BeyhondKalmanFilterModels/tensorboard/PPO-learning/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/PPO_1/events.out.tfevents.1770240315.Andreas-MacBook-Air.local.53063.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Cartea-Jaimungal
# y_line = float(results_cj["Mean PnL"].iloc[0])
# ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
#           linestyles='--', color='tab:red',
#           label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to .././BeyhondKalmanFilterModels/PPO-best/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = ".././CJ_models/tensorboard/PPO-learning/CjMm_500/2025-12-01_17-23-18/PPO_1/events.out.tfevents.1764609800.0dd7747a86c4.45167.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# # Plot the rewards
# ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# # Add the baseline from Cartea-Jaimungal
# y_line = float(results_cj["Mean PnL"].iloc[0])
# ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
#           linestyles='--', color='tab:red',
#           label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# /var/folders/kx/1mlzw51d67d3cr090d4kd9zc0000gn/T/ipykernel_53063/665966212.py:30: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Plot saved to .././BeyhondKalmanFilterModels/PPO-best/BeyhondKalmanFilter_PPO_prove/2026-02-04_22-25-13/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===
rollout_file = ".././CJ_models/tensorboard/PPO-learning/CjMm_500/2025-12-01_17-23-18/PPO_1/events.out.tfevents.1764609800.0dd7747a86c4.45167.0"

ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)

# Add baseline line
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[57], line 50
#      48 # Save the figure
#      49 plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
# ---> 50 fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
#      51 print(f"Plot saved to {plot_filename}")
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)
#     479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/PIL/Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# NotADirectoryError: [Errno 20] Not a directory: '.././CJ_models/PPO-best/CjMm_PPO_500_000_000steps_Baseline/2025-10-23_11-40-14/best_model.zip/Training_process_rewards.png'

# %%
def moving_average(x, window):
    if window < 1:
        raise ValueError("Window size must be >= 1")
    return np.convolve(x, np.ones(window)/window, mode='valid')

# %%
ma_window = 5  # recommended
eval_rewards_ma = moving_average(eval_rewards, ma_window)

# Align steps
eval_steps_ma = eval_steps[ma_window - 1:]

# %%
fig, ax = plt.subplots(figsize=(8, 5))

# Raw curves
ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue',
        alpha=0.5, label='Rollout reward (raw)')
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange',
        alpha=0.3, label='Eval reward (raw)')

# Smoothed eval curve
ax.plot(eval_steps_ma, eval_rewards_ma, '-', color='tab:orange',
        linewidth=2.5, label=f'Eval reward (MA {ma_window})')

# Baseline
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps),
          xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red',
          label='Closed-form solution')

ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# %%
from scipy.ndimage import gaussian_filter1d

# %%
sigma = 2   # recommended for RL eval curves
eval_rewards_gauss = gaussian_filter1d(eval_rewards, sigma=sigma)

# %%
eval_steps_gauss = eval_steps

# %%
import numpy as np
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt

# --- Moving average ---
def moving_average(x, window):
    return np.convolve(x, np.ones(window)/window, mode='valid')

# --- Smooth signals ---
ma_window = 5
eval_rewards_ma = moving_average(eval_rewards, ma_window)
eval_steps_ma = eval_steps[ma_window - 1:]

# Gaussian smoothing
sigma = 2
eval_rewards_gauss = gaussian_filter1d(eval_rewards, sigma=sigma)
eval_steps_gauss = eval_steps   # same length

# --- Plot ---
fig, ax = plt.subplots(figsize=(8, 5))

# Raw signals
ax.plot(rollout_steps, rollout_rewards, color='tab:blue', alpha=0.4,
        label='Rollout reward (raw)')
ax.plot(eval_steps, eval_rewards, color='tab:orange', alpha=0.2,
        label='Eval reward (raw)')

# Moving average
ax.plot(eval_steps_ma, eval_rewards_ma, color='tab:orange', linewidth=2.5,
        label=f'Eval reward (MA {ma_window})')

# Gaussian smoothing
ax.plot(eval_steps_gauss, eval_rewards_gauss, color='tab:red', linewidth=2,
        label=f'Eval reward (Gaussian σ={sigma})')

# Baseline
y_line = float(results_cj["Mean PnL"].iloc[0])
ax.hlines(y=y_line,
          xmin=min(rollout_steps + eval_steps),
          xmax=max(rollout_steps + eval_steps),
          color='black', linestyle='--', linewidth=1.5,
          label='Closed-form solution')

ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()
