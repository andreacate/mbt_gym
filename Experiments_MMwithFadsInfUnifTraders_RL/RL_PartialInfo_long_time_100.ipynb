# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from scipy.integrate import quad
import torch
from torch import nn
from datetime import datetime
from matplotlib.gridspec import GridSpec
from tensorboard.backend.event_processing import event_accumulator

from copy import deepcopy

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics
from mbt_gym.agents.BaselineAgents import *
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.arrival_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *

# helpers
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.index_names import *
from mbt_gym.gym.helpers.plotting import *
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.wrappers import *

# %%
seed_value = 42
global seed  
seed = seed_value

# Reset seeds for all randomness sources
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Parameters

# %%
max_inventory = 20

# %%
initial_price = 100
terminal_time = 10.0
sigma = 1.0
n_steps = 1000
initial_inventory = 0
fads_proportion = 0.6 # p is defined directly inside the ArithmeticBrownianMotionWithFadsMidpriceModel class as sqrt(1-q^2)
eta = 10
phi = 15
k = 1
fill_exponent = k
gamma = k
alpha=0.001
mu=0
big_phi=0.1

# %%
total_arrivals = 30.0
# OU parameters
u0 = 0.0
xi = 1.0

# %%
# Replace your compute_psi function with this:
def compute_aux_integral_for_psi():
    """Compute the integral needed to rescale psi, matching Adrien's implementation."""
    # This matches Adrien's compute_integral_related_to_psi
    time_grid = np.linspace(0, terminal_time, n_steps)
    
    def v(t):
        return (xi**2) / (2.0 * eta) * (1.0 - np.exp(-2.0 * eta * t))
    
    # Compute exp(γ²/2 * v(t)) for each time point
    integrand_values = np.exp((gamma * sigma * fads_proportion)**2 / 2 * v(time_grid))
    
    # Return T * mean(integrand)
    return terminal_time * np.mean(integrand_values)

# Now compute psi correctly
aux_integral = compute_aux_integral_for_psi()
psi = (total_arrivals * terminal_time - phi * terminal_time) / aux_integral

print(f"aux_integral: {aux_integral}")
print(f"psi value: {psi}")
# Out:
# aux_integral: 10.08990691848612
# psi value: 14.866341306397885

# %%
def get_closed_form_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,

                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
pi_env = get_closed_form_env(fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)

# %%
pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=pi_env)
print(pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x146097130>

# %%
plot_trajectory_extended(pi_env, pi_agent)

# %%
plot_trajectory(pi_env, pi_agent, seed = seed)

# %%
num_trajectories = 1000
vec_pi_env = get_closed_form_env(num_trajectories, fads_proportion=fads_proportion, psi=psi, phi=phi, eta=eta, gamma=gamma)
vec_pi_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=vec_pi_env)

print(vec_pi_env.model_dynamics
      .midprice_model)
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points
# <mbt_gym.stochastic_processes.midprice_models.ArithmeticBrownianMotionWithFadsMidpriceModel object at 0x147c85150>

# %%
observations_pi, actions_pi, rewards_pi = generate_trajectory(vec_pi_env, vec_pi_agent)

# %%
results_pi, fig_pi, total_rewards_pi = generate_results_table_and_hist(vec_env=vec_pi_env,agent=vec_pi_agent)
# Out:
# /Users/andrea/Desktop/gitProject/mbt_gym/Experiments_MMwithFadsInfUnifTraders_RL/../mbt_gym/agents/BaselineAgents.py:700: UserWarning: MM agent is quoting a negative spread
#   warnings.warn("MM agent is quoting a negative spread")

# %%
results_pi
# Out:
#           Mean spread    Mean PnL    Std PnL Mean terminal inventory  \
# Inventory    2.092324  210.464198  15.116967                  -0.165
#
#           Std terminal inventory
# Inventory               3.109626

# %% [markdown]
# ### Rinforncement Learning

# %% [markdown]
# #### Random initial inventory

# %%
random_initial_inventory = (-6,5)

# %% [markdown]
# #### Random start time

# %%
def make_random_start_time_sampler(terminal_time: float):
    """
    Returns a callable that samples an initial time according to:
      - with probability 0.5: uniform in [0, 0.8 * T]
      - with probability 0.5: uniform in [0.8 * T, 0.99 * T]
    
    Parameters
    ----------
    terminal_time : float
        The terminal time T of the episode.
    
    Returns
    -------
    callable
        A function that samples and returns a random start time.
    """
    def _sample_start_time():
        if np.random.rand() < 0.5:
            # 50% chance: early part of episode
            return np.random.uniform(0.0, 0.8 * terminal_time)
        else:
            # 50% chance: near the end of episode
            return np.random.uniform(0.8 * terminal_time, 0.99 * terminal_time)
    return _sample_start_time

# %%
def get_rl_env(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory=max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
reduced_training_indices = [INVENTORY_INDEX, TIME_INDEX, ASSET_PRICE_INDEX, FILTERED_FADS_INDEX]
aux_rl_env = get_rl_env(num_trajectories)
rl_env = ReduceStateSizeWrapper(get_rl_env(num_trajectories), reduced_training_indices)
#rl_env = NormaliseASObservation(rl_env)
sb_rl_env = StableBaselinesTradingEnvironment(trading_env=rl_env)
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:225: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/gymnasium/spaces/box.py:295: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %% [markdown]
# ### PPO

# %%
total_steps = 100_000_000  
#eval_freq = total_steps // 10 
n_eval_episodes = 256

use_normalized_agent = False

# %%
# Monitor sb_rl_env
sb_rl_env = VecMonitor(sb_rl_env)

# Generate timestamp string
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
experiment_name = "PIMm_PPO_100_000_000steps_LongTime"
# Paths with timestamp
tensorboard_logdir = f"./Partial_Info_models/tensorboard/PPO-learning/{experiment_name}/{run_id}/"
best_model_path = f"./Partial_Info_models/PPO-best/{experiment_name}/{run_id}/"

# %%
# Make sure directories exist
os.makedirs(tensorboard_logdir, exist_ok=True)
os.makedirs(best_model_path, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EntropyDecayCallback(BaseCallback):
    def __init__(self, initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=10_000_000, verbose=0):
        super().__init__(verbose)
        self.initial_ent_coef = initial_ent_coef
        self.final_ent_coef = final_ent_coef
        self.decay_steps = decay_steps

    def _on_step(self) -> bool:
        progress = min(1.0, self.num_timesteps / self.decay_steps)
        new_ent_coef = self.initial_ent_coef * (1 - progress) + self.final_ent_coef * progress
        self.model.ent_coef = new_ent_coef
        return True

# %%
#policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

policy_kwargs = dict(
    activation_fn=nn.Tanh,                 
    net_arch=[dict(pi=[256, 256], vf=[256, 256])]
)
PPO_params = {"policy":'MlpPolicy', "env": sb_rl_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps),
              #"ent_coef": 0.05 # added ent_coef to encourage exploration
                }
callback_params = dict(eval_env=sb_rl_env, n_eval_episodes = 256, #200 before  (n_eval_episodes)
                       #eval_freq=200_000,
                       best_model_save_path = best_model_path, 
                       deterministic=True)

#entropy_decay_callback = EntropyDecayCallback(initial_ent_coef=0.05, final_ent_coef=0.001, decay_steps=20_000_000)
#callback = CallbackList([EvalCallback(**callback_params), entropy_decay_callback])

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /opt/anaconda3/envs/mtb_gym_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %%
print(sb_rl_env.observation_space)
# Out:
# Box([-20.           0.         -12.51928806 -10.        ], [ 20.          10.         112.51928711  10.        ], (4,), float64)

# %%
model.learn(total_timesteps = total_steps, callback=callback)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -16.6    |
# | time/              |          |
# |    fps             | 355313   |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -15.8        |
# | time/                   |              |
# |    fps                  | 117533       |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0035809237 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.034        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.36         |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.995        |
# |    value_loss           | 10           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.43        |
# | time/                   |             |
# |    fps                  | 95993       |
# |    iterations           | 3           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3000000     |
# | train/                  |             |
# |    approx_kl            | 0.004095507 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.77        |
# |    n_updates            | 6           |
# |    policy_gradient_loss | -0.0012     |
# |    std                  | 0.992       |
# |    value_loss           | 8.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26.1        |
# | time/                   |             |
# |    fps                  | 86071       |
# |    iterations           | 4           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4000000     |
# | train/                  |             |
# |    approx_kl            | 0.004176995 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.55        |
# |    n_updates            | 9           |
# |    policy_gradient_loss | -0.00135    |
# |    std                  | 0.987       |
# |    value_loss           | 7.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 81578       |
# |    iterations           | 5           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.004193269 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.982       |
# |    value_loss           | 6.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 67.5         |
# | time/                   |              |
# |    fps                  | 79161        |
# |    iterations           | 6            |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0047481977 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65         |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.977        |
# |    value_loss           | 5.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 63.4        |
# | time/                   |             |
# |    fps                  | 77525       |
# |    iterations           | 7           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.005393288 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 0.971       |
# |    value_loss           | 4.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 75.7        |
# | time/                   |             |
# |    fps                  | 76181       |
# |    iterations           | 8           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 8000000     |
# | train/                  |             |
# |    approx_kl            | 0.005870425 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77        |
# |    n_updates            | 21          |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.962       |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 74994       |
# |    iterations           | 9           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.005979969 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.000601   |
# |    std                  | 0.956       |
# |    value_loss           | 3.1         |
# -----------------------------------------
# Eval num_timesteps=10000000, episode_reward=131.69 +/- 9.70
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 132          |
# | time/                   |              |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0030323358 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 27           |
# |    policy_gradient_loss | 0.000229     |
# |    std                  | 0.95         |
# |    value_loss           | 2.8          |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 88.4     |
# | time/              |          |
# |    fps             | 73223    |
# |    iterations      | 10       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 10000000 |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 72687       |
# |    iterations           | 11          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 11000000    |
# | train/                  |             |
# |    approx_kl            | 0.005535894 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00271    |
# |    std                  | 0.944       |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 99.8        |
# | time/                   |             |
# |    fps                  | 72213       |
# |    iterations           | 12          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.007852152 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 33          |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.936       |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 71644       |
# |    iterations           | 13          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 13000000    |
# | train/                  |             |
# |    approx_kl            | 0.008447434 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00116    |
# |    std                  | 0.928       |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 71260       |
# |    iterations           | 14          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 14000000    |
# | train/                  |             |
# |    approx_kl            | 0.006601521 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 39          |
# |    policy_gradient_loss | -0.000394   |
# |    std                  | 0.92        |
# |    value_loss           | 2.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 71006       |
# |    iterations           | 15          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 15000000    |
# | train/                  |             |
# |    approx_kl            | 0.004731317 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.95        |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.000333   |
# |    std                  | 0.912       |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 70782       |
# |    iterations           | 16          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 16000000    |
# | train/                  |             |
# |    approx_kl            | 0.004561076 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.932       |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.00234    |
# |    std                  | 0.906       |
# |    value_loss           | 1.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 70556        |
# |    iterations           | 17           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0038520326 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.952        |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00206     |
# |    std                  | 0.9          |
# |    value_loss           | 1.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 70363        |
# |    iterations           | 18           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 18000000     |
# | train/                  |              |
# |    approx_kl            | 0.0031058632 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.934        |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.893        |
# |    value_loss           | 1.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 70192       |
# |    iterations           | 19          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 19000000    |
# | train/                  |             |
# |    approx_kl            | 0.004610322 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.95        |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 0.885       |
# |    value_loss           | 1.95        |
# -----------------------------------------
# Eval num_timesteps=20000000, episode_reward=201.96 +/- 12.12
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 202          |
# | time/                   |              |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034451552 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.983        |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000954    |
# |    std                  | 0.878        |
# |    value_loss           | 1.98         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 136      |
# | time/              |          |
# |    fps             | 69609    |
# |    iterations      | 20       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 20000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 69500        |
# |    iterations           | 21           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0047674784 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.998        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00117     |
# |    std                  | 0.87         |
# |    value_loss           | 2.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 69373       |
# |    iterations           | 22          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 22000000    |
# | train/                  |             |
# |    approx_kl            | 0.005101529 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.997       |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -0.000254   |
# |    std                  | 0.863       |
# |    value_loss           | 2.06        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 69278        |
# |    iterations           | 23           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011999554 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1            |
# |    n_updates            | 66           |
# |    policy_gradient_loss | 0.000361     |
# |    std                  | 0.857        |
# |    value_loss           | 2.05         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 69180        |
# |    iterations           | 24           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033352878 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.958        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.852        |
# |    value_loss           | 1.98         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 69050        |
# |    iterations           | 25           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0059524407 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.674        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.978        |
# |    n_updates            | 72           |
# |    policy_gradient_loss | 0.000576     |
# |    std                  | 0.845        |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 68979        |
# |    iterations           | 26           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0059605637 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.993        |
# |    n_updates            | 75           |
# |    policy_gradient_loss | 1.83e-05     |
# |    std                  | 0.84         |
# |    value_loss           | 1.99         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 68902       |
# |    iterations           | 27          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 27000000    |
# | train/                  |             |
# |    approx_kl            | 0.003468717 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.964       |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -0.001      |
# |    std                  | 0.83        |
# |    value_loss           | 1.95        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 68823        |
# |    iterations           | 28           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 28000000     |
# | train/                  |              |
# |    approx_kl            | 0.0042682127 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.976        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -3.91e-05    |
# |    std                  | 0.823        |
# |    value_loss           | 1.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 68679        |
# |    iterations           | 29           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0036794688 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.818        |
# |    value_loss           | 2.06         |
# ------------------------------------------
# Eval num_timesteps=30000000, episode_reward=207.91 +/- 14.82
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 208         |
# | time/                   |             |
# |    total_timesteps      | 30000000    |
# | train/                  |             |
# |    approx_kl            | 0.002054014 |
# |    clip_fraction        | 0.00867     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 87          |
# |    policy_gradient_loss | -0.000473   |
# |    std                  | 0.815       |
# |    value_loss           | 2.07        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    fps             | 68366    |
# |    iterations      | 30       |
# |    time_elapsed    | 438      |
# |    total_timesteps | 30000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 68323        |
# |    iterations           | 31           |
# |    time_elapsed         | 453          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034105093 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000971    |
# |    std                  | 0.809        |
# |    value_loss           | 2.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 68258        |
# |    iterations           | 32           |
# |    time_elapsed         | 468          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021384496 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -0.000924    |
# |    std                  | 0.803        |
# |    value_loss           | 2.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 68175        |
# |    iterations           | 33           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032273226 |
# |    clip_fraction        | 0.00943      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00052     |
# |    std                  | 0.798        |
# |    value_loss           | 2.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 68144        |
# |    iterations           | 34           |
# |    time_elapsed         | 498          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0022408268 |
# |    clip_fraction        | 0.00541      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.00029     |
# |    std                  | 0.793        |
# |    value_loss           | 2.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 68091       |
# |    iterations           | 35          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 35000000    |
# | train/                  |             |
# |    approx_kl            | 0.001814561 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 102         |
# |    policy_gradient_loss | -0.000366   |
# |    std                  | 0.787       |
# |    value_loss           | 2.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 68045        |
# |    iterations           | 36           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 36000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032025601 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11         |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.00022     |
# |    std                  | 0.782        |
# |    value_loss           | 2.21         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 67997       |
# |    iterations           | 37          |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 37000000    |
# | train/                  |             |
# |    approx_kl            | 0.004903627 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | 0.000223    |
# |    std                  | 0.777       |
# |    value_loss           | 2.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 67975       |
# |    iterations           | 38          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 38000000    |
# | train/                  |             |
# |    approx_kl            | 0.002006959 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 111         |
# |    policy_gradient_loss | -0.00014    |
# |    std                  | 0.772       |
# |    value_loss           | 2.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 67937        |
# |    iterations           | 39           |
# |    time_elapsed         | 574          |
# |    total_timesteps      | 39000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019352159 |
# |    clip_fraction        | 0.00169      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -0.000239    |
# |    std                  | 0.769        |
# |    value_loss           | 2.16         |
# ------------------------------------------
# Eval num_timesteps=40000000, episode_reward=202.64 +/- 17.75
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 203          |
# | time/                   |              |
# |    total_timesteps      | 40000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024815002 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -0.00016     |
# |    std                  | 0.766        |
# |    value_loss           | 2.18         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    fps             | 67741    |
# |    iterations      | 40       |
# |    time_elapsed    | 590      |
# |    total_timesteps | 40000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 67640        |
# |    iterations           | 41           |
# |    time_elapsed         | 606          |
# |    total_timesteps      | 41000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011971205 |
# |    clip_fraction        | 0.000136     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -9.26e-05    |
# |    std                  | 0.763        |
# |    value_loss           | 2.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 67627        |
# |    iterations           | 42           |
# |    time_elapsed         | 621          |
# |    total_timesteps      | 42000000     |
# | train/                  |              |
# |    approx_kl            | 0.0041791676 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 123          |
# |    policy_gradient_loss | 0.000293     |
# |    std                  | 0.756        |
# |    value_loss           | 2.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 67618        |
# |    iterations           | 43           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 43000000     |
# | train/                  |              |
# |    approx_kl            | 0.0026392336 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 126          |
# |    policy_gradient_loss | 0.000936     |
# |    std                  | 0.752        |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 67604        |
# |    iterations           | 44           |
# |    time_elapsed         | 650          |
# |    total_timesteps      | 44000000     |
# | train/                  |              |
# |    approx_kl            | 0.0011892954 |
# |    clip_fraction        | 0.00125      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -8.42e-05    |
# |    std                  | 0.748        |
# |    value_loss           | 2.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 67578        |
# |    iterations           | 45           |
# |    time_elapsed         | 665          |
# |    total_timesteps      | 45000000     |
# | train/                  |              |
# |    approx_kl            | 0.0044236877 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | 0.000212     |
# |    std                  | 0.743        |
# |    value_loss           | 2.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 67456        |
# |    iterations           | 46           |
# |    time_elapsed         | 681          |
# |    total_timesteps      | 46000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024803113 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 135          |
# |    policy_gradient_loss | 0.000487     |
# |    std                  | 0.741        |
# |    value_loss           | 2.32         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 67371       |
# |    iterations           | 47          |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 47000000    |
# | train/                  |             |
# |    approx_kl            | 0.001034996 |
# |    clip_fraction        | 0.00656     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 138         |
# |    policy_gradient_loss | 0.000135    |
# |    std                  | 0.739       |
# |    value_loss           | 2.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 67309       |
# |    iterations           | 48          |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 48000000    |
# | train/                  |             |
# |    approx_kl            | 0.008303301 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 141         |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 0.736       |
# |    value_loss           | 2.31        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 67193        |
# |    iterations           | 49           |
# |    time_elapsed         | 729          |
# |    total_timesteps      | 49000000     |
# | train/                  |              |
# |    approx_kl            | 0.0038473117 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | 0.000261     |
# |    std                  | 0.732        |
# |    value_loss           | 2.32         |
# ------------------------------------------
# Eval num_timesteps=50000000, episode_reward=198.38 +/- 17.75
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 198          |
# | time/                   |              |
# |    total_timesteps      | 50000000     |
# | train/                  |              |
# |    approx_kl            | 0.0014569036 |
# |    clip_fraction        | 0.00461      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -4.03e-05    |
# |    std                  | 0.73         |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    fps             | 66971    |
# |    iterations      | 50       |
# |    time_elapsed    | 746      |
# |    total_timesteps | 50000000 |
# ---------------------------------
# -----------------------------------------
# ...
# |    loss                 | 1.18         |
# |    n_updates            | 249          |
# |    policy_gradient_loss | 0.000334     |
# |    std                  | 0.626        |
# |    value_loss           | 2.39         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 176           |
# | time/                   |               |
# |    fps                  | 67554         |
# |    iterations           | 85            |
# |    time_elapsed         | 1258          |
# |    total_timesteps      | 85000000      |
# | train/                  |               |
# |    approx_kl            | 0.00016910379 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.824         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16          |
# |    n_updates            | 252           |
# |    policy_gradient_loss | -2.46e-05     |
# |    std                  | 0.625         |
# |    value_loss           | 2.32          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 67574        |
# |    iterations           | 86           |
# |    time_elapsed         | 1272         |
# |    total_timesteps      | 86000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018786071 |
# |    clip_fraction        | 0.00368      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 255          |
# |    policy_gradient_loss | -9.34e-05    |
# |    std                  | 0.622        |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 67564        |
# |    iterations           | 87           |
# |    time_elapsed         | 1287         |
# |    total_timesteps      | 87000000     |
# | train/                  |              |
# |    approx_kl            | 0.0023561106 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 258          |
# |    policy_gradient_loss | 0.000287     |
# |    std                  | 0.619        |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 67548        |
# |    iterations           | 88           |
# |    time_elapsed         | 1302         |
# |    total_timesteps      | 88000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020621917 |
# |    clip_fraction        | 0.00181      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 261          |
# |    policy_gradient_loss | -0.000148    |
# |    std                  | 0.616        |
# |    value_loss           | 2.33         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 178           |
# | time/                   |               |
# |    fps                  | 67554         |
# |    iterations           | 89            |
# |    time_elapsed         | 1317          |
# |    total_timesteps      | 89000000      |
# | train/                  |               |
# |    approx_kl            | 0.00088683004 |
# |    clip_fraction        | 0.00417       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.86         |
# |    explained_variance   | 0.829         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.2           |
# |    n_updates            | 264           |
# |    policy_gradient_loss | -5.59e-05     |
# |    std                  | 0.614         |
# |    value_loss           | 2.36          |
# -------------------------------------------
# Eval num_timesteps=90000000, episode_reward=203.00 +/- 16.49
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 203          |
# | time/                   |              |
# |    total_timesteps      | 90000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018928836 |
# |    clip_fraction        | 0.0013       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 267          |
# |    policy_gradient_loss | -0.00011     |
# |    std                  | 0.612        |
# |    value_loss           | 2.29         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    fps             | 67491    |
# |    iterations      | 90       |
# |    time_elapsed    | 1333     |
# |    total_timesteps | 90000000 |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 67513        |
# |    iterations           | 91           |
# |    time_elapsed         | 1347         |
# |    total_timesteps      | 91000000     |
# | train/                  |              |
# |    approx_kl            | 0.0016881062 |
# |    clip_fraction        | 0.000816     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -7.23e-05    |
# |    std                  | 0.611        |
# |    value_loss           | 2.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 67544       |
# |    iterations           | 92          |
# |    time_elapsed         | 1362        |
# |    total_timesteps      | 92000000    |
# | train/                  |             |
# |    approx_kl            | 0.013204133 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 273         |
# |    policy_gradient_loss | 0.0028      |
# |    std                  | 0.607       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 67551        |
# |    iterations           | 93           |
# |    time_elapsed         | 1376         |
# |    total_timesteps      | 93000000     |
# | train/                  |              |
# |    approx_kl            | 0.0046433564 |
# |    clip_fraction        | 0.16         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2          |
# |    n_updates            | 276          |
# |    policy_gradient_loss | 0.00844      |
# |    std                  | 0.605        |
# |    value_loss           | 2.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 67539        |
# |    iterations           | 94           |
# |    time_elapsed         | 1391         |
# |    total_timesteps      | 94000000     |
# | train/                  |              |
# |    approx_kl            | 0.0020183965 |
# |    clip_fraction        | 0.00399      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 279          |
# |    policy_gradient_loss | -1.07e-05    |
# |    std                  | 0.604        |
# |    value_loss           | 2.38         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 67542       |
# |    iterations           | 95          |
# |    time_elapsed         | 1406        |
# |    total_timesteps      | 95000000    |
# | train/                  |             |
# |    approx_kl            | 0.006294106 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 282         |
# |    policy_gradient_loss | 0.00289     |
# |    std                  | 0.602       |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 67515       |
# |    iterations           | 96          |
# |    time_elapsed         | 1421        |
# |    total_timesteps      | 96000000    |
# | train/                  |             |
# |    approx_kl            | 0.008864874 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 285         |
# |    policy_gradient_loss | 0.0037      |
# |    std                  | 0.6         |
# |    value_loss           | 2.34        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 67525        |
# |    iterations           | 97           |
# |    time_elapsed         | 1436         |
# |    total_timesteps      | 97000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024687895 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 288          |
# |    policy_gradient_loss | 0.000536     |
# |    std                  | 0.597        |
# |    value_loss           | 2.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 67545        |
# |    iterations           | 98           |
# |    time_elapsed         | 1450         |
# |    total_timesteps      | 98000000     |
# | train/                  |              |
# |    approx_kl            | 0.0010955473 |
# |    clip_fraction        | 0.00134      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 291          |
# |    policy_gradient_loss | 8.79e-06     |
# |    std                  | 0.595        |
# |    value_loss           | 2.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 67549        |
# |    iterations           | 99           |
# |    time_elapsed         | 1465         |
# |    total_timesteps      | 99000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018118611 |
# |    clip_fraction        | 0.000626     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -7.5e-05     |
# |    std                  | 0.594        |
# |    value_loss           | 2.33         |
# ------------------------------------------
# Eval num_timesteps=100000000, episode_reward=204.38 +/- 16.45
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 204          |
# | time/                   |              |
# |    total_timesteps      | 100000000    |
# | train/                  |              |
# |    approx_kl            | 0.0016458279 |
# |    clip_fraction        | 0.000991     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 297          |
# |    policy_gradient_loss | -7.21e-05    |
# |    std                  | 0.593        |
# |    value_loss           | 2.31         |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 179       |
# | time/              |           |
# |    fps             | 67489     |
# |    iterations      | 100       |
# |    time_elapsed    | 1481      |
# |    total_timesteps | 100000000 |
# ----------------------------------

# %% [markdown]
# ### Visualization

# %%
def get_rl_env_visualization(num_trajectories:int = 1, fads_proportion:float=0.6, 
               psi:float = 15.0, phi:float = 15.0, eta:float = 10.0,
               gamma:float = 1.0,
               ) -> TradingEnvironment:
    midprice_model = ArithmeticBrownianMotionWithFadsMidpriceModel(initial_price=initial_price, drift=mu,
                                                 volatility=sigma, fads_proportion=fads_proportion, eta=eta, step_size=terminal_time/n_steps,
                                                 terminal_time=terminal_time,
                                                 num_trajectories=num_trajectories, seed=seed)
    arrival_model = ModifiedPoissonArrivalModel(phi=phi,
                                                psi=psi,
                                                gamma=gamma,
                                                fads_proportion=fads_proportion,
                                                sigma=sigma,
                                                step_size=terminal_time/n_steps,
                                                num_trajectories=num_trajectories,
                                                seed=seed)
    fill_probability_model = ExponentialFillFunction(fill_exponent=k, 
                                                     step_size=terminal_time/n_steps,
                                                     num_trajectories=num_trajectories,
                                                     seed=seed)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories, seed=seed)
    reward = CjMmCriterion(per_step_inventory_aversion = big_phi,
                           terminal_inventory_aversion = alpha,
                           terminal_time = terminal_time)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      seed = seed,
                      initial_inventory = initial_inventory,
                      #initial_inventory = random_initial_inventory,
                      #start_time = make_random_start_time_sampler(terminal_time),
                      model_dynamics = LOtrader,
                      reward_function = reward,
                      max_inventory = max_inventory,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      normalise_rewards = False,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
rl_env_visualization = get_rl_env_visualization(num_trajectories=5)

# %%
from mbt_gym.agents.SbAgent import SbAgent
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_visualization, use_normalized_agent=use_normalized_agent)

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_rl_trajectory_extended(rl_env_visualization, ppo_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "trajectory_plot.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Generating RL trajectory plot...
# env.observation_space: Box([-1.1251929e+05 -2.0000000e+01  0.0000000e+00 -1.2519288e+01
#  -1.0000000e+01 -1.0000000e+01  0.0000000e+00  0.0000000e+00], [1.1251929e+05 2.0000000e+01 1.0000000e+01 1.1251929e+02 1.0000000e+01
#  1.0000000e+01 6.0000000e+01 6.0000000e+01], (8,), float32)
# env.action_space: Box(0.0, 4.6051702, (2,), float32)
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/trajectory_plot.png

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
observations_rl, actions_rl, rewards_rl = generate_trajectory_rl(env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl, fig_rl, total_rewards_rl = generate_results_table_and_hist_rl(vec_env=rl_env_evaluation, rl_agent=ppo_agent)

# %%
results_rl
# Out:
#          Mean spread    Mean PnL    Std PnL Mean terminal inventory  \
# RL Agent    2.591975  205.436425  16.841536                  -0.413
#
#          Std terminal inventory
# RL Agent               2.191901

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
# For the StableBaselinesTradingEnvironment
print("SB Environment Action Space:")
print(f"Shape: {sb_rl_env.action_space}")
print(f"Low bounds: {sb_rl_env.action_space.low}")
print(f"High bounds: {sb_rl_env.action_space.high}")

# For the original trading environment
print("\nOriginal Trading Environment Action Space:")
print(f"Shape: {rl_env.action_space}")
print(f"Low bounds: {rl_env.action_space.low}")
print(f"High bounds: {rl_env.action_space.high}")
# Out:
# SB Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]
#
# Original Trading Environment Action Space:
# Shape: Box(0.0, 4.6051702, (2,), float32)
# Low bounds: [0. 0.]
# High bounds: [4.6051702 4.6051702]

# %%
rl_env_evaluation = get_rl_env_visualization(num_trajectories=1000)

# %%
def normalize_inventory(inventories, max_inventory, use_normalized=False, inverse=False):
    if not use_normalized:
        return inventories

    inventory_low = -max_inventory
    gradient_inventory = (max_inventory - inventory_low) / 2  # equals max_inventory

    if inverse:
        # Denormalize: from [-1, 1] back to original scale
        return (inventories + 1) * gradient_inventory + inventory_low
    else:
        # Normalize: from [-max_inventory, max_inventory] to [-1, 1]
        return (inventories - inventory_low) / gradient_inventory - 1

# %%
inventories = np.arange(-4,5,1)
inventories_normalised = normalize_inventory(inventories, max_inventory, use_normalized=use_normalized_agent, inverse=False)

# %%
ppo_agent = SbAgent(model, reduced_training_indices=reduced_training_indices, env=rl_env_evaluation, use_normalized_agent=use_normalized_agent)

# %%
bid_actions = []
ask_actions = []
for inventory in inventories_normalised:
    if use_normalized_agent:
        state = np.array([[inventory, 0, 0, 0]])   # attention here for normalised agent maybe it is -1 instead of 0
    else:
        state = np.array([[inventory, 0.5, 100, 0]])
    bid_action, ask_action = ppo_agent.get_action(state).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
partial_info_agent = OptimizedPartialInfoMMwithFadsInformedUniformedTradersAgent(env=get_closed_form_env())
# Out:
# ✓ Pre-computed ODE solutions for 1000 time points

# %%
# Get the Partial Information action
pi_bid_actions = []
pi_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = partial_info_agent.get_action(np.array([[0,inventory,0.5,100,0,0]])).reshape(-1)
    pi_bid_actions.append(bid_action)
    pi_ask_actions.append(ask_action)

# %%
# Create a policy comparison plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(inventories, bid_actions, label="bid (RL)", color="k")
ax.plot(inventories, ask_actions, label="ask (RL)", color="r")
ax.plot(inventories, pi_bid_actions, label="bid (PI)", color="k", linestyle="--")
ax.plot(inventories, pi_ask_actions, label="ask (PI)", color="r", linestyle="--")
ax.legend()
ax.set_xlabel("Inventory")
ax.set_ylabel("Spread")
ax.set_title("Policy Comparison: Reinforcement Learning vs. Partial Information")
ax.grid(alpha=0.3)

# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Save the figure to the best model path
policy_comparison_filename = os.path.join(best_model_path, "policy_comparison.png")
fig.savefig(policy_comparison_filename, dpi=300, bbox_inches='tight')
print(f"Policy comparison plot saved to {policy_comparison_filename}")
# Out:
# Policy comparison plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/policy_comparison.png

# %% [markdown]
# ## Dependence of policy on time

# %%
# Function to create the plot comparing PPO and closed approx agent
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  # 0 to 30 seconds
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # PI bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # PI ask
    
        
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context
    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions 
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Plot the data
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])

    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()

# %%
plot_policy_time_dependence(ppo_agent, partial_info_agent)

# %%
def plot_policy_time_dependence(ppo_agent, agent):
    # Time points to evaluate
    times = np.linspace(0, terminal_time, n_steps+1)  
    inventories = np.array([-3, -2, -1, 0, 1, 2, 3])
    
    # Colors for different inventory levels
    colors = {
        -3: 'blue',
        -2: 'orange',
        -1: 'green',
        0: 'red',
        1: 'salmon',
        2: 'purple',
        3: 'brown'
    }
    
    # Create figure with 2x2 subplots
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 2, width_ratios=[1, 1])
    
    ax1 = plt.subplot(gs[0, 0])  # RL bid
    ax2 = plt.subplot(gs[0, 1])  # CJ bid
    ax3 = plt.subplot(gs[1, 0])  # RL ask
    ax4 = plt.subplot(gs[1, 1])  # CJ ask
    
    price = 100.0  # Fixed price for evaluation
    if use_normalized_agent:
        price_normalized = 0  # Normalize price to [-1, 1]
    else:
        price_normalized = price  # Assuming no normalization for price in this context

    filtered_fad = 0.0  # Fixed fad for evaluation
    if use_normalized_agent:
        filtered_fad_normalized = -1  # Normalize fad to [-1, 1]
    else:
        filtered_fad_normalized = filtered_fad  # Assuming no normalization for fad in this context

    
    # Track global min/max for all plots
    global_min = float('inf')
    global_max = float('-inf')
    
    # Store all data to plot later
    all_data = []
    
    # For each inventory level
    for inv in inventories:
        rl_bids = []
        rl_asks = []
        bids = []
        asks = []
        
        # For each time point
        for t in times:
            normalized_time = t/terminal_time  # Normalize time to [0,1]
            
            # Get PPO agent's actions
            rl_bid, rl_ask = ppo_agent.get_action(np.array([[inv, normalized_time, price, filtered_fad_normalized]])).reshape(-1)
            rl_bids.append(rl_bid)
            rl_asks.append(rl_ask)
            
            # Get agent's actions
            #bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, filtered_fad]])).reshape(-1)
            bid, ask = agent.get_action(np.array([[0, inv, normalized_time, price, 0, filtered_fad]])).reshape(-1)
            bids.append(bid)
            asks.append(ask)
        
        # Update global min/max
        global_min = min(global_min, min(rl_bids), min(rl_asks), min(bids), min(asks))
        global_max = max(global_max, max(rl_bids), max(rl_asks), max(bids), max(asks))
        
        # Store data for later plotting
        all_data.append((inv, rl_bids, rl_asks, bids, asks))
    
    # Now plot all data with the same y-axis scale
    for inv, rl_bids, rl_asks, bids, asks in all_data:
        ax1.plot(times, rl_bids, label=f"Inventory = {inv}", color=colors[inv])
        ax2.plot(times, bids, label=f"Inventory = {inv}", color=colors[inv])
        ax3.plot(times, rl_asks, label=f"Inventory = {inv}", color=colors[inv])
        ax4.plot(times, asks, label=f"Inventory = {inv}", color=colors[inv])
    
    # Apply the same y-axis limits to all subplots
    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_ylim(global_min, global_max)
    
    # Setting titles and labels
    ax1.set_title("RL PI δ^bid")
    ax2.set_title("PI δ^bid")
    ax3.set_title("RL PI δ^ask")
    ax4.set_title("PI δ^ask")

    for ax in [ax1, ax2, ax3, ax4]:
        ax.set_xlabel("Time (secs)")
        ax.set_xlim(0, terminal_time)
        ax.grid(True, alpha=0.3)
    
    # Add a legend to the first subplot
    ax1.legend()
    
    plt.suptitle("Dependence of policy on time", fontsize=16)
    plt.tight_layout()
    
    # Add an overall figure caption
    fig.text(0.5, 0.01, "Figure 5: Learnt PPO agent versus approx. closed-form solution for the Partial Information setting as a function of time.", 
             ha='center', fontsize=12)
    
    plt.show()
    return fig

# %%
# Ensure the directory exists
os.makedirs(best_model_path, exist_ok=True)

# Create the plot
fig = plot_policy_time_dependence(ppo_agent, pi_agent)

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "policy_time_dependence.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/policy_time_dependence.png

# %%
total_rewards = rewards_rl.sum(axis=-1).reshape(-1)
print('mean: ',np.mean(total_rewards))
print('median: ',np.median(total_rewards))
print('std: ',np.std(total_rewards))
# Out:
# mean:  205.38652569398027
# median:  205.42673667218588
# std:  16.35411167827095

# %%
# Load the event file
event_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/PPO_1/events.out.tfevents.1762422562.MacBookAir.lan.44127.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the rollout/ep_rew_mean data
tag = "rollout/ep_rew_mean"
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_rollout_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/Training_process_rollout_reward.png

# %%
# Load the event file
event_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/PPO_1/events.out.tfevents.1762422562.MacBookAir.lan.44127.0"
# Load the data
ea = event_accumulator.EventAccumulator(event_file)
ea.Reload()
# Extract the eval/ep_rew_mean data
tag = "eval/mean_reward"
print(ea.Tags())
events = ea.Scalars(tag)
steps = [event.step for event in events]
rewards = [event.value for event in events]

# Plot the rewards
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the rewards
ax.plot(steps, rewards, '-', color='tab:blue', label='PPO reward', alpha=0.7)

# Add the baseline from Partial Information
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(steps), xmax=max(steps), 
          linestyles='--', color='tab:red',
          label='Closed-form solution')

# Formatting
plt.grid(alpha=0.3)
plt.xlabel('Training steps')
plt.ylabel('Mean episode reward')
plt.title('Training Progress')
plt.legend()
plt.tight_layout()
plt.show()

# Save the figure to the best model path
plot_filename = os.path.join(best_model_path, "Training_process_eval_reward.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/Training_process_eval_reward.png

# %%
# === Load rollout rewards ===

rollout_file = "./Partial_Info_models/tensorboard/PPO-learning/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/PPO_1/events.out.tfevents.1762422562.MacBookAir.lan.44127.0"
ea_rollout = event_accumulator.EventAccumulator(rollout_file)
ea_rollout.Reload()

# === Load eval rewards ===
eval_file = rollout_file  # same file if training and eval in same run
ea_eval = event_accumulator.EventAccumulator(eval_file)
ea_eval.Reload()

# Extract rollout and eval data
rollout_tag = "rollout/ep_rew_mean"
eval_tag = "eval/mean_reward"

# Make sure both tags exist
print("Available tags:", ea_rollout.Tags())

rollout_events = ea_rollout.Scalars(rollout_tag)
eval_events = ea_eval.Scalars(eval_tag)

rollout_steps = [e.step for e in rollout_events]
rollout_rewards = [e.value for e in rollout_events]

eval_steps = [e.step for e in eval_events]
eval_rewards = [e.value for e in eval_events]

# === Plot both ===
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(rollout_steps, rollout_rewards, '-', color='tab:blue', label='Rollout reward', alpha=0.6)
ax.plot(eval_steps, eval_rewards, '-', color='tab:orange', label='Eval reward', alpha=0.8)
    
# Add baseline line
y_line = float(results_pi["Mean PnL"].iloc[0])
ax.hlines(y=y_line, xmin=min(rollout_steps + eval_steps), xmax=max(rollout_steps + eval_steps),
          linestyles='--', color='tab:red', label='Closed-form solution')

# Formatting
ax.grid(alpha=0.3)
ax.set_xlabel('Training steps')
ax.set_ylabel('Mean episode reward')
ax.set_title('Training Progress (Rollout + Eval)')
ax.legend()
plt.tight_layout()
plt.show()

# Save the figure
plot_filename = os.path.join(best_model_path, "Training_process_rewards.png")
fig.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Plot saved to {plot_filename}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/std', 'train/value_loss', 'eval/mean_ep_length', 'eval/mean_reward'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# Plot saved to ./Partial_Info_models/PPO-best/PIMm_PPO_100_000_000steps_LongTime/2025-11-06_10-49-21/Training_process_rewards.png
